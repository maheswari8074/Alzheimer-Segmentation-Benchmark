# %% [markdown]
# # Brain MRI Tissue Segmentation — Multi-Class Semantic Segmentation
# ## FCN (Fully Convolutional Network) | 4-Class (Background / CSF / Grey Matter / White Matter) | MRBrainS18 Dataset
#
# **Dataset:** MRBrainS18 Challenge Dataset — 7 labeled training subjects, multi-sequence MRI (T1, FLAIR, IR). Only the `training` split is used since the `test` split has no publicly released segmentation labels.
#
# **Label Remapping:** MRBrainS18 uses 9 classes which are consolidated into 4 tissue classes:
# - 0 → Background
# - 1, 2, 8 → Grey Matter (cortical GM + basal ganglia + brainstem/cerebellum)
# - 3, 4 → White Matter (WM + WM lesions)
# - 5, 6, 7 → CSF (ventricular CSF + vessels + external CSF)
#
# **Training Notes:**
# - Only 7 labeled subjects are available; therefore, every slice (`step=1`) is used to maximize the training dataset.
# - Strong data augmentation is applied to improve model generalization.
# - EarlyStopping is disabled so the model trains for the full configured number of epochs.

# %% [markdown]
# ## 1. Import Libraries

# %%
import os
import cv2
import random
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import (
    Input, Conv2D, UpSampling2D, concatenate,
    BatchNormalization, Dropout, Activation
)
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Conv2DTranspose, Add
from tensorflow.keras import callbacks
from sklearn.model_selection import train_test_split
from tqdm.auto import tqdm
import time
import datetime

# !pip install nibabel -q
import nibabel as nib

print('TensorFlow version:', tf.__version__)
print('GPUs available:', tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.20.0
# GPUs available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 2. Configuration

# %%
# ─── Paths ────────────────────────────────────────────────────────────────────
TRAIN_ROOT = '/kaggle/input/datasets/maheswarimudadla/training/training'
# Note: test split excluded — no public segmentation labels available

PROCESSED_DIR  = 'mrbrains_processed'
IMAGE_FOLDER   = os.path.join(PROCESSED_DIR, 'images')
MASK_FOLDER    = os.path.join(PROCESSED_DIR, 'masks')
TRAIN_IMG_DIR  = os.path.join(PROCESSED_DIR, 'train', 'images')
TRAIN_MASK_DIR = os.path.join(PROCESSED_DIR, 'train', 'masks')
TEST_IMG_DIR   = os.path.join(PROCESSED_DIR, 'test',  'images')
TEST_MASK_DIR  = os.path.join(PROCESSED_DIR, 'test',  'masks')

# ─── Hyperparameters ──────────────────────────────────────────────────────────
IMG_SIZE    = (224, 224)
BATCH_SIZE  = 8    # smaller batch — fewer total slices than OASIS/IBSR
EPOCHS      = 100
SEED        = 42
TEST_SPLIT  = 0.20  # slightly larger test split given small dataset
NUM_CLASSES = 4
CLASS_NAMES = ['Background', 'CSF', 'Grey Matter', 'White Matter']

# ─── MRBrainS18 label remapping ───────────────────────────────────────────────
# Original 9 classes → 4 standard tissue classes (matches OASIS-1 and IBSR)
MRBRAINS_REMAP = {
    0: 0,  # Background
    1: 2,  # Cortical Grey Matter → GM
    2: 2,  # Basal Ganglia → GM
    3: 3,  # White Matter → WM
    4: 3,  # White Matter Lesions → WM
    5: 1,  # Ventricular CSF → CSF
    6: 1,  # Vessels/Choroid Plexus → CSF
    7: 1,  # External CSF/Sulci → CSF
    8: 2,  # Brainstem + Cerebellum → GM
}

print('Config set ✓')
print('Label remapping:', MRBRAINS_REMAP)
# Out:
# Config set ✓
# Label remapping: {0: 0, 1: 2, 2: 2, 3: 3, 4: 3, 5: 1, 6: 1, 7: 1, 8: 2}

# %% [markdown]
# ## 3. Extract 2D Slices — Remap 9 Classes to 4

# %%
for d in [IMAGE_FOLDER, MASK_FOLDER,
          TRAIN_IMG_DIR, TRAIN_MASK_DIR,
          TEST_IMG_DIR,  TEST_MASK_DIR]:
    os.makedirs(d, exist_ok=True)

print('Directories ready ✓')
# Out:
# Directories ready ✓

# %%
import os
import shutil
import cv2
import nibabel as nib
import numpy as np
from tqdm import tqdm


def normalize_slice(arr):
    mn, mx = arr.min(), arr.max()
    if mx - mn == 0:
        return np.zeros_like(arr, dtype=np.uint8)
    return ((arr - mn) / (mx - mn) * 255).astype(np.uint8)


def remap_labels(seg_arr, remap_dict):
    """Remap integer label array using a dictionary mapping."""
    out = np.zeros_like(seg_arr, dtype=np.uint8)
    for orig_label, new_label in remap_dict.items():
        out[seg_arr == orig_label] = new_label
    return out


def extract_slices_mrbrains(subject_dir, subject_name, img_out, mask_out, step=1):
    """
    Extract aligned T1 and segmentation slices from MRBrainS18.

    Uses reg_T1.nii because it is already registered to segm.nii.
    Both volumes have shape (240, 240, 48).
    """

    # Candidate paths for registered T1
    t1_candidates = [
        os.path.join(subject_dir, "orig", "reg_T1.nii"),
        os.path.join(subject_dir, "orig", "reg_T1.nii.gz"),
        os.path.join(subject_dir, "pre", "reg_T1.nii"),
        os.path.join(subject_dir, "pre", "reg_T1.nii.gz"),
    ]

    t1_path = None
    for p in t1_candidates:
        if os.path.exists(p):
            t1_path = p
            break

    # Segmentation
    seg_candidates = [
        os.path.join(subject_dir, "segm.nii"),
        os.path.join(subject_dir, "segm.nii.gz"),
    ]

    seg_path = None
    for p in seg_candidates:
        if os.path.exists(p):
            seg_path = p
            break

    if t1_path is None or seg_path is None:
        print(f"Skipping {subject_name} (missing reg_T1 or segm)")
        return 0

    # Load volumes
    brain_vol = np.squeeze(nib.load(t1_path).get_fdata())
    seg_vol = np.squeeze(nib.load(seg_path).get_fdata())

    print(f"{subject_name}")
    print(f"  T1 : {brain_vol.shape}")
    print(f"  Seg: {seg_vol.shape}")

    # Safety check
    if brain_vol.shape != seg_vol.shape:
        print(f"Shape mismatch in {subject_name}, skipping.")
        return 0

    saved = 0

    for i in range(0, brain_vol.shape[2], step):

        brain_slice = brain_vol[:, :, i]
        seg_slice = seg_vol[:, :, i]

        # Skip completely empty MRI slices
        if np.max(brain_slice) == 0:
            continue

        img_arr = normalize_slice(brain_slice)

        mask_arr = remap_labels(
            np.round(seg_slice).astype(np.uint8),
            MRBRAINS_REMAP
        )

        filename = f"{subject_name}_sl{i:03d}.png"

        cv2.imwrite(
            os.path.join(img_out, filename),
            img_arr
        )

        cv2.imwrite(
            os.path.join(mask_out, filename),
            mask_arr
        )

        saved += 1

    return saved


# ---------------------------------------------------------
# Remove previous extracted dataset
# ---------------------------------------------------------

for folder in [IMAGE_FOLDER, MASK_FOLDER]:
    if os.path.exists(folder):
        shutil.rmtree(folder)
    os.makedirs(folder, exist_ok=True)


# ---------------------------------------------------------
# Extract slices from all training subjects
# ---------------------------------------------------------

subject_folders = sorted([
    d for d in os.listdir(TRAIN_ROOT)
    if os.path.isdir(os.path.join(TRAIN_ROOT, d))
])

print(f"Found {len(subject_folders)} training subjects:")
print(subject_folders)
print()

total_slices = 0

for subj_name in tqdm(subject_folders, desc="Extracting slices"):

    subj_dir = os.path.join(TRAIN_ROOT, subj_name)

    total_slices += extract_slices_mrbrains(
        subj_dir,
        subj_name,
        IMAGE_FOLDER,
        MASK_FOLDER,
        step=1
    )

print("\nExtraction Complete!")
print(f"Total slices extracted : {total_slices}")
print(f"Images saved           : {len(os.listdir(IMAGE_FOLDER))}")
print(f"Masks saved            : {len(os.listdir(MASK_FOLDER))}")
# Out:
# Found 7 training subjects:
# ['1', '14', '27', '29', '4', '5', '7']
# Extracting slices:   0%|          | 0/7 [00:00<?, ?it/s]
# 1
#   T1 : (240, 240, 48)
#   Seg: (240, 240, 48)
# Extracting slices:  29%|██▊       | 2/7 [00:00<00:01,  4.57it/s]
# 14
#   T1 : (240, 240, 48)
#   Seg: (240, 240, 48)
# Extracting slices:  43%|████▎     | 3/7 [00:00<00:01,  3.88it/s]
# 27
#   T1 : (240, 240, 48)
#   Seg: (240, 240, 48)
# Extracting slices:  57%|█████▋    | 4/7 [00:01<00:00,  3.59it/s]
# 29
#   T1 : (240, 240, 48)
#   Seg: (240, 240, 48)
# Extracting slices:  71%|███████▏  | 5/7 [00:01<00:00,  3.82it/s]
# 4
#   T1 : (240, 240, 48)
#   Seg: (240, 240, 48)
# Extracting slices:  86%|████████▌ | 6/7 [00:01<00:00,  4.11it/s]
# 5
#   T1 : (240, 240, 48)
#   Seg: (240, 240, 48)
# Extracting slices: 100%|██████████| 7/7 [00:01<00:00,  3.96it/s]
# 7
#   T1 : (240, 240, 48)
#   Seg: (240, 240, 48)
#
# Extraction Complete!
# Total slices extracted : 336
# Images saved           : 336
# Masks saved            : 336

# %% [markdown]
# ## 4. Verify Label Remapping & Visualize

# %%
sample_mask_files = random.sample(os.listdir(MASK_FOLDER), min(20, len(os.listdir(MASK_FOLDER))))
all_vals = set()
for f in sample_mask_files:
    m = cv2.imread(os.path.join(MASK_FOLDER, f), cv2.IMREAD_GRAYSCALE)
    all_vals.update(np.unique(m).tolist())

print('Unique label values found across sample masks:', sorted(all_vals))
print('Expected: [0, 1, 2, 3]  (Background, CSF, Grey Matter, White Matter)')
# Out:
# Unique label values found across sample masks: [0, 1, 2, 3]
# Expected: [0, 1, 2, 3]  (Background, CSF, Grey Matter, White Matter)

# %%
CLASS_COLORS = ['black', 'cyan', 'orange', 'magenta']
cmap_classes = mcolors.ListedColormap(CLASS_COLORS)

def visualize_sample(image_name):
    img  = cv2.imread(os.path.join(IMAGE_FOLDER, image_name), cv2.IMREAD_GRAYSCALE)
    mask = cv2.imread(os.path.join(MASK_FOLDER,  image_name), cv2.IMREAD_GRAYSCALE)

    fig, axes = plt.subplots(1, 2, figsize=(12, 6))
    axes[0].imshow(img, cmap='gray')
    axes[0].set_title('Brain MRI Slice (T1)', fontsize=13)

    im = axes[1].imshow(mask, cmap=cmap_classes, vmin=0, vmax=NUM_CLASSES - 1)
    axes[1].set_title('Tissue Labels (CSF / GM / WM)', fontsize=13)
    cbar = plt.colorbar(im, ax=axes[1], ticks=range(NUM_CLASSES))
    cbar.ax.set_yticklabels(CLASS_NAMES)

    for ax in axes: ax.axis('off')
    plt.suptitle(image_name, fontsize=10, color='gray')
    plt.tight_layout()
    plt.show()


all_images = os.listdir(IMAGE_FOLDER)
for _ in range(4):
    visualize_sample(random.choice(all_images))

# %% [markdown]
# ## 5. Train / Test Split

# %%
images = sorted([f for f in os.listdir(IMAGE_FOLDER) if f.endswith('.png')])
masks  = sorted([f for f in os.listdir(MASK_FOLDER)  if f.endswith('.png')])

assert images == masks, 'Image-mask mismatch!'

train_imgs, test_imgs = train_test_split(images, test_size=TEST_SPLIT, random_state=SEED)
print(f'Train: {len(train_imgs)}  |  Test: {len(test_imgs)}')

def copy_files(file_list, src_img, src_mask, dst_img, dst_mask):
    for f in tqdm(file_list, leave=False):
        shutil.copy(os.path.join(src_img,  f), os.path.join(dst_img,  f))
        shutil.copy(os.path.join(src_mask, f), os.path.join(dst_mask, f))

copy_files(train_imgs, IMAGE_FOLDER, MASK_FOLDER, TRAIN_IMG_DIR, TRAIN_MASK_DIR)
copy_files(test_imgs,  IMAGE_FOLDER, MASK_FOLDER, TEST_IMG_DIR,  TEST_MASK_DIR)
print('Files copied ✓')
# Out:
# Train: 268  |  Test: 68
# Files copied ✓

# %% [markdown]
# ## 6. tf.data Pipeline — with stronger augmentation (small dataset)

# %%
def load_image(img_path, mask_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE, method='bilinear')
    img = tf.cast(img, tf.float32) / 255.0

    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=1)
    mask = tf.image.resize(mask, IMG_SIZE, method='nearest')
    mask = tf.cast(mask, tf.int32)
    mask = tf.squeeze(mask, axis=-1)
    mask = tf.one_hot(mask, depth=NUM_CLASSES)
    mask = tf.cast(mask, tf.float32)
    return img, mask


def augment(img, mask):
    # Stronger augmentation since dataset is small (7 subjects)
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_left_right(img)
        mask = tf.image.flip_left_right(mask)
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_up_down(img)
        mask = tf.image.flip_up_down(mask)
    img = tf.image.random_brightness(img, max_delta=0.1)
    img = tf.image.random_contrast(img, lower=0.9, upper=1.1)
    img = tf.clip_by_value(img, 0.0, 1.0)
    return img, mask


def build_dataset(img_dir, mask_dir, augment_data=False, batch=BATCH_SIZE):
    img_files  = sorted([os.path.join(img_dir,  f) for f in os.listdir(img_dir)  if f.endswith('.png')])
    mask_files = sorted([os.path.join(mask_dir, f) for f in os.listdir(mask_dir) if f.endswith('.png')])
    ds = tf.data.Dataset.from_tensor_slices((img_files, mask_files))
    ds = ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
    if augment_data:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch).prefetch(tf.data.AUTOTUNE)
    return ds


train_dataset = build_dataset(TRAIN_IMG_DIR, TRAIN_MASK_DIR, augment_data=True)
test_dataset  = build_dataset(TEST_IMG_DIR,  TEST_MASK_DIR,  augment_data=False)

print('Datasets ready ✓')
for imgs, masks in train_dataset.take(1):
    print('Batch shapes → images:', imgs.shape, ' masks:', masks.shape)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1783414406.444282      57 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Datasets ready ✓
# Batch shapes → images: (8, 224, 224, 3)  masks: (8, 224, 224, 4)

# %% [markdown]
# ## 7. Model — FCN-8s (VGG16 backbone + transposed-conv upsampling), 4-class softmax output
# **Simplest decoder** — fuses 3 coarse prediction stages via upsample-and-add instead of a full mirror decoder.

# %%
def build_model(input_shape=(224,224,3), num_classes=4, freeze_encoder=True):
    inputs=Input(shape=input_shape,name='input')
    base=VGG16(include_top=False,weights='imagenet',input_tensor=inputs)
    if freeze_encoder:
        for layer in base.layers: layer.trainable=False
    pool3=base.get_layer('block3_pool').output
    pool4=base.get_layer('block4_pool').output
    pool5=base.get_layer('block5_pool').output
    x=Conv2D(4096,(7,7),padding='same',activation='relu',name='fc6')(pool5)
    x=Dropout(0.5,name='fc6_drop')(x)
    x=Conv2D(4096,(1,1),padding='same',activation='relu',name='fc7')(x)
    x=Dropout(0.5,name='fc7_drop')(x)
    score5=Conv2D(num_classes,(1,1),padding='same',name='score_pool5')(x)
    up5=Conv2DTranspose(num_classes,(4,4),strides=2,padding='same',name='upscore_pool5')(score5)
    score4=Conv2D(num_classes,(1,1),padding='same',name='score_pool4')(pool4)
    fuse4=Add(name='fuse_pool4')([up5,score4])
    up4=Conv2DTranspose(num_classes,(4,4),strides=2,padding='same',name='upscore_pool4')(fuse4)
    score3=Conv2D(num_classes,(1,1),padding='same',name='score_pool3')(pool3)
    fuse3=Add(name='fuse_pool3')([up4,score3])
    up_final=Conv2DTranspose(num_classes,(16,16),strides=8,padding='same',name='upscore_final')(fuse3)
    output=Activation('softmax',name='output')(up_final)
    return Model(inputs=inputs,outputs=output,name='FCN8s_MultiClass_MRBrainS18')

model=build_model(input_shape=(*IMG_SIZE,3),num_classes=NUM_CLASSES)
print('Model built')
print(f'Total parameters     : {model.count_params():,}')
print(f'Trainable parameters : {sum([K.count_params(w) for w in model.trainable_weights]):,}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model built
# Total parameters     : 134,284,632
# Trainable parameters : 119,569,944

# %% [markdown]
# ## 8. Custom Metrics & Loss

# %%
def dice_coefficient_multiclass(y_true, y_pred, smooth=1.0):
    y_true_f = K.reshape(y_true, [-1, NUM_CLASSES])
    y_pred_f = K.reshape(y_pred, [-1, NUM_CLASSES])
    intersection = K.sum(y_true_f * y_pred_f, axis=0)
    union = K.sum(y_true_f, axis=0) + K.sum(y_pred_f, axis=0)
    return K.mean((2.0 * intersection + smooth) / (union + smooth))

def dice_loss_multiclass(y_true, y_pred):
    return 1.0 - dice_coefficient_multiclass(y_true, y_pred)

def iou_score_multiclass(y_true, y_pred, smooth=1.0):
    y_true_f = K.reshape(y_true, [-1, NUM_CLASSES])
    y_pred_f = K.reshape(y_pred, [-1, NUM_CLASSES])
    intersection = K.sum(y_true_f * y_pred_f, axis=0)
    total = K.sum(y_true_f, axis=0) + K.sum(y_pred_f, axis=0) - intersection
    return K.mean((intersection + smooth) / (total + smooth))

def csf_iou(y_true, y_pred, smooth=1.0):
    t = y_true[..., 1]; p = y_pred[..., 1]
    i = K.sum(t * p)
    return (i + smooth) / (K.sum(t) + K.sum(p) - i + smooth)

def gm_iou(y_true, y_pred, smooth=1.0):
    t = y_true[..., 2]; p = y_pred[..., 2]
    i = K.sum(t * p)
    return (i + smooth) / (K.sum(t) + K.sum(p) - i + smooth)

def wm_iou(y_true, y_pred, smooth=1.0):
    t = y_true[..., 3]; p = y_pred[..., 3]
    i = K.sum(t * p)
    return (i + smooth) / (K.sum(t) + K.sum(p) - i + smooth)

def pixel_accuracy_multiclass(y_true, y_pred):
    return K.mean(K.cast(K.equal(K.argmax(y_true, axis=-1), K.argmax(y_pred, axis=-1)), K.floatx()))

def combined_loss_multiclass(y_true, y_pred):
    return dice_loss_multiclass(y_true, y_pred) + tf.keras.losses.categorical_crossentropy(y_true, y_pred)


model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=combined_loss_multiclass,
    metrics=[dice_coefficient_multiclass, iou_score_multiclass,
             pixel_accuracy_multiclass, csf_iou, gm_iou, wm_iou]
)
print('Model compiled ✓')
# Out:
# Model compiled ✓

# %% [markdown]
# ## 9. Model Summary

# %%
model.summary()
try:
    tf.keras.utils.plot_model(model, to_file='fcn8s_mrbrains_architecture.png',
                               show_shapes=True, show_layer_names=True, dpi=64)
    print('Architecture diagram saved ✓')
except Exception as e:
    print('Architecture plot skipped:', str(e)[:100])
# Out:
# Model: "FCN8s_MultiClass_MRBrainS18"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 224, 224,  │          0 │ -                 │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 224, 224,  │      1,792 │ input[0][0]       │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 224, 224,  │     36,928 │ block1_conv1[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 112, 112,  │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 112, 112,  │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 112, 112,  │    147,584 │ block2_conv1[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 56, 56,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 56, 56,    │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 56, 56,    │    590,080 │ block3_conv1[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 56, 56,    │    590,080 │ block3_conv2[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 28, 28,    │          0 │ block3_conv3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 28, 28,    │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 28, 28,    │  2,359,808 │ block4_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 28, 28,    │  2,359,808 │ block4_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 14, 14,    │          0 │ block4_conv3[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 14, 14,    │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 14, 14,    │  2,359,808 │ block5_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 14, 14,    │  2,359,808 │ block5_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_pool         │ (None, 7, 7, 512) │          0 │ block5_conv3[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc6 (Conv2D)        │ (None, 7, 7,      │ 102,764,5… │ block5_pool[0][0] │
# │                     │ 4096)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc6_drop (Dropout)  │ (None, 7, 7,      │          0 │ fc6[0][0]         │
# │                     │ 4096)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc7 (Conv2D)        │ (None, 7, 7,      │ 16,781,312 │ fc6_drop[0][0]    │
# │                     │ 4096)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc7_drop (Dropout)  │ (None, 7, 7,      │          0 │ fc7[0][0]         │
# │                     │ 4096)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ score_pool5         │ (None, 7, 7, 4)   │     16,388 │ fc7_drop[0][0]    │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upscore_pool5       │ (None, 14, 14, 4) │        260 │ score_pool5[0][0] │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ score_pool4         │ (None, 14, 14, 4) │      2,052 │ block4_pool[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fuse_pool4 (Add)    │ (None, 14, 14, 4) │          0 │ upscore_pool5[0]… │
# │                     │                   │            │ score_pool4[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upscore_pool4       │ (None, 28, 28, 4) │        260 │ fuse_pool4[0][0]  │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ score_pool3         │ (None, 28, 28, 4) │      1,028 │ block3_pool[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fuse_pool3 (Add)    │ (None, 28, 28, 4) │          0 │ upscore_pool4[0]… │
# │                     │                   │            │ score_pool3[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upscore_final       │ (None, 224, 224,  │      4,100 │ fuse_pool3[0][0]  │
# │ (Conv2DTranspose)   │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Activation) │ (None, 224, 224,  │          0 │ upscore_final[0]… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 134,284,632 (512.26 MB)
#  Trainable params: 119,569,944 (456.12 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)
# Architecture diagram saved ✓

# %% [markdown]
# ## 10. Callbacks (EarlyStopping disabled)

# %%
def decode_mask(onehot_mask):
    return tf.argmax(onehot_mask, axis=-1)

def colorize_mask(label_map):
    colors = np.array([[0,0,0],[0,255,255],[255,165,0],[255,0,255]], dtype=np.uint8)
    return colors[np.array(label_map).astype(int)]

def show_predictions(dataset, num=3, model_to_use=None):
    m = model_to_use or model
    for imgs, masks in dataset.take(1):
        preds = m.predict(imgs, verbose=0)
        for i in range(min(num, len(imgs))):
            fig, axes = plt.subplots(1, 3, figsize=(13, 4))
            axes[0].imshow(imgs[i].numpy());                              axes[0].set_title('Input MRI')
            axes[1].imshow(colorize_mask(decode_mask(masks[i]).numpy())); axes[1].set_title('Ground Truth')
            axes[2].imshow(colorize_mask(decode_mask(preds[i]).numpy())); axes[2].set_title('Prediction')
            for ax in axes: ax.axis('off')
            plt.tight_layout(); plt.show()

class DisplayCallback(callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % 10 == 0:
            show_predictions(test_dataset, num=2)
            print(f'Prediction after epoch {epoch + 1}\n')

logdir = os.path.join('logs', datetime.datetime.now().strftime('%Y%m%d-%H%M%S'))

callbacks_list = [
    DisplayCallback(),
    callbacks.TensorBoard(logdir, histogram_freq=1),
    callbacks.ModelCheckpoint('best_model_fcn8s_mrbrains.keras', verbose=1,
                               save_best_only=True, monitor='val_iou_score_multiclass', mode='max'),
    callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-7, verbose=1),
    # EarlyStopping intentionally removed
]
print('Callbacks ready ✓ (no EarlyStopping — will run all', EPOCHS, 'epochs)')
# Out:
# Callbacks ready ✓ (no EarlyStopping — will run all 100 epochs)

# %% [markdown]
# ## 11. Initial Predictions (before training)

# %%
print('Predictions before training:')
show_predictions(test_dataset, num=2)
# Out:
# Predictions before training:
# I0000 00:00:1783414418.892371     133 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %% [markdown]
# ## 12. Training

# %%
steps_per_epoch  = max(1, len(os.listdir(TRAIN_IMG_DIR)) // BATCH_SIZE)
validation_steps = max(1, len(os.listdir(TEST_IMG_DIR))  // BATCH_SIZE)

print(f'Steps per epoch  : {steps_per_epoch}')
print(f'Validation steps : {validation_steps}')

start_time = time.time()
history = model.fit(
    train_dataset, validation_data=test_dataset, epochs=EPOCHS,
    steps_per_epoch=steps_per_epoch, validation_steps=validation_steps,
    callbacks=callbacks_list
)
print(f'\nTraining time: {(time.time()-start_time)/60:.1f} min')
# Out:
# Steps per epoch  : 33
# Validation steps : 8
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - csf_iou: 0.0595 - dice_coefficient_multiclass: 0.1799 - gm_iou: 0.0599 - iou_score_multiclass: 0.1071 - loss: 2.5418 - pixel_accuracy_multiclass: 0.3059 - wm_iou: 0.0376
# Epoch 1: val_iou_score_multiclass improved from None to 0.12784, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 1: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 43s 998ms/step - csf_iou: 0.0589 - dice_coefficient_multiclass: 0.1869 - gm_iou: 0.0599 - iou_score_multiclass: 0.1127 - loss: 2.4384 - pixel_accuracy_multiclass: 0.3423 - wm_iou: 0.0397 - val_csf_iou: 0.0625 - val_dice_coefficient_multiclass: 0.2077 - val_gm_iou: 0.0641 - val_iou_score_multiclass: 0.1278 - val_loss: 2.2378 - val_pixel_accuracy_multiclass: 0.4159 - val_wm_iou: 0.0448 - learning_rate: 1.0000e-04
# Epoch 2/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 3:43 7s/step - csf_iou: 0.0065 - dice_coefficient_multiclass: 0.1356 - gm_iou: 1.1551e-04 - iou_score_multiclass: 0.0916 - loss: 2.1134 - pixel_accuracy_multiclass: 0.4813 - wm_iou: 2.3043e-05
# Epoch 2: val_iou_score_multiclass improved from 0.12784 to 0.12881, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 2: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 36s 919ms/step - csf_iou: 0.0065 - dice_coefficient_multiclass: 0.1356 - gm_iou: 1.1551e-04 - iou_score_multiclass: 0.0916 - loss: 2.1134 - pixel_accuracy_multiclass: 0.4813 - wm_iou: 2.3043e-05 - val_csf_iou: 0.0626 - val_dice_coefficient_multiclass: 0.2088 - val_gm_iou: 0.0643 - val_iou_score_multiclass: 0.1288 - val_loss: 2.2271 - val_pixel_accuracy_multiclass: 0.4206 - val_wm_iou: 0.0449 - learning_rate: 1.0000e-04
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.0608 - dice_coefficient_multiclass: 0.2129 - gm_iou: 0.0647 - iou_score_multiclass: 0.1347 - loss: 2.1533 - pixel_accuracy_multiclass: 0.4552 - wm_iou: 0.0415
# Epoch 3: val_iou_score_multiclass improved from 0.12881 to 0.17228, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 3: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - csf_iou: 0.0614 - dice_coefficient_multiclass: 0.2243 - gm_iou: 0.0666 - iou_score_multiclass: 0.1448 - loss: 2.0588 - pixel_accuracy_multiclass: 0.4969 - wm_iou: 0.0446 - val_csf_iou: 0.0680 - val_dice_coefficient_multiclass: 0.2575 - val_gm_iou: 0.0770 - val_iou_score_multiclass: 0.1723 - val_loss: 1.8461 - val_pixel_accuracy_multiclass: 0.5811 - val_wm_iou: 0.0542 - learning_rate: 1.0000e-04
# Epoch 4/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - csf_iou: 0.0067 - dice_coefficient_multiclass: 0.1762 - gm_iou: 9.8480e-05 - iou_score_multiclass: 0.1338 - loss: 1.6590 - pixel_accuracy_multiclass: 0.6925 - wm_iou: 3.0661e-05
# Epoch 4: val_iou_score_multiclass improved from 0.17228 to 0.17399, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 4: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - csf_iou: 0.0067 - dice_coefficient_multiclass: 0.1762 - gm_iou: 9.8480e-05 - iou_score_multiclass: 0.1338 - loss: 1.6590 - pixel_accuracy_multiclass: 0.6925 - wm_iou: 3.0661e-05 - val_csf_iou: 0.0680 - val_dice_coefficient_multiclass: 0.2592 - val_gm_iou: 0.0772 - val_iou_score_multiclass: 0.1740 - val_loss: 1.8341 - val_pixel_accuracy_multiclass: 0.5855 - val_wm_iou: 0.0545 - learning_rate: 1.0000e-04
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.0676 - dice_coefficient_multiclass: 0.2641 - gm_iou: 0.0777 - iou_score_multiclass: 0.1828 - loss: 1.7554 - pixel_accuracy_multiclass: 0.6191 - wm_iou: 0.0504
# Epoch 5: val_iou_score_multiclass improved from 0.17399 to 0.23883, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 5: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 970ms/step - csf_iou: 0.0709 - dice_coefficient_multiclass: 0.2803 - gm_iou: 0.0836 - iou_score_multiclass: 0.1987 - loss: 1.6511 - pixel_accuracy_multiclass: 0.6566 - wm_iou: 0.0565 - val_csf_iou: 0.0858 - val_dice_coefficient_multiclass: 0.3276 - val_gm_iou: 0.1086 - val_iou_score_multiclass: 0.2388 - val_loss: 1.4352 - val_pixel_accuracy_multiclass: 0.7249 - val_wm_iou: 0.0788 - learning_rate: 1.0000e-04
# Epoch 6/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - csf_iou: 0.0083 - dice_coefficient_multiclass: 0.2170 - gm_iou: 1.6600e-04 - iou_score_multiclass: 0.1874 - loss: 1.2012 - pixel_accuracy_multiclass: 0.8600 - wm_iou: 5.5312e-05
# Epoch 6: val_iou_score_multiclass improved from 0.23883 to 0.24080, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 6: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 879ms/step - csf_iou: 0.0083 - dice_coefficient_multiclass: 0.2170 - gm_iou: 1.6600e-04 - iou_score_multiclass: 0.1874 - loss: 1.2012 - pixel_accuracy_multiclass: 0.8600 - wm_iou: 5.5312e-05 - val_csf_iou: 0.0864 - val_dice_coefficient_multiclass: 0.3296 - val_gm_iou: 0.1097 - val_iou_score_multiclass: 0.2408 - val_loss: 1.4246 - val_pixel_accuracy_multiclass: 0.7286 - val_wm_iou: 0.0796 - learning_rate: 1.0000e-04
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.0866 - dice_coefficient_multiclass: 0.3260 - gm_iou: 0.1053 - iou_score_multiclass: 0.2449 - loss: 1.3791 - pixel_accuracy_multiclass: 0.7489 - wm_iou: 0.0686
# Epoch 7: val_iou_score_multiclass improved from 0.24080 to 0.29887, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 7: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 967ms/step - csf_iou: 0.0921 - dice_coefficient_multiclass: 0.3413 - gm_iou: 0.1138 - iou_score_multiclass: 0.2597 - loss: 1.3078 - pixel_accuracy_multiclass: 0.7715 - wm_iou: 0.0771 - val_csf_iou: 0.1176 - val_dice_coefficient_multiclass: 0.3926 - val_gm_iou: 0.1500 - val_iou_score_multiclass: 0.2989 - val_loss: 1.1658 - val_pixel_accuracy_multiclass: 0.8035 - val_wm_iou: 0.1122 - learning_rate: 1.0000e-04
# Epoch 8/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - csf_iou: 0.0154 - dice_coefficient_multiclass: 0.2428 - gm_iou: 6.7707e-04 - iou_score_multiclass: 0.2255 - loss: 0.9268 - pixel_accuracy_multiclass: 0.9531 - wm_iou: 1.2419e-04
# Epoch 8: val_iou_score_multiclass improved from 0.29887 to 0.30076, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 8: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 888ms/step - csf_iou: 0.0154 - dice_coefficient_multiclass: 0.2428 - gm_iou: 6.7707e-04 - iou_score_multiclass: 0.2255 - loss: 0.9268 - pixel_accuracy_multiclass: 0.9531 - wm_iou: 1.2419e-04 - val_csf_iou: 0.1178 - val_dice_coefficient_multiclass: 0.3944 - val_gm_iou: 0.1509 - val_iou_score_multiclass: 0.3008 - val_loss: 1.1562 - val_pixel_accuracy_multiclass: 0.8059 - val_wm_iou: 0.1137 - learning_rate: 1.0000e-04
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.1126 - dice_coefficient_multiclass: 0.3778 - gm_iou: 0.1390 - iou_score_multiclass: 0.2950 - loss: 1.1482 - pixel_accuracy_multiclass: 0.8138 - wm_iou: 0.0898
# Epoch 9: val_iou_score_multiclass improved from 0.30076 to 0.33477, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 9: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 962ms/step - csf_iou: 0.1167 - dice_coefficient_multiclass: 0.3883 - gm_iou: 0.1460 - iou_score_multiclass: 0.3046 - loss: 1.1091 - pixel_accuracy_multiclass: 0.8230 - wm_iou: 0.0984 - val_csf_iou: 0.1311 - val_dice_coefficient_multiclass: 0.4307 - val_gm_iou: 0.1764 - val_iou_score_multiclass: 0.3348 - val_loss: 1.0243 - val_pixel_accuracy_multiclass: 0.8357 - val_wm_iou: 0.1437 - learning_rate: 1.0000e-04
# Epoch 10/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - csf_iou: 0.0213 - dice_coefficient_multiclass: 0.2554 - gm_iou: 0.0011 - iou_score_multiclass: 0.2451 - loss: 0.8178 - pixel_accuracy_multiclass: 0.9798 - wm_iou: 3.5837e-04
# Prediction after epoch 10
#
#
# Epoch 10: val_iou_score_multiclass improved from 0.33477 to 0.33547, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 10: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 29s 912ms/step - csf_iou: 0.0213 - dice_coefficient_multiclass: 0.2554 - gm_iou: 0.0011 - iou_score_multiclass: 0.2451 - loss: 0.8178 - pixel_accuracy_multiclass: 0.9798 - wm_iou: 3.5837e-04 - val_csf_iou: 0.1312 - val_dice_coefficient_multiclass: 0.4314 - val_gm_iou: 0.1768 - val_iou_score_multiclass: 0.3355 - val_loss: 1.0226 - val_pixel_accuracy_multiclass: 0.8362 - val_wm_iou: 0.1446 - learning_rate: 1.0000e-04
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.1288 - dice_coefficient_multiclass: 0.4052 - gm_iou: 0.1601 - iou_score_multiclass: 0.3201 - loss: 1.0471 - pixel_accuracy_multiclass: 0.8346 - wm_iou: 0.1045
# Epoch 11: val_iou_score_multiclass improved from 0.33547 to 0.34749, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 11: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 961ms/step - csf_iou: 0.1298 - dice_coefficient_multiclass: 0.4103 - gm_iou: 0.1628 - iou_score_multiclass: 0.3244 - loss: 1.0305 - pixel_accuracy_multiclass: 0.8381 - wm_iou: 0.1120 - val_csf_iou: 0.1342 - val_dice_coefficient_multiclass: 0.4450 - val_gm_iou: 0.1876 - val_iou_score_multiclass: 0.3475 - val_loss: 0.9730 - val_pixel_accuracy_multiclass: 0.8462 - val_wm_iou: 0.1609 - learning_rate: 1.0000e-04
# Epoch 12/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - csf_iou: 0.0241 - dice_coefficient_multiclass: 0.2592 - gm_iou: 0.0019 - iou_score_multiclass: 0.2501 - loss: 0.7919 - pixel_accuracy_multiclass: 0.9873 - wm_iou: 6.9428e-04
# Epoch 12: val_iou_score_multiclass improved from 0.34749 to 0.34871, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 12: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 876ms/step - csf_iou: 0.0241 - dice_coefficient_multiclass: 0.2592 - gm_iou: 0.0019 - iou_score_multiclass: 0.2501 - loss: 0.7919 - pixel_accuracy_multiclass: 0.9873 - wm_iou: 6.9428e-04 - val_csf_iou: 0.1367 - val_dice_coefficient_multiclass: 0.4466 - val_gm_iou: 0.1894 - val_iou_score_multiclass: 0.3487 - val_loss: 0.9670 - val_pixel_accuracy_multiclass: 0.8463 - val_wm_iou: 0.1605 - learning_rate: 1.0000e-04
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.1404 - dice_coefficient_multiclass: 0.4208 - gm_iou: 0.1732 - iou_score_multiclass: 0.3336 - loss: 0.9884 - pixel_accuracy_multiclass: 0.8446 - wm_iou: 0.1132
# Epoch 13: val_iou_score_multiclass improved from 0.34871 to 0.35998, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 13: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 953ms/step - csf_iou: 0.1441 - dice_coefficient_multiclass: 0.4287 - gm_iou: 0.1789 - iou_score_multiclass: 0.3401 - loss: 0.9670 - pixel_accuracy_multiclass: 0.8485 - wm_iou: 0.1216 - val_csf_iou: 0.1538 - val_dice_coefficient_multiclass: 0.4604 - val_gm_iou: 0.2016 - val_iou_score_multiclass: 0.3600 - val_loss: 0.9259 - val_pixel_accuracy_multiclass: 0.8483 - val_wm_iou: 0.1644 - learning_rate: 1.0000e-04
# Epoch 14/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - csf_iou: 0.0861 - dice_coefficient_multiclass: 0.2886 - gm_iou: 0.0038 - iou_score_multiclass: 0.2671 - loss: 0.7511 - pixel_accuracy_multiclass: 0.9875 - wm_iou: 7.3258e-04
# Epoch 14: val_iou_score_multiclass improved from 0.35998 to 0.36009, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 14: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 29s 900ms/step - csf_iou: 0.0861 - dice_coefficient_multiclass: 0.2886 - gm_iou: 0.0038 - iou_score_multiclass: 0.2671 - loss: 0.7511 - pixel_accuracy_multiclass: 0.9875 - wm_iou: 7.3258e-04 - val_csf_iou: 0.1541 - val_dice_coefficient_multiclass: 0.4606 - val_gm_iou: 0.2018 - val_iou_score_multiclass: 0.3601 - val_loss: 0.9258 - val_pixel_accuracy_multiclass: 0.8481 - val_wm_iou: 0.1643 - learning_rate: 1.0000e-04
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.1536 - dice_coefficient_multiclass: 0.4351 - gm_iou: 0.1860 - iou_score_multiclass: 0.3454 - loss: 0.9441 - pixel_accuracy_multiclass: 0.8504 - wm_iou: 0.1200
# Epoch 15: val_iou_score_multiclass improved from 0.36009 to 0.36823, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 15: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - csf_iou: 0.1552 - dice_coefficient_multiclass: 0.4402 - gm_iou: 0.1882 - iou_score_multiclass: 0.3496 - loss: 0.9288 - pixel_accuracy_multiclass: 0.8539 - wm_iou: 0.1277 - val_csf_iou: 0.1628 - val_dice_coefficient_multiclass: 0.4702 - val_gm_iou: 0.2070 - val_iou_score_multiclass: 0.3682 - val_loss: 0.8909 - val_pixel_accuracy_multiclass: 0.8541 - val_wm_iou: 0.1731 - learning_rate: 1.0000e-04
# Epoch 16/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - csf_iou: 0.0806 - dice_coefficient_multiclass: 0.2878 - gm_iou: 0.0056 - iou_score_multiclass: 0.2676 - loss: 0.7451 - pixel_accuracy_multiclass: 0.9899 - wm_iou: 0.0012
# Epoch 16: val_iou_score_multiclass did not improve from 0.36823
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 671ms/step - csf_iou: 0.0806 - dice_coefficient_multiclass: 0.2878 - gm_iou: 0.0056 - iou_score_multiclass: 0.2676 - loss: 0.7451 - pixel_accuracy_multiclass: 0.9899 - wm_iou: 0.0012 - val_csf_iou: 0.1635 - val_dice_coefficient_multiclass: 0.4700 - val_gm_iou: 0.2071 - val_iou_score_multiclass: 0.3679 - val_loss: 0.8923 - val_pixel_accuracy_multiclass: 0.8532 - val_wm_iou: 0.1720 - learning_rate: 1.0000e-04
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.1645 - dice_coefficient_multiclass: 0.4439 - gm_iou: 0.1918 - iou_score_multiclass: 0.3525 - loss: 0.9145 - pixel_accuracy_multiclass: 0.8545 - wm_iou: 0.1244
# Epoch 17: val_iou_score_multiclass improved from 0.36823 to 0.37549, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 17: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 944ms/step - csf_iou: 0.1660 - dice_coefficient_multiclass: 0.4490 - gm_iou: 0.1940 - iou_score_multiclass: 0.3566 - loss: 0.9015 - pixel_accuracy_multiclass: 0.8575 - wm_iou: 0.1325 - val_csf_iou: 0.1724 - val_dice_coefficient_multiclass: 0.4792 - val_gm_iou: 0.2124 - val_iou_score_multiclass: 0.3755 - val_loss: 0.8658 - val_pixel_accuracy_multiclass: 0.8575 - val_wm_iou: 0.1811 - learning_rate: 1.0000e-04
# Epoch 18/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - csf_iou: 0.1376 - dice_coefficient_multiclass: 0.3111 - gm_iou: 0.0051 - iou_score_multiclass: 0.2822 - loss: 0.7181 - pixel_accuracy_multiclass: 0.9898 - wm_iou: 0.0011
# Epoch 18: val_iou_score_multiclass did not improve from 0.37549
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 676ms/step - csf_iou: 0.1376 - dice_coefficient_multiclass: 0.3111 - gm_iou: 0.0051 - iou_score_multiclass: 0.2822 - loss: 0.7181 - pixel_accuracy_multiclass: 0.9898 - wm_iou: 0.0011 - val_csf_iou: 0.1731 - val_dice_coefficient_multiclass: 0.4793 - val_gm_iou: 0.2125 - val_iou_score_multiclass: 0.3755 - val_loss: 0.8661 - val_pixel_accuracy_multiclass: 0.8572 - val_wm_iou: 0.1805 - learning_rate: 1.0000e-04
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.1780 - dice_coefficient_multiclass: 0.4541 - gm_iou: 0.1975 - iou_score_multiclass: 0.3605 - loss: 0.8870 - pixel_accuracy_multiclass: 0.8588 - wm_iou: 0.1303
# Epoch 19: val_iou_score_multiclass improved from 0.37549 to 0.38263, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 19: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 945ms/step - csf_iou: 0.1798 - dice_coefficient_multiclass: 0.4585 - gm_iou: 0.1986 - iou_score_multiclass: 0.3641 - loss: 0.8751 - pixel_accuracy_multiclass: 0.8613 - wm_iou: 0.1379 - val_csf_iou: 0.1854 - val_dice_coefficient_multiclass: 0.4882 - val_gm_iou: 0.2143 - val_iou_score_multiclass: 0.3826 - val_loss: 0.8408 - val_pixel_accuracy_multiclass: 0.8617 - val_wm_iou: 0.1890 - learning_rate: 1.0000e-04
# Epoch 20/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - csf_iou: 0.1438 - dice_coefficient_multiclass: 0.3152 - gm_iou: 0.0077 - iou_score_multiclass: 0.2857 - loss: 0.7066 - pixel_accuracy_multiclass: 0.9928 - wm_iou: 0.0021
# Prediction after epoch 20
#
#
# Epoch 20: val_iou_score_multiclass improved from 0.38263 to 0.38284, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 20: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 29s 899ms/step - csf_iou: 0.1438 - dice_coefficient_multiclass: 0.3152 - gm_iou: 0.0077 - iou_score_multiclass: 0.2857 - loss: 0.7066 - pixel_accuracy_multiclass: 0.9928 - wm_iou: 0.0021 - val_csf_iou: 0.1860 - val_dice_coefficient_multiclass: 0.4885 - val_gm_iou: 0.2148 - val_iou_score_multiclass: 0.3828 - val_loss: 0.8411 - val_pixel_accuracy_multiclass: 0.8613 - val_wm_iou: 0.1888 - learning_rate: 1.0000e-04
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - csf_iou: 0.1898 - dice_coefficient_multiclass: 0.4626 - gm_iou: 0.2013 - iou_score_multiclass: 0.3671 - loss: 0.8645 - pixel_accuracy_multiclass: 0.8625 - wm_iou: 0.1361
# Epoch 21: val_iou_score_multiclass improved from 0.38284 to 0.38701, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 21: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 53s 956ms/step - csf_iou: 0.1921 - dice_coefficient_multiclass: 0.4666 - gm_iou: 0.2014 - iou_score_multiclass: 0.3703 - loss: 0.8542 - pixel_accuracy_multiclass: 0.8648 - wm_iou: 0.1436 - val_csf_iou: 0.1980 - val_dice_coefficient_multiclass: 0.4946 - val_gm_iou: 0.2153 - val_iou_score_multiclass: 0.3870 - val_loss: 0.8269 - val_pixel_accuracy_multiclass: 0.8620 - val_wm_iou: 0.1943 - learning_rate: 1.0000e-04
# Epoch 22/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - csf_iou: 0.1666 - dice_coefficient_multiclass: 0.3230 - gm_iou: 0.0065 - iou_score_multiclass: 0.2904 - loss: 0.7028 - pixel_accuracy_multiclass: 0.9910 - wm_iou: 0.0016
# Epoch 22: val_iou_score_multiclass did not improve from 0.38701
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 675ms/step - csf_iou: 0.1666 - dice_coefficient_multiclass: 0.3230 - gm_iou: 0.0065 - iou_score_multiclass: 0.2904 - loss: 0.7028 - pixel_accuracy_multiclass: 0.9910 - wm_iou: 0.0016 - val_csf_iou: 0.1974 - val_dice_coefficient_multiclass: 0.4940 - val_gm_iou: 0.2154 - val_iou_score_multiclass: 0.3863 - val_loss: 0.8316 - val_pixel_accuracy_multiclass: 0.8604 - val_wm_iou: 0.1935 - learning_rate: 1.0000e-04
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.2034 - dice_coefficient_multiclass: 0.4704 - gm_iou: 0.2038 - iou_score_multiclass: 0.3730 - loss: 0.8447 - pixel_accuracy_multiclass: 0.8648 - wm_iou: 0.1414
# Epoch 23: val_iou_score_multiclass improved from 0.38701 to 0.39663, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 23: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 943ms/step - csf_iou: 0.2065 - dice_coefficient_multiclass: 0.4760 - gm_iou: 0.2053 - iou_score_multiclass: 0.3775 - loss: 0.8313 - pixel_accuracy_multiclass: 0.8680 - wm_iou: 0.1506 - val_csf_iou: 0.2125 - val_dice_coefficient_multiclass: 0.5065 - val_gm_iou: 0.2173 - val_iou_score_multiclass: 0.3966 - val_loss: 0.7974 - val_pixel_accuracy_multiclass: 0.8685 - val_wm_iou: 0.2098 - learning_rate: 1.0000e-04
# Epoch 24/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - csf_iou: 0.2476 - dice_coefficient_multiclass: 0.3519 - gm_iou: 0.0072 - iou_score_multiclass: 0.3122 - loss: 0.6671 - pixel_accuracy_multiclass: 0.9934 - wm_iou: 0.0024
# Epoch 24: val_iou_score_multiclass improved from 0.39663 to 0.39695, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 24: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 880ms/step - csf_iou: 0.2476 - dice_coefficient_multiclass: 0.3519 - gm_iou: 0.0072 - iou_score_multiclass: 0.3122 - loss: 0.6671 - pixel_accuracy_multiclass: 0.9934 - wm_iou: 0.0024 - val_csf_iou: 0.2133 - val_dice_coefficient_multiclass: 0.5069 - val_gm_iou: 0.2173 - val_iou_score_multiclass: 0.3970 - val_loss: 0.7966 - val_pixel_accuracy_multiclass: 0.8686 - val_wm_iou: 0.2101 - learning_rate: 1.0000e-04
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.2154 - dice_coefficient_multiclass: 0.4789 - gm_iou: 0.2046 - iou_score_multiclass: 0.3794 - loss: 0.8259 - pixel_accuracy_multiclass: 0.8688 - wm_iou: 0.1511
# Epoch 25: val_iou_score_multiclass improved from 0.39695 to 0.40225, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 25: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 961ms/step - csf_iou: 0.2155 - dice_coefficient_multiclass: 0.4821 - gm_iou: 0.2046 - iou_score_multiclass: 0.3820 - loss: 0.8187 - pixel_accuracy_multiclass: 0.8707 - wm_iou: 0.1591 - val_csf_iou: 0.2240 - val_dice_coefficient_multiclass: 0.5141 - val_gm_iou: 0.2183 - val_iou_score_multiclass: 0.4023 - val_loss: 0.7806 - val_pixel_accuracy_multiclass: 0.8710 - val_wm_iou: 0.2201 - learning_rate: 1.0000e-04
# Epoch 26/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - csf_iou: 0.2296 - dice_coefficient_multiclass: 0.3463 - gm_iou: 0.0081 - iou_score_multiclass: 0.3075 - loss: 0.6748 - pixel_accuracy_multiclass: 0.9925 - wm_iou: 0.0025
# Epoch 26: val_iou_score_multiclass did not improve from 0.40225
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 673ms/step - csf_iou: 0.2296 - dice_coefficient_multiclass: 0.3463 - gm_iou: 0.0081 - iou_score_multiclass: 0.3075 - loss: 0.6748 - pixel_accuracy_multiclass: 0.9925 - wm_iou: 0.0025 - val_csf_iou: 0.2231 - val_dice_coefficient_multiclass: 0.5137 - val_gm_iou: 0.2187 - val_iou_score_multiclass: 0.4017 - val_loss: 0.7847 - val_pixel_accuracy_multiclass: 0.8695 - val_wm_iou: 0.2198 - learning_rate: 1.0000e-04
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.2302 - dice_coefficient_multiclass: 0.4880 - gm_iou: 0.2075 - iou_score_multiclass: 0.3862 - loss: 0.8059 - pixel_accuracy_multiclass: 0.8718 - wm_iou: 0.1598
# Epoch 27: val_iou_score_multiclass improved from 0.40225 to 0.41117, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 27: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 949ms/step - csf_iou: 0.2334 - dice_coefficient_multiclass: 0.4935 - gm_iou: 0.2091 - iou_score_multiclass: 0.3908 - loss: 0.7948 - pixel_accuracy_multiclass: 0.8743 - wm_iou: 0.1690 - val_csf_iou: 0.2341 - val_dice_coefficient_multiclass: 0.5249 - val_gm_iou: 0.2181 - val_iou_score_multiclass: 0.4112 - val_loss: 0.7628 - val_pixel_accuracy_multiclass: 0.8772 - val_wm_iou: 0.2409 - learning_rate: 1.0000e-04
# Epoch 28/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - csf_iou: 0.2202 - dice_coefficient_multiclass: 0.3475 - gm_iou: 0.0143 - iou_score_multiclass: 0.3096 - loss: 0.6676 - pixel_accuracy_multiclass: 0.9941 - wm_iou: 0.0105
# Epoch 28: val_iou_score_multiclass improved from 0.41117 to 0.41235, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 28: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 881ms/step - csf_iou: 0.2202 - dice_coefficient_multiclass: 0.3475 - gm_iou: 0.0143 - iou_score_multiclass: 0.3096 - loss: 0.6676 - pixel_accuracy_multiclass: 0.9941 - wm_iou: 0.0105 - val_csf_iou: 0.2372 - val_dice_coefficient_multiclass: 0.5264 - val_gm_iou: 0.2195 - val_iou_score_multiclass: 0.4124 - val_loss: 0.7586 - val_pixel_accuracy_multiclass: 0.8773 - val_wm_iou: 0.2404 - learning_rate: 1.0000e-04
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - csf_iou: 0.2376 - dice_coefficient_multiclass: 0.4925 - gm_iou: 0.2041 - iou_score_multiclass: 0.3895 - loss: 0.8007 - pixel_accuracy_multiclass: 0.8733 - wm_iou: 0.1696
# Epoch 29: val_iou_score_multiclass improved from 0.41235 to 0.41943, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 29: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 54s 967ms/step - csf_iou: 0.2429 - dice_coefficient_multiclass: 0.4997 - gm_iou: 0.2088 - iou_score_multiclass: 0.3954 - loss: 0.7849 - pixel_accuracy_multiclass: 0.8761 - wm_iou: 0.1790 - val_csf_iou: 0.2454 - val_dice_coefficient_multiclass: 0.5354 - val_gm_iou: 0.2231 - val_iou_score_multiclass: 0.4194 - val_loss: 0.7420 - val_pixel_accuracy_multiclass: 0.8798 - val_wm_iou: 0.2565 - learning_rate: 1.0000e-04
# Epoch 30/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - csf_iou: 0.2236 - dice_coefficient_multiclass: 0.3493 - gm_iou: 0.0149 - iou_score_multiclass: 0.3110 - loss: 0.6660 - pixel_accuracy_multiclass: 0.9944 - wm_iou: 0.0121
# Prediction after epoch 30
#
#
# Epoch 30: val_iou_score_multiclass improved from 0.41943 to 0.42001, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 30: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 29s 911ms/step - csf_iou: 0.2236 - dice_coefficient_multiclass: 0.3493 - gm_iou: 0.0149 - iou_score_multiclass: 0.3110 - loss: 0.6660 - pixel_accuracy_multiclass: 0.9944 - wm_iou: 0.0121 - val_csf_iou: 0.2471 - val_dice_coefficient_multiclass: 0.5361 - val_gm_iou: 0.2238 - val_iou_score_multiclass: 0.4200 - val_loss: 0.7401 - val_pixel_accuracy_multiclass: 0.8799 - val_wm_iou: 0.2563 - learning_rate: 1.0000e-04
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.2540 - dice_coefficient_multiclass: 0.5030 - gm_iou: 0.2101 - iou_score_multiclass: 0.3978 - loss: 0.7789 - pixel_accuracy_multiclass: 0.8772 - wm_iou: 0.1776
# Epoch 31: val_iou_score_multiclass improved from 0.42001 to 0.42567, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 31: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 966ms/step - csf_iou: 0.2552 - dice_coefficient_multiclass: 0.5065 - gm_iou: 0.2108 - iou_score_multiclass: 0.4007 - loss: 0.7736 - pixel_accuracy_multiclass: 0.8784 - wm_iou: 0.1854 - val_csf_iou: 0.2533 - val_dice_coefficient_multiclass: 0.5439 - val_gm_iou: 0.2281 - val_iou_score_multiclass: 0.4257 - val_loss: 0.7312 - val_pixel_accuracy_multiclass: 0.8791 - val_wm_iou: 0.2716 - learning_rate: 1.0000e-04
# Epoch 32/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - csf_iou: 0.2167 - dice_coefficient_multiclass: 0.3410 - gm_iou: 0.0061 - iou_score_multiclass: 0.3034 - loss: 0.6878 - pixel_accuracy_multiclass: 0.9883 - wm_iou: 0.0043
# Epoch 32: val_iou_score_multiclass improved from 0.42567 to 0.42593, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 32: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 880ms/step - csf_iou: 0.2167 - dice_coefficient_multiclass: 0.3410 - gm_iou: 0.0061 - iou_score_multiclass: 0.3034 - loss: 0.6878 - pixel_accuracy_multiclass: 0.9883 - wm_iou: 0.0043 - val_csf_iou: 0.2526 - val_dice_coefficient_multiclass: 0.5443 - val_gm_iou: 0.2289 - val_iou_score_multiclass: 0.4259 - val_loss: 0.7321 - val_pixel_accuracy_multiclass: 0.8787 - val_wm_iou: 0.2727 - learning_rate: 1.0000e-04
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.2669 - dice_coefficient_multiclass: 0.5146 - gm_iou: 0.2172 - iou_score_multiclass: 0.4069 - loss: 0.7549 - pixel_accuracy_multiclass: 0.8813 - wm_iou: 0.1911
# Epoch 33: val_iou_score_multiclass improved from 0.42593 to 0.43646, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 33: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 954ms/step - csf_iou: 0.2686 - dice_coefficient_multiclass: 0.5178 - gm_iou: 0.2170 - iou_score_multiclass: 0.4099 - loss: 0.7490 - pixel_accuracy_multiclass: 0.8830 - wm_iou: 0.1982 - val_csf_iou: 0.2725 - val_dice_coefficient_multiclass: 0.5565 - val_gm_iou: 0.2310 - val_iou_score_multiclass: 0.4365 - val_loss: 0.7076 - val_pixel_accuracy_multiclass: 0.8840 - val_wm_iou: 0.2883 - learning_rate: 1.0000e-04
# Epoch 34/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - csf_iou: 0.3034 - dice_coefficient_multiclass: 0.3719 - gm_iou: 0.0104 - iou_score_multiclass: 0.3284 - loss: 0.6459 - pixel_accuracy_multiclass: 0.9928 - wm_iou: 0.0086
# Epoch 34: val_iou_score_multiclass improved from 0.43646 to 0.43654, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 34: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 888ms/step - csf_iou: 0.3034 - dice_coefficient_multiclass: 0.3719 - gm_iou: 0.0104 - iou_score_multiclass: 0.3284 - loss: 0.6459 - pixel_accuracy_multiclass: 0.9928 - wm_iou: 0.0086 - val_csf_iou: 0.2729 - val_dice_coefficient_multiclass: 0.5567 - val_gm_iou: 0.2313 - val_iou_score_multiclass: 0.4365 - val_loss: 0.7080 - val_pixel_accuracy_multiclass: 0.8838 - val_wm_iou: 0.2884 - learning_rate: 1.0000e-04
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.2843 - dice_coefficient_multiclass: 0.5247 - gm_iou: 0.2202 - iou_score_multiclass: 0.4152 - loss: 0.7356 - pixel_accuracy_multiclass: 0.8849 - wm_iou: 0.2009
# Epoch 35: val_iou_score_multiclass improved from 0.43654 to 0.44552, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 35: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 965ms/step - csf_iou: 0.2859 - dice_coefficient_multiclass: 0.5288 - gm_iou: 0.2221 - iou_score_multiclass: 0.4188 - loss: 0.7278 - pixel_accuracy_multiclass: 0.8867 - wm_iou: 0.2088 - val_csf_iou: 0.2899 - val_dice_coefficient_multiclass: 0.5671 - val_gm_iou: 0.2349 - val_iou_score_multiclass: 0.4455 - val_loss: 0.6861 - val_pixel_accuracy_multiclass: 0.8891 - val_wm_iou: 0.3002 - learning_rate: 1.0000e-04
# Epoch 36/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - csf_iou: 0.2802 - dice_coefficient_multiclass: 0.3701 - gm_iou: 0.0120 - iou_score_multiclass: 0.3288 - loss: 0.6429 - pixel_accuracy_multiclass: 0.9946 - wm_iou: 0.0295
# Epoch 36: val_iou_score_multiclass improved from 0.44552 to 0.44573, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 36: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 884ms/step - csf_iou: 0.2802 - dice_coefficient_multiclass: 0.3701 - gm_iou: 0.0120 - iou_score_multiclass: 0.3288 - loss: 0.6429 - pixel_accuracy_multiclass: 0.9946 - wm_iou: 0.0295 - val_csf_iou: 0.2898 - val_dice_coefficient_multiclass: 0.5674 - val_gm_iou: 0.2361 - val_iou_score_multiclass: 0.4457 - val_loss: 0.6876 - val_pixel_accuracy_multiclass: 0.8883 - val_wm_iou: 0.3007 - learning_rate: 1.0000e-04
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.2976 - dice_coefficient_multiclass: 0.5337 - gm_iou: 0.2231 - iou_score_multiclass: 0.4224 - loss: 0.7222 - pixel_accuracy_multiclass: 0.8875 - wm_iou: 0.2126
# Epoch 37: val_iou_score_multiclass improved from 0.44573 to 0.45287, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 37: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 962ms/step - csf_iou: 0.2991 - dice_coefficient_multiclass: 0.5380 - gm_iou: 0.2257 - iou_score_multiclass: 0.4262 - loss: 0.7142 - pixel_accuracy_multiclass: 0.8893 - wm_iou: 0.2207 - val_csf_iou: 0.3038 - val_dice_coefficient_multiclass: 0.5757 - val_gm_iou: 0.2386 - val_iou_score_multiclass: 0.4529 - val_loss: 0.6719 - val_pixel_accuracy_multiclass: 0.8915 - val_wm_iou: 0.3113 - learning_rate: 1.0000e-04
# Epoch 38/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - csf_iou: 0.3934 - dice_coefficient_multiclass: 0.4043 - gm_iou: 0.0164 - iou_score_multiclass: 0.3581 - loss: 0.6077 - pixel_accuracy_multiclass: 0.9956 - wm_iou: 0.0285
# Epoch 38: val_iou_score_multiclass improved from 0.45287 to 0.45326, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 38: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 882ms/step - csf_iou: 0.3934 - dice_coefficient_multiclass: 0.4043 - gm_iou: 0.0164 - iou_score_multiclass: 0.3581 - loss: 0.6077 - pixel_accuracy_multiclass: 0.9956 - wm_iou: 0.0285 - val_csf_iou: 0.3047 - val_dice_coefficient_multiclass: 0.5761 - val_gm_iou: 0.2388 - val_iou_score_multiclass: 0.4533 - val_loss: 0.6711 - val_pixel_accuracy_multiclass: 0.8919 - val_wm_iou: 0.3113 - learning_rate: 1.0000e-04
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.3112 - dice_coefficient_multiclass: 0.5433 - gm_iou: 0.2283 - iou_score_multiclass: 0.4302 - loss: 0.7061 - pixel_accuracy_multiclass: 0.8905 - wm_iou: 0.2233
# Epoch 39: val_iou_score_multiclass improved from 0.45326 to 0.45969, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 39: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 965ms/step - csf_iou: 0.3084 - dice_coefficient_multiclass: 0.5454 - gm_iou: 0.2310 - iou_score_multiclass: 0.4323 - loss: 0.7011 - pixel_accuracy_multiclass: 0.8918 - wm_iou: 0.2293 - val_csf_iou: 0.3114 - val_dice_coefficient_multiclass: 0.5837 - val_gm_iou: 0.2441 - val_iou_score_multiclass: 0.4597 - val_loss: 0.6608 - val_pixel_accuracy_multiclass: 0.8934 - val_wm_iou: 0.3251 - learning_rate: 1.0000e-04
# Epoch 40/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - csf_iou: 0.3122 - dice_coefficient_multiclass: 0.3897 - gm_iou: 0.0196 - iou_score_multiclass: 0.3466 - loss: 0.6225 - pixel_accuracy_multiclass: 0.9947 - wm_iou: 0.0607
# Prediction after epoch 40
#
#
# Epoch 40: val_iou_score_multiclass did not improve from 0.45969
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 694ms/step - csf_iou: 0.3122 - dice_coefficient_multiclass: 0.3897 - gm_iou: 0.0196 - iou_score_multiclass: 0.3466 - loss: 0.6225 - pixel_accuracy_multiclass: 0.9947 - wm_iou: 0.0607 - val_csf_iou: 0.3107 - val_dice_coefficient_multiclass: 0.5838 - val_gm_iou: 0.2454 - val_iou_score_multiclass: 0.4596 - val_loss: 0.6632 - val_pixel_accuracy_multiclass: 0.8924 - val_wm_iou: 0.3251 - learning_rate: 1.0000e-04
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.3210 - dice_coefficient_multiclass: 0.5507 - gm_iou: 0.2330 - iou_score_multiclass: 0.4363 - loss: 0.6939 - pixel_accuracy_multiclass: 0.8926 - wm_iou: 0.2326
# Epoch 41: val_iou_score_multiclass improved from 0.45969 to 0.46530, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 41: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 942ms/step - csf_iou: 0.3208 - dice_coefficient_multiclass: 0.5530 - gm_iou: 0.2340 - iou_score_multiclass: 0.4388 - loss: 0.6881 - pixel_accuracy_multiclass: 0.8944 - wm_iou: 0.2384 - val_csf_iou: 0.3216 - val_dice_coefficient_multiclass: 0.5903 - val_gm_iou: 0.2493 - val_iou_score_multiclass: 0.4653 - val_loss: 0.6495 - val_pixel_accuracy_multiclass: 0.8952 - val_wm_iou: 0.3317 - learning_rate: 1.0000e-04
# Epoch 42/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - csf_iou: 0.3770 - dice_coefficient_multiclass: 0.4016 - gm_iou: 0.0100 - iou_score_multiclass: 0.3568 - loss: 0.6135 - pixel_accuracy_multiclass: 0.9940 - wm_iou: 0.0479
# Epoch 42: val_iou_score_multiclass improved from 0.46530 to 0.46550, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 42: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 886ms/step - csf_iou: 0.3770 - dice_coefficient_multiclass: 0.4016 - gm_iou: 0.0100 - iou_score_multiclass: 0.3568 - loss: 0.6135 - pixel_accuracy_multiclass: 0.9940 - wm_iou: 0.0479 - val_csf_iou: 0.3235 - val_dice_coefficient_multiclass: 0.5904 - val_gm_iou: 0.2489 - val_iou_score_multiclass: 0.4655 - val_loss: 0.6476 - val_pixel_accuracy_multiclass: 0.8960 - val_wm_iou: 0.3303 - learning_rate: 1.0000e-04
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.3254 - dice_coefficient_multiclass: 0.5548 - gm_iou: 0.2376 - iou_score_multiclass: 0.4398 - loss: 0.6877 - pixel_accuracy_multiclass: 0.8942 - wm_iou: 0.2370
# Epoch 43: val_iou_score_multiclass improved from 0.46550 to 0.47144, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 43: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 966ms/step - csf_iou: 0.3202 - dice_coefficient_multiclass: 0.5549 - gm_iou: 0.2380 - iou_score_multiclass: 0.4403 - loss: 0.6872 - pixel_accuracy_multiclass: 0.8949 - wm_iou: 0.2418 - val_csf_iou: 0.3260 - val_dice_coefficient_multiclass: 0.5972 - val_gm_iou: 0.2540 - val_iou_score_multiclass: 0.4714 - val_loss: 0.6413 - val_pixel_accuracy_multiclass: 0.8963 - val_wm_iou: 0.3471 - learning_rate: 1.0000e-04
# Epoch 44/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - csf_iou: 0.3636 - dice_coefficient_multiclass: 0.4044 - gm_iou: 0.0138 - iou_score_multiclass: 0.3594 - loss: 0.6096 - pixel_accuracy_multiclass: 0.9940 - wm_iou: 0.0679
# Epoch 44: val_iou_score_multiclass did not improve from 0.47144
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 671ms/step - csf_iou: 0.3636 - dice_coefficient_multiclass: 0.4044 - gm_iou: 0.0138 - iou_score_multiclass: 0.3594 - loss: 0.6096 - pixel_accuracy_multiclass: 0.9940 - wm_iou: 0.0679 - val_csf_iou: 0.3244 - val_dice_coefficient_multiclass: 0.5972 - val_gm_iou: 0.2550 - val_iou_score_multiclass: 0.4712 - val_loss: 0.6438 - val_pixel_accuracy_multiclass: 0.8954 - val_wm_iou: 0.3477 - learning_rate: 1.0000e-04
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.3396 - dice_coefficient_multiclass: 0.5658 - gm_iou: 0.2450 - iou_score_multiclass: 0.4490 - loss: 0.6686 - pixel_accuracy_multiclass: 0.8969 - wm_iou: 0.2508
# Epoch 45: val_iou_score_multiclass improved from 0.47144 to 0.47780, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 45: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - csf_iou: 0.3362 - dice_coefficient_multiclass: 0.5661 - gm_iou: 0.2452 - iou_score_multiclass: 0.4497 - loss: 0.6666 - pixel_accuracy_multiclass: 0.8981 - wm_iou: 0.2538 - val_csf_iou: 0.3418 - val_dice_coefficient_multiclass: 0.6040 - val_gm_iou: 0.2585 - val_iou_score_multiclass: 0.4778 - val_loss: 0.6236 - val_pixel_accuracy_multiclass: 0.9009 - val_wm_iou: 0.3488 - learning_rate: 1.0000e-04
# Epoch 46/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - csf_iou: 0.4609 - dice_coefficient_multiclass: 0.4348 - gm_iou: 0.0159 - iou_score_multiclass: 0.3896 - loss: 0.5762 - pixel_accuracy_multiclass: 0.9959 - wm_iou: 0.0874
# Epoch 46: val_iou_score_multiclass improved from 0.47780 to 0.47817, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 46: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 874ms/step - csf_iou: 0.4609 - dice_coefficient_multiclass: 0.4348 - gm_iou: 0.0159 - iou_score_multiclass: 0.3896 - loss: 0.5762 - pixel_accuracy_multiclass: 0.9959 - wm_iou: 0.0874 - val_csf_iou: 0.3418 - val_dice_coefficient_multiclass: 0.6045 - val_gm_iou: 0.2594 - val_iou_score_multiclass: 0.4782 - val_loss: 0.6238 - val_pixel_accuracy_multiclass: 0.9007 - val_wm_iou: 0.3496 - learning_rate: 1.0000e-04
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.3467 - dice_coefficient_multiclass: 0.5711 - gm_iou: 0.2499 - iou_score_multiclass: 0.4535 - loss: 0.6585 - pixel_accuracy_multiclass: 0.8993 - wm_iou: 0.2557
# Epoch 47: val_iou_score_multiclass improved from 0.47817 to 0.48400, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 47: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 963ms/step - csf_iou: 0.3434 - dice_coefficient_multiclass: 0.5721 - gm_iou: 0.2511 - iou_score_multiclass: 0.4549 - loss: 0.6559 - pixel_accuracy_multiclass: 0.9002 - wm_iou: 0.2604 - val_csf_iou: 0.3515 - val_dice_coefficient_multiclass: 0.6108 - val_gm_iou: 0.2621 - val_iou_score_multiclass: 0.4840 - val_loss: 0.6136 - val_pixel_accuracy_multiclass: 0.9026 - val_wm_iou: 0.3596 - learning_rate: 1.0000e-04
# Epoch 48/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - csf_iou: 0.3173 - dice_coefficient_multiclass: 0.4182 - gm_iou: 0.0330 - iou_score_multiclass: 0.3747 - loss: 0.5942 - pixel_accuracy_multiclass: 0.9949 - wm_iou: 0.1543
# Epoch 48: val_iou_score_multiclass improved from 0.48400 to 0.48403, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 48: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 870ms/step - csf_iou: 0.3173 - dice_coefficient_multiclass: 0.4182 - gm_iou: 0.0330 - iou_score_multiclass: 0.3747 - loss: 0.5942 - pixel_accuracy_multiclass: 0.9949 - wm_iou: 0.1543 - val_csf_iou: 0.3504 - val_dice_coefficient_multiclass: 0.6112 - val_gm_iou: 0.2647 - val_iou_score_multiclass: 0.4840 - val_loss: 0.6169 - val_pixel_accuracy_multiclass: 0.9011 - val_wm_iou: 0.3597 - learning_rate: 1.0000e-04
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.3491 - dice_coefficient_multiclass: 0.5746 - gm_iou: 0.2511 - iou_score_multiclass: 0.4563 - loss: 0.6556 - pixel_accuracy_multiclass: 0.8999 - wm_iou: 0.2643
# Epoch 49: val_iou_score_multiclass improved from 0.48403 to 0.48709, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 49: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 959ms/step - csf_iou: 0.3505 - dice_coefficient_multiclass: 0.5773 - gm_iou: 0.2536 - iou_score_multiclass: 0.4594 - loss: 0.6494 - pixel_accuracy_multiclass: 0.9014 - wm_iou: 0.2688 - val_csf_iou: 0.3560 - val_dice_coefficient_multiclass: 0.6141 - val_gm_iou: 0.2643 - val_iou_score_multiclass: 0.4871 - val_loss: 0.6059 - val_pixel_accuracy_multiclass: 0.9048 - val_wm_iou: 0.3636 - learning_rate: 1.0000e-04
# Epoch 50/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - csf_iou: 0.4830 - dice_coefficient_multiclass: 0.4607 - gm_iou: 0.0193 - iou_score_multiclass: 0.4170 - loss: 0.5486 - pixel_accuracy_multiclass: 0.9963 - wm_iou: 0.1705
# Prediction after epoch 50
#
#
# Epoch 50: val_iou_score_multiclass improved from 0.48709 to 0.48736, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 50: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 29s 895ms/step - csf_iou: 0.4830 - dice_coefficient_multiclass: 0.4607 - gm_iou: 0.0193 - iou_score_multiclass: 0.4170 - loss: 0.5486 - pixel_accuracy_multiclass: 0.9963 - wm_iou: 0.1705 - val_csf_iou: 0.3566 - val_dice_coefficient_multiclass: 0.6144 - val_gm_iou: 0.2650 - val_iou_score_multiclass: 0.4874 - val_loss: 0.6055 - val_pixel_accuracy_multiclass: 0.9048 - val_wm_iou: 0.3633 - learning_rate: 1.0000e-04
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.3598 - dice_coefficient_multiclass: 0.5779 - gm_iou: 0.2550 - iou_score_multiclass: 0.4601 - loss: 0.6470 - pixel_accuracy_multiclass: 0.9023 - wm_iou: 0.2626
# Epoch 51: val_iou_score_multiclass improved from 0.48736 to 0.49232, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 51: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 954ms/step - csf_iou: 0.3506 - dice_coefficient_multiclass: 0.5767 - gm_iou: 0.2550 - iou_score_multiclass: 0.4593 - loss: 0.6491 - pixel_accuracy_multiclass: 0.9024 - wm_iou: 0.2669 - val_csf_iou: 0.3576 - val_dice_coefficient_multiclass: 0.6200 - val_gm_iou: 0.2712 - val_iou_score_multiclass: 0.4923 - val_loss: 0.5983 - val_pixel_accuracy_multiclass: 0.9052 - val_wm_iou: 0.3765 - learning_rate: 1.0000e-04
# Epoch 52/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - csf_iou: 0.4701 - dice_coefficient_multiclass: 0.4688 - gm_iou: 0.0242 - iou_score_multiclass: 0.4249 - loss: 0.5395 - pixel_accuracy_multiclass: 0.9966 - wm_iou: 0.2100
# Epoch 52: val_iou_score_multiclass improved from 0.49232 to 0.49249, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 52: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 877ms/step - csf_iou: 0.4701 - dice_coefficient_multiclass: 0.4688 - gm_iou: 0.0242 - iou_score_multiclass: 0.4249 - loss: 0.5395 - pixel_accuracy_multiclass: 0.9966 - wm_iou: 0.2100 - val_csf_iou: 0.3560 - val_dice_coefficient_multiclass: 0.6204 - val_gm_iou: 0.2738 - val_iou_score_multiclass: 0.4925 - val_loss: 0.6015 - val_pixel_accuracy_multiclass: 0.9040 - val_wm_iou: 0.3775 - learning_rate: 1.0000e-04
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.3681 - dice_coefficient_multiclass: 0.5867 - gm_iou: 0.2630 - iou_score_multiclass: 0.4673 - loss: 0.6336 - pixel_accuracy_multiclass: 0.9038 - wm_iou: 0.2751
# Epoch 53: val_iou_score_multiclass improved from 0.49249 to 0.49659, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 53: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 54s 950ms/step - csf_iou: 0.3606 - dice_coefficient_multiclass: 0.5857 - gm_iou: 0.2627 - iou_score_multiclass: 0.4668 - loss: 0.6342 - pixel_accuracy_multiclass: 0.9044 - wm_iou: 0.2779 - val_csf_iou: 0.3674 - val_dice_coefficient_multiclass: 0.6245 - val_gm_iou: 0.2764 - val_iou_score_multiclass: 0.4966 - val_loss: 0.5890 - val_pixel_accuracy_multiclass: 0.9078 - val_wm_iou: 0.3765 - learning_rate: 1.0000e-04
# Epoch 54/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - csf_iou: 0.5062 - dice_coefficient_multiclass: 0.4984 - gm_iou: 0.0286 - iou_score_multiclass: 0.4544 - loss: 0.5111 - pixel_accuracy_multiclass: 0.9963 - wm_iou: 0.2876
# Epoch 54: val_iou_score_multiclass improved from 0.49659 to 0.49742, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 54: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 29s 893ms/step - csf_iou: 0.5062 - dice_coefficient_multiclass: 0.4984 - gm_iou: 0.0286 - iou_score_multiclass: 0.4544 - loss: 0.5111 - pixel_accuracy_multiclass: 0.9963 - wm_iou: 0.2876 - val_csf_iou: 0.3682 - val_dice_coefficient_multiclass: 0.6255 - val_gm_iou: 0.2783 - val_iou_score_multiclass: 0.4974 - val_loss: 0.5882 - val_pixel_accuracy_multiclass: 0.9075 - val_wm_iou: 0.3774 - learning_rate: 1.0000e-04
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.3730 - dice_coefficient_multiclass: 0.5904 - gm_iou: 0.2672 - iou_score_multiclass: 0.4706 - loss: 0.6271 - pixel_accuracy_multiclass: 0.9060 - wm_iou: 0.2776
# Epoch 55: val_iou_score_multiclass improved from 0.49742 to 0.49805, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 55: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 53s 953ms/step - csf_iou: 0.3656 - dice_coefficient_multiclass: 0.5896 - gm_iou: 0.2671 - iou_score_multiclass: 0.4702 - loss: 0.6290 - pixel_accuracy_multiclass: 0.9057 - wm_iou: 0.2813 - val_csf_iou: 0.3707 - val_dice_coefficient_multiclass: 0.6259 - val_gm_iou: 0.2740 - val_iou_score_multiclass: 0.4981 - val_loss: 0.5866 - val_pixel_accuracy_multiclass: 0.9085 - val_wm_iou: 0.3818 - learning_rate: 1.0000e-04
# Epoch 56/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - csf_iou: 0.4526 - dice_coefficient_multiclass: 0.5018 - gm_iou: 0.0411 - iou_score_multiclass: 0.4583 - loss: 0.5078 - pixel_accuracy_multiclass: 0.9962 - wm_iou: 0.3438
# Epoch 56: val_iou_score_multiclass improved from 0.49805 to 0.50029, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 56: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 879ms/step - csf_iou: 0.4526 - dice_coefficient_multiclass: 0.5018 - gm_iou: 0.0411 - iou_score_multiclass: 0.4583 - loss: 0.5078 - pixel_accuracy_multiclass: 0.9962 - wm_iou: 0.3438 - val_csf_iou: 0.3731 - val_dice_coefficient_multiclass: 0.6285 - val_gm_iou: 0.2780 - val_iou_score_multiclass: 0.5003 - val_loss: 0.5831 - val_pixel_accuracy_multiclass: 0.9085 - val_wm_iou: 0.3844 - learning_rate: 1.0000e-04
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - csf_iou: 0.3749 - dice_coefficient_multiclass: 0.5949 - gm_iou: 0.2708 - iou_score_multiclass: 0.4743 - loss: 0.6226 - pixel_accuracy_multiclass: 0.9064 - wm_iou: 0.2877
# Epoch 57: val_iou_score_multiclass did not improve from 0.50029
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 24s 749ms/step - csf_iou: 0.3700 - dice_coefficient_multiclass: 0.5942 - gm_iou: 0.2711 - iou_score_multiclass: 0.4741 - loss: 0.6233 - pixel_accuracy_multiclass: 0.9066 - wm_iou: 0.2890 - val_csf_iou: 0.3728 - val_dice_coefficient_multiclass: 0.6257 - val_gm_iou: 0.2751 - val_iou_score_multiclass: 0.4978 - val_loss: 0.5884 - val_pixel_accuracy_multiclass: 0.9092 - val_wm_iou: 0.3774 - learning_rate: 1.0000e-04
# Epoch 58/100
# ...
# Epoch 81/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - csf_iou: 0.4377 - dice_coefficient_multiclass: 0.6382 - gm_iou: 0.3234 - iou_score_multiclass: 0.5146 - loss: 0.5470 - pixel_accuracy_multiclass: 0.9209 - wm_iou: 0.3249
# Epoch 81: val_iou_score_multiclass improved from 0.53937 to 0.54036, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 81: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 939ms/step - csf_iou: 0.4275 - dice_coefficient_multiclass: 0.6366 - gm_iou: 0.3244 - iou_score_multiclass: 0.5136 - loss: 0.5507 - pixel_accuracy_multiclass: 0.9203 - wm_iou: 0.3279 - val_csf_iou: 0.4246 - val_dice_coefficient_multiclass: 0.6704 - val_gm_iou: 0.3333 - val_iou_score_multiclass: 0.5404 - val_loss: 0.5202 - val_pixel_accuracy_multiclass: 0.9200 - val_wm_iou: 0.4320 - learning_rate: 1.0000e-04
# Epoch 82/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - csf_iou: 0.5644 - dice_coefficient_multiclass: 0.6867 - gm_iou: 0.0542 - iou_score_multiclass: 0.6463 - loss: 0.3231 - pixel_accuracy_multiclass: 0.9963 - wm_iou: 0.9711
# Epoch 82: val_iou_score_multiclass did not improve from 0.54036
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 21s 669ms/step - csf_iou: 0.5644 - dice_coefficient_multiclass: 0.6867 - gm_iou: 0.0542 - iou_score_multiclass: 0.6463 - loss: 0.3231 - pixel_accuracy_multiclass: 0.9963 - wm_iou: 0.9711 - val_csf_iou: 0.4257 - val_dice_coefficient_multiclass: 0.6694 - val_gm_iou: 0.3322 - val_iou_score_multiclass: 0.5394 - val_loss: 0.5207 - val_pixel_accuracy_multiclass: 0.9203 - val_wm_iou: 0.4278 - learning_rate: 1.0000e-04
# Epoch 83/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - csf_iou: 0.4418 - dice_coefficient_multiclass: 0.6409 - gm_iou: 0.3292 - iou_score_multiclass: 0.5173 - loss: 0.5420 - pixel_accuracy_multiclass: 0.9217 - wm_iou: 0.3249
# Epoch 83: val_iou_score_multiclass improved from 0.54036 to 0.54246, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 83: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 935ms/step - csf_iou: 0.4314 - dice_coefficient_multiclass: 0.6395 - gm_iou: 0.3295 - iou_score_multiclass: 0.5163 - loss: 0.5463 - pixel_accuracy_multiclass: 0.9209 - wm_iou: 0.3295 - val_csf_iou: 0.4288 - val_dice_coefficient_multiclass: 0.6726 - val_gm_iou: 0.3362 - val_iou_score_multiclass: 0.5425 - val_loss: 0.5190 - val_pixel_accuracy_multiclass: 0.9200 - val_wm_iou: 0.4335 - learning_rate: 1.0000e-04
# Epoch 84/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - csf_iou: 0.5894 - dice_coefficient_multiclass: 0.6939 - gm_iou: 0.0589 - iou_score_multiclass: 0.6554 - loss: 0.3135 - pixel_accuracy_multiclass: 0.9970 - wm_iou: 0.9768
# Epoch 84: val_iou_score_multiclass did not improve from 0.54246
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 677ms/step - csf_iou: 0.5894 - dice_coefficient_multiclass: 0.6939 - gm_iou: 0.0589 - iou_score_multiclass: 0.6554 - loss: 0.3135 - pixel_accuracy_multiclass: 0.9970 - wm_iou: 0.9768 - val_csf_iou: 0.4302 - val_dice_coefficient_multiclass: 0.6717 - val_gm_iou: 0.3354 - val_iou_score_multiclass: 0.5416 - val_loss: 0.5198 - val_pixel_accuracy_multiclass: 0.9201 - val_wm_iou: 0.4294 - learning_rate: 1.0000e-04
# Epoch 85/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - csf_iou: 0.4443 - dice_coefficient_multiclass: 0.6436 - gm_iou: 0.3324 - iou_score_multiclass: 0.5197 - loss: 0.5387 - pixel_accuracy_multiclass: 0.9222 - wm_iou: 0.3288
# Epoch 85: val_iou_score_multiclass improved from 0.54246 to 0.54610, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 85: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 941ms/step - csf_iou: 0.4357 - dice_coefficient_multiclass: 0.6420 - gm_iou: 0.3313 - iou_score_multiclass: 0.5187 - loss: 0.5424 - pixel_accuracy_multiclass: 0.9218 - wm_iou: 0.3326 - val_csf_iou: 0.4292 - val_dice_coefficient_multiclass: 0.6761 - val_gm_iou: 0.3406 - val_iou_score_multiclass: 0.5461 - val_loss: 0.5117 - val_pixel_accuracy_multiclass: 0.9215 - val_wm_iou: 0.4423 - learning_rate: 1.0000e-04
# Epoch 86/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - csf_iou: 0.6207 - dice_coefficient_multiclass: 0.7018 - gm_iou: 0.0619 - iou_score_multiclass: 0.6651 - loss: 0.3054 - pixel_accuracy_multiclass: 0.9972 - wm_iou: 0.9807
# Epoch 86: val_iou_score_multiclass did not improve from 0.54610
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 676ms/step - csf_iou: 0.6207 - dice_coefficient_multiclass: 0.7018 - gm_iou: 0.0619 - iou_score_multiclass: 0.6651 - loss: 0.3054 - pixel_accuracy_multiclass: 0.9972 - wm_iou: 0.9807 - val_csf_iou: 0.4311 - val_dice_coefficient_multiclass: 0.6756 - val_gm_iou: 0.3406 - val_iou_score_multiclass: 0.5455 - val_loss: 0.5122 - val_pixel_accuracy_multiclass: 0.9214 - val_wm_iou: 0.4379 - learning_rate: 1.0000e-04
# Epoch 87/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - csf_iou: 0.4509 - dice_coefficient_multiclass: 0.6479 - gm_iou: 0.3400 - iou_score_multiclass: 0.5239 - loss: 0.5323 - pixel_accuracy_multiclass: 0.9233 - wm_iou: 0.3310
# Epoch 87: val_iou_score_multiclass improved from 0.54610 to 0.54793, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 87: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 31s 952ms/step - csf_iou: 0.4408 - dice_coefficient_multiclass: 0.6457 - gm_iou: 0.3379 - iou_score_multiclass: 0.5223 - loss: 0.5366 - pixel_accuracy_multiclass: 0.9226 - wm_iou: 0.3347 - val_csf_iou: 0.4332 - val_dice_coefficient_multiclass: 0.6778 - val_gm_iou: 0.3412 - val_iou_score_multiclass: 0.5479 - val_loss: 0.5085 - val_pixel_accuracy_multiclass: 0.9223 - val_wm_iou: 0.4444 - learning_rate: 1.0000e-04
# Epoch 88/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - csf_iou: 0.6224 - dice_coefficient_multiclass: 0.7020 - gm_iou: 0.0585 - iou_score_multiclass: 0.6653 - loss: 0.3055 - pixel_accuracy_multiclass: 0.9973 - wm_iou: 0.9836
# Epoch 88: val_iou_score_multiclass did not improve from 0.54793
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 677ms/step - csf_iou: 0.6224 - dice_coefficient_multiclass: 0.7020 - gm_iou: 0.0585 - iou_score_multiclass: 0.6653 - loss: 0.3055 - pixel_accuracy_multiclass: 0.9973 - wm_iou: 0.9836 - val_csf_iou: 0.4347 - val_dice_coefficient_multiclass: 0.6769 - val_gm_iou: 0.3402 - val_iou_score_multiclass: 0.5470 - val_loss: 0.5096 - val_pixel_accuracy_multiclass: 0.9224 - val_wm_iou: 0.4399 - learning_rate: 1.0000e-04
# Epoch 89/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - csf_iou: 0.4540 - dice_coefficient_multiclass: 0.6503 - gm_iou: 0.3407 - iou_score_multiclass: 0.5262 - loss: 0.5287 - pixel_accuracy_multiclass: 0.9240 - wm_iou: 0.3355
# Epoch 89: val_iou_score_multiclass improved from 0.54793 to 0.55038, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 89: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 939ms/step - csf_iou: 0.4428 - dice_coefficient_multiclass: 0.6478 - gm_iou: 0.3397 - iou_score_multiclass: 0.5243 - loss: 0.5337 - pixel_accuracy_multiclass: 0.9232 - wm_iou: 0.3384 - val_csf_iou: 0.4379 - val_dice_coefficient_multiclass: 0.6803 - val_gm_iou: 0.3440 - val_iou_score_multiclass: 0.5504 - val_loss: 0.5060 - val_pixel_accuracy_multiclass: 0.9227 - val_wm_iou: 0.4466 - learning_rate: 1.0000e-04
# Epoch 90/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - csf_iou: 0.6321 - dice_coefficient_multiclass: 0.7071 - gm_iou: 0.0667 - iou_score_multiclass: 0.6711 - loss: 0.2989 - pixel_accuracy_multiclass: 0.9977 - wm_iou: 0.9886
# Prediction after epoch 90
#
#
# Epoch 90: val_iou_score_multiclass did not improve from 0.55038
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 685ms/step - csf_iou: 0.6321 - dice_coefficient_multiclass: 0.7071 - gm_iou: 0.0667 - iou_score_multiclass: 0.6711 - loss: 0.2989 - pixel_accuracy_multiclass: 0.9977 - wm_iou: 0.9886 - val_csf_iou: 0.4394 - val_dice_coefficient_multiclass: 0.6798 - val_gm_iou: 0.3438 - val_iou_score_multiclass: 0.5498 - val_loss: 0.5065 - val_pixel_accuracy_multiclass: 0.9226 - val_wm_iou: 0.4431 - learning_rate: 1.0000e-04
# Epoch 91/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - csf_iou: 0.4592 - dice_coefficient_multiclass: 0.6529 - gm_iou: 0.3455 - iou_score_multiclass: 0.5289 - loss: 0.5242 - pixel_accuracy_multiclass: 0.9247 - wm_iou: 0.3359
# Epoch 91: val_iou_score_multiclass improved from 0.55038 to 0.55217, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 91: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 940ms/step - csf_iou: 0.4471 - dice_coefficient_multiclass: 0.6498 - gm_iou: 0.3435 - iou_score_multiclass: 0.5263 - loss: 0.5306 - pixel_accuracy_multiclass: 0.9237 - wm_iou: 0.3383 - val_csf_iou: 0.4394 - val_dice_coefficient_multiclass: 0.6820 - val_gm_iou: 0.3471 - val_iou_score_multiclass: 0.5522 - val_loss: 0.5029 - val_pixel_accuracy_multiclass: 0.9232 - val_wm_iou: 0.4486 - learning_rate: 1.0000e-04
# Epoch 92/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - csf_iou: 0.6146 - dice_coefficient_multiclass: 0.7006 - gm_iou: 0.0549 - iou_score_multiclass: 0.6634 - loss: 0.3104 - pixel_accuracy_multiclass: 0.9966 - wm_iou: 0.9879
# Epoch 92: val_iou_score_multiclass did not improve from 0.55217
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 670ms/step - csf_iou: 0.6146 - dice_coefficient_multiclass: 0.7006 - gm_iou: 0.0549 - iou_score_multiclass: 0.6634 - loss: 0.3104 - pixel_accuracy_multiclass: 0.9966 - wm_iou: 0.9879 - val_csf_iou: 0.4400 - val_dice_coefficient_multiclass: 0.6813 - val_gm_iou: 0.3465 - val_iou_score_multiclass: 0.5514 - val_loss: 0.5034 - val_pixel_accuracy_multiclass: 0.9234 - val_wm_iou: 0.4453 - learning_rate: 1.0000e-04
# Epoch 93/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - csf_iou: 0.4589 - dice_coefficient_multiclass: 0.6544 - gm_iou: 0.3484 - iou_score_multiclass: 0.5303 - loss: 0.5212 - pixel_accuracy_multiclass: 0.9253 - wm_iou: 0.3387
# Epoch 93: val_iou_score_multiclass improved from 0.55217 to 0.55433, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 93: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 937ms/step - csf_iou: 0.4490 - dice_coefficient_multiclass: 0.6521 - gm_iou: 0.3480 - iou_score_multiclass: 0.5286 - loss: 0.5268 - pixel_accuracy_multiclass: 0.9243 - wm_iou: 0.3406 - val_csf_iou: 0.4399 - val_dice_coefficient_multiclass: 0.6843 - val_gm_iou: 0.3495 - val_iou_score_multiclass: 0.5543 - val_loss: 0.5013 - val_pixel_accuracy_multiclass: 0.9232 - val_wm_iou: 0.4548 - learning_rate: 1.0000e-04
# Epoch 94/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - csf_iou: 0.6809 - dice_coefficient_multiclass: 0.7143 - gm_iou: 0.0593 - iou_score_multiclass: 0.6816 - loss: 0.2943 - pixel_accuracy_multiclass: 0.9975 - wm_iou: 0.9891
# Epoch 94: val_iou_score_multiclass did not improve from 0.55433
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 21s 650ms/step - csf_iou: 0.6809 - dice_coefficient_multiclass: 0.7143 - gm_iou: 0.0593 - iou_score_multiclass: 0.6816 - loss: 0.2943 - pixel_accuracy_multiclass: 0.9975 - wm_iou: 0.9891 - val_csf_iou: 0.4420 - val_dice_coefficient_multiclass: 0.6837 - val_gm_iou: 0.3489 - val_iou_score_multiclass: 0.5538 - val_loss: 0.5010 - val_pixel_accuracy_multiclass: 0.9235 - val_wm_iou: 0.4507 - learning_rate: 1.0000e-04
# Epoch 95/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - csf_iou: 0.4627 - dice_coefficient_multiclass: 0.6563 - gm_iou: 0.3503 - iou_score_multiclass: 0.5323 - loss: 0.5180 - pixel_accuracy_multiclass: 0.9260 - wm_iou: 0.3406
# Epoch 95: val_iou_score_multiclass improved from 0.55433 to 0.55464, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 95: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 949ms/step - csf_iou: 0.4506 - dice_coefficient_multiclass: 0.6530 - gm_iou: 0.3475 - iou_score_multiclass: 0.5294 - loss: 0.5246 - pixel_accuracy_multiclass: 0.9249 - wm_iou: 0.3426 - val_csf_iou: 0.4442 - val_dice_coefficient_multiclass: 0.6846 - val_gm_iou: 0.3507 - val_iou_score_multiclass: 0.5546 - val_loss: 0.4995 - val_pixel_accuracy_multiclass: 0.9238 - val_wm_iou: 0.4501 - learning_rate: 1.0000e-04
# Epoch 96/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - csf_iou: 0.6493 - dice_coefficient_multiclass: 0.7085 - gm_iou: 0.0566 - iou_score_multiclass: 0.6736 - loss: 0.2993 - pixel_accuracy_multiclass: 0.9973 - wm_iou: 0.9915
# Epoch 96: val_iou_score_multiclass did not improve from 0.55464
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 21s 664ms/step - csf_iou: 0.6493 - dice_coefficient_multiclass: 0.7085 - gm_iou: 0.0566 - iou_score_multiclass: 0.6736 - loss: 0.2993 - pixel_accuracy_multiclass: 0.9973 - wm_iou: 0.9915 - val_csf_iou: 0.4451 - val_dice_coefficient_multiclass: 0.6835 - val_gm_iou: 0.3496 - val_iou_score_multiclass: 0.5536 - val_loss: 0.5002 - val_pixel_accuracy_multiclass: 0.9239 - val_wm_iou: 0.4459 - learning_rate: 1.0000e-04
# Epoch 97/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - csf_iou: 0.4630 - dice_coefficient_multiclass: 0.6581 - gm_iou: 0.3538 - iou_score_multiclass: 0.5339 - loss: 0.5161 - pixel_accuracy_multiclass: 0.9264 - wm_iou: 0.3431
# Epoch 97: val_iou_score_multiclass improved from 0.55464 to 0.55663, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 97: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 926ms/step - csf_iou: 0.4537 - dice_coefficient_multiclass: 0.6548 - gm_iou: 0.3499 - iou_score_multiclass: 0.5313 - loss: 0.5225 - pixel_accuracy_multiclass: 0.9253 - wm_iou: 0.3444 - val_csf_iou: 0.4456 - val_dice_coefficient_multiclass: 0.6866 - val_gm_iou: 0.3551 - val_iou_score_multiclass: 0.5566 - val_loss: 0.4973 - val_pixel_accuracy_multiclass: 0.9243 - val_wm_iou: 0.4521 - learning_rate: 1.0000e-04
# Epoch 98/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - csf_iou: 0.6794 - dice_coefficient_multiclass: 0.7150 - gm_iou: 0.0599 - iou_score_multiclass: 0.6822 - loss: 0.2925 - pixel_accuracy_multiclass: 0.9976 - wm_iou: 0.9924
# Epoch 98: val_iou_score_multiclass did not improve from 0.55663
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 676ms/step - csf_iou: 0.6794 - dice_coefficient_multiclass: 0.7150 - gm_iou: 0.0599 - iou_score_multiclass: 0.6822 - loss: 0.2925 - pixel_accuracy_multiclass: 0.9976 - wm_iou: 0.9924 - val_csf_iou: 0.4469 - val_dice_coefficient_multiclass: 0.6853 - val_gm_iou: 0.3542 - val_iou_score_multiclass: 0.5554 - val_loss: 0.4985 - val_pixel_accuracy_multiclass: 0.9245 - val_wm_iou: 0.4464 - learning_rate: 1.0000e-04
# Epoch 99/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - csf_iou: 0.4695 - dice_coefficient_multiclass: 0.6613 - gm_iou: 0.3598 - iou_score_multiclass: 0.5372 - loss: 0.5115 - pixel_accuracy_multiclass: 0.9271 - wm_iou: 0.3433
# Epoch 99: val_iou_score_multiclass improved from 0.55663 to 0.55994, saving model to best_model_fcn8s_mrbrains.keras
#
# Epoch 99: finished saving model to best_model_fcn8s_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 940ms/step - csf_iou: 0.4577 - dice_coefficient_multiclass: 0.6575 - gm_iou: 0.3548 - iou_score_multiclass: 0.5340 - loss: 0.5188 - pixel_accuracy_multiclass: 0.9260 - wm_iou: 0.3458 - val_csf_iou: 0.4464 - val_dice_coefficient_multiclass: 0.6898 - val_gm_iou: 0.3587 - val_iou_score_multiclass: 0.5599 - val_loss: 0.4955 - val_pixel_accuracy_multiclass: 0.9240 - val_wm_iou: 0.4613 - learning_rate: 1.0000e-04
# Epoch 100/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - csf_iou: 0.6899 - dice_coefficient_multiclass: 0.7187 - gm_iou: 0.0651 - iou_score_multiclass: 0.6867 - loss: 0.2868 - pixel_accuracy_multiclass: 0.9979 - wm_iou: 0.9942
# Prediction after epoch 100
#
#
# Epoch 100: val_iou_score_multiclass did not improve from 0.55994
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 686ms/step - csf_iou: 0.6899 - dice_coefficient_multiclass: 0.7187 - gm_iou: 0.0651 - iou_score_multiclass: 0.6867 - loss: 0.2868 - pixel_accuracy_multiclass: 0.9979 - wm_iou: 0.9942 - val_csf_iou: 0.4488 - val_dice_coefficient_multiclass: 0.6892 - val_gm_iou: 0.3587 - val_iou_score_multiclass: 0.5592 - val_loss: 0.4964 - val_pixel_accuracy_multiclass: 0.9239 - val_wm_iou: 0.4564 - learning_rate: 1.0000e-04
#
# Training time: 49.5 min

# %% [markdown]
# ## 13. Training Graphs

# %%
H = history.history

fig, axes = plt.subplots(4, 2, figsize=(14, 20))
fig.suptitle('FCN-8s (Multi-Class)  |  MRBrainS18  |  Training History',
             fontsize=15, fontweight='bold', y=0.99)

plot_specs = [
    ('loss', 'val_loss', 'Loss (Dice + CCE)', 'Loss'),
    ('dice_coefficient_multiclass', 'val_dice_coefficient_multiclass', 'Dice (macro-avg)', 'Dice'),
    ('iou_score_multiclass', 'val_iou_score_multiclass', 'IoU (macro-avg)', 'IoU'),
    ('pixel_accuracy_multiclass', 'val_pixel_accuracy_multiclass', 'Pixel Accuracy', 'Accuracy'),
    ('csf_iou', 'val_csf_iou', 'CSF IoU', 'IoU'),
    ('gm_iou', 'val_gm_iou', 'Grey Matter IoU', 'IoU'),
    ('wm_iou', 'val_wm_iou', 'White Matter IoU', 'IoU'),
]

for ax, (tk, vk, title, ylabel) in zip(axes.flatten(), plot_specs):
    er = range(1, len(H[tk]) + 1)
    ax.plot(er, H[tk], label='Train', color='steelblue', linewidth=2)
    ax.plot(er, H[vk], label='Val', color='darkorange', linewidth=2, linestyle='--')
    ax.set_title(title, fontsize=12, fontweight='bold')
    ax.set_xlabel('Epoch'); ax.set_ylabel(ylabel)
    ax.legend(fontsize=10); ax.grid(True, alpha=0.3)

axes.flatten()[-1].axis('off')
plt.tight_layout()
plt.savefig('training_history_fcn8s_mrbrains.png', dpi=150, bbox_inches='tight')
plt.show()
print('Plot saved ✓')
# Out:
# Plot saved ✓

# %% [markdown]
# ## 14. Best & Average Metrics Table

# %%
metric_spec = [
    ('Loss', 'loss', 'min'),
    ('Dice (macro-avg)', 'dice_coefficient_multiclass', 'max'),
    ('IoU (macro-avg)', 'iou_score_multiclass', 'max'),
    ('Pixel Accuracy', 'pixel_accuracy_multiclass', 'max'),
    ('CSF IoU', 'csf_iou', 'max'),
    ('Grey Matter IoU', 'gm_iou', 'max'),
    ('White Matter IoU', 'wm_iou', 'max'),
]

rows = []
for disp, key, mode in metric_spec:
    tr = np.asarray(H[key], dtype=np.float64)
    va = np.asarray(H['val_' + key], dtype=np.float64)
    pick = np.min if mode == 'min' else np.max
    rows.append({'Metric': disp, 'Train Best': pick(tr), 'Train Avg': tr.mean(),
                 'Val Best': pick(va), 'Val Avg': va.mean()})

report = pd.DataFrame(rows).set_index('Metric').round(4)

print('=' * 68)
print('   BEST & AVERAGE METRICS  —  FCN-8s Multi-Class  |  MRBrainS18')
print('=' * 68)
print(report.to_string())
print('=' * 68)
best_epoch = int(np.argmax(H['val_iou_score_multiclass'])) + 1
print(f'\nBest Val IoU (macro-avg): {max(H["val_iou_score_multiclass"]):.4f}  (epoch {best_epoch})')
print(f'Best Val CSF IoU         : {max(H["val_csf_iou"]):.4f}')
print(f'Best Val Grey Matter IoU : {max(H["val_gm_iou"]):.4f}')
print(f'Best Val White Matter IoU: {max(H["val_wm_iou"]):.4f}')
report
# Out:
# ====================================================================
#    BEST & AVERAGE METRICS  —  FCN-8s Multi-Class  |  MRBrainS18
# ====================================================================
#                   Train Best  Train Avg  Val Best  Val Avg
# Metric
# Loss                  0.2868     0.6770    0.4955   0.7233
# Dice (macro-avg)      0.7187     0.5146    0.6898   0.5768
# IoU (macro-avg)       0.6867     0.4407    0.5599   0.4571
# Pixel Accuracy        0.9979     0.9226    0.9245   0.8770
# CSF IoU               0.6899     0.3494    0.4488   0.3156
# Grey Matter IoU       0.3548     0.1397    0.3587   0.2619
# White Matter IoU      0.9942     0.3306    0.4613   0.3223
# ====================================================================
#
# Best Val IoU (macro-avg): 0.5599  (epoch 99)
# Best Val CSF IoU         : 0.4488
# Best Val Grey Matter IoU : 0.3587
# Best Val White Matter IoU: 0.4613
#                   Train Best  Train Avg  Val Best  Val Avg
# Metric
# Loss                  0.2868     0.6770    0.4955   0.7233
# Dice (macro-avg)      0.7187     0.5146    0.6898   0.5768
# IoU (macro-avg)       0.6867     0.4407    0.5599   0.4571
# Pixel Accuracy        0.9979     0.9226    0.9245   0.8770
# CSF IoU               0.6899     0.3494    0.4488   0.3156
# Grey Matter IoU       0.3548     0.1397    0.3587   0.2619
# White Matter IoU      0.9942     0.3306    0.4613   0.3223

# %% [markdown]
# ## 15. Load Best Model & Final Evaluation

# %%
best_model = tf.keras.models.load_model(
    'best_model_fcn8s_mrbrains.keras',
    custom_objects={
        'combined_loss_multiclass': combined_loss_multiclass,
        'dice_coefficient_multiclass': dice_coefficient_multiclass,
        'iou_score_multiclass': iou_score_multiclass,
        'pixel_accuracy_multiclass': pixel_accuracy_multiclass,
        'csf_iou': csf_iou, 'gm_iou': gm_iou, 'wm_iou': wm_iou,
    }
)
print('Best model loaded ✓')
# Out:
# Best model loaded ✓

# %%
test_results = best_model.evaluate(test_dataset, verbose=1)
test_dict = dict(zip(best_model.metrics_names, test_results))

print('\n' + '=' * 60)
print('  FINAL TEST-SET METRICS  (FCN-8s | MRBrainS18)')
print('=' * 60)
for k, v in test_dict.items():
    print(f'  {k:35s}: {v:.4f}')
print('=' * 60)

pd.DataFrame([{
    'Model': 'FCN-8s (MRBrainS18)',
    'IoU (macro)': round(test_dict.get('iou_score_multiclass', float('nan')), 4),
    'Dice (macro)': round(test_dict.get('dice_coefficient_multiclass', float('nan')), 4),
    'CSF IoU': round(test_dict.get('csf_iou', float('nan')), 4),
    'GM IoU': round(test_dict.get('gm_iou', float('nan')), 4),
    'WM IoU': round(test_dict.get('wm_iou', float('nan')), 4),
    'Pixel Accuracy': round(test_dict.get('pixel_accuracy_multiclass', float('nan')), 4),
}]).set_index('Model')
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 276ms/step - csf_iou: 0.4488 - dice_coefficient_multiclass: 0.6813 - gm_iou: 0.3577 - iou_score_multiclass: 0.5528 - loss: 0.4946 - pixel_accuracy_multiclass: 0.9280 - wm_iou: 0.4298
#
# ============================================================
#   FINAL TEST-SET METRICS  (FCN-8s | MRBrainS18)
# ============================================================
#   loss                               : 0.4946
#   compile_metrics                    : 0.6813
# ============================================================
#                      IoU (macro)  Dice (macro)  CSF IoU  GM IoU  WM IoU  \
# Model
# FCN-8s (MRBrainS18)          NaN           NaN      NaN     NaN     NaN
#
#                      Pixel Accuracy
# Model
# FCN-8s (MRBrainS18)             NaN

# %% [markdown]
# ## 16. Test Predictions Visualization

# %%
show_predictions(test_dataset, num=5, model_to_use=best_model)

# %% [markdown]
# ## 17. Save Final Model

# %%
best_model.save('mrbrains_fcn8s_multiclass_final.keras')
print('Model saved ✓')
# Out:
# Model saved ✓
