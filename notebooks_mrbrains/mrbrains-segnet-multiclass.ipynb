# %% [markdown]
# # Brain MRI Tissue Segmentation — Multi-Class Semantic Segmentation
# ## SegNet | 4-Class (Background / CSF / Grey Matter / White Matter) | MRBrainS18 Dataset
#
# **Dataset:** MRBrainS18 Challenge Dataset — 7 labeled training subjects, multi-sequence MRI (T1, FLAIR, IR). Only the `training` split is used since the `test` split has no publicly released segmentation labels.
#
# **Label Remapping:** MRBrainS18 uses 9 classes which are consolidated into 4 tissue classes:
# - 0 → Background
# - 1, 2, 8 → Grey Matter (cortical GM + basal ganglia + brainstem/cerebellum)
# - 3, 4 → White Matter (WM + WM lesions)
# - 5, 6, 7 → CSF (ventricular CSF + vessels + external CSF)
#
# **Training Notes:**
# - Only 7 labeled subjects are available; therefore, every slice (`step=1`) is used to maximize the training dataset.
# - Strong data augmentation is applied to improve generalization.
# - EarlyStopping is disabled so the model trains for the full configured number of epochs.

# %% [markdown]
# ## 1. Import Libraries

# %%
import os
import cv2
import random
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import warnings
import tensorflow as tf
tf.config.optimizer.set_jit(False)
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import (
    Input, Conv2D, UpSampling2D, concatenate,
    BatchNormalization, Dropout, Activation
)
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Layer
from tensorflow.keras import callbacks
from sklearn.model_selection import train_test_split
from tqdm.auto import tqdm
import time
import datetime

# !pip install nibabel -q
import nibabel as nib

print('TensorFlow version:', tf.__version__)
print('GPUs available:', tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.20.0
# GPUs available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 2. Configuration

# %%
# ─── Paths ────────────────────────────────────────────────────────────────────
TRAIN_ROOT = '/kaggle/input/datasets/mahi789/trainingg/training'
# Note: test split excluded — no public segmentation labels available

PROCESSED_DIR  = 'mrbrains_processed'
IMAGE_FOLDER   = os.path.join(PROCESSED_DIR, 'images')
MASK_FOLDER    = os.path.join(PROCESSED_DIR, 'masks')
TRAIN_IMG_DIR  = os.path.join(PROCESSED_DIR, 'train', 'images')
TRAIN_MASK_DIR = os.path.join(PROCESSED_DIR, 'train', 'masks')
TEST_IMG_DIR   = os.path.join(PROCESSED_DIR, 'test',  'images')
TEST_MASK_DIR  = os.path.join(PROCESSED_DIR, 'test',  'masks')

# ─── Hyperparameters ──────────────────────────────────────────────────────────
IMG_SIZE    = (224, 224)
BATCH_SIZE  = 8    # smaller batch — fewer total slices than OASIS/IBSR
EPOCHS      = 100
SEED        = 42
TEST_SPLIT  = 0.20  # slightly larger test split given small dataset
NUM_CLASSES = 4
CLASS_NAMES = ['Background', 'CSF', 'Grey Matter', 'White Matter']

# ─── MRBrainS18 label remapping ───────────────────────────────────────────────
# Original 9 classes → 4 standard tissue classes (matches OASIS-1 and IBSR)
MRBRAINS_REMAP = {
    0: 0,  # Background
    1: 2,  # Cortical Grey Matter → GM
    2: 2,  # Basal Ganglia → GM
    3: 3,  # White Matter → WM
    4: 3,  # White Matter Lesions → WM
    5: 1,  # Ventricular CSF → CSF
    6: 1,  # Vessels/Choroid Plexus → CSF
    7: 1,  # External CSF/Sulci → CSF
    8: 2,  # Brainstem + Cerebellum → GM
}

print('Config set ✓')
print('Label remapping:', MRBRAINS_REMAP)
# Out:
# Config set ✓
# Label remapping: {0: 0, 1: 2, 2: 2, 3: 3, 4: 3, 5: 1, 6: 1, 7: 1, 8: 2}

# %% [markdown]
# ## 3. Extract 2D Slices — Remap 9 Classes to 4

# %%
for d in [IMAGE_FOLDER, MASK_FOLDER,
          TRAIN_IMG_DIR, TRAIN_MASK_DIR,
          TEST_IMG_DIR,  TEST_MASK_DIR]:
    os.makedirs(d, exist_ok=True)

print('Directories ready ✓')
# Out:
# Directories ready ✓

# %%
import os
import shutil
import cv2
import nibabel as nib
import numpy as np
from tqdm import tqdm


def normalize_slice(arr):
    mn, mx = arr.min(), arr.max()
    if mx - mn == 0:
        return np.zeros_like(arr, dtype=np.uint8)
    return ((arr - mn) / (mx - mn) * 255).astype(np.uint8)


def remap_labels(seg_arr, remap_dict):
    """Remap integer label array using a dictionary mapping."""
    out = np.zeros_like(seg_arr, dtype=np.uint8)
    for orig_label, new_label in remap_dict.items():
        out[seg_arr == orig_label] = new_label
    return out


def extract_slices_mrbrains(subject_dir, subject_name, img_out, mask_out, step=1):
    """
    Extract aligned T1 and segmentation slices from MRBrainS18.

    Uses reg_T1.nii because it is already registered to segm.nii.
    Both volumes have shape (240, 240, 48).
    """

    # Candidate paths for registered T1
    t1_candidates = [
        os.path.join(subject_dir, "orig", "reg_T1.nii"),
        os.path.join(subject_dir, "orig", "reg_T1.nii.gz"),
        os.path.join(subject_dir, "pre", "reg_T1.nii"),
        os.path.join(subject_dir, "pre", "reg_T1.nii.gz"),
    ]

    t1_path = None
    for p in t1_candidates:
        if os.path.exists(p):
            t1_path = p
            break

    # Segmentation
    seg_candidates = [
        os.path.join(subject_dir, "segm.nii"),
        os.path.join(subject_dir, "segm.nii.gz"),
    ]

    seg_path = None
    for p in seg_candidates:
        if os.path.exists(p):
            seg_path = p
            break

    if t1_path is None or seg_path is None:
        print(f"Skipping {subject_name} (missing reg_T1 or segm)")
        return 0

    # Load volumes
    brain_vol = np.squeeze(nib.load(t1_path).get_fdata())
    seg_vol = np.squeeze(nib.load(seg_path).get_fdata())

    print(f"{subject_name}")
    print(f"  T1 : {brain_vol.shape}")
    print(f"  Seg: {seg_vol.shape}")

    # Safety check
    if brain_vol.shape != seg_vol.shape:
        print(f"Shape mismatch in {subject_name}, skipping.")
        return 0

    saved = 0

    for i in range(0, brain_vol.shape[2], step):

        brain_slice = brain_vol[:, :, i]
        seg_slice = seg_vol[:, :, i]

        # Skip completely empty MRI slices
        if np.max(brain_slice) == 0:
            continue

        img_arr = normalize_slice(brain_slice)

        mask_arr = remap_labels(
            np.round(seg_slice).astype(np.uint8),
            MRBRAINS_REMAP
        )

        filename = f"{subject_name}_sl{i:03d}.png"

        cv2.imwrite(
            os.path.join(img_out, filename),
            img_arr
        )

        cv2.imwrite(
            os.path.join(mask_out, filename),
            mask_arr
        )

        saved += 1

    return saved


# ---------------------------------------------------------
# Remove previous extracted dataset
# ---------------------------------------------------------

for folder in [IMAGE_FOLDER, MASK_FOLDER]:
    if os.path.exists(folder):
        shutil.rmtree(folder)
    os.makedirs(folder, exist_ok=True)


# ---------------------------------------------------------
# Extract slices from all training subjects
# ---------------------------------------------------------

subject_folders = sorted([
    d for d in os.listdir(TRAIN_ROOT)
    if os.path.isdir(os.path.join(TRAIN_ROOT, d))
])

print(f"Found {len(subject_folders)} training subjects:")
print(subject_folders)
print()

total_slices = 0

for subj_name in tqdm(subject_folders, desc="Extracting slices"):

    subj_dir = os.path.join(TRAIN_ROOT, subj_name)

    total_slices += extract_slices_mrbrains(
        subj_dir,
        subj_name,
        IMAGE_FOLDER,
        MASK_FOLDER,
        step=1
    )

print("\nExtraction Complete!")
print(f"Total slices extracted : {total_slices}")
print(f"Images saved           : {len(os.listdir(IMAGE_FOLDER))}")
print(f"Masks saved            : {len(os.listdir(MASK_FOLDER))}")
# Out:
# Found 7 training subjects:
# ['1', '14', '27', '29', '4', '5', '7']
# Extracting slices:   0%|          | 0/7 [00:00<?, ?it/s]
# 1
#   T1 : (240, 240, 48)
#   Seg: (240, 240, 48)
# Extracting slices:  14%|█▍        | 1/7 [00:00<00:00,  8.57it/s]
# 14
#   T1 : (240, 240, 48)
#   Seg: (240, 240, 48)
# Extracting slices:  29%|██▊       | 2/7 [00:00<00:00,  8.36it/s]
# 27
#   T1 : (240, 240, 48)
#   Seg: (240, 240, 48)
# Extracting slices:  43%|████▎     | 3/7 [00:00<00:00,  8.11it/s]
# 29
#   T1 : (240, 240, 48)
#   Seg: (240, 240, 48)
# Extracting slices:  57%|█████▋    | 4/7 [00:00<00:00,  7.97it/s]
# 4
#   T1 : (240, 240, 48)
#   Seg: (240, 240, 48)
# Extracting slices:  71%|███████▏  | 5/7 [00:00<00:00,  7.94it/s]
# 5
#   T1 : (240, 240, 48)
#   Seg: (240, 240, 48)
# Extracting slices:  86%|████████▌ | 6/7 [00:00<00:00,  8.07it/s]
# 7
#   T1 : (240, 240, 48)
#   Seg: (240, 240, 48)
# Extracting slices: 100%|██████████| 7/7 [00:00<00:00,  8.09it/s]
# Extraction Complete!
# Total slices extracted : 336
# Images saved           : 336
# Masks saved            : 336

# %% [markdown]
# ## 4. Verify Label Remapping & Visualize

# %%
sample_mask_files = random.sample(os.listdir(MASK_FOLDER), min(20, len(os.listdir(MASK_FOLDER))))
all_vals = set()
for f in sample_mask_files:
    m = cv2.imread(os.path.join(MASK_FOLDER, f), cv2.IMREAD_GRAYSCALE)
    all_vals.update(np.unique(m).tolist())

print('Unique label values found across sample masks:', sorted(all_vals))
print('Expected: [0, 1, 2, 3]  (Background, CSF, Grey Matter, White Matter)')
# Out:
# Unique label values found across sample masks: [0, 1, 2, 3]
# Expected: [0, 1, 2, 3]  (Background, CSF, Grey Matter, White Matter)

# %%
CLASS_COLORS = ['black', 'cyan', 'orange', 'magenta']
cmap_classes = mcolors.ListedColormap(CLASS_COLORS)

def visualize_sample(image_name):
    img  = cv2.imread(os.path.join(IMAGE_FOLDER, image_name), cv2.IMREAD_GRAYSCALE)
    mask = cv2.imread(os.path.join(MASK_FOLDER,  image_name), cv2.IMREAD_GRAYSCALE)

    fig, axes = plt.subplots(1, 2, figsize=(12, 6))
    axes[0].imshow(img, cmap='gray')
    axes[0].set_title('Brain MRI Slice (T1)', fontsize=13)

    im = axes[1].imshow(mask, cmap=cmap_classes, vmin=0, vmax=NUM_CLASSES - 1)
    axes[1].set_title('Tissue Labels (CSF / GM / WM)', fontsize=13)
    cbar = plt.colorbar(im, ax=axes[1], ticks=range(NUM_CLASSES))
    cbar.ax.set_yticklabels(CLASS_NAMES)

    for ax in axes: ax.axis('off')
    plt.suptitle(image_name, fontsize=10, color='gray')
    plt.tight_layout()
    plt.show()


all_images = os.listdir(IMAGE_FOLDER)
for _ in range(4):
    visualize_sample(random.choice(all_images))

# %% [markdown]
# ## 5. Train / Test Split

# %%
images = sorted([f for f in os.listdir(IMAGE_FOLDER) if f.endswith('.png')])
masks  = sorted([f for f in os.listdir(MASK_FOLDER)  if f.endswith('.png')])

assert images == masks, 'Image-mask mismatch!'

train_imgs, test_imgs = train_test_split(images, test_size=TEST_SPLIT, random_state=SEED)
print(f'Train: {len(train_imgs)}  |  Test: {len(test_imgs)}')

def copy_files(file_list, src_img, src_mask, dst_img, dst_mask):
    for f in tqdm(file_list, leave=False):
        shutil.copy(os.path.join(src_img,  f), os.path.join(dst_img,  f))
        shutil.copy(os.path.join(src_mask, f), os.path.join(dst_mask, f))

copy_files(train_imgs, IMAGE_FOLDER, MASK_FOLDER, TRAIN_IMG_DIR, TRAIN_MASK_DIR)
copy_files(test_imgs,  IMAGE_FOLDER, MASK_FOLDER, TEST_IMG_DIR,  TEST_MASK_DIR)
print('Files copied ✓')
# Out:
# Train: 268  |  Test: 68
# Files copied ✓

# %% [markdown]
# ## 6. tf.data Pipeline — with stronger augmentation (small dataset)

# %%
def load_image(img_path, mask_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE, method='bilinear')
    img = tf.cast(img, tf.float32) / 255.0

    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=1)
    mask = tf.image.resize(mask, IMG_SIZE, method='nearest')
    mask = tf.cast(mask, tf.int32)
    mask = tf.squeeze(mask, axis=-1)
    mask = tf.one_hot(mask, depth=NUM_CLASSES)
    mask = tf.cast(mask, tf.float32)
    return img, mask


def augment(img, mask):
    # Stronger augmentation since dataset is small (7 subjects)
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_left_right(img)
        mask = tf.image.flip_left_right(mask)
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_up_down(img)
        mask = tf.image.flip_up_down(mask)
    img = tf.image.random_brightness(img, max_delta=0.1)
    img = tf.image.random_contrast(img, lower=0.9, upper=1.1)
    img = tf.clip_by_value(img, 0.0, 1.0)
    return img, mask


def build_dataset(img_dir, mask_dir, augment_data=False, batch=BATCH_SIZE):
    img_files  = sorted([os.path.join(img_dir,  f) for f in os.listdir(img_dir)  if f.endswith('.png')])
    mask_files = sorted([os.path.join(mask_dir, f) for f in os.listdir(mask_dir) if f.endswith('.png')])
    ds = tf.data.Dataset.from_tensor_slices((img_files, mask_files))
    ds = ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
    if augment_data:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch).prefetch(tf.data.AUTOTUNE)
    return ds


train_dataset = build_dataset(TRAIN_IMG_DIR, TRAIN_MASK_DIR, augment_data=True)
test_dataset  = build_dataset(TEST_IMG_DIR,  TEST_MASK_DIR,  augment_data=False)

print('Datasets ready ✓')
for imgs, masks in train_dataset.take(1):
    print('Batch shapes → images:', imgs.shape, ' masks:', masks.shape)
# Out:
# Datasets ready ✓
# Batch shapes → images: (8, 224, 224, 3)  masks: (8, 224, 224, 4)

# %% [markdown]
# ## 7. Model — SegNet (pooling-index unpooling), 4-class softmax output
# **No skip connections** — uses stored max-pooling indices for unpooling. Built from scratch (no pretrained weights).

# %%
class MaxPoolingWithIndices(Layer):
    def call(self, x):
        pooled, indices = tf.nn.max_pool_with_argmax(
            x, ksize=2, strides=2, padding='SAME', include_batch_in_index=True)
        return pooled, indices

class MaxUnpooling(Layer):
    def __init__(self, h, w, c, **kwargs):
        super().__init__(**kwargs)
        self.h=h; self.w=w; self.c=c
    def call(self, inputs):
        x, indices = inputs
        batch_size = tf.shape(x)[0]
        flat_x = tf.reshape(x, [-1])
        flat_indices = tf.reshape(indices, [-1, 1])
        flat_out = tf.scatter_nd(flat_indices, flat_x, [batch_size*self.h*self.w*self.c])
        return tf.reshape(flat_out, [batch_size, self.h, self.w, self.c])
    def get_config(self):
        cfg=super().get_config(); cfg.update({'h':self.h,'w':self.w,'c':self.c}); return cfg

def conv_bn_relu(x, filters, name_prefix, n=1):
    for i in range(n):
        x=Conv2D(filters,(3,3),padding='same',name=f'{name_prefix}_c{i+1}')(x)
        x=BatchNormalization(name=f'{name_prefix}_bn{i+1}')(x)
        x=Activation('relu',name=f'{name_prefix}_act{i+1}')(x)
    return x

def build_model(input_shape=(224,224,3), num_classes=4):
    inputs=Input(shape=input_shape,name='input')
    pool_layer=MaxPoolingWithIndices()
    e1=conv_bn_relu(inputs,64,'enc1',n=2); h1,w1,c1=e1.shape[1],e1.shape[2],e1.shape[3]; p1,idx1=pool_layer(e1)
    e2=conv_bn_relu(p1,128,'enc2',n=2); h2,w2,c2=e2.shape[1],e2.shape[2],e2.shape[3]; p2,idx2=pool_layer(e2)
    e3=conv_bn_relu(p2,256,'enc3',n=3); h3,w3,c3=e3.shape[1],e3.shape[2],e3.shape[3]; p3,idx3=pool_layer(e3)
    e4=conv_bn_relu(p3,512,'enc4',n=3); h4,w4,c4=e4.shape[1],e4.shape[2],e4.shape[3]; p4,idx4=pool_layer(e4)
    e5=conv_bn_relu(p4,512,'enc5',n=3); h5,w5,c5=e5.shape[1],e5.shape[2],e5.shape[3]; p5,idx5=pool_layer(e5)
    x=Dropout(0.3,name='bottleneck_drop')(p5)
    d5=MaxUnpooling(h5,w5,c5,name='unpool5')([x,idx5]); d5=conv_bn_relu(d5,512,'dec5',n=3)
    d4=MaxUnpooling(h4,w4,c4,name='unpool4')([d5,idx4]); d4=conv_bn_relu(d4,256,'dec4',n=3)
    d3=MaxUnpooling(h3,w3,c3,name='unpool3')([d4,idx3]); d3=conv_bn_relu(d3,128,'dec3',n=3)
    d2=MaxUnpooling(h2,w2,c2,name='unpool2')([d3,idx2]); d2=conv_bn_relu(d2,64,'dec2',n=2)
    d1=MaxUnpooling(h1,w1,c1,name='unpool1')([d2,idx1]); d1=conv_bn_relu(d1,64,'dec1',n=2)
    output=Conv2D(num_classes,(1,1),activation='softmax',name='output')(d1)
    return Model(inputs=inputs,outputs=output,name='SegNet_MultiClass_MRBrainS18')

model=build_model(input_shape=(*IMG_SIZE,3),num_classes=NUM_CLASSES)
print('Model built')
print(f'Total parameters     : {model.count_params():,}')
print(f'Trainable parameters : {sum([K.count_params(w) for w in model.trainable_weights]):,}')
# Out:
# Model built
# Total parameters     : 24,957,892
# Trainable parameters : 24,943,556

# %% [markdown]
# ## 8. Custom Metrics & Loss

# %%
def dice_coefficient_multiclass(y_true, y_pred, smooth=1.0):
    y_true_f = K.reshape(y_true, [-1, NUM_CLASSES])
    y_pred_f = K.reshape(y_pred, [-1, NUM_CLASSES])
    intersection = K.sum(y_true_f * y_pred_f, axis=0)
    union = K.sum(y_true_f, axis=0) + K.sum(y_pred_f, axis=0)
    return K.mean((2.0 * intersection + smooth) / (union + smooth))

def dice_loss_multiclass(y_true, y_pred):
    return 1.0 - dice_coefficient_multiclass(y_true, y_pred)

def iou_score_multiclass(y_true, y_pred, smooth=1.0):
    y_true_f = K.reshape(y_true, [-1, NUM_CLASSES])
    y_pred_f = K.reshape(y_pred, [-1, NUM_CLASSES])
    intersection = K.sum(y_true_f * y_pred_f, axis=0)
    total = K.sum(y_true_f, axis=0) + K.sum(y_pred_f, axis=0) - intersection
    return K.mean((intersection + smooth) / (total + smooth))

def csf_iou(y_true, y_pred, smooth=1.0):
    t = y_true[..., 1]; p = y_pred[..., 1]
    i = K.sum(t * p)
    return (i + smooth) / (K.sum(t) + K.sum(p) - i + smooth)

def gm_iou(y_true, y_pred, smooth=1.0):
    t = y_true[..., 2]; p = y_pred[..., 2]
    i = K.sum(t * p)
    return (i + smooth) / (K.sum(t) + K.sum(p) - i + smooth)

def wm_iou(y_true, y_pred, smooth=1.0):
    t = y_true[..., 3]; p = y_pred[..., 3]
    i = K.sum(t * p)
    return (i + smooth) / (K.sum(t) + K.sum(p) - i + smooth)

def pixel_accuracy_multiclass(y_true, y_pred):
    return K.mean(K.cast(K.equal(K.argmax(y_true, axis=-1), K.argmax(y_pred, axis=-1)), K.floatx()))

def combined_loss_multiclass(y_true, y_pred):
    return dice_loss_multiclass(y_true, y_pred) + tf.keras.losses.categorical_crossentropy(y_true, y_pred)


model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=combined_loss_multiclass,
    metrics=[dice_coefficient_multiclass, iou_score_multiclass,
             pixel_accuracy_multiclass, csf_iou, gm_iou, wm_iou],
      jit_compile=False
)
print('Model compiled ✓')
# Out:
# Model compiled ✓

# %% [markdown]
# ## 9. Model Summary

# %%
model.summary()
try:
    tf.keras.utils.plot_model(model, to_file='segnet_mrbrains_architecture.png',
                               show_shapes=True, show_layer_names=True, dpi=64)
    print('Architecture diagram saved ✓')
except Exception as e:
    print('Architecture plot skipped:', str(e)[:100])
# Out:
# Model: "SegNet_MultiClass_MRBrainS18"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 224, 224,  │          0 │ -                 │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc1_c1 (Conv2D)    │ (None, 224, 224,  │      1,792 │ input[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc1_bn1            │ (None, 224, 224,  │        256 │ enc1_c1[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc1_act1           │ (None, 224, 224,  │          0 │ enc1_bn1[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc1_c2 (Conv2D)    │ (None, 224, 224,  │     36,928 │ enc1_act1[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc1_bn2            │ (None, 224, 224,  │        256 │ enc1_c2[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc1_act2           │ (None, 224, 224,  │          0 │ enc1_bn2[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling_with_i… │ [(None, 7, 7,     │          0 │ enc1_act2[0][0],  │
# │ (MaxPoolingWithInd… │ 512), (None, 7,   │            │ enc2_act2[0][0],  │
# │                     │ 7, 512)]          │            │ enc3_act3[0][0],  │
# │                     │                   │            │ enc4_act3[0][0],  │
# │                     │                   │            │ enc5_act3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc2_c1 (Conv2D)    │ (None, 112, 112,  │     73,856 │ max_pooling_with… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc2_bn1            │ (None, 112, 112,  │        512 │ enc2_c1[0][0]     │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc2_act1           │ (None, 112, 112,  │          0 │ enc2_bn1[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc2_c2 (Conv2D)    │ (None, 112, 112,  │    147,584 │ enc2_act1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc2_bn2            │ (None, 112, 112,  │        512 │ enc2_c2[0][0]     │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc2_act2           │ (None, 112, 112,  │          0 │ enc2_bn2[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc3_c1 (Conv2D)    │ (None, 56, 56,    │    295,168 │ max_pooling_with… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc3_bn1            │ (None, 56, 56,    │      1,024 │ enc3_c1[0][0]     │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc3_act1           │ (None, 56, 56,    │          0 │ enc3_bn1[0][0]    │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc3_c2 (Conv2D)    │ (None, 56, 56,    │    590,080 │ enc3_act1[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc3_bn2            │ (None, 56, 56,    │      1,024 │ enc3_c2[0][0]     │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc3_act2           │ (None, 56, 56,    │          0 │ enc3_bn2[0][0]    │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc3_c3 (Conv2D)    │ (None, 56, 56,    │    590,080 │ enc3_act2[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc3_bn3            │ (None, 56, 56,    │      1,024 │ enc3_c3[0][0]     │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc3_act3           │ (None, 56, 56,    │          0 │ enc3_bn3[0][0]    │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc4_c1 (Conv2D)    │ (None, 28, 28,    │  1,180,160 │ max_pooling_with… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc4_bn1            │ (None, 28, 28,    │      2,048 │ enc4_c1[0][0]     │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc4_act1           │ (None, 28, 28,    │          0 │ enc4_bn1[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc4_c2 (Conv2D)    │ (None, 28, 28,    │  2,359,808 │ enc4_act1[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc4_bn2            │ (None, 28, 28,    │      2,048 │ enc4_c2[0][0]     │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc4_act2           │ (None, 28, 28,    │          0 │ enc4_bn2[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc4_c3 (Conv2D)    │ (None, 28, 28,    │  2,359,808 │ enc4_act2[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc4_bn3            │ (None, 28, 28,    │      2,048 │ enc4_c3[0][0]     │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc4_act3           │ (None, 28, 28,    │          0 │ enc4_bn3[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc5_c1 (Conv2D)    │ (None, 14, 14,    │  2,359,808 │ max_pooling_with… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc5_bn1            │ (None, 14, 14,    │      2,048 │ enc5_c1[0][0]     │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc5_act1           │ (None, 14, 14,    │          0 │ enc5_bn1[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc5_c2 (Conv2D)    │ (None, 14, 14,    │  2,359,808 │ enc5_act1[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc5_bn2            │ (None, 14, 14,    │      2,048 │ enc5_c2[0][0]     │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc5_act2           │ (None, 14, 14,    │          0 │ enc5_bn2[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc5_c3 (Conv2D)    │ (None, 14, 14,    │  2,359,808 │ enc5_act2[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc5_bn3            │ (None, 14, 14,    │      2,048 │ enc5_c3[0][0]     │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc5_act3           │ (None, 14, 14,    │          0 │ enc5_bn3[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bottleneck_drop     │ (None, 7, 7, 512) │          0 │ max_pooling_with… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ unpool5             │ (None, 14, 14,    │          0 │ bottleneck_drop[… │
# │ (MaxUnpooling)      │ 512)              │            │ max_pooling_with… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec5_c1 (Conv2D)    │ (None, 14, 14,    │  2,359,808 │ unpool5[0][0]     │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec5_bn1            │ (None, 14, 14,    │      2,048 │ dec5_c1[0][0]     │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec5_act1           │ (None, 14, 14,    │          0 │ dec5_bn1[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec5_c2 (Conv2D)    │ (None, 14, 14,    │  2,359,808 │ dec5_act1[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec5_bn2            │ (None, 14, 14,    │      2,048 │ dec5_c2[0][0]     │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec5_act2           │ (None, 14, 14,    │          0 │ dec5_bn2[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec5_c3 (Conv2D)    │ (None, 14, 14,    │  2,359,808 │ dec5_act2[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec5_bn3            │ (None, 14, 14,    │      2,048 │ dec5_c3[0][0]     │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec5_act3           │ (None, 14, 14,    │          0 │ dec5_bn3[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ unpool4             │ (None, 28, 28,    │          0 │ dec5_act3[0][0],  │
# │ (MaxUnpooling)      │ 512)              │            │ max_pooling_with… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_c1 (Conv2D)    │ (None, 28, 28,    │  1,179,904 │ unpool4[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_bn1            │ (None, 28, 28,    │      1,024 │ dec4_c1[0][0]     │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_act1           │ (None, 28, 28,    │          0 │ dec4_bn1[0][0]    │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_c2 (Conv2D)    │ (None, 28, 28,    │    590,080 │ dec4_act1[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_bn2            │ (None, 28, 28,    │      1,024 │ dec4_c2[0][0]     │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_act2           │ (None, 28, 28,    │          0 │ dec4_bn2[0][0]    │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_c3 (Conv2D)    │ (None, 28, 28,    │    590,080 │ dec4_act2[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_bn3            │ (None, 28, 28,    │      1,024 │ dec4_c3[0][0]     │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_act3           │ (None, 28, 28,    │          0 │ dec4_bn3[0][0]    │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ unpool3             │ (None, 56, 56,    │          0 │ dec4_act3[0][0],  │
# │ (MaxUnpooling)      │ 256)              │            │ max_pooling_with… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_c1 (Conv2D)    │ (None, 56, 56,    │    295,040 │ unpool3[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_bn1            │ (None, 56, 56,    │        512 │ dec3_c1[0][0]     │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_act1           │ (None, 56, 56,    │          0 │ dec3_bn1[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_c2 (Conv2D)    │ (None, 56, 56,    │    147,584 │ dec3_act1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_bn2            │ (None, 56, 56,    │        512 │ dec3_c2[0][0]     │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_act2           │ (None, 56, 56,    │          0 │ dec3_bn2[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_c3 (Conv2D)    │ (None, 56, 56,    │    147,584 │ dec3_act2[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_bn3            │ (None, 56, 56,    │        512 │ dec3_c3[0][0]     │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_act3           │ (None, 56, 56,    │          0 │ dec3_bn3[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ unpool2             │ (None, 112, 112,  │          0 │ dec3_act3[0][0],  │
# │ (MaxUnpooling)      │ 128)              │            │ max_pooling_with… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_c1 (Conv2D)    │ (None, 112, 112,  │     73,792 │ unpool2[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_bn1            │ (None, 112, 112,  │        256 │ dec2_c1[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_act1           │ (None, 112, 112,  │          0 │ dec2_bn1[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_c2 (Conv2D)    │ (None, 112, 112,  │     36,928 │ dec2_act1[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_bn2            │ (None, 112, 112,  │        256 │ dec2_c2[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_act2           │ (None, 112, 112,  │          0 │ dec2_bn2[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ unpool1             │ (None, 224, 224,  │          0 │ dec2_act2[0][0],  │
# │ (MaxUnpooling)      │ 64)               │            │ max_pooling_with… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_c1 (Conv2D)    │ (None, 224, 224,  │     36,928 │ unpool1[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_bn1            │ (None, 224, 224,  │        256 │ dec1_c1[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_act1           │ (None, 224, 224,  │          0 │ dec1_bn1[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_c2 (Conv2D)    │ (None, 224, 224,  │     36,928 │ dec1_act1[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_bn2            │ (None, 224, 224,  │        256 │ dec1_c2[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_act2           │ (None, 224, 224,  │          0 │ dec1_bn2[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Conv2D)     │ (None, 224, 224,  │        260 │ dec1_act2[0][0]   │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,957,892 (95.21 MB)
#  Trainable params: 24,943,556 (95.15 MB)
#  Non-trainable params: 14,336 (56.00 KB)
# Architecture diagram saved ✓

# %% [markdown]
# ## 10. Callbacks (EarlyStopping disabled)

# %%
def decode_mask(onehot_mask):
    return tf.argmax(onehot_mask, axis=-1)

def colorize_mask(label_map):
    colors = np.array([[0,0,0],[0,255,255],[255,165,0],[255,0,255]], dtype=np.uint8)
    return colors[np.array(label_map).astype(int)]

def show_predictions(dataset, num=3, model_to_use=None):
    m = model_to_use or model
    for imgs, masks in dataset.take(1):
        preds = m.predict(imgs, verbose=0)
        for i in range(min(num, len(imgs))):
            fig, axes = plt.subplots(1, 3, figsize=(13, 4))
            axes[0].imshow(imgs[i].numpy());                              axes[0].set_title('Input MRI')
            axes[1].imshow(colorize_mask(decode_mask(masks[i]).numpy())); axes[1].set_title('Ground Truth')
            axes[2].imshow(colorize_mask(decode_mask(preds[i]).numpy())); axes[2].set_title('Prediction')
            for ax in axes: ax.axis('off')
            plt.tight_layout(); plt.show()

class DisplayCallback(callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % 10 == 0:
            show_predictions(test_dataset, num=2)
            print(f'Prediction after epoch {epoch + 1}\n')

logdir = os.path.join('logs', datetime.datetime.now().strftime('%Y%m%d-%H%M%S'))

callbacks_list = [
    DisplayCallback(),
    callbacks.TensorBoard(logdir, histogram_freq=1),
    callbacks.ModelCheckpoint('best_model_segnet_mrbrains.keras', verbose=1,
                               save_best_only=True, monitor='val_iou_score_multiclass', mode='max'),
    callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-7, verbose=1),
    # EarlyStopping intentionally removed
]
print('Callbacks ready ✓ (no EarlyStopping — will run all', EPOCHS, 'epochs)')
# Out:
# Callbacks ready ✓ (no EarlyStopping — will run all 100 epochs)

# %% [markdown]
# ## 11. Initial Predictions (before training)

# %%
print('Predictions before training:')
show_predictions(test_dataset, num=2)
# Out:
# Predictions before training:

# %% [markdown]
# ## 12. Training

# %%
steps_per_epoch  = max(1, len(os.listdir(TRAIN_IMG_DIR)) // BATCH_SIZE)
validation_steps = max(1, len(os.listdir(TEST_IMG_DIR))  // BATCH_SIZE)

print(f'Steps per epoch  : {steps_per_epoch}')
print(f'Validation steps : {validation_steps}')

start_time = time.time()
history = model.fit(
    train_dataset, validation_data=test_dataset, epochs=EPOCHS,
    steps_per_epoch=steps_per_epoch, validation_steps=validation_steps,
    callbacks=callbacks_list
)
print(f'\nTraining time: {(time.time()-start_time)/60:.1f} min')
# Out:
# Steps per epoch  : 33
# Validation steps : 8
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - csf_iou: 0.0684 - dice_coefficient_multiclass: 0.1992 - gm_iou: 0.0573 - iou_score_multiclass: 0.1233 - loss: 2.1444 - pixel_accuracy_multiclass: 0.4762 - wm_iou: 0.0440
# Epoch 1: val_iou_score_multiclass improved from None to 0.10601, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 1: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 41s 516ms/step - csf_iou: 0.0756 - dice_coefficient_multiclass: 0.2387 - gm_iou: 0.0733 - iou_score_multiclass: 0.1562 - loss: 1.8886 - pixel_accuracy_multiclass: 0.6432 - wm_iou: 0.0535 - val_csf_iou: 0.0613 - val_dice_coefficient_multiclass: 0.1800 - val_gm_iou: 0.0557 - val_iou_score_multiclass: 0.1060 - val_loss: 2.1129 - val_pixel_accuracy_multiclass: 0.8079 - val_wm_iou: 0.0416 - learning_rate: 1.0000e-04
# Epoch 2/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - csf_iou: 0.0105 - dice_coefficient_multiclass: 0.1805 - gm_iou: 2.6064e-04 - iou_score_multiclass: 0.1375 - loss: 2.0036 - pixel_accuracy_multiclass: 0.8369 - wm_iou: 3.1126e-05
# Epoch 2: val_iou_score_multiclass improved from 0.10601 to 0.10642, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 2: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 215ms/step - csf_iou: 0.0105 - dice_coefficient_multiclass: 0.1805 - gm_iou: 2.6064e-04 - iou_score_multiclass: 0.1375 - loss: 2.0036 - pixel_accuracy_multiclass: 0.8369 - wm_iou: 3.1126e-05 - val_csf_iou: 0.0613 - val_dice_coefficient_multiclass: 0.1805 - val_gm_iou: 0.0557 - val_iou_score_multiclass: 0.1064 - val_loss: 2.1075 - val_pixel_accuracy_multiclass: 0.8079 - val_wm_iou: 0.0416 - learning_rate: 1.0000e-04
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.0945 - dice_coefficient_multiclass: 0.3142 - gm_iou: 0.1068 - iou_score_multiclass: 0.2249 - loss: 1.4502 - pixel_accuracy_multiclass: 0.8084 - wm_iou: 0.0706
# Epoch 3: val_iou_score_multiclass improved from 0.10642 to 0.12776, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 3: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 452ms/step - csf_iou: 0.1002 - dice_coefficient_multiclass: 0.3281 - gm_iou: 0.1110 - iou_score_multiclass: 0.2380 - loss: 1.3690 - pixel_accuracy_multiclass: 0.8202 - wm_iou: 0.0803 - val_csf_iou: 0.0601 - val_dice_coefficient_multiclass: 0.2050 - val_gm_iou: 0.0551 - val_iou_score_multiclass: 0.1278 - val_loss: 1.8636 - val_pixel_accuracy_multiclass: 0.8079 - val_wm_iou: 0.0410 - learning_rate: 1.0000e-04
# Epoch 4/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - csf_iou: 0.0142 - dice_coefficient_multiclass: 0.2012 - gm_iou: 3.3278e-04 - iou_score_multiclass: 0.1622 - loss: 1.8644 - pixel_accuracy_multiclass: 0.8051 - wm_iou: 4.0122e-05
# Epoch 4: val_iou_score_multiclass improved from 0.12776 to 0.12831, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 4: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 217ms/step - csf_iou: 0.0142 - dice_coefficient_multiclass: 0.2012 - gm_iou: 3.3278e-04 - iou_score_multiclass: 0.1622 - loss: 1.8644 - pixel_accuracy_multiclass: 0.8051 - wm_iou: 4.0122e-05 - val_csf_iou: 0.0601 - val_dice_coefficient_multiclass: 0.2055 - val_gm_iou: 0.0550 - val_iou_score_multiclass: 0.1283 - val_loss: 1.8582 - val_pixel_accuracy_multiclass: 0.8079 - val_wm_iou: 0.0409 - learning_rate: 1.0000e-04
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.1142 - dice_coefficient_multiclass: 0.3563 - gm_iou: 0.1242 - iou_score_multiclass: 0.2645 - loss: 1.2217 - pixel_accuracy_multiclass: 0.8381 - wm_iou: 0.0968
# Epoch 5: val_iou_score_multiclass improved from 0.12831 to 0.15150, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 5: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 456ms/step - csf_iou: 0.1198 - dice_coefficient_multiclass: 0.3672 - gm_iou: 0.1285 - iou_score_multiclass: 0.2739 - loss: 1.1774 - pixel_accuracy_multiclass: 0.8449 - wm_iou: 0.1081 - val_csf_iou: 0.0576 - val_dice_coefficient_multiclass: 0.2280 - val_gm_iou: 0.0532 - val_iou_score_multiclass: 0.1515 - val_loss: 1.6581 - val_pixel_accuracy_multiclass: 0.8079 - val_wm_iou: 0.0401 - learning_rate: 1.0000e-04
# Epoch 6/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - csf_iou: 0.0183 - dice_coefficient_multiclass: 0.2077 - gm_iou: 3.7013e-04 - iou_score_multiclass: 0.1694 - loss: 1.6146 - pixel_accuracy_multiclass: 0.8712 - wm_iou: 4.3270e-05
# Epoch 6: val_iou_score_multiclass improved from 0.15150 to 0.15200, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 6: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 221ms/step - csf_iou: 0.0183 - dice_coefficient_multiclass: 0.2077 - gm_iou: 3.7013e-04 - iou_score_multiclass: 0.1694 - loss: 1.6146 - pixel_accuracy_multiclass: 0.8712 - wm_iou: 4.3270e-05 - val_csf_iou: 0.0576 - val_dice_coefficient_multiclass: 0.2285 - val_gm_iou: 0.0532 - val_iou_score_multiclass: 0.1520 - val_loss: 1.6543 - val_pixel_accuracy_multiclass: 0.8079 - val_wm_iou: 0.0401 - learning_rate: 1.0000e-04
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.1403 - dice_coefficient_multiclass: 0.3952 - gm_iou: 0.1439 - iou_score_multiclass: 0.2986 - loss: 1.0721 - pixel_accuracy_multiclass: 0.8615 - wm_iou: 0.1303
# Epoch 7: val_iou_score_multiclass improved from 0.15200 to 0.17349, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 7: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 453ms/step - csf_iou: 0.1502 - dice_coefficient_multiclass: 0.4058 - gm_iou: 0.1470 - iou_score_multiclass: 0.3072 - loss: 1.0404 - pixel_accuracy_multiclass: 0.8686 - wm_iou: 0.1418 - val_csf_iou: 0.0537 - val_dice_coefficient_multiclass: 0.2456 - val_gm_iou: 0.0498 - val_iou_score_multiclass: 0.1735 - val_loss: 1.5140 - val_pixel_accuracy_multiclass: 0.8079 - val_wm_iou: 0.0391 - learning_rate: 1.0000e-04
# Epoch 8/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - csf_iou: 0.0207 - dice_coefficient_multiclass: 0.2145 - gm_iou: 3.3781e-04 - iou_score_multiclass: 0.1779 - loss: 1.4920 - pixel_accuracy_multiclass: 0.8812 - wm_iou: 4.8835e-05
# Epoch 8: val_iou_score_multiclass improved from 0.17349 to 0.17392, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 8: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 222ms/step - csf_iou: 0.0207 - dice_coefficient_multiclass: 0.2145 - gm_iou: 3.3781e-04 - iou_score_multiclass: 0.1779 - loss: 1.4920 - pixel_accuracy_multiclass: 0.8812 - wm_iou: 4.8835e-05 - val_csf_iou: 0.0537 - val_dice_coefficient_multiclass: 0.2460 - val_gm_iou: 0.0498 - val_iou_score_multiclass: 0.1739 - val_loss: 1.5116 - val_pixel_accuracy_multiclass: 0.8079 - val_wm_iou: 0.0392 - learning_rate: 1.0000e-04
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.1760 - dice_coefficient_multiclass: 0.4268 - gm_iou: 0.1564 - iou_score_multiclass: 0.3248 - loss: 0.9887 - pixel_accuracy_multiclass: 0.8736 - wm_iou: 0.1582
# Epoch 9: val_iou_score_multiclass improved from 0.17392 to 0.18870, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 9: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 457ms/step - csf_iou: 0.1917 - dice_coefficient_multiclass: 0.4415 - gm_iou: 0.1619 - iou_score_multiclass: 0.3369 - loss: 0.9510 - pixel_accuracy_multiclass: 0.8834 - wm_iou: 0.1756 - val_csf_iou: 0.0500 - val_dice_coefficient_multiclass: 0.2550 - val_gm_iou: 0.0451 - val_iou_score_multiclass: 0.1887 - val_loss: 1.4404 - val_pixel_accuracy_multiclass: 0.8079 - val_wm_iou: 0.0371 - learning_rate: 1.0000e-04
# Epoch 10/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - csf_iou: 0.0241 - dice_coefficient_multiclass: 0.2255 - gm_iou: 7.2319e-04 - iou_score_multiclass: 0.1923 - loss: 1.4110 - pixel_accuracy_multiclass: 0.9261 - wm_iou: 6.3164e-05
# Prediction after epoch 10
#
#
# Epoch 10: val_iou_score_multiclass improved from 0.18870 to 0.18883, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 10: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 244ms/step - csf_iou: 0.0241 - dice_coefficient_multiclass: 0.2255 - gm_iou: 7.2319e-04 - iou_score_multiclass: 0.1923 - loss: 1.4110 - pixel_accuracy_multiclass: 0.9261 - wm_iou: 6.3164e-05 - val_csf_iou: 0.0499 - val_dice_coefficient_multiclass: 0.2551 - val_gm_iou: 0.0450 - val_iou_score_multiclass: 0.1888 - val_loss: 1.4399 - val_pixel_accuracy_multiclass: 0.8079 - val_wm_iou: 0.0371 - learning_rate: 1.0000e-04
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.2270 - dice_coefficient_multiclass: 0.4701 - gm_iou: 0.1820 - iou_score_multiclass: 0.3617 - loss: 0.8787 - pixel_accuracy_multiclass: 0.8987 - wm_iou: 0.2005
# Epoch 11: val_iou_score_multiclass improved from 0.18883 to 0.19779, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 11: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 454ms/step - csf_iou: 0.2398 - dice_coefficient_multiclass: 0.4820 - gm_iou: 0.1895 - iou_score_multiclass: 0.3715 - loss: 0.8530 - pixel_accuracy_multiclass: 0.9035 - wm_iou: 0.2132 - val_csf_iou: 0.0457 - val_dice_coefficient_multiclass: 0.2582 - val_gm_iou: 0.0391 - val_iou_score_multiclass: 0.1978 - val_loss: 1.4143 - val_pixel_accuracy_multiclass: 0.8079 - val_wm_iou: 0.0345 - learning_rate: 1.0000e-04
# Epoch 12/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - csf_iou: 0.0278 - dice_coefficient_multiclass: 0.2284 - gm_iou: 3.3446e-04 - iou_score_multiclass: 0.1952 - loss: 1.2543 - pixel_accuracy_multiclass: 0.9607 - wm_iou: 6.2655e-05
# Epoch 12: val_iou_score_multiclass improved from 0.19779 to 0.19790, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 12: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 217ms/step - csf_iou: 0.0278 - dice_coefficient_multiclass: 0.2284 - gm_iou: 3.3446e-04 - iou_score_multiclass: 0.1952 - loss: 1.2543 - pixel_accuracy_multiclass: 0.9607 - wm_iou: 6.2655e-05 - val_csf_iou: 0.0456 - val_dice_coefficient_multiclass: 0.2582 - val_gm_iou: 0.0391 - val_iou_score_multiclass: 0.1979 - val_loss: 1.4142 - val_pixel_accuracy_multiclass: 0.8079 - val_wm_iou: 0.0345 - learning_rate: 1.0000e-04
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.2628 - dice_coefficient_multiclass: 0.5031 - gm_iou: 0.2129 - iou_score_multiclass: 0.3902 - loss: 0.8133 - pixel_accuracy_multiclass: 0.9092 - wm_iou: 0.2277
# Epoch 13: val_iou_score_multiclass improved from 0.19790 to 0.20376, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 13: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 455ms/step - csf_iou: 0.2754 - dice_coefficient_multiclass: 0.5143 - gm_iou: 0.2208 - iou_score_multiclass: 0.3998 - loss: 0.7868 - pixel_accuracy_multiclass: 0.9148 - wm_iou: 0.2407 - val_csf_iou: 0.0414 - val_dice_coefficient_multiclass: 0.2586 - val_gm_iou: 0.0333 - val_iou_score_multiclass: 0.2038 - val_loss: 1.4122 - val_pixel_accuracy_multiclass: 0.8079 - val_wm_iou: 0.0317 - learning_rate: 1.0000e-04
# Epoch 14/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - csf_iou: 0.0294 - dice_coefficient_multiclass: 0.2346 - gm_iou: 9.3951e-04 - iou_score_multiclass: 0.2039 - loss: 1.1979 - pixel_accuracy_multiclass: 0.9633 - wm_iou: 7.4264e-05
# Epoch 14: val_iou_score_multiclass improved from 0.20376 to 0.20386, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 14: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 219ms/step - csf_iou: 0.0294 - dice_coefficient_multiclass: 0.2346 - gm_iou: 9.3951e-04 - iou_score_multiclass: 0.2039 - loss: 1.1979 - pixel_accuracy_multiclass: 0.9633 - wm_iou: 7.4264e-05 - val_csf_iou: 0.0412 - val_dice_coefficient_multiclass: 0.2586 - val_gm_iou: 0.0331 - val_iou_score_multiclass: 0.2039 - val_loss: 1.4126 - val_pixel_accuracy_multiclass: 0.8079 - val_wm_iou: 0.0316 - learning_rate: 1.0000e-04
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.2928 - dice_coefficient_multiclass: 0.5298 - gm_iou: 0.2422 - iou_score_multiclass: 0.4141 - loss: 0.7553 - pixel_accuracy_multiclass: 0.9185 - wm_iou: 0.2500
# Epoch 15: val_iou_score_multiclass improved from 0.20386 to 0.20632, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 15: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 452ms/step - csf_iou: 0.2994 - dice_coefficient_multiclass: 0.5361 - gm_iou: 0.2458 - iou_score_multiclass: 0.4196 - loss: 0.7438 - pixel_accuracy_multiclass: 0.9192 - wm_iou: 0.2576 - val_csf_iou: 0.0352 - val_dice_coefficient_multiclass: 0.2550 - val_gm_iou: 0.0260 - val_iou_score_multiclass: 0.2063 - val_loss: 1.4388 - val_pixel_accuracy_multiclass: 0.8079 - val_wm_iou: 0.0276 - learning_rate: 1.0000e-04
# Epoch 16/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - csf_iou: 0.0472 - dice_coefficient_multiclass: 0.2476 - gm_iou: 2.2557e-04 - iou_score_multiclass: 0.2164 - loss: 1.2632 - pixel_accuracy_multiclass: 0.9474 - wm_iou: 8.6034e-05
# Epoch 16: val_iou_score_multiclass did not improve from 0.20632
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 168ms/step - csf_iou: 0.0472 - dice_coefficient_multiclass: 0.2476 - gm_iou: 2.2557e-04 - iou_score_multiclass: 0.2164 - loss: 1.2632 - pixel_accuracy_multiclass: 0.9474 - wm_iou: 8.6034e-05 - val_csf_iou: 0.0347 - val_dice_coefficient_multiclass: 0.2540 - val_gm_iou: 0.0252 - val_iou_score_multiclass: 0.2059 - val_loss: 1.4451 - val_pixel_accuracy_multiclass: 0.8079 - val_wm_iou: 0.0263 - learning_rate: 1.0000e-04
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - csf_iou: 0.2635 - dice_coefficient_multiclass: 0.5095 - gm_iou: 0.2291 - iou_score_multiclass: 0.3959 - loss: 0.8534 - pixel_accuracy_multiclass: 0.8916 - wm_iou: 0.2248
# Epoch 17: val_iou_score_multiclass improved from 0.20632 to 0.21415, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 17: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 453ms/step - csf_iou: 0.2751 - dice_coefficient_multiclass: 0.5179 - gm_iou: 0.2296 - iou_score_multiclass: 0.4032 - loss: 0.8211 - pixel_accuracy_multiclass: 0.8974 - wm_iou: 0.2384 - val_csf_iou: 0.0668 - val_dice_coefficient_multiclass: 0.2711 - val_gm_iou: 0.0351 - val_iou_score_multiclass: 0.2142 - val_loss: 1.4067 - val_pixel_accuracy_multiclass: 0.8152 - val_wm_iou: 0.0257 - learning_rate: 1.0000e-04
# Epoch 18/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - csf_iou: 0.0515 - dice_coefficient_multiclass: 0.2503 - gm_iou: 4.4936e-04 - iou_score_multiclass: 0.2185 - loss: 1.2327 - pixel_accuracy_multiclass: 0.9526 - wm_iou: 9.5285e-05
# Epoch 18: val_iou_score_multiclass did not improve from 0.21415
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - csf_iou: 0.0515 - dice_coefficient_multiclass: 0.2503 - gm_iou: 4.4936e-04 - iou_score_multiclass: 0.2185 - loss: 1.2327 - pixel_accuracy_multiclass: 0.9526 - wm_iou: 9.5285e-05 - val_csf_iou: 0.0658 - val_dice_coefficient_multiclass: 0.2707 - val_gm_iou: 0.0352 - val_iou_score_multiclass: 0.2139 - val_loss: 1.4078 - val_pixel_accuracy_multiclass: 0.8150 - val_wm_iou: 0.0256 - learning_rate: 1.0000e-04
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.3145 - dice_coefficient_multiclass: 0.5484 - gm_iou: 0.2606 - iou_score_multiclass: 0.4314 - loss: 0.7159 - pixel_accuracy_multiclass: 0.9204 - wm_iou: 0.2619
# Epoch 19: val_iou_score_multiclass did not improve from 0.21415
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 13s 402ms/step - csf_iou: 0.3272 - dice_coefficient_multiclass: 0.5585 - gm_iou: 0.2689 - iou_score_multiclass: 0.4405 - loss: 0.6960 - pixel_accuracy_multiclass: 0.9240 - wm_iou: 0.2734 - val_csf_iou: 0.0329 - val_dice_coefficient_multiclass: 0.2524 - val_gm_iou: 0.0206 - val_iou_score_multiclass: 0.2078 - val_loss: 1.4772 - val_pixel_accuracy_multiclass: 0.8085 - val_wm_iou: 0.0238 - learning_rate: 1.0000e-04
# Epoch 20/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - csf_iou: 0.0531 - dice_coefficient_multiclass: 0.2550 - gm_iou: 0.0016 - iou_score_multiclass: 0.2250 - loss: 1.1270 - pixel_accuracy_multiclass: 0.9741 - wm_iou: 1.0792e-04
# Prediction after epoch 20
#
#
# Epoch 20: val_iou_score_multiclass did not improve from 0.21415
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 187ms/step - csf_iou: 0.0531 - dice_coefficient_multiclass: 0.2550 - gm_iou: 0.0016 - iou_score_multiclass: 0.2250 - loss: 1.1270 - pixel_accuracy_multiclass: 0.9741 - wm_iou: 1.0792e-04 - val_csf_iou: 0.0348 - val_dice_coefficient_multiclass: 0.2544 - val_gm_iou: 0.0213 - val_iou_score_multiclass: 0.2092 - val_loss: 1.4729 - val_pixel_accuracy_multiclass: 0.8088 - val_wm_iou: 0.0246 - learning_rate: 1.0000e-04
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - csf_iou: 0.3580 - dice_coefficient_multiclass: 0.5790 - gm_iou: 0.2955 - iou_score_multiclass: 0.4599 - loss: 0.6576 - pixel_accuracy_multiclass: 0.9297 - wm_iou: 0.2862
# Epoch 21: val_iou_score_multiclass improved from 0.21415 to 0.22468, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 21: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 454ms/step - csf_iou: 0.3678 - dice_coefficient_multiclass: 0.5867 - gm_iou: 0.3003 - iou_score_multiclass: 0.4668 - loss: 0.6436 - pixel_accuracy_multiclass: 0.9314 - wm_iou: 0.2967 - val_csf_iou: 0.0462 - val_dice_coefficient_multiclass: 0.2763 - val_gm_iou: 0.0334 - val_iou_score_multiclass: 0.2247 - val_loss: 1.4186 - val_pixel_accuracy_multiclass: 0.8137 - val_wm_iou: 0.0419 - learning_rate: 1.0000e-04
# Epoch 22/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - csf_iou: 0.0688 - dice_coefficient_multiclass: 0.2624 - gm_iou: 2.6244e-04 - iou_score_multiclass: 0.2305 - loss: 1.0319 - pixel_accuracy_multiclass: 0.9839 - wm_iou: 1.0859e-04
# Epoch 22: val_iou_score_multiclass improved from 0.22468 to 0.23102, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 22: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 221ms/step - csf_iou: 0.0688 - dice_coefficient_multiclass: 0.2624 - gm_iou: 2.6244e-04 - iou_score_multiclass: 0.2305 - loss: 1.0319 - pixel_accuracy_multiclass: 0.9839 - wm_iou: 1.0859e-04 - val_csf_iou: 0.0516 - val_dice_coefficient_multiclass: 0.2859 - val_gm_iou: 0.0396 - val_iou_score_multiclass: 0.2310 - val_loss: 1.3938 - val_pixel_accuracy_multiclass: 0.8167 - val_wm_iou: 0.0501 - learning_rate: 1.0000e-04
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - csf_iou: 0.3970 - dice_coefficient_multiclass: 0.6036 - gm_iou: 0.3293 - iou_score_multiclass: 0.4833 - loss: 0.6108 - pixel_accuracy_multiclass: 0.9375 - wm_iou: 0.2985
# Epoch 23: val_iou_score_multiclass improved from 0.23102 to 0.31553, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 23: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 452ms/step - csf_iou: 0.4042 - dice_coefficient_multiclass: 0.6109 - gm_iou: 0.3321 - iou_score_multiclass: 0.4904 - loss: 0.5991 - pixel_accuracy_multiclass: 0.9385 - wm_iou: 0.3128 - val_csf_iou: 0.1317 - val_dice_coefficient_multiclass: 0.4123 - val_gm_iou: 0.1255 - val_iou_score_multiclass: 0.3155 - val_loss: 1.0794 - val_pixel_accuracy_multiclass: 0.8535 - val_wm_iou: 0.1689 - learning_rate: 1.0000e-04
# Epoch 24/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - csf_iou: 0.0717 - dice_coefficient_multiclass: 0.2655 - gm_iou: 0.0010 - iou_score_multiclass: 0.2339 - loss: 0.9933 - pixel_accuracy_multiclass: 0.9893 - wm_iou: 1.1465e-04
# Epoch 24: val_iou_score_multiclass improved from 0.31553 to 0.32289, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 24: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 222ms/step - csf_iou: 0.0717 - dice_coefficient_multiclass: 0.2655 - gm_iou: 0.0010 - iou_score_multiclass: 0.2339 - loss: 0.9933 - pixel_accuracy_multiclass: 0.9893 - wm_iou: 1.1465e-04 - val_csf_iou: 0.1386 - val_dice_coefficient_multiclass: 0.4225 - val_gm_iou: 0.1335 - val_iou_score_multiclass: 0.3229 - val_loss: 1.0562 - val_pixel_accuracy_multiclass: 0.8575 - val_wm_iou: 0.1800 - learning_rate: 1.0000e-04
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.4208 - dice_coefficient_multiclass: 0.6195 - gm_iou: 0.3517 - iou_score_multiclass: 0.4995 - loss: 0.5818 - pixel_accuracy_multiclass: 0.9414 - wm_iou: 0.3097
# Epoch 25: val_iou_score_multiclass improved from 0.32289 to 0.33888, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 25: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 453ms/step - csf_iou: 0.4210 - dice_coefficient_multiclass: 0.6243 - gm_iou: 0.3514 - iou_score_multiclass: 0.5040 - loss: 0.5761 - pixel_accuracy_multiclass: 0.9406 - wm_iou: 0.3247 - val_csf_iou: 0.1637 - val_dice_coefficient_multiclass: 0.4442 - val_gm_iou: 0.1522 - val_iou_score_multiclass: 0.3389 - val_loss: 1.0215 - val_pixel_accuracy_multiclass: 0.8600 - val_wm_iou: 0.1873 - learning_rate: 1.0000e-04
# Epoch 26/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - csf_iou: 0.0838 - dice_coefficient_multiclass: 0.2747 - gm_iou: 0.0021 - iou_score_multiclass: 0.2432 - loss: 0.9479 - pixel_accuracy_multiclass: 0.9914 - wm_iou: 1.4027e-04
# Epoch 26: val_iou_score_multiclass improved from 0.33888 to 0.34035, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 26: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 219ms/step - csf_iou: 0.0838 - dice_coefficient_multiclass: 0.2747 - gm_iou: 0.0021 - iou_score_multiclass: 0.2432 - loss: 0.9479 - pixel_accuracy_multiclass: 0.9914 - wm_iou: 1.4027e-04 - val_csf_iou: 0.1642 - val_dice_coefficient_multiclass: 0.4464 - val_gm_iou: 0.1538 - val_iou_score_multiclass: 0.3403 - val_loss: 1.0180 - val_pixel_accuracy_multiclass: 0.8609 - val_wm_iou: 0.1914 - learning_rate: 1.0000e-04
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.4340 - dice_coefficient_multiclass: 0.6338 - gm_iou: 0.3745 - iou_score_multiclass: 0.5139 - loss: 0.5572 - pixel_accuracy_multiclass: 0.9435 - wm_iou: 0.3249
# Epoch 27: val_iou_score_multiclass improved from 0.34035 to 0.45559, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 27: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 456ms/step - csf_iou: 0.4382 - dice_coefficient_multiclass: 0.6398 - gm_iou: 0.3739 - iou_score_multiclass: 0.5195 - loss: 0.5497 - pixel_accuracy_multiclass: 0.9432 - wm_iou: 0.3405 - val_csf_iou: 0.2674 - val_dice_coefficient_multiclass: 0.5874 - val_gm_iou: 0.3003 - val_iou_score_multiclass: 0.4556 - val_loss: 0.7103 - val_pixel_accuracy_multiclass: 0.9100 - val_wm_iou: 0.3556 - learning_rate: 1.0000e-04
# Epoch 28/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - csf_iou: 0.0704 - dice_coefficient_multiclass: 0.2679 - gm_iou: 8.5047e-04 - iou_score_multiclass: 0.2389 - loss: 1.0465 - pixel_accuracy_multiclass: 0.9704 - wm_iou: 1.4353e-04
# Epoch 28: val_iou_score_multiclass did not improve from 0.45559
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step - csf_iou: 0.0704 - dice_coefficient_multiclass: 0.2679 - gm_iou: 8.5047e-04 - iou_score_multiclass: 0.2389 - loss: 1.0465 - pixel_accuracy_multiclass: 0.9704 - wm_iou: 1.4353e-04 - val_csf_iou: 0.2622 - val_dice_coefficient_multiclass: 0.5816 - val_gm_iou: 0.2955 - val_iou_score_multiclass: 0.4504 - val_loss: 0.7162 - val_pixel_accuracy_multiclass: 0.9086 - val_wm_iou: 0.3459 - learning_rate: 1.0000e-04
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.4291 - dice_coefficient_multiclass: 0.6303 - gm_iou: 0.3673 - iou_score_multiclass: 0.5101 - loss: 0.5691 - pixel_accuracy_multiclass: 0.9394 - wm_iou: 0.3174
# Epoch 29: val_iou_score_multiclass improved from 0.45559 to 0.49411, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 29: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 452ms/step - csf_iou: 0.4261 - dice_coefficient_multiclass: 0.6315 - gm_iou: 0.3606 - iou_score_multiclass: 0.5112 - loss: 0.5695 - pixel_accuracy_multiclass: 0.9380 - wm_iou: 0.3304 - val_csf_iou: 0.3820 - val_dice_coefficient_multiclass: 0.6286 - val_gm_iou: 0.3042 - val_iou_score_multiclass: 0.4941 - val_loss: 0.6082 - val_pixel_accuracy_multiclass: 0.9226 - val_wm_iou: 0.3754 - learning_rate: 1.0000e-04
# Epoch 30/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - csf_iou: 0.0906 - dice_coefficient_multiclass: 0.2789 - gm_iou: 9.8923e-04 - iou_score_multiclass: 0.2480 - loss: 0.9631 - pixel_accuracy_multiclass: 0.9863 - wm_iou: 1.6828e-04
# Prediction after epoch 30
#
#
# Epoch 30: val_iou_score_multiclass improved from 0.49411 to 0.49577, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 30: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 242ms/step - csf_iou: 0.0906 - dice_coefficient_multiclass: 0.2789 - gm_iou: 9.8923e-04 - iou_score_multiclass: 0.2480 - loss: 0.9631 - pixel_accuracy_multiclass: 0.9863 - wm_iou: 1.6828e-04 - val_csf_iou: 0.3772 - val_dice_coefficient_multiclass: 0.6302 - val_gm_iou: 0.3039 - val_iou_score_multiclass: 0.4958 - val_loss: 0.6057 - val_pixel_accuracy_multiclass: 0.9232 - val_wm_iou: 0.3881 - learning_rate: 1.0000e-04
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.4421 - dice_coefficient_multiclass: 0.6400 - gm_iou: 0.3753 - iou_score_multiclass: 0.5204 - loss: 0.5476 - pixel_accuracy_multiclass: 0.9421 - wm_iou: 0.3340
# Epoch 31: val_iou_score_multiclass improved from 0.49577 to 0.54572, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 31: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 33s 451ms/step - csf_iou: 0.4451 - dice_coefficient_multiclass: 0.6466 - gm_iou: 0.3785 - iou_score_multiclass: 0.5265 - loss: 0.5400 - pixel_accuracy_multiclass: 0.9418 - wm_iou: 0.3493 - val_csf_iou: 0.3804 - val_dice_coefficient_multiclass: 0.6814 - val_gm_iou: 0.4289 - val_iou_score_multiclass: 0.5457 - val_loss: 0.5274 - val_pixel_accuracy_multiclass: 0.9350 - val_wm_iou: 0.4455 - learning_rate: 1.0000e-04
# Epoch 32/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - csf_iou: 0.1057 - dice_coefficient_multiclass: 0.2871 - gm_iou: 0.0028 - iou_score_multiclass: 0.2542 - loss: 0.9541 - pixel_accuracy_multiclass: 0.9877 - wm_iou: 1.8266e-04
# Epoch 32: val_iou_score_multiclass did not improve from 0.54572
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 168ms/step - csf_iou: 0.1057 - dice_coefficient_multiclass: 0.2871 - gm_iou: 0.0028 - iou_score_multiclass: 0.2542 - loss: 0.9541 - pixel_accuracy_multiclass: 0.9877 - wm_iou: 1.8266e-04 - val_csf_iou: 0.3748 - val_dice_coefficient_multiclass: 0.6750 - val_gm_iou: 0.4200 - val_iou_score_multiclass: 0.5391 - val_loss: 0.5363 - val_pixel_accuracy_multiclass: 0.9338 - val_wm_iou: 0.4347 - learning_rate: 1.0000e-04
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - csf_iou: 0.4706 - dice_coefficient_multiclass: 0.6618 - gm_iou: 0.4091 - iou_score_multiclass: 0.5418 - loss: 0.5097 - pixel_accuracy_multiclass: 0.9466 - wm_iou: 0.3509
# Epoch 33: val_iou_score_multiclass did not improve from 0.54572
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 13s 405ms/step - csf_iou: 0.4697 - dice_coefficient_multiclass: 0.6648 - gm_iou: 0.4061 - iou_score_multiclass: 0.5448 - loss: 0.5078 - pixel_accuracy_multiclass: 0.9457 - wm_iou: 0.3647 - val_csf_iou: 0.4311 - val_dice_coefficient_multiclass: 0.6723 - val_gm_iou: 0.3658 - val_iou_score_multiclass: 0.5370 - val_loss: 0.5266 - val_pixel_accuracy_multiclass: 0.9342 - val_wm_iou: 0.4164 - learning_rate: 1.0000e-04
# Epoch 34/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - csf_iou: 0.1137 - dice_coefficient_multiclass: 0.2911 - gm_iou: 0.0024 - iou_score_multiclass: 0.2577 - loss: 0.8885 - pixel_accuracy_multiclass: 0.9937 - wm_iou: 1.7649e-04
# Epoch 34: val_iou_score_multiclass did not improve from 0.54572
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - csf_iou: 0.1137 - dice_coefficient_multiclass: 0.2911 - gm_iou: 0.0024 - iou_score_multiclass: 0.2577 - loss: 0.8885 - pixel_accuracy_multiclass: 0.9937 - wm_iou: 1.7649e-04 - val_csf_iou: 0.4263 - val_dice_coefficient_multiclass: 0.6708 - val_gm_iou: 0.3721 - val_iou_score_multiclass: 0.5353 - val_loss: 0.5294 - val_pixel_accuracy_multiclass: 0.9337 - val_wm_iou: 0.4090 - learning_rate: 1.0000e-04
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - csf_iou: 0.4915 - dice_coefficient_multiclass: 0.6758 - gm_iou: 0.4315 - iou_score_multiclass: 0.5569 - loss: 0.4837 - pixel_accuracy_multiclass: 0.9502 - wm_iou: 0.3624
# Epoch 35: val_iou_score_multiclass improved from 0.54572 to 0.58109, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 35: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 454ms/step - csf_iou: 0.4871 - dice_coefficient_multiclass: 0.6785 - gm_iou: 0.4278 - iou_score_multiclass: 0.5593 - loss: 0.4835 - pixel_accuracy_multiclass: 0.9488 - wm_iou: 0.3790 - val_csf_iou: 0.4805 - val_dice_coefficient_multiclass: 0.7139 - val_gm_iou: 0.3984 - val_iou_score_multiclass: 0.5811 - val_loss: 0.4506 - val_pixel_accuracy_multiclass: 0.9445 - val_wm_iou: 0.5026 - learning_rate: 1.0000e-04
# Epoch 36/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - csf_iou: 0.1217 - dice_coefficient_multiclass: 0.2942 - gm_iou: 0.0015 - iou_score_multiclass: 0.2602 - loss: 0.8897 - pixel_accuracy_multiclass: 0.9916 - wm_iou: 1.9235e-04
# Epoch 36: val_iou_score_multiclass did not improve from 0.58109
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 168ms/step - csf_iou: 0.1217 - dice_coefficient_multiclass: 0.2942 - gm_iou: 0.0015 - iou_score_multiclass: 0.2602 - loss: 0.8897 - pixel_accuracy_multiclass: 0.9916 - wm_iou: 1.9235e-04 - val_csf_iou: 0.4719 - val_dice_coefficient_multiclass: 0.7080 - val_gm_iou: 0.3959 - val_iou_score_multiclass: 0.5745 - val_loss: 0.4618 - val_pixel_accuracy_multiclass: 0.9427 - val_wm_iou: 0.4887 - learning_rate: 1.0000e-04
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.5137 - dice_coefficient_multiclass: 0.6929 - gm_iou: 0.4582 - iou_score_multiclass: 0.5744 - loss: 0.4563 - pixel_accuracy_multiclass: 0.9530 - wm_iou: 0.3792
# Epoch 37: val_iou_score_multiclass improved from 0.58109 to 0.58468, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 37: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 453ms/step - csf_iou: 0.5095 - dice_coefficient_multiclass: 0.6932 - gm_iou: 0.4499 - iou_score_multiclass: 0.5751 - loss: 0.4572 - pixel_accuracy_multiclass: 0.9523 - wm_iou: 0.3930 - val_csf_iou: 0.4887 - val_dice_coefficient_multiclass: 0.7177 - val_gm_iou: 0.4219 - val_iou_score_multiclass: 0.5847 - val_loss: 0.4398 - val_pixel_accuracy_multiclass: 0.9463 - val_wm_iou: 0.4837 - learning_rate: 1.0000e-04
# Epoch 38/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - csf_iou: 0.1267 - dice_coefficient_multiclass: 0.2981 - gm_iou: 0.0022 - iou_score_multiclass: 0.2645 - loss: 0.8700 - pixel_accuracy_multiclass: 0.9942 - wm_iou: 2.2550e-04
# Epoch 38: val_iou_score_multiclass did not improve from 0.58468
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 169ms/step - csf_iou: 0.1267 - dice_coefficient_multiclass: 0.2981 - gm_iou: 0.0022 - iou_score_multiclass: 0.2645 - loss: 0.8700 - pixel_accuracy_multiclass: 0.9942 - wm_iou: 2.2550e-04 - val_csf_iou: 0.4820 - val_dice_coefficient_multiclass: 0.7106 - val_gm_iou: 0.4187 - val_iou_score_multiclass: 0.5769 - val_loss: 0.4524 - val_pixel_accuracy_multiclass: 0.9441 - val_wm_iou: 0.4633 - learning_rate: 1.0000e-04
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - csf_iou: 0.5289 - dice_coefficient_multiclass: 0.7039 - gm_iou: 0.4735 - iou_score_multiclass: 0.5863 - loss: 0.4382 - pixel_accuracy_multiclass: 0.9548 - wm_iou: 0.3921
# Epoch 39: val_iou_score_multiclass improved from 0.58468 to 0.59160, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 39: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 451ms/step - csf_iou: 0.5256 - dice_coefficient_multiclass: 0.7046 - gm_iou: 0.4658 - iou_score_multiclass: 0.5873 - loss: 0.4388 - pixel_accuracy_multiclass: 0.9542 - wm_iou: 0.4057 - val_csf_iou: 0.4861 - val_dice_coefficient_multiclass: 0.7240 - val_gm_iou: 0.4352 - val_iou_score_multiclass: 0.5916 - val_loss: 0.4314 - val_pixel_accuracy_multiclass: 0.9471 - val_wm_iou: 0.4986 - learning_rate: 1.0000e-04
# Epoch 40/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - csf_iou: 0.1393 - dice_coefficient_multiclass: 0.3040 - gm_iou: 0.0029 - iou_score_multiclass: 0.2692 - loss: 0.8563 - pixel_accuracy_multiclass: 0.9951 - wm_iou: 2.4957e-04
# Prediction after epoch 40
#
#
# Epoch 40: val_iou_score_multiclass did not improve from 0.59160
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 195ms/step - csf_iou: 0.1393 - dice_coefficient_multiclass: 0.3040 - gm_iou: 0.0029 - iou_score_multiclass: 0.2692 - loss: 0.8563 - pixel_accuracy_multiclass: 0.9951 - wm_iou: 2.4957e-04 - val_csf_iou: 0.4795 - val_dice_coefficient_multiclass: 0.7144 - val_gm_iou: 0.4258 - val_iou_score_multiclass: 0.5811 - val_loss: 0.4485 - val_pixel_accuracy_multiclass: 0.9442 - val_wm_iou: 0.4736 - learning_rate: 1.0000e-04
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - csf_iou: 0.5421 - dice_coefficient_multiclass: 0.7145 - gm_iou: 0.4925 - iou_score_multiclass: 0.5981 - loss: 0.4211 - pixel_accuracy_multiclass: 0.9566 - wm_iou: 0.4035
# Epoch 41: val_iou_score_multiclass improved from 0.59160 to 0.60365, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 41: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 458ms/step - csf_iou: 0.5373 - dice_coefficient_multiclass: 0.7141 - gm_iou: 0.4816 - iou_score_multiclass: 0.5978 - loss: 0.4237 - pixel_accuracy_multiclass: 0.9558 - wm_iou: 0.4169 - val_csf_iou: 0.4601 - val_dice_coefficient_multiclass: 0.7350 - val_gm_iou: 0.4807 - val_iou_score_multiclass: 0.6037 - val_loss: 0.4228 - val_pixel_accuracy_multiclass: 0.9453 - val_wm_iou: 0.5288 - learning_rate: 1.0000e-04
# Epoch 42/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - csf_iou: 0.1445 - dice_coefficient_multiclass: 0.3061 - gm_iou: 0.0015 - iou_score_multiclass: 0.2716 - loss: 0.8340 - pixel_accuracy_multiclass: 0.9946 - wm_iou: 2.7084e-04
# Epoch 42: val_iou_score_multiclass did not improve from 0.60365
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 171ms/step - csf_iou: 0.1445 - dice_coefficient_multiclass: 0.3061 - gm_iou: 0.0015 - iou_score_multiclass: 0.2716 - loss: 0.8340 - pixel_accuracy_multiclass: 0.9946 - wm_iou: 2.7084e-04 - val_csf_iou: 0.4574 - val_dice_coefficient_multiclass: 0.7290 - val_gm_iou: 0.4776 - val_iou_score_multiclass: 0.5968 - val_loss: 0.4337 - val_pixel_accuracy_multiclass: 0.9435 - val_wm_iou: 0.5080 - learning_rate: 1.0000e-04
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.5549 - dice_coefficient_multiclass: 0.7227 - gm_iou: 0.5031 - iou_score_multiclass: 0.6072 - loss: 0.4079 - pixel_accuracy_multiclass: 0.9578 - wm_iou: 0.4136
# Epoch 43: val_iou_score_multiclass improved from 0.60365 to 0.61702, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 43: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 454ms/step - csf_iou: 0.5512 - dice_coefficient_multiclass: 0.7230 - gm_iou: 0.4942 - iou_score_multiclass: 0.6075 - loss: 0.4092 - pixel_accuracy_multiclass: 0.9572 - wm_iou: 0.4263 - val_csf_iou: 0.5121 - val_dice_coefficient_multiclass: 0.7466 - val_gm_iou: 0.4698 - val_iou_score_multiclass: 0.6170 - val_loss: 0.3963 - val_pixel_accuracy_multiclass: 0.9505 - val_wm_iou: 0.5350 - learning_rate: 1.0000e-04
# Epoch 44/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - csf_iou: 0.1629 - dice_coefficient_multiclass: 0.3153 - gm_iou: 0.0051 - iou_score_multiclass: 0.2781 - loss: 0.8270 - pixel_accuracy_multiclass: 0.9949 - wm_iou: 2.9130e-04
# Epoch 44: val_iou_score_multiclass did not improve from 0.61702
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - csf_iou: 0.1629 - dice_coefficient_multiclass: 0.3153 - gm_iou: 0.0051 - iou_score_multiclass: 0.2781 - loss: 0.8270 - pixel_accuracy_multiclass: 0.9949 - wm_iou: 2.9130e-04 - val_csf_iou: 0.5065 - val_dice_coefficient_multiclass: 0.7421 - val_gm_iou: 0.4672 - val_iou_score_multiclass: 0.6118 - val_loss: 0.4044 - val_pixel_accuracy_multiclass: 0.9492 - val_wm_iou: 0.5234 - learning_rate: 1.0000e-04
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - csf_iou: 0.5676 - dice_coefficient_multiclass: 0.7324 - gm_iou: 0.5198 - iou_score_multiclass: 0.6179 - loss: 0.3933 - pixel_accuracy_multiclass: 0.9590 - wm_iou: 0.4244
# Epoch 45: val_iou_score_multiclass improved from 0.61702 to 0.62435, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 45: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 457ms/step - csf_iou: 0.5614 - dice_coefficient_multiclass: 0.7303 - gm_iou: 0.5062 - iou_score_multiclass: 0.6159 - loss: 0.3980 - pixel_accuracy_multiclass: 0.9582 - wm_iou: 0.4351 - val_csf_iou: 0.5205 - val_dice_coefficient_multiclass: 0.7530 - val_gm_iou: 0.5000 - val_iou_score_multiclass: 0.6243 - val_loss: 0.3884 - val_pixel_accuracy_multiclass: 0.9507 - val_wm_iou: 0.5234 - learning_rate: 1.0000e-04
# Epoch 46/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - csf_iou: 0.1836 - dice_coefficient_multiclass: 0.3232 - gm_iou: 0.0043 - iou_score_multiclass: 0.2845 - loss: 0.8049 - pixel_accuracy_multiclass: 0.9962 - wm_iou: 3.2169e-04
# Epoch 46: val_iou_score_multiclass did not improve from 0.62435
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step - csf_iou: 0.1836 - dice_coefficient_multiclass: 0.3232 - gm_iou: 0.0043 - iou_score_multiclass: 0.2845 - loss: 0.8049 - pixel_accuracy_multiclass: 0.9962 - wm_iou: 3.2169e-04 - val_csf_iou: 0.5155 - val_dice_coefficient_multiclass: 0.7478 - val_gm_iou: 0.4957 - val_iou_score_multiclass: 0.6183 - val_loss: 0.3971 - val_pixel_accuracy_multiclass: 0.9492 - val_wm_iou: 0.5092 - learning_rate: 1.0000e-04
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.5773 - dice_coefficient_multiclass: 0.7372 - gm_iou: 0.5257 - iou_score_multiclass: 0.6236 - loss: 0.3858 - pixel_accuracy_multiclass: 0.9597 - wm_iou: 0.4296
# Epoch 47: val_iou_score_multiclass improved from 0.62435 to 0.62871, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 47: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 457ms/step - csf_iou: 0.5732 - dice_coefficient_multiclass: 0.7369 - gm_iou: 0.5153 - iou_score_multiclass: 0.6235 - loss: 0.3879 - pixel_accuracy_multiclass: 0.9591 - wm_iou: 0.4421 - val_csf_iou: 0.5534 - val_dice_coefficient_multiclass: 0.7561 - val_gm_iou: 0.4941 - val_iou_score_multiclass: 0.6287 - val_loss: 0.3832 - val_pixel_accuracy_multiclass: 0.9513 - val_wm_iou: 0.5092 - learning_rate: 1.0000e-04
# Epoch 48/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - csf_iou: 0.1773 - dice_coefficient_multiclass: 0.3201 - gm_iou: 0.0021 - iou_score_multiclass: 0.2827 - loss: 0.7907 - pixel_accuracy_multiclass: 0.9957 - wm_iou: 3.3570e-04
# Epoch 48: val_iou_score_multiclass did not improve from 0.62871
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - csf_iou: 0.1773 - dice_coefficient_multiclass: 0.3201 - gm_iou: 0.0021 - iou_score_multiclass: 0.2827 - loss: 0.7907 - pixel_accuracy_multiclass: 0.9957 - wm_iou: 3.3570e-04 - val_csf_iou: 0.5526 - val_dice_coefficient_multiclass: 0.7521 - val_gm_iou: 0.4895 - val_iou_score_multiclass: 0.6242 - val_loss: 0.3894 - val_pixel_accuracy_multiclass: 0.9503 - val_wm_iou: 0.4967 - learning_rate: 1.0000e-04
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.5854 - dice_coefficient_multiclass: 0.7468 - gm_iou: 0.5401 - iou_score_multiclass: 0.6337 - loss: 0.3720 - pixel_accuracy_multiclass: 0.9606 - wm_iou: 0.4448
# Epoch 49: val_iou_score_multiclass did not improve from 0.62871
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 13s 405ms/step - csf_iou: 0.5785 - dice_coefficient_multiclass: 0.7438 - gm_iou: 0.5259 - iou_score_multiclass: 0.6305 - loss: 0.3789 - pixel_accuracy_multiclass: 0.9594 - wm_iou: 0.4524 - val_csf_iou: 0.5187 - val_dice_coefficient_multiclass: 0.7552 - val_gm_iou: 0.5108 - val_iou_score_multiclass: 0.6270 - val_loss: 0.3933 - val_pixel_accuracy_multiclass: 0.9476 - val_wm_iou: 0.5235 - learning_rate: 1.0000e-04
# Epoch 50/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - csf_iou: 0.1814 - dice_coefficient_multiclass: 0.3235 - gm_iou: 0.0048 - iou_score_multiclass: 0.2857 - loss: 0.8027 - pixel_accuracy_multiclass: 0.9955 - wm_iou: 3.8714e-04
# Prediction after epoch 50
#
#
# Epoch 50: val_iou_score_multiclass did not improve from 0.62871
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 187ms/step - csf_iou: 0.1814 - dice_coefficient_multiclass: 0.3235 - gm_iou: 0.0048 - iou_score_multiclass: 0.2857 - loss: 0.8027 - pixel_accuracy_multiclass: 0.9955 - wm_iou: 3.8714e-04 - val_csf_iou: 0.5083 - val_dice_coefficient_multiclass: 0.7464 - val_gm_iou: 0.4998 - val_iou_score_multiclass: 0.6169 - val_loss: 0.4081 - val_pixel_accuracy_multiclass: 0.9450 - val_wm_iou: 0.5056 - learning_rate: 1.0000e-04
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - csf_iou: 0.5940 - dice_coefficient_multiclass: 0.7511 - gm_iou: 0.5452 - iou_score_multiclass: 0.6388 - loss: 0.3660 - pixel_accuracy_multiclass: 0.9610 - wm_iou: 0.4497
# Epoch 51: val_iou_score_multiclass did not improve from 0.62871
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 13s 405ms/step - csf_iou: 0.5885 - dice_coefficient_multiclass: 0.7497 - gm_iou: 0.5335 - iou_score_multiclass: 0.6372 - loss: 0.3705 - pixel_accuracy_multiclass: 0.9600 - wm_iou: 0.4597 - val_csf_iou: 0.4789 - val_dice_coefficient_multiclass: 0.7446 - val_gm_iou: 0.5195 - val_iou_score_multiclass: 0.6147 - val_loss: 0.4148 - val_pixel_accuracy_multiclass: 0.9436 - val_wm_iou: 0.5092 - learning_rate: 1.0000e-04
# Epoch 52/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - csf_iou: 0.1918 - dice_coefficient_multiclass: 0.3268 - gm_iou: 0.0041 - iou_score_multiclass: 0.2881 - loss: 0.7714 - pixel_accuracy_multiclass: 0.9941 - wm_iou: 3.9263e-04
# Epoch 52: val_iou_score_multiclass did not improve from 0.62871
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - csf_iou: 0.1918 - dice_coefficient_multiclass: 0.3268 - gm_iou: 0.0041 - iou_score_multiclass: 0.2881 - loss: 0.7714 - pixel_accuracy_multiclass: 0.9941 - wm_iou: 3.9263e-04 - val_csf_iou: 0.4634 - val_dice_coefficient_multiclass: 0.7337 - val_gm_iou: 0.5097 - val_iou_score_multiclass: 0.6025 - val_loss: 0.4349 - val_pixel_accuracy_multiclass: 0.9402 - val_wm_iou: 0.4880 - learning_rate: 1.0000e-04
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.6012 - dice_coefficient_multiclass: 0.7575 - gm_iou: 0.5567 - iou_score_multiclass: 0.6458 - loss: 0.3564 - pixel_accuracy_multiclass: 0.9617 - wm_iou: 0.4575
# Epoch 53: val_iou_score_multiclass improved from 0.62871 to 0.67276, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 53: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 458ms/step - csf_iou: 0.5929 - dice_coefficient_multiclass: 0.7538 - gm_iou: 0.5409 - iou_score_multiclass: 0.6417 - loss: 0.3648 - pixel_accuracy_multiclass: 0.9603 - wm_iou: 0.4647 - val_csf_iou: 0.5790 - val_dice_coefficient_multiclass: 0.7923 - val_gm_iou: 0.5342 - val_iou_score_multiclass: 0.6728 - val_loss: 0.3370 - val_pixel_accuracy_multiclass: 0.9553 - val_wm_iou: 0.6148 - learning_rate: 5.0000e-05
# Epoch 54/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - csf_iou: 0.2141 - dice_coefficient_multiclass: 0.3355 - gm_iou: 0.0047 - iou_score_multiclass: 0.2952 - loss: 0.7770 - pixel_accuracy_multiclass: 0.9954 - wm_iou: 4.3993e-04
# Epoch 54: val_iou_score_multiclass did not improve from 0.67276
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 171ms/step - csf_iou: 0.2141 - dice_coefficient_multiclass: 0.3355 - gm_iou: 0.0047 - iou_score_multiclass: 0.2952 - loss: 0.7770 - pixel_accuracy_multiclass: 0.9954 - wm_iou: 4.3993e-04 - val_csf_iou: 0.5741 - val_dice_coefficient_multiclass: 0.7920 - val_gm_iou: 0.5397 - val_iou_score_multiclass: 0.6722 - val_loss: 0.3372 - val_pixel_accuracy_multiclass: 0.9554 - val_wm_iou: 0.6126 - learning_rate: 5.0000e-05
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - csf_iou: 0.6018 - dice_coefficient_multiclass: 0.7597 - gm_iou: 0.5599 - iou_score_multiclass: 0.6482 - loss: 0.3544 - pixel_accuracy_multiclass: 0.9615 - wm_iou: 0.4633
# Epoch 55: val_iou_score_multiclass improved from 0.67276 to 0.67462, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 55: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 458ms/step - csf_iou: 0.5990 - dice_coefficient_multiclass: 0.7567 - gm_iou: 0.5456 - iou_score_multiclass: 0.6453 - loss: 0.3596 - pixel_accuracy_multiclass: 0.9609 - wm_iou: 0.4676 - val_csf_iou: 0.5911 - val_dice_coefficient_multiclass: 0.7937 - val_gm_iou: 0.5258 - val_iou_score_multiclass: 0.6746 - val_loss: 0.3299 - val_pixel_accuracy_multiclass: 0.9572 - val_wm_iou: 0.6174 - learning_rate: 5.0000e-05
# Epoch 56/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - csf_iou: 0.2098 - dice_coefficient_multiclass: 0.3349 - gm_iou: 0.0064 - iou_score_multiclass: 0.2944 - loss: 0.7858 - pixel_accuracy_multiclass: 0.9951 - wm_iou: 4.3081e-04
# Epoch 56: val_iou_score_multiclass improved from 0.67462 to 0.67500, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 56: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 219ms/step - csf_iou: 0.2098 - dice_coefficient_multiclass: 0.3349 - gm_iou: 0.0064 - iou_score_multiclass: 0.2944 - loss: 0.7858 - pixel_accuracy_multiclass: 0.9951 - wm_iou: 4.3081e-04 - val_csf_iou: 0.5897 - val_dice_coefficient_multiclass: 0.7941 - val_gm_iou: 0.5311 - val_iou_score_multiclass: 0.6750 - val_loss: 0.3289 - val_pixel_accuracy_multiclass: 0.9574 - val_wm_iou: 0.6153 - learning_rate: 5.0000e-05
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.6117 - dice_coefficient_multiclass: 0.7646 - gm_iou: 0.5652 - iou_score_multiclass: 0.6539 - loss: 0.3454 - pixel_accuracy_multiclass: 0.9628 - wm_iou: 0.4691
# Epoch 57: val_iou_score_multiclass did not improve from 0.67500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 13s 407ms/step - csf_iou: 0.6066 - dice_coefficient_multiclass: 0.7610 - gm_iou: 0.5508 - iou_score_multiclass: 0.6500 - loss: 0.3523 - pixel_accuracy_multiclass: 0.9618 - wm_iou: 0.4724 - val_csf_iou: 0.5854 - val_dice_coefficient_multiclass: 0.7893 - val_gm_iou: 0.5093 - val_iou_score_multiclass: 0.6694 - val_loss: 0.3378 - val_pixel_accuracy_multiclass: 0.9559 - val_wm_iou: 0.6192 - learning_rate: 5.0000e-05
# Epoch 58/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - csf_iou: 0.2325 - dice_coefficient_multiclass: 0.3425 - gm_iou: 0.0058 - iou_score_multiclass: 0.3005 - loss: 0.7661 - pixel_accuracy_multiclass: 0.9969 - wm_iou: 4.4476e-04
# Epoch 58: val_iou_score_multiclass did not improve from 0.67500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step - csf_iou: 0.2325 - dice_coefficient_multiclass: 0.3425 - gm_iou: 0.0058 - iou_score_multiclass: 0.3005 - loss: 0.7661 - pixel_accuracy_multiclass: 0.9969 - wm_iou: 4.4476e-04 - val_csf_iou: 0.5835 - val_dice_coefficient_multiclass: 0.7901 - val_gm_iou: 0.5152 - val_iou_score_multiclass: 0.6703 - val_loss: 0.3362 - val_pixel_accuracy_multiclass: 0.9563 - val_wm_iou: 0.6189 - learning_rate: 5.0000e-05
# Epoch 59/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.6182 - dice_coefficient_multiclass: 0.7698 - gm_iou: 0.5733 - iou_score_multiclass: 0.6598 - loss: 0.3378 - pixel_accuracy_multiclass: 0.9634 - wm_iou: 0.4770
# Epoch 59: val_iou_score_multiclass did not improve from 0.67500
# ...
# Epoch 81/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.6462 - dice_coefficient_multiclass: 0.7910 - gm_iou: 0.6025 - iou_score_multiclass: 0.6843 - loss: 0.3086 - pixel_accuracy_multiclass: 0.9654 - wm_iou: 0.5128
# Epoch 81: val_iou_score_multiclass did not improve from 0.71224
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 13s 404ms/step - csf_iou: 0.6400 - dice_coefficient_multiclass: 0.7866 - gm_iou: 0.5908 - iou_score_multiclass: 0.6795 - loss: 0.3155 - pixel_accuracy_multiclass: 0.9646 - wm_iou: 0.5114 - val_csf_iou: 0.6260 - val_dice_coefficient_multiclass: 0.8188 - val_gm_iou: 0.5896 - val_iou_score_multiclass: 0.7066 - val_loss: 0.2968 - val_pixel_accuracy_multiclass: 0.9598 - val_wm_iou: 0.6394 - learning_rate: 1.2500e-05
# Epoch 82/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - csf_iou: 0.2711 - dice_coefficient_multiclass: 0.3562 - gm_iou: 0.0059 - iou_score_multiclass: 0.3128 - loss: 0.7346 - pixel_accuracy_multiclass: 0.9966 - wm_iou: 6.5852e-04
# Epoch 82: val_iou_score_multiclass did not improve from 0.71224
#
# Epoch 82: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - csf_iou: 0.2711 - dice_coefficient_multiclass: 0.3562 - gm_iou: 0.0059 - iou_score_multiclass: 0.3128 - loss: 0.7346 - pixel_accuracy_multiclass: 0.9966 - wm_iou: 6.5852e-04 - val_csf_iou: 0.6251 - val_dice_coefficient_multiclass: 0.8190 - val_gm_iou: 0.5889 - val_iou_score_multiclass: 0.7068 - val_loss: 0.2959 - val_pixel_accuracy_multiclass: 0.9600 - val_wm_iou: 0.6422 - learning_rate: 1.2500e-05
# Epoch 83/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.6515 - dice_coefficient_multiclass: 0.7927 - gm_iou: 0.6070 - iou_score_multiclass: 0.6870 - loss: 0.3043 - pixel_accuracy_multiclass: 0.9664 - wm_iou: 0.5134
# Epoch 83: val_iou_score_multiclass improved from 0.71224 to 0.71225, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 83: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 451ms/step - csf_iou: 0.6447 - dice_coefficient_multiclass: 0.7879 - gm_iou: 0.5931 - iou_score_multiclass: 0.6816 - loss: 0.3119 - pixel_accuracy_multiclass: 0.9653 - wm_iou: 0.5123 - val_csf_iou: 0.6314 - val_dice_coefficient_multiclass: 0.8230 - val_gm_iou: 0.5943 - val_iou_score_multiclass: 0.7123 - val_loss: 0.2886 - val_pixel_accuracy_multiclass: 0.9611 - val_wm_iou: 0.6514 - learning_rate: 6.2500e-06
# Epoch 84/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - csf_iou: 0.2852 - dice_coefficient_multiclass: 0.3611 - gm_iou: 0.0071 - iou_score_multiclass: 0.3167 - loss: 0.7221 - pixel_accuracy_multiclass: 0.9972 - wm_iou: 6.3367e-04
# Epoch 84: val_iou_score_multiclass did not improve from 0.71225
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - csf_iou: 0.2852 - dice_coefficient_multiclass: 0.3611 - gm_iou: 0.0071 - iou_score_multiclass: 0.3167 - loss: 0.7221 - pixel_accuracy_multiclass: 0.9972 - wm_iou: 6.3367e-04 - val_csf_iou: 0.6292 - val_dice_coefficient_multiclass: 0.8225 - val_gm_iou: 0.5934 - val_iou_score_multiclass: 0.7115 - val_loss: 0.2895 - val_pixel_accuracy_multiclass: 0.9610 - val_wm_iou: 0.6517 - learning_rate: 6.2500e-06
# Epoch 85/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - csf_iou: 0.6536 - dice_coefficient_multiclass: 0.7946 - gm_iou: 0.6106 - iou_score_multiclass: 0.6892 - loss: 0.3014 - pixel_accuracy_multiclass: 0.9666 - wm_iou: 0.5161
# Epoch 85: val_iou_score_multiclass did not improve from 0.71225
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 13s 404ms/step - csf_iou: 0.6473 - dice_coefficient_multiclass: 0.7896 - gm_iou: 0.5959 - iou_score_multiclass: 0.6835 - loss: 0.3093 - pixel_accuracy_multiclass: 0.9656 - wm_iou: 0.5143 - val_csf_iou: 0.6316 - val_dice_coefficient_multiclass: 0.8228 - val_gm_iou: 0.5943 - val_iou_score_multiclass: 0.7120 - val_loss: 0.2889 - val_pixel_accuracy_multiclass: 0.9610 - val_wm_iou: 0.6502 - learning_rate: 6.2500e-06
# Epoch 86/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - csf_iou: 0.2699 - dice_coefficient_multiclass: 0.3549 - gm_iou: 0.0041 - iou_score_multiclass: 0.3120 - loss: 0.7052 - pixel_accuracy_multiclass: 0.9963 - wm_iou: 6.7316e-04
# Epoch 86: val_iou_score_multiclass did not improve from 0.71225
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - csf_iou: 0.2699 - dice_coefficient_multiclass: 0.3549 - gm_iou: 0.0041 - iou_score_multiclass: 0.3120 - loss: 0.7052 - pixel_accuracy_multiclass: 0.9963 - wm_iou: 6.7316e-04 - val_csf_iou: 0.6299 - val_dice_coefficient_multiclass: 0.8223 - val_gm_iou: 0.5934 - val_iou_score_multiclass: 0.7113 - val_loss: 0.2896 - val_pixel_accuracy_multiclass: 0.9610 - val_wm_iou: 0.6504 - learning_rate: 6.2500e-06
# Epoch 87/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.6550 - dice_coefficient_multiclass: 0.7951 - gm_iou: 0.6109 - iou_score_multiclass: 0.6896 - loss: 0.3007 - pixel_accuracy_multiclass: 0.9666 - wm_iou: 0.5158
# Epoch 87: val_iou_score_multiclass improved from 0.71225 to 0.71409, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 87: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 454ms/step - csf_iou: 0.6497 - dice_coefficient_multiclass: 0.7908 - gm_iou: 0.5983 - iou_score_multiclass: 0.6850 - loss: 0.3072 - pixel_accuracy_multiclass: 0.9659 - wm_iou: 0.5149 - val_csf_iou: 0.6328 - val_dice_coefficient_multiclass: 0.8244 - val_gm_iou: 0.5972 - val_iou_score_multiclass: 0.7141 - val_loss: 0.2862 - val_pixel_accuracy_multiclass: 0.9613 - val_wm_iou: 0.6539 - learning_rate: 6.2500e-06
# Epoch 88/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - csf_iou: 0.2749 - dice_coefficient_multiclass: 0.3571 - gm_iou: 0.0054 - iou_score_multiclass: 0.3137 - loss: 0.7336 - pixel_accuracy_multiclass: 0.9963 - wm_iou: 6.7848e-04
# Epoch 88: val_iou_score_multiclass did not improve from 0.71409
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 171ms/step - csf_iou: 0.2749 - dice_coefficient_multiclass: 0.3571 - gm_iou: 0.0054 - iou_score_multiclass: 0.3137 - loss: 0.7336 - pixel_accuracy_multiclass: 0.9963 - wm_iou: 6.7848e-04 - val_csf_iou: 0.6315 - val_dice_coefficient_multiclass: 0.8240 - val_gm_iou: 0.5965 - val_iou_score_multiclass: 0.7136 - val_loss: 0.2866 - val_pixel_accuracy_multiclass: 0.9613 - val_wm_iou: 0.6543 - learning_rate: 6.2500e-06
# Epoch 89/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.6556 - dice_coefficient_multiclass: 0.7959 - gm_iou: 0.6116 - iou_score_multiclass: 0.6906 - loss: 0.2994 - pixel_accuracy_multiclass: 0.9668 - wm_iou: 0.5186
# Epoch 89: val_iou_score_multiclass did not improve from 0.71409
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 13s 405ms/step - csf_iou: 0.6486 - dice_coefficient_multiclass: 0.7908 - gm_iou: 0.5970 - iou_score_multiclass: 0.6848 - loss: 0.3074 - pixel_accuracy_multiclass: 0.9658 - wm_iou: 0.5167 - val_csf_iou: 0.6303 - val_dice_coefficient_multiclass: 0.8233 - val_gm_iou: 0.5962 - val_iou_score_multiclass: 0.7127 - val_loss: 0.2881 - val_pixel_accuracy_multiclass: 0.9611 - val_wm_iou: 0.6521 - learning_rate: 6.2500e-06
# Epoch 90/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - csf_iou: 0.2759 - dice_coefficient_multiclass: 0.3577 - gm_iou: 0.0061 - iou_score_multiclass: 0.3140 - loss: 0.7268 - pixel_accuracy_multiclass: 0.9963 - wm_iou: 6.7387e-04
# Prediction after epoch 90
#
#
# Epoch 90: val_iou_score_multiclass did not improve from 0.71409
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 185ms/step - csf_iou: 0.2759 - dice_coefficient_multiclass: 0.3577 - gm_iou: 0.0061 - iou_score_multiclass: 0.3140 - loss: 0.7268 - pixel_accuracy_multiclass: 0.9963 - wm_iou: 6.7387e-04 - val_csf_iou: 0.6281 - val_dice_coefficient_multiclass: 0.8226 - val_gm_iou: 0.5948 - val_iou_score_multiclass: 0.7117 - val_loss: 0.2893 - val_pixel_accuracy_multiclass: 0.9609 - val_wm_iou: 0.6520 - learning_rate: 6.2500e-06
# Epoch 91/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.6548 - dice_coefficient_multiclass: 0.7949 - gm_iou: 0.6110 - iou_score_multiclass: 0.6896 - loss: 0.3007 - pixel_accuracy_multiclass: 0.9667 - wm_iou: 0.5161
# Epoch 91: val_iou_score_multiclass did not improve from 0.71409
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 13s 404ms/step - csf_iou: 0.6497 - dice_coefficient_multiclass: 0.7912 - gm_iou: 0.5986 - iou_score_multiclass: 0.6857 - loss: 0.3062 - pixel_accuracy_multiclass: 0.9661 - wm_iou: 0.5172 - val_csf_iou: 0.6302 - val_dice_coefficient_multiclass: 0.8229 - val_gm_iou: 0.5944 - val_iou_score_multiclass: 0.7121 - val_loss: 0.2884 - val_pixel_accuracy_multiclass: 0.9611 - val_wm_iou: 0.6516 - learning_rate: 6.2500e-06
# Epoch 92/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - csf_iou: 0.2788 - dice_coefficient_multiclass: 0.3567 - gm_iou: 0.0024 - iou_score_multiclass: 0.3136 - loss: 0.6975 - pixel_accuracy_multiclass: 0.9971 - wm_iou: 6.3694e-04
# Epoch 92: val_iou_score_multiclass did not improve from 0.71409
#
# Epoch 92: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - csf_iou: 0.2788 - dice_coefficient_multiclass: 0.3567 - gm_iou: 0.0024 - iou_score_multiclass: 0.3136 - loss: 0.6975 - pixel_accuracy_multiclass: 0.9971 - wm_iou: 6.3694e-04 - val_csf_iou: 0.6285 - val_dice_coefficient_multiclass: 0.8222 - val_gm_iou: 0.5929 - val_iou_score_multiclass: 0.7112 - val_loss: 0.2893 - val_pixel_accuracy_multiclass: 0.9610 - val_wm_iou: 0.6516 - learning_rate: 6.2500e-06
# Epoch 93/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.6603 - dice_coefficient_multiclass: 0.7976 - gm_iou: 0.6154 - iou_score_multiclass: 0.6931 - loss: 0.2959 - pixel_accuracy_multiclass: 0.9675 - wm_iou: 0.5197
# Epoch 93: val_iou_score_multiclass improved from 0.71409 to 0.71439, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 93: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 455ms/step - csf_iou: 0.6531 - dice_coefficient_multiclass: 0.7921 - gm_iou: 0.6000 - iou_score_multiclass: 0.6869 - loss: 0.3042 - pixel_accuracy_multiclass: 0.9665 - wm_iou: 0.5170 - val_csf_iou: 0.6346 - val_dice_coefficient_multiclass: 0.8246 - val_gm_iou: 0.5964 - val_iou_score_multiclass: 0.7144 - val_loss: 0.2853 - val_pixel_accuracy_multiclass: 0.9615 - val_wm_iou: 0.6541 - learning_rate: 3.1250e-06
# Epoch 94/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - csf_iou: 0.3001 - dice_coefficient_multiclass: 0.3636 - gm_iou: 0.0031 - iou_score_multiclass: 0.3195 - loss: 0.6893 - pixel_accuracy_multiclass: 0.9971 - wm_iou: 6.7644e-04
# Epoch 94: val_iou_score_multiclass did not improve from 0.71439
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 168ms/step - csf_iou: 0.3001 - dice_coefficient_multiclass: 0.3636 - gm_iou: 0.0031 - iou_score_multiclass: 0.3195 - loss: 0.6893 - pixel_accuracy_multiclass: 0.9971 - wm_iou: 6.7644e-04 - val_csf_iou: 0.6324 - val_dice_coefficient_multiclass: 0.8238 - val_gm_iou: 0.5946 - val_iou_score_multiclass: 0.7133 - val_loss: 0.2868 - val_pixel_accuracy_multiclass: 0.9613 - val_wm_iou: 0.6538 - learning_rate: 3.1250e-06
# Epoch 95/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.6581 - dice_coefficient_multiclass: 0.7962 - gm_iou: 0.6122 - iou_score_multiclass: 0.6911 - loss: 0.2985 - pixel_accuracy_multiclass: 0.9670 - wm_iou: 0.5171
# Epoch 95: val_iou_score_multiclass improved from 0.71439 to 0.71518, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 95: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 452ms/step - csf_iou: 0.6523 - dice_coefficient_multiclass: 0.7920 - gm_iou: 0.5998 - iou_score_multiclass: 0.6866 - loss: 0.3049 - pixel_accuracy_multiclass: 0.9662 - wm_iou: 0.5169 - val_csf_iou: 0.6344 - val_dice_coefficient_multiclass: 0.8252 - val_gm_iou: 0.5969 - val_iou_score_multiclass: 0.7152 - val_loss: 0.2844 - val_pixel_accuracy_multiclass: 0.9616 - val_wm_iou: 0.6568 - learning_rate: 3.1250e-06
# Epoch 96/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - csf_iou: 0.2778 - dice_coefficient_multiclass: 0.3597 - gm_iou: 0.0086 - iou_score_multiclass: 0.3155 - loss: 0.7262 - pixel_accuracy_multiclass: 0.9971 - wm_iou: 6.8253e-04
# Epoch 96: val_iou_score_multiclass did not improve from 0.71518
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 169ms/step - csf_iou: 0.2778 - dice_coefficient_multiclass: 0.3597 - gm_iou: 0.0086 - iou_score_multiclass: 0.3155 - loss: 0.7262 - pixel_accuracy_multiclass: 0.9971 - wm_iou: 6.8253e-04 - val_csf_iou: 0.6327 - val_dice_coefficient_multiclass: 0.8245 - val_gm_iou: 0.5957 - val_iou_score_multiclass: 0.7143 - val_loss: 0.2855 - val_pixel_accuracy_multiclass: 0.9614 - val_wm_iou: 0.6565 - learning_rate: 3.1250e-06
# Epoch 97/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.6569 - dice_coefficient_multiclass: 0.7966 - gm_iou: 0.6124 - iou_score_multiclass: 0.6915 - loss: 0.2983 - pixel_accuracy_multiclass: 0.9670 - wm_iou: 0.5199
# Epoch 97: val_iou_score_multiclass improved from 0.71518 to 0.71592, saving model to best_model_segnet_mrbrains.keras
#
# Epoch 97: finished saving model to best_model_segnet_mrbrains.keras
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 454ms/step - csf_iou: 0.6517 - dice_coefficient_multiclass: 0.7924 - gm_iou: 0.6004 - iou_score_multiclass: 0.6870 - loss: 0.3044 - pixel_accuracy_multiclass: 0.9663 - wm_iou: 0.5185 - val_csf_iou: 0.6349 - val_dice_coefficient_multiclass: 0.8257 - val_gm_iou: 0.5982 - val_iou_score_multiclass: 0.7159 - val_loss: 0.2836 - val_pixel_accuracy_multiclass: 0.9616 - val_wm_iou: 0.6579 - learning_rate: 3.1250e-06
# Epoch 98/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - csf_iou: 0.2828 - dice_coefficient_multiclass: 0.3588 - gm_iou: 0.0037 - iou_score_multiclass: 0.3154 - loss: 0.7313 - pixel_accuracy_multiclass: 0.9968 - wm_iou: 6.7942e-04
# Epoch 98: val_iou_score_multiclass did not improve from 0.71592
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 171ms/step - csf_iou: 0.2828 - dice_coefficient_multiclass: 0.3588 - gm_iou: 0.0037 - iou_score_multiclass: 0.3154 - loss: 0.7313 - pixel_accuracy_multiclass: 0.9968 - wm_iou: 6.7942e-04 - val_csf_iou: 0.6336 - val_dice_coefficient_multiclass: 0.8253 - val_gm_iou: 0.5976 - val_iou_score_multiclass: 0.7153 - val_loss: 0.2841 - val_pixel_accuracy_multiclass: 0.9616 - val_wm_iou: 0.6575 - learning_rate: 3.1250e-06
# Epoch 99/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - csf_iou: 0.6598 - dice_coefficient_multiclass: 0.7986 - gm_iou: 0.6165 - iou_score_multiclass: 0.6939 - loss: 0.2946 - pixel_accuracy_multiclass: 0.9675 - wm_iou: 0.5222
# Epoch 99: val_iou_score_multiclass did not improve from 0.71592
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 13s 405ms/step - csf_iou: 0.6533 - dice_coefficient_multiclass: 0.7933 - gm_iou: 0.6013 - iou_score_multiclass: 0.6880 - loss: 0.3026 - pixel_accuracy_multiclass: 0.9665 - wm_iou: 0.5199 - val_csf_iou: 0.6365 - val_dice_coefficient_multiclass: 0.8257 - val_gm_iou: 0.5986 - val_iou_score_multiclass: 0.7158 - val_loss: 0.2836 - val_pixel_accuracy_multiclass: 0.9616 - val_wm_iou: 0.6554 - learning_rate: 3.1250e-06
# Epoch 100/100
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - csf_iou: 0.2757 - dice_coefficient_multiclass: 0.3580 - gm_iou: 0.0065 - iou_score_multiclass: 0.3143 - loss: 0.7283 - pixel_accuracy_multiclass: 0.9961 - wm_iou: 6.8757e-04
# Prediction after epoch 100
#
#
# Epoch 100: val_iou_score_multiclass did not improve from 0.71592
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 205ms/step - csf_iou: 0.2757 - dice_coefficient_multiclass: 0.3580 - gm_iou: 0.0065 - iou_score_multiclass: 0.3143 - loss: 0.7283 - pixel_accuracy_multiclass: 0.9961 - wm_iou: 6.8757e-04 - val_csf_iou: 0.6352 - val_dice_coefficient_multiclass: 0.8253 - val_gm_iou: 0.5980 - val_iou_score_multiclass: 0.7153 - val_loss: 0.2842 - val_pixel_accuracy_multiclass: 0.9615 - val_wm_iou: 0.6553 - learning_rate: 3.1250e-06
#
# Training time: 17.8 min

# %% [markdown]
# ## 13. Training Graphs

# %%
H = history.history

fig, axes = plt.subplots(4, 2, figsize=(14, 20))
fig.suptitle('SegNet (Multi-Class)  |  MRBrainS18  |  Training History',
             fontsize=15, fontweight='bold', y=0.99)

plot_specs = [
    ('loss', 'val_loss', 'Loss (Dice + CCE)', 'Loss'),
    ('dice_coefficient_multiclass', 'val_dice_coefficient_multiclass', 'Dice (macro-avg)', 'Dice'),
    ('iou_score_multiclass', 'val_iou_score_multiclass', 'IoU (macro-avg)', 'IoU'),
    ('pixel_accuracy_multiclass', 'val_pixel_accuracy_multiclass', 'Pixel Accuracy', 'Accuracy'),
    ('csf_iou', 'val_csf_iou', 'CSF IoU', 'IoU'),
    ('gm_iou', 'val_gm_iou', 'Grey Matter IoU', 'IoU'),
    ('wm_iou', 'val_wm_iou', 'White Matter IoU', 'IoU'),
]

for ax, (tk, vk, title, ylabel) in zip(axes.flatten(), plot_specs):
    er = range(1, len(H[tk]) + 1)
    ax.plot(er, H[tk], label='Train', color='steelblue', linewidth=2)
    ax.plot(er, H[vk], label='Val', color='darkorange', linewidth=2, linestyle='--')
    ax.set_title(title, fontsize=12, fontweight='bold')
    ax.set_xlabel('Epoch'); ax.set_ylabel(ylabel)
    ax.legend(fontsize=10); ax.grid(True, alpha=0.3)

axes.flatten()[-1].axis('off')
plt.tight_layout()
plt.savefig('training_history_segnet_mrbrains.png', dpi=150, bbox_inches='tight')
plt.show()
print('Plot saved ✓')
# Out:
# Plot saved ✓

# %% [markdown]
# ## 14. Best & Average Metrics Table

# %%
metric_spec = [
    ('Loss', 'loss', 'min'),
    ('Dice (macro-avg)', 'dice_coefficient_multiclass', 'max'),
    ('IoU (macro-avg)', 'iou_score_multiclass', 'max'),
    ('Pixel Accuracy', 'pixel_accuracy_multiclass', 'max'),
    ('CSF IoU', 'csf_iou', 'max'),
    ('Grey Matter IoU', 'gm_iou', 'max'),
    ('White Matter IoU', 'wm_iou', 'max'),
]

rows = []
for disp, key, mode in metric_spec:
    tr = np.asarray(H[key], dtype=np.float64)
    va = np.asarray(H['val_' + key], dtype=np.float64)
    pick = np.min if mode == 'min' else np.max
    rows.append({'Metric': disp, 'Train Best': pick(tr), 'Train Avg': tr.mean(),
                 'Val Best': pick(va), 'Val Avg': va.mean()})

report = pd.DataFrame(rows).set_index('Metric').round(4)

print('=' * 68)
print('   BEST & AVERAGE METRICS  —  SegNet Multi-Class  |  MRBrainS18')
print('=' * 68)
print(report.to_string())
print('=' * 68)
best_epoch = int(np.argmax(H['val_iou_score_multiclass'])) + 1
print(f'\nBest Val IoU (macro-avg): {max(H["val_iou_score_multiclass"]):.4f}  (epoch {best_epoch})')
print(f'Best Val CSF IoU         : {max(H["val_csf_iou"]):.4f}')
print(f'Best Val Grey Matter IoU : {max(H["val_gm_iou"]):.4f}')
print(f'Best Val White Matter IoU: {max(H["val_wm_iou"]):.4f}')
report
# Out:
# ====================================================================
#    BEST & AVERAGE METRICS  —  SegNet Multi-Class  |  MRBrainS18
# ====================================================================
#                   Train Best  Train Avg  Val Best  Val Avg
# Metric
# Loss                  0.3026     0.7220    0.2836   0.6539
# Dice (macro-avg)      0.7933     0.4939    0.8257   0.6446
# IoU (macro-avg)       0.6880     0.4197    0.7159   0.5379
# Pixel Accuracy        0.9972     0.9583    0.9616   0.9171
# CSF IoU               0.6533     0.3364    0.6365   0.4299
# Grey Matter IoU       0.6013     0.2278    0.5986   0.3992
# White Matter IoU      0.5199     0.1994    0.6589   0.4465
# ====================================================================
#
# Best Val IoU (macro-avg): 0.7159  (epoch 97)
# Best Val CSF IoU         : 0.6365
# Best Val Grey Matter IoU : 0.5986
# Best Val White Matter IoU: 0.6589
#                   Train Best  Train Avg  Val Best  Val Avg
# Metric
# Loss                  0.3026     0.7220    0.2836   0.6539
# Dice (macro-avg)      0.7933     0.4939    0.8257   0.6446
# IoU (macro-avg)       0.6880     0.4197    0.7159   0.5379
# Pixel Accuracy        0.9972     0.9583    0.9616   0.9171
# CSF IoU               0.6533     0.3364    0.6365   0.4299
# Grey Matter IoU       0.6013     0.2278    0.5986   0.3992
# White Matter IoU      0.5199     0.1994    0.6589   0.4465

# %% [markdown]
# ## 15. Load Best Model & Final Evaluation

# %%
best_model = tf.keras.models.load_model(
    'best_model_segnet_mrbrains.keras',
    custom_objects={
        'combined_loss_multiclass':    combined_loss_multiclass,
        'dice_coefficient_multiclass': dice_coefficient_multiclass,
        'iou_score_multiclass':        iou_score_multiclass,
        'pixel_accuracy_multiclass':   pixel_accuracy_multiclass,
        'csf_iou': csf_iou, 'gm_iou': gm_iou, 'wm_iou': wm_iou,
        'MaxPoolingWithIndices':        MaxPoolingWithIndices,
        'MaxUnpooling':                MaxUnpooling,
    }
)
print('Best model loaded ✓')
# Out:
# Best model loaded ✓

# %%
test_results = best_model.evaluate(test_dataset, verbose=1)
test_dict = dict(zip(best_model.metrics_names, test_results))

print('\n' + '=' * 60)
print('  FINAL TEST-SET METRICS  (SegNet | MRBrainS18)')
print('=' * 60)
for k, v in test_dict.items():
    print(f'  {k:35s}: {v:.4f}')
print('=' * 60)

pd.DataFrame([{
    'Model': 'SegNet (MRBrainS18)',
    'IoU (macro)': round(test_dict.get('iou_score_multiclass', float('nan')), 4),
    'Dice (macro)': round(test_dict.get('dice_coefficient_multiclass', float('nan')), 4),
    'CSF IoU': round(test_dict.get('csf_iou', float('nan')), 4),
    'GM IoU': round(test_dict.get('gm_iou', float('nan')), 4),
    'WM IoU': round(test_dict.get('wm_iou', float('nan')), 4),
    'Pixel Accuracy': round(test_dict.get('pixel_accuracy_multiclass', float('nan')), 4),
}]).set_index('Model')
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - csf_iou: 0.6403 - dice_coefficient_multiclass: 0.8183 - gm_iou: 0.5975 - iou_score_multiclass: 0.7081 - loss: 0.2844 - pixel_accuracy_multiclass: 0.9637 - wm_iou: 0.6208
#
# ============================================================
#   FINAL TEST-SET METRICS  (SegNet | MRBrainS18)
# ============================================================
#   loss                               : 0.2844
#   compile_metrics                    : 0.8183
# ============================================================
#                      IoU (macro)  Dice (macro)  CSF IoU  GM IoU  WM IoU  \
# Model
# SegNet (MRBrainS18)          NaN           NaN      NaN     NaN     NaN
#
#                      Pixel Accuracy
# Model
# SegNet (MRBrainS18)             NaN

# %% [markdown]
# ## 16. Test Predictions Visualization

# %%
show_predictions(test_dataset, num=5, model_to_use=best_model)

# %% [markdown]
# ## 17. Save Final Model

# %%
best_model.save('mrbrains_segnet_multiclass_final.keras')
print('Model saved ✓')
# Out:
# Model saved ✓
