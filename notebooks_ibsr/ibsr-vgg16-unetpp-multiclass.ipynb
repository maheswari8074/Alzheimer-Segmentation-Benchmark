# %% [markdown]
# # Alzheimer's Disease Brain MRI — Multi-Class Tissue Segmentation
# ## VGG16 + UNet++ | 4-Class (Background / CSF / Grey Matter / White Matter) | IBSR Dataset
#
# **Dataset:** Internet Brain Segmentation Repository (IBSR) — 18 subjects, expert-annotated tri-class tissue segmentation (`segTRI`).
#
# **Architecture:** UNet++ (Nested UNet) replaces plain UNet skip connections with dense nested sub-networks between encoder and decoder, enabling multi-scale feature re-use and stronger gradient flow.
#
# **Why multi-class directly (no binary step):** The binary-then-multiclass pipeline was already validated on OASIS-1. Since IBSR's `segTRI` masks use the same 4-label convention (0=background, 1=CSF, 2=GM, 3=WM), we go directly to multi-class here.
#
# **Note:** EarlyStopping disabled — model trains for the full configured epochs as instructed.
#
# **Note on CSF class:** IBSR's CSF label is far sparser (~0.17% of voxels) than OASIS-1's (~7.5%) — expect CSF IoU to be a harder, noisier metric here purely due to extreme class imbalance, not a pipeline issue.

# %% [markdown]
# ## 1. Import Libraries

# %%
import os
import re
import cv2
import random
import shutil
import tarfile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import (
    Input, Conv2D, UpSampling2D, concatenate, BatchNormalization, Dropout, Activation
)
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG16
from tensorflow.keras import callbacks
from sklearn.model_selection import train_test_split
from tqdm.auto import tqdm
import time
import datetime

# !pip install nibabel -q
import nibabel as nib

print('TensorFlow version:', tf.__version__)
print('GPUs available:', tf.config.list_physical_devices('GPU'))
# Out:
# 2026-06-29 09:53:08.621472: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1782726788.828192      58 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1782726788.883660      58 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1782726789.318294      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782726789.318333      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782726789.318336      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782726789.318338      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow version: 2.19.0
# GPUs available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 2. Configuration & Extraction

# %%
# ─── Paths ────────────────────────────────────────────────────────────────────
IBSR_TGZ_PATH = '/kaggle/input/datasets/mahi789/ibsr-datasett/IBSR_V2.0_nifti_stripped.tgz'
EXTRACT_DIR   = '/kaggle/working/ibsr_extracted'
IBSR_ROOT     = os.path.join(EXTRACT_DIR, 'IBSR_nifti_stripped')

PROCESSED_DIR   = 'ibsr_processed'
IMAGE_FOLDER    = os.path.join(PROCESSED_DIR, 'images')
MASK_FOLDER     = os.path.join(PROCESSED_DIR, 'masks')
TRAIN_IMG_DIR   = os.path.join(PROCESSED_DIR, 'train', 'images')
TRAIN_MASK_DIR  = os.path.join(PROCESSED_DIR, 'train', 'masks')
TEST_IMG_DIR    = os.path.join(PROCESSED_DIR, 'test',  'images')
TEST_MASK_DIR   = os.path.join(PROCESSED_DIR, 'test',  'masks')

# ─── Hyperparameters ──────────────────────────────────────────────────────────
IMG_SIZE    = (224, 224)
BATCH_SIZE  = 16
EPOCHS      = 100
SEED        = 42
TEST_SPLIT  = 0.15
NUM_CLASSES = 4   # 0=background, 1=CSF, 2=Grey Matter, 3=White Matter
CLASS_NAMES = ['Background', 'CSF', 'Grey Matter', 'White Matter']

print('Config set ✓')
# Out:
# Config set ✓

# %%
# ─── Extract the .tgz if not already done ─────────────────────────────────────
if not os.path.exists(IBSR_ROOT):
    os.makedirs(EXTRACT_DIR, exist_ok=True)
    print('Extracting IBSR archive...')
    with tarfile.open(IBSR_TGZ_PATH, 'r:gz') as tar:
        tar.extractall(path=EXTRACT_DIR)
    print('Extraction done ✓')
else:
    print('Already extracted ✓')

subject_folders = sorted([
    d for d in os.listdir(IBSR_ROOT)
    if os.path.isdir(os.path.join(IBSR_ROOT, d)) and d.startswith('IBSR_')
])
print(f'Found {len(subject_folders)} subjects: {subject_folders}')
# Out:
# Extracting IBSR archive...
# Extraction done ✓
# Found 18 subjects: ['IBSR_01', 'IBSR_02', 'IBSR_03', 'IBSR_04', 'IBSR_05', 'IBSR_06', 'IBSR_07', 'IBSR_08', 'IBSR_09', 'IBSR_10', 'IBSR_11', 'IBSR_12', 'IBSR_13', 'IBSR_14', 'IBSR_15', 'IBSR_16', 'IBSR_17', 'IBSR_18']

# %% [markdown]
# ## 3. Extract 2D Slices — Keep All 4 Tissue Labels

# %%
def make_dir(path):
    os.makedirs(path, exist_ok=True)

for d in [IMAGE_FOLDER, MASK_FOLDER,
          TRAIN_IMG_DIR, TRAIN_MASK_DIR,
          TEST_IMG_DIR,  TEST_MASK_DIR]:
    make_dir(d)

print('Directories ready ✓')
# Out:
# Directories ready ✓

# %%
def normalize_slice(arr):
    """Min-max normalise a 2-D array to [0, 255] uint8."""
    mn, mx = arr.min(), arr.max()
    if mx - mn == 0:
        return np.zeros_like(arr, dtype=np.uint8)
    return ((arr - mn) / (mx - mn) * 255).astype(np.uint8)


def extract_slices_ibsr(subject_dir, subject_name, img_out, mask_out, step=1):
    """
    IBSR file naming: <subject>_ana_strip.nii.gz  (skull-stripped brain)
                       <subject>_segTRI_ana.nii    (4-class tissue mask)
    Both are (256, 128, 256, 1) — squeeze the trailing singleton dim.
    Mask labels kept as raw integers 0/1/2/3.
    """
    brain_path = os.path.join(subject_dir, f'{subject_name}_ana_strip.nii.gz')
    seg_path   = os.path.join(subject_dir, f'{subject_name}_segTRI_ana.nii')

    if not os.path.exists(brain_path) or not os.path.exists(seg_path):
        print(f'  Skipping {subject_name} — missing file(s)')
        return 0

    brain_vol = np.squeeze(nib.load(brain_path).get_fdata())
    seg_vol   = np.squeeze(nib.load(seg_path).get_fdata())

    saved = 0
    for i in range(0, brain_vol.shape[1], step):
        b_sl   = brain_vol[:, i, :]
        seg_sl = seg_vol[:, i, :]

        if b_sl.max() == 0:
            continue

        img_arr  = normalize_slice(b_sl)
        mask_arr = np.round(seg_sl).astype(np.uint8)
        mask_arr = np.clip(mask_arr, 0, NUM_CLASSES - 1)

        fname = f'{subject_name}_sl{i:03d}.png'
        cv2.imwrite(os.path.join(img_out,  fname), img_arr)
        cv2.imwrite(os.path.join(mask_out, fname), mask_arr)
        saved += 1

    return saved


for folder in [IMAGE_FOLDER, MASK_FOLDER]:
    if os.path.exists(folder):
        shutil.rmtree(folder)
    os.makedirs(folder)

total_slices = 0
for subj_name in tqdm(subject_folders, desc='Extracting slices'):
    subj_dir = os.path.join(IBSR_ROOT, subj_name)
    total_slices += extract_slices_ibsr(subj_dir, subj_name, IMAGE_FOLDER, MASK_FOLDER, step=1)

print(f'\nTotal slices extracted : {total_slices}')
print(f'Images saved           : {len(os.listdir(IMAGE_FOLDER))}')
print(f'Masks  saved           : {len(os.listdir(MASK_FOLDER))}')
print('Note: step=1 (every slice) since IBSR only has 18 subjects.')
# Out:
# Extracting slices:   0%|          | 0/18 [00:00<?, ?it/s]
#   Skipping IBSR_02 — missing file(s)
#   Skipping IBSR_03 — missing file(s)
#   Skipping IBSR_04 — missing file(s)
#   Skipping IBSR_05 — missing file(s)
#   Skipping IBSR_07 — missing file(s)
#   Skipping IBSR_08 — missing file(s)
#   Skipping IBSR_09 — missing file(s)
#   Skipping IBSR_10 — missing file(s)
#   Skipping IBSR_11 — missing file(s)
#   Skipping IBSR_12 — missing file(s)
#   Skipping IBSR_13 — missing file(s)
#   Skipping IBSR_14 — missing file(s)
#   Skipping IBSR_15 — missing file(s)
#   Skipping IBSR_16 — missing file(s)
#   Skipping IBSR_17 — missing file(s)
#   Skipping IBSR_18 — missing file(s)
#
# Total slices extracted : 236
# Images saved           : 236
# Masks  saved           : 236
# Note: step=1 (every slice) since IBSR only has 18 subjects.

# %% [markdown]
# ## 4. Verify Label Distribution & Visualize

# %%
sample_mask_files = random.sample(os.listdir(MASK_FOLDER), min(20, len(os.listdir(MASK_FOLDER))))
all_vals = set()
for f in sample_mask_files:
    m = cv2.imread(os.path.join(MASK_FOLDER, f), cv2.IMREAD_GRAYSCALE)
    all_vals.update(np.unique(m).tolist())

print('Unique label values found across sample masks:', sorted(all_vals))
print('Expected: [0, 1, 2, 3]  (Background, CSF, Grey Matter, White Matter)')
# Out:
# Unique label values found across sample masks: [0, 1, 2, 3]
# Expected: [0, 1, 2, 3]  (Background, CSF, Grey Matter, White Matter)

# %%
CLASS_COLORS = ['black', 'cyan', 'orange', 'magenta']
cmap_classes = mcolors.ListedColormap(CLASS_COLORS)

def visualize_sample_multiclass(image_name, img_dir=IMAGE_FOLDER, mask_dir=MASK_FOLDER):
    img  = cv2.imread(os.path.join(img_dir,  image_name), cv2.IMREAD_GRAYSCALE)
    mask = cv2.imread(os.path.join(mask_dir, image_name), cv2.IMREAD_GRAYSCALE)

    fig, axes = plt.subplots(1, 2, figsize=(12, 6))
    axes[0].imshow(img, cmap='gray')
    axes[0].set_title('Brain MRI Slice', fontsize=13)

    im = axes[1].imshow(mask, cmap=cmap_classes, vmin=0, vmax=NUM_CLASSES - 1)
    axes[1].set_title('Tissue Labels (CSF / GM / WM)', fontsize=13)
    cbar = plt.colorbar(im, ax=axes[1], ticks=range(NUM_CLASSES))
    cbar.ax.set_yticklabels(CLASS_NAMES)

    for ax in axes: ax.axis('off')
    plt.suptitle(image_name, fontsize=10, color='gray')
    plt.tight_layout()
    plt.show()


all_images = os.listdir(IMAGE_FOLDER)
for _ in range(4):
    visualize_sample_multiclass(random.choice(all_images))

# %% [markdown]
# ## 5. Train / Test Split

# %%
images = sorted([f for f in os.listdir(IMAGE_FOLDER) if f.endswith('.png')])
masks  = sorted([f for f in os.listdir(MASK_FOLDER)  if f.endswith('.png')])

assert images == masks, 'Image-mask mismatch! Check filenames.'

train_imgs, test_imgs = train_test_split(images, test_size=TEST_SPLIT, random_state=SEED)
print(f'Train: {len(train_imgs)}  |  Test: {len(test_imgs)}')

def copy_files(file_list, src_img, src_mask, dst_img, dst_mask):
    for f in tqdm(file_list, leave=False):
        shutil.copy(os.path.join(src_img,  f), os.path.join(dst_img,  f))
        shutil.copy(os.path.join(src_mask, f), os.path.join(dst_mask, f))

copy_files(train_imgs, IMAGE_FOLDER, MASK_FOLDER, TRAIN_IMG_DIR, TRAIN_MASK_DIR)
copy_files(test_imgs,  IMAGE_FOLDER, MASK_FOLDER, TEST_IMG_DIR,  TEST_MASK_DIR)
print('Files copied ✓')
# Out:
# Train: 200  |  Test: 36
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/36 [00:00<?, ?it/s]
# Files copied ✓

# %% [markdown]
# ## 6. tf.data Pipeline — one-hot encoded masks

# %%
def load_image(img_path, mask_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE, method='bilinear')
    img = tf.cast(img, tf.float32) / 255.0

    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=1)
    mask = tf.image.resize(mask, IMG_SIZE, method='nearest')
    mask = tf.cast(mask, tf.int32)
    mask = tf.squeeze(mask, axis=-1)
    mask = tf.one_hot(mask, depth=NUM_CLASSES)
    mask = tf.cast(mask, tf.float32)

    return img, mask


def augment(img, mask):
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_left_right(img)
        mask = tf.image.flip_left_right(mask)
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_up_down(img)
        mask = tf.image.flip_up_down(mask)
    img = tf.image.random_brightness(img, max_delta=0.05)
    img = tf.clip_by_value(img, 0.0, 1.0)
    return img, mask


def build_dataset(img_dir, mask_dir, augment_data=False, batch=BATCH_SIZE):
    img_files  = sorted([os.path.join(img_dir,  f) for f in os.listdir(img_dir)  if f.endswith('.png')])
    mask_files = sorted([os.path.join(mask_dir, f) for f in os.listdir(mask_dir) if f.endswith('.png')])

    ds = tf.data.Dataset.from_tensor_slices((img_files, mask_files))
    ds = ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
    if augment_data:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch).prefetch(tf.data.AUTOTUNE)
    return ds


train_dataset = build_dataset(TRAIN_IMG_DIR, TRAIN_MASK_DIR, augment_data=True)
test_dataset  = build_dataset(TEST_IMG_DIR,  TEST_MASK_DIR,  augment_data=False)

print('Datasets ready ✓')
for imgs, masks in train_dataset.take(1):
    print('Batch shapes →  images:', imgs.shape, ' masks:', masks.shape)
# Out:
# I0000 00:00:1782726811.694439      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Datasets ready ✓
# Batch shapes →  images: (16, 224, 224, 3)  masks: (16, 224, 224, 4)

# %% [markdown]
# ## 7. Model — VGG16 Encoder + UNet++ Decoder, 4-class softmax output
#
# ### UNet++ Architecture
#
# UNet++ (Zhou et al., 2018) replaces the single long skip connections of UNet with **dense nested sub-networks**:
#
# - Each node `X^{i,j}` receives feature maps from:
#   - All previous nodes in the same encoder level: `X^{i,0..j-1}` (horizontal dense connections)
#   - The upsampled output from one level deeper: `X^{i+1,j-1}` (vertical / decoder path)
# - This creates **progressive feature aggregation** across multiple semantic scales.
# - Deep supervision can optionally be applied at each depth output (not used here).
#
# ```
# Encoder (VGG16)         Dense Nodes                         Output
# X00  ─────────────── X01 ────── X02 ────── X03 ────── X04  → softmax
# X10  ──────────────────────── X11 ────── X12 ────── X13
# X20  ──────────────────────────────────── X21 ────── X22
# X30  ──────────────────────────────────────────────── X31
# X40  (bottleneck)
# ```

# %%
def conv_block(x, filters, name_prefix):
    """Standard double-conv block with BN + ReLU."""
    x = Conv2D(filters, (3, 3), padding='same', name=f'{name_prefix}_c1')(x)
    x = BatchNormalization(name=f'{name_prefix}_bn1')(x)
    x = Activation('relu', name=f'{name_prefix}_act1')(x)
    x = Conv2D(filters, (3, 3), padding='same', name=f'{name_prefix}_c2')(x)
    x = BatchNormalization(name=f'{name_prefix}_bn2')(x)
    x = Activation('relu', name=f'{name_prefix}_act2')(x)
    return x


def unetpp_node(up_input, skip_inputs, filters, name_prefix):
    """
    UNet++ dense node X^{i,j}:
      - up_input    : upsampled tensor from X^{i+1, j-1}  (vertical path)
      - skip_inputs : list of X^{i, 0..j-1}               (horizontal dense path)
      - filters     : number of conv filters
    """
    x = UpSampling2D((2, 2), name=f'{name_prefix}_up')(up_input)
    x = concatenate([x] + skip_inputs, name=f'{name_prefix}_cat')
    x = Dropout(0.2, name=f'{name_prefix}_drop')(x)
    x = conv_block(x, filters, name_prefix)
    return x


def build_vgg16_unetpp_multiclass(input_shape=(224, 224, 3), num_classes=4, freeze_encoder=True):
    """
    VGG16 encoder with UNet++ nested decoder.

    Encoder nodes (VGG16 feature map outputs):
      X00 = block1_conv2  (224x224,  64 ch)
      X10 = block2_conv2  (112x112, 128 ch)
      X20 = block3_conv3  ( 56x56,  256 ch)
      X30 = block4_conv3  ( 28x28,  512 ch)
      X40 = block5_conv3  ( 14x14,  512 ch)  <- bottleneck

    Dense decoder nodes:
      Depth 1 : X31, X21, X11, X01
      Depth 2 : X22, X12, X02
      Depth 3 : X13, X03
      Depth 4 : X04  <- final output node
    """
    inputs = Input(shape=input_shape, name='input')
    base   = VGG16(include_top=False, weights='imagenet', input_tensor=inputs)

    if freeze_encoder:
        for layer in base.layers:
            layer.trainable = False

    # ── Encoder nodes ─────────────────────────────────────────────────────────
    X00 = base.get_layer('block1_conv2').output   # 224x224, 64
    X10 = base.get_layer('block2_conv2').output   # 112x112, 128
    X20 = base.get_layer('block3_conv3').output   #  56x56,  256
    X30 = base.get_layer('block4_conv3').output   #  28x28,  512
    X40 = base.get_layer('block5_conv3').output   #  14x14,  512

    # ── Depth 1 — one step up from each encoder level ─────────────────────────
    X31 = unetpp_node(X40, [X30],        512, 'X31')
    X21 = unetpp_node(X30, [X20],        256, 'X21')
    X11 = unetpp_node(X20, [X10],        128, 'X11')
    X01 = unetpp_node(X10, [X00],         64, 'X01')

    # ── Depth 2 — dense connections accumulate ────────────────────────────────
    X22 = unetpp_node(X31, [X20, X21],   256, 'X22')
    X12 = unetpp_node(X21, [X10, X11],   128, 'X12')
    X02 = unetpp_node(X11, [X00, X01],    64, 'X02')

    # ── Depth 3 ───────────────────────────────────────────────────────────────
    X13 = unetpp_node(X22, [X10, X11, X12], 128, 'X13')
    X03 = unetpp_node(X12, [X00, X01, X02],  64, 'X03')

    # ── Depth 4 — final decoder node ──────────────────────────────────────────
    X04 = unetpp_node(X13, [X00, X01, X02, X03], 64, 'X04')

    # ── Output head ───────────────────────────────────────────────────────────
    output = Conv2D(num_classes, (1, 1), activation='softmax', name='output')(X04)

    model = Model(inputs=inputs, outputs=output, name='VGG16_UNetPP_MultiClass')
    return model


model = build_vgg16_unetpp_multiclass(
    input_shape=(*IMG_SIZE, 3), num_classes=NUM_CLASSES, freeze_encoder=True
)
print('Model built ✓')
print(f'Total parameters      : {model.count_params():,}')
print(f'Trainable parameters  : {sum([K.count_params(w) for w in model.trainable_weights]):,}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model built ✓
# Total parameters      : 30,140,740
# Trainable parameters  : 15,419,396

# %% [markdown]
# ## 8. Custom Metrics & Loss — categorical versions

# %%
def dice_coefficient_multiclass(y_true, y_pred, smooth=1.0):
    y_true_f = K.reshape(y_true, [-1, NUM_CLASSES])
    y_pred_f = K.reshape(y_pred, [-1, NUM_CLASSES])
    intersection = K.sum(y_true_f * y_pred_f, axis=0)
    union = K.sum(y_true_f, axis=0) + K.sum(y_pred_f, axis=0)
    dice_per_class = (2.0 * intersection + smooth) / (union + smooth)
    return K.mean(dice_per_class)


def dice_loss_multiclass(y_true, y_pred):
    return 1.0 - dice_coefficient_multiclass(y_true, y_pred)


def iou_score_multiclass(y_true, y_pred, smooth=1.0):
    y_true_f = K.reshape(y_true, [-1, NUM_CLASSES])
    y_pred_f = K.reshape(y_pred, [-1, NUM_CLASSES])
    intersection = K.sum(y_true_f * y_pred_f, axis=0)
    total = K.sum(y_true_f, axis=0) + K.sum(y_pred_f, axis=0) - intersection
    iou_per_class = (intersection + smooth) / (total + smooth)
    return K.mean(iou_per_class)


def csf_iou(y_true, y_pred, smooth=1.0):
    t = y_true[..., 1]; p = y_pred[..., 1]
    intersection = K.sum(t * p)
    union = K.sum(t) + K.sum(p) - intersection
    return (intersection + smooth) / (union + smooth)


def gm_iou(y_true, y_pred, smooth=1.0):
    t = y_true[..., 2]; p = y_pred[..., 2]
    intersection = K.sum(t * p)
    union = K.sum(t) + K.sum(p) - intersection
    return (intersection + smooth) / (union + smooth)


def wm_iou(y_true, y_pred, smooth=1.0):
    t = y_true[..., 3]; p = y_pred[..., 3]
    intersection = K.sum(t * p)
    union = K.sum(t) + K.sum(p) - intersection
    return (intersection + smooth) / (union + smooth)


def pixel_accuracy_multiclass(y_true, y_pred):
    true_labels = K.argmax(y_true, axis=-1)
    pred_labels = K.argmax(y_pred, axis=-1)
    correct = K.cast(K.equal(true_labels, pred_labels), K.floatx())
    return K.mean(correct)


def combined_loss_multiclass(y_true, y_pred):
    return dice_loss_multiclass(y_true, y_pred) + tf.keras.losses.categorical_crossentropy(y_true, y_pred)


model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=combined_loss_multiclass,
    metrics=[dice_coefficient_multiclass, iou_score_multiclass, pixel_accuracy_multiclass,
             csf_iou, gm_iou, wm_iou]
)

print('Model compiled ✓')
# Out:
# Model compiled ✓

# %% [markdown]
# ## 9. Model Summary

# %%
model.summary()

try:
    tf.keras.utils.plot_model(
        model, to_file='vgg16_unetpp_multiclass_ibsr_architecture.png',
        show_shapes=True, show_layer_names=True, rankdir='TB', dpi=64
    )
    print('Architecture diagram saved ✓')
except Exception as e:
    print('Architecture plot skipped:', str(e)[:150])
# Out:
# Model: "VGG16_UNetPP_MultiClass"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 224, 224,  │          0 │ -                 │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 224, 224,  │      1,792 │ input[0][0]       │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 224, 224,  │     36,928 │ block1_conv1[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 112, 112,  │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 112, 112,  │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 112, 112,  │    147,584 │ block2_conv1[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 56, 56,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 56, 56,    │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 56, 56,    │    590,080 │ block3_conv1[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 56, 56,    │    590,080 │ block3_conv2[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 28, 28,    │          0 │ block3_conv3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 28, 28,    │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 28, 28,    │  2,359,808 │ block4_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 28, 28,    │  2,359,808 │ block4_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 14, 14,    │          0 │ block4_conv3[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 14, 14,    │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 14, 14,    │  2,359,808 │ block5_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 14, 14,    │  2,359,808 │ block5_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_up              │ (None, 28, 28,    │          0 │ block5_conv3[0][… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_cat             │ (None, 28, 28,    │          0 │ X31_up[0][0],     │
# │ (Concatenate)       │ 1024)             │            │ block4_conv3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_up              │ (None, 56, 56,    │          0 │ block4_conv3[0][… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_drop (Dropout)  │ (None, 28, 28,    │          0 │ X31_cat[0][0]     │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_cat             │ (None, 56, 56,    │          0 │ X21_up[0][0],     │
# │ (Concatenate)       │ 768)              │            │ block3_conv3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_up              │ (None, 112, 112,  │          0 │ block3_conv3[0][… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_c1 (Conv2D)     │ (None, 28, 28,    │  4,719,104 │ X31_drop[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_drop (Dropout)  │ (None, 56, 56,    │          0 │ X21_cat[0][0]     │
# │                     │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_cat             │ (None, 112, 112,  │          0 │ X11_up[0][0],     │
# │ (Concatenate)       │ 384)              │            │ block2_conv2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_up              │ (None, 224, 224,  │          0 │ block2_conv2[0][… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_bn1             │ (None, 28, 28,    │      2,048 │ X31_c1[0][0]      │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_c1 (Conv2D)     │ (None, 56, 56,    │  1,769,728 │ X21_drop[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_drop (Dropout)  │ (None, 112, 112,  │          0 │ X11_cat[0][0]     │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_cat             │ (None, 224, 224,  │          0 │ X01_up[0][0],     │
# │ (Concatenate)       │ 192)              │            │ block1_conv2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_act1            │ (None, 28, 28,    │          0 │ X31_bn1[0][0]     │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_bn1             │ (None, 56, 56,    │      1,024 │ X21_c1[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_c1 (Conv2D)     │ (None, 112, 112,  │    442,496 │ X11_drop[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_drop (Dropout)  │ (None, 224, 224,  │          0 │ X01_cat[0][0]     │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_c2 (Conv2D)     │ (None, 28, 28,    │  2,359,808 │ X31_act1[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_act1            │ (None, 56, 56,    │          0 │ X21_bn1[0][0]     │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_bn1             │ (None, 112, 112,  │        512 │ X11_c1[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_c1 (Conv2D)     │ (None, 224, 224,  │    110,656 │ X01_drop[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_bn2             │ (None, 28, 28,    │      2,048 │ X31_c2[0][0]      │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_c2 (Conv2D)     │ (None, 56, 56,    │    590,080 │ X21_act1[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_act1            │ (None, 112, 112,  │          0 │ X11_bn1[0][0]     │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_bn1             │ (None, 224, 224,  │        256 │ X01_c1[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_act2            │ (None, 28, 28,    │          0 │ X31_bn2[0][0]     │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_bn2             │ (None, 56, 56,    │      1,024 │ X21_c2[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_c2 (Conv2D)     │ (None, 112, 112,  │    147,584 │ X11_act1[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_act1            │ (None, 224, 224,  │          0 │ X01_bn1[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_up              │ (None, 56, 56,    │          0 │ X31_act2[0][0]    │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_act2            │ (None, 56, 56,    │          0 │ X21_bn2[0][0]     │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_bn2             │ (None, 112, 112,  │        512 │ X11_c2[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_c2 (Conv2D)     │ (None, 224, 224,  │     36,928 │ X01_act1[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_cat             │ (None, 56, 56,    │          0 │ X22_up[0][0],     │
# │ (Concatenate)       │ 1024)             │            │ block3_conv3[0][… │
# │                     │                   │            │ X21_act2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_act2            │ (None, 112, 112,  │          0 │ X11_bn2[0][0]     │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_up              │ (None, 112, 112,  │          0 │ X21_act2[0][0]    │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_bn2             │ (None, 224, 224,  │        256 │ X01_c2[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_drop (Dropout)  │ (None, 56, 56,    │          0 │ X22_cat[0][0]     │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_cat             │ (None, 112, 112,  │          0 │ X12_up[0][0],     │
# │ (Concatenate)       │ 512)              │            │ block2_conv2[0][… │
# │                     │                   │            │ X11_act2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_act2            │ (None, 224, 224,  │          0 │ X01_bn2[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_up              │ (None, 224, 224,  │          0 │ X11_act2[0][0]    │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_c1 (Conv2D)     │ (None, 56, 56,    │  2,359,552 │ X22_drop[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_drop (Dropout)  │ (None, 112, 112,  │          0 │ X12_cat[0][0]     │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_cat             │ (None, 224, 224,  │          0 │ X02_up[0][0],     │
# │ (Concatenate)       │ 256)              │            │ block1_conv2[0][… │
# │                     │                   │            │ X01_act2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_bn1             │ (None, 56, 56,    │      1,024 │ X22_c1[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_c1 (Conv2D)     │ (None, 112, 112,  │    589,952 │ X12_drop[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_drop (Dropout)  │ (None, 224, 224,  │          0 │ X02_cat[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_act1            │ (None, 56, 56,    │          0 │ X22_bn1[0][0]     │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_bn1             │ (None, 112, 112,  │        512 │ X12_c1[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_c1 (Conv2D)     │ (None, 224, 224,  │    147,520 │ X02_drop[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_c2 (Conv2D)     │ (None, 56, 56,    │    590,080 │ X22_act1[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_act1            │ (None, 112, 112,  │          0 │ X12_bn1[0][0]     │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_bn1             │ (None, 224, 224,  │        256 │ X02_c1[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_bn2             │ (None, 56, 56,    │      1,024 │ X22_c2[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_c2 (Conv2D)     │ (None, 112, 112,  │    147,584 │ X12_act1[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_act1            │ (None, 224, 224,  │          0 │ X02_bn1[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_act2            │ (None, 56, 56,    │          0 │ X22_bn2[0][0]     │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_bn2             │ (None, 112, 112,  │        512 │ X12_c2[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_c2 (Conv2D)     │ (None, 224, 224,  │     36,928 │ X02_act1[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_up              │ (None, 112, 112,  │          0 │ X22_act2[0][0]    │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_act2            │ (None, 112, 112,  │          0 │ X12_bn2[0][0]     │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_bn2             │ (None, 224, 224,  │        256 │ X02_c2[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_cat             │ (None, 112, 112,  │          0 │ X13_up[0][0],     │
# │ (Concatenate)       │ 640)              │            │ block2_conv2[0][… │
# │                     │                   │            │ X11_act2[0][0],   │
# │                     │                   │            │ X12_act2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_act2            │ (None, 224, 224,  │          0 │ X02_bn2[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_up              │ (None, 224, 224,  │          0 │ X12_act2[0][0]    │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_drop (Dropout)  │ (None, 112, 112,  │          0 │ X13_cat[0][0]     │
# │                     │ 640)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_cat             │ (None, 224, 224,  │          0 │ X03_up[0][0],     │
# │ (Concatenate)       │ 320)              │            │ block1_conv2[0][… │
# │                     │                   │            │ X01_act2[0][0],   │
# │                     │                   │            │ X02_act2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_c1 (Conv2D)     │ (None, 112, 112,  │    737,408 │ X13_drop[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_drop (Dropout)  │ (None, 224, 224,  │          0 │ X03_cat[0][0]     │
# │                     │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_bn1             │ (None, 112, 112,  │        512 │ X13_c1[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_c1 (Conv2D)     │ (None, 224, 224,  │    184,384 │ X03_drop[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_act1            │ (None, 112, 112,  │          0 │ X13_bn1[0][0]     │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_bn1             │ (None, 224, 224,  │        256 │ X03_c1[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_c2 (Conv2D)     │ (None, 112, 112,  │    147,584 │ X13_act1[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_act1            │ (None, 224, 224,  │          0 │ X03_bn1[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_bn2             │ (None, 112, 112,  │        512 │ X13_c2[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_c2 (Conv2D)     │ (None, 224, 224,  │     36,928 │ X03_act1[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_act2            │ (None, 112, 112,  │          0 │ X13_bn2[0][0]     │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_bn2             │ (None, 224, 224,  │        256 │ X03_c2[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_up              │ (None, 224, 224,  │          0 │ X13_act2[0][0]    │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_act2            │ (None, 224, 224,  │          0 │ X03_bn2[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_cat             │ (None, 224, 224,  │          0 │ X04_up[0][0],     │
# │ (Concatenate)       │ 384)              │            │ block1_conv2[0][… │
# │                     │                   │            │ X01_act2[0][0],   │
# │                     │                   │            │ X02_act2[0][0],   │
# │                     │                   │            │ X03_act2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_drop (Dropout)  │ (None, 224, 224,  │          0 │ X04_cat[0][0]     │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_c1 (Conv2D)     │ (None, 224, 224,  │    221,248 │ X04_drop[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_bn1             │ (None, 224, 224,  │        256 │ X04_c1[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_act1            │ (None, 224, 224,  │          0 │ X04_bn1[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_c2 (Conv2D)     │ (None, 224, 224,  │     36,928 │ X04_act1[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_bn2             │ (None, 224, 224,  │        256 │ X04_c2[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_act2            │ (None, 224, 224,  │          0 │ X04_bn2[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Conv2D)     │ (None, 224, 224,  │        260 │ X04_act2[0][0]    │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 30,140,740 (114.98 MB)
#  Trainable params: 15,419,396 (58.82 MB)
#  Non-trainable params: 14,721,344 (56.16 MB)
# Architecture diagram saved ✓

# %% [markdown]
# ## 10. Callbacks (EarlyStopping disabled)

# %%
def decode_mask(onehot_mask):
    return tf.argmax(onehot_mask, axis=-1)


def colorize_mask(label_map):
    colors = np.array([[0,0,0], [0,255,255], [255,165,0], [255,0,255]], dtype=np.uint8)
    label_map = np.array(label_map).astype(int)
    return colors[label_map]


def show_predictions(dataset, num=3, model_to_use=None):
    m = model_to_use or model
    for imgs, masks in dataset.take(1):
        preds = m.predict(imgs, verbose=0)
        for i in range(min(num, len(imgs))):
            gt_labels   = decode_mask(masks[i]).numpy()
            pred_labels = decode_mask(preds[i]).numpy()
            fig, axes = plt.subplots(1, 3, figsize=(13, 4.5))
            axes[0].imshow(imgs[i].numpy());            axes[0].set_title('Input MRI')
            axes[1].imshow(colorize_mask(gt_labels));   axes[1].set_title('Ground Truth')
            axes[2].imshow(colorize_mask(pred_labels)); axes[2].set_title('Prediction')
            for ax in axes: ax.axis('off')
            plt.tight_layout()
            plt.show()


class DisplayCallback(callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % 10 == 0:
            show_predictions(test_dataset, num=2)
            print(f'Prediction after epoch {epoch + 1}\n')


logdir = os.path.join('logs', datetime.datetime.now().strftime('%Y%m%d-%H%M%S'))

callbacks_list = [
    DisplayCallback(),
    callbacks.TensorBoard(logdir, histogram_freq=1),
    callbacks.ModelCheckpoint('best_model_vgg16unetpp_multiclass_ibsr.keras', verbose=1,
                               save_best_only=True, monitor='val_iou_score_multiclass', mode='max'),
    callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-7, verbose=1),
]

print('Callbacks ready ✓ (no EarlyStopping — will run all', EPOCHS, 'epochs)')
# Out:
# Callbacks ready ✓ (no EarlyStopping — will run all 100 epochs)

# %% [markdown]
# ## 11. Initial Predictions (before training)

# %%
print('Predictions before training:')
show_predictions(test_dataset, num=2)
# Out:
# Predictions before training:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1782726820.077992     132 service.cc:152] XLA service 0x7c4884009cb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1782726820.078025     132 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1782726820.541725     132 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1782726850.577296     132 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %% [markdown]
# ## 12. Training

# %%
steps_per_epoch  = max(1, len(os.listdir(TRAIN_IMG_DIR)) // BATCH_SIZE)
validation_steps = max(1, len(os.listdir(TEST_IMG_DIR))  // BATCH_SIZE)

print(f'Steps per epoch  : {steps_per_epoch}')
print(f'Validation steps : {validation_steps}')

start_time = time.time()

history = model.fit(
    train_dataset, validation_data=test_dataset, epochs=EPOCHS,
    steps_per_epoch=steps_per_epoch, validation_steps=validation_steps,
    callbacks=callbacks_list
)

elapsed = time.time() - start_time
print(f'\nTraining time: {elapsed/60:.1f} min')
# Out:
# Steps per epoch  : 12
# Validation steps : 2
# Epoch 1/100
# 2026-06-29 09:54:33.686361: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng2{k2=3,k3=0} for conv %cudnn-conv-bw-input.17 = (f32[16,384,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,224,224]{3,2,1,0} %bitcast.51371, f32[64,384,3,3]{3,2,1,0} %bitcast.44074), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/VGG16_UNetPP_MultiClass_1/X04_c1_1/convolution/Conv2DBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-29 09:54:33.751748: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.065505816s
# Trying algorithm eng2{k2=3,k3=0} for conv %cudnn-conv-bw-input.17 = (f32[16,384,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,224,224]{3,2,1,0} %bitcast.51371, f32[64,384,3,3]{3,2,1,0} %bitcast.44074), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/VGG16_UNetPP_MultiClass_1/X04_c1_1/convolution/Conv2DBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - csf_iou: 6.7266e-04 - dice_coefficient_multiclass: 0.2396 - gm_iou: 0.1787 - iou_score_multiclass: 0.1571 - loss: 1.8408 - pixel_accuracy_multiclass: 0.6232 - wm_iou: 0.0547
# Epoch 1: val_iou_score_multiclass improved from None to 0.02564, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 1: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step - csf_iou: 0.0010 - dice_coefficient_multiclass: 0.2845 - gm_iou: 0.1928 - iou_score_multiclass: 0.1917 - loss: 1.6298 - pixel_accuracy_multiclass: 0.7553 - wm_iou: 0.1104 - val_csf_iou: 2.9468e-05 - val_dice_coefficient_multiclass: 0.0466 - val_gm_iou: 0.1003 - val_iou_score_multiclass: 0.0256 - val_loss: 10.0470 - val_pixel_accuracy_multiclass: 0.0931 - val_wm_iou: 0.0015 - learning_rate: 1.0000e-04
# Epoch 2/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 8:50 48s/step - csf_iou: 1.6059e-05 - dice_coefficient_multiclass: 0.1978 - gm_iou: 0.0656 - iou_score_multiclass: 0.1359 - loss: 1.6917 - pixel_accuracy_multiclass: 0.8505 - wm_iou: 0.0208
# Epoch 2: val_iou_score_multiclass improved from 0.02564 to 0.02572, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 2: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 55s 595ms/step - csf_iou: 1.6059e-05 - dice_coefficient_multiclass: 0.1978 - gm_iou: 0.0656 - iou_score_multiclass: 0.1359 - loss: 1.6917 - pixel_accuracy_multiclass: 0.8505 - wm_iou: 0.0208 - val_csf_iou: 2.6699e-05 - val_dice_coefficient_multiclass: 0.0468 - val_gm_iou: 0.1008 - val_iou_score_multiclass: 0.0257 - val_loss: 10.0856 - val_pixel_accuracy_multiclass: 0.0931 - val_wm_iou: 0.0012 - learning_rate: 1.0000e-04
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.0023 - dice_coefficient_multiclass: 0.3775 - gm_iou: 0.2694 - iou_score_multiclass: 0.2711 - loss: 1.1849 - pixel_accuracy_multiclass: 0.9424 - wm_iou: 0.2129
# Epoch 3: val_iou_score_multiclass improved from 0.02572 to 0.03778, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 3: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.0038 - dice_coefficient_multiclass: 0.3910 - gm_iou: 0.2698 - iou_score_multiclass: 0.2826 - loss: 1.1441 - pixel_accuracy_multiclass: 0.9493 - wm_iou: 0.2396 - val_csf_iou: 1.3875e-05 - val_dice_coefficient_multiclass: 0.0689 - val_gm_iou: 0.1175 - val_iou_score_multiclass: 0.0378 - val_loss: 7.6149 - val_pixel_accuracy_multiclass: 0.0962 - val_wm_iou: 0.0305 - learning_rate: 1.0000e-04
# Epoch 4/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - csf_iou: 1.6748e-05 - dice_coefficient_multiclass: 0.2199 - gm_iou: 0.0761 - iou_score_multiclass: 0.1561 - loss: 1.4973 - pixel_accuracy_multiclass: 0.9702 - wm_iou: 0.0270
# Epoch 4: val_iou_score_multiclass improved from 0.03778 to 0.04051, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 4: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 598ms/step - csf_iou: 1.6748e-05 - dice_coefficient_multiclass: 0.2199 - gm_iou: 0.0761 - iou_score_multiclass: 0.1561 - loss: 1.4973 - pixel_accuracy_multiclass: 0.9702 - wm_iou: 0.0270 - val_csf_iou: 1.4925e-05 - val_dice_coefficient_multiclass: 0.0738 - val_gm_iou: 0.1203 - val_iou_score_multiclass: 0.0405 - val_loss: 7.3398 - val_pixel_accuracy_multiclass: 0.0973 - val_wm_iou: 0.0381 - learning_rate: 1.0000e-04
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 693ms/step - csf_iou: 0.0044 - dice_coefficient_multiclass: 0.4279 - gm_iou: 0.3247 - iou_score_multiclass: 0.3201 - loss: 0.9946 - pixel_accuracy_multiclass: 0.9681 - wm_iou: 0.2737
# Epoch 5: val_iou_score_multiclass improved from 0.04051 to 0.06072, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 5: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.0059 - dice_coefficient_multiclass: 0.4355 - gm_iou: 0.3193 - iou_score_multiclass: 0.3264 - loss: 0.9802 - pixel_accuracy_multiclass: 0.9665 - wm_iou: 0.2938 - val_csf_iou: 1.1640e-04 - val_dice_coefficient_multiclass: 0.1087 - val_gm_iou: 0.1525 - val_iou_score_multiclass: 0.0607 - val_loss: 5.0795 - val_pixel_accuracy_multiclass: 0.1079 - val_wm_iou: 0.0714 - learning_rate: 1.0000e-04
# Epoch 6/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 4s 371ms/step - csf_iou: 1.7328e-05 - dice_coefficient_multiclass: 0.2357 - gm_iou: 0.0901 - iou_score_multiclass: 0.1711 - loss: 1.3842 - pixel_accuracy_multiclass: 0.9869 - wm_iou: 0.0279
# Epoch 6: val_iou_score_multiclass improved from 0.06072 to 0.06481, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 6: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 600ms/step - csf_iou: 1.7328e-05 - dice_coefficient_multiclass: 0.2357 - gm_iou: 0.0901 - iou_score_multiclass: 0.1711 - loss: 1.3842 - pixel_accuracy_multiclass: 0.9869 - wm_iou: 0.0279 - val_csf_iou: 1.3933e-04 - val_dice_coefficient_multiclass: 0.1155 - val_gm_iou: 0.1580 - val_iou_score_multiclass: 0.0648 - val_loss: 4.9030 - val_pixel_accuracy_multiclass: 0.1097 - val_wm_iou: 0.0799 - learning_rate: 1.0000e-04
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 691ms/step - csf_iou: 0.0058 - dice_coefficient_multiclass: 0.4577 - gm_iou: 0.3658 - iou_score_multiclass: 0.3509 - loss: 0.8970 - pixel_accuracy_multiclass: 0.9730 - wm_iou: 0.3108
# Epoch 7: val_iou_score_multiclass improved from 0.06481 to 0.10344, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 7: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.0077 - dice_coefficient_multiclass: 0.4637 - gm_iou: 0.3541 - iou_score_multiclass: 0.3556 - loss: 0.8896 - pixel_accuracy_multiclass: 0.9706 - wm_iou: 0.3325 - val_csf_iou: 5.5460e-04 - val_dice_coefficient_multiclass: 0.1781 - val_gm_iou: 0.2203 - val_iou_score_multiclass: 0.1034 - val_loss: 3.3490 - val_pixel_accuracy_multiclass: 0.1263 - val_wm_iou: 0.1145 - learning_rate: 1.0000e-04
# Epoch 8/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 359ms/step - csf_iou: 1.9073e-05 - dice_coefficient_multiclass: 0.2513 - gm_iou: 0.0989 - iou_score_multiclass: 0.1865 - loss: 1.2830 - pixel_accuracy_multiclass: 0.9896 - wm_iou: 0.0335
# Epoch 8: val_iou_score_multiclass improved from 0.10344 to 0.10848, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 8: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 614ms/step - csf_iou: 1.9073e-05 - dice_coefficient_multiclass: 0.2513 - gm_iou: 0.0989 - iou_score_multiclass: 0.1865 - loss: 1.2830 - pixel_accuracy_multiclass: 0.9896 - wm_iou: 0.0335 - val_csf_iou: 6.6375e-04 - val_dice_coefficient_multiclass: 0.1859 - val_gm_iou: 0.2276 - val_iou_score_multiclass: 0.1085 - val_loss: 3.2141 - val_pixel_accuracy_multiclass: 0.1280 - val_wm_iou: 0.1180 - learning_rate: 1.0000e-04
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 691ms/step - csf_iou: 0.0081 - dice_coefficient_multiclass: 0.4813 - gm_iou: 0.3927 - iou_score_multiclass: 0.3759 - loss: 0.8220 - pixel_accuracy_multiclass: 0.9747 - wm_iou: 0.3430
# Epoch 9: val_iou_score_multiclass improved from 0.10848 to 0.18165, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 9: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - csf_iou: 0.0107 - dice_coefficient_multiclass: 0.4888 - gm_iou: 0.3836 - iou_score_multiclass: 0.3821 - loss: 0.8122 - pixel_accuracy_multiclass: 0.9725 - wm_iou: 0.3668 - val_csf_iou: 0.0023 - val_dice_coefficient_multiclass: 0.2896 - val_gm_iou: 0.2978 - val_iou_score_multiclass: 0.1817 - val_loss: 2.0018 - val_pixel_accuracy_multiclass: 0.2717 - val_wm_iou: 0.1566 - learning_rate: 1.0000e-04
# Epoch 10/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 359ms/step - csf_iou: 2.1882e-05 - dice_coefficient_multiclass: 0.2703 - gm_iou: 0.1103 - iou_score_multiclass: 0.2052 - loss: 1.1743 - pixel_accuracy_multiclass: 0.9900 - wm_iou: 0.0426
# Prediction after epoch 10
#
#
# Epoch 10: val_iou_score_multiclass improved from 0.18165 to 0.18938, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 10: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 672ms/step - csf_iou: 2.1882e-05 - dice_coefficient_multiclass: 0.2703 - gm_iou: 0.1103 - iou_score_multiclass: 0.2052 - loss: 1.1743 - pixel_accuracy_multiclass: 0.9900 - wm_iou: 0.0426 - val_csf_iou: 0.0024 - val_dice_coefficient_multiclass: 0.2998 - val_gm_iou: 0.3006 - val_iou_score_multiclass: 0.1894 - val_loss: 1.9293 - val_pixel_accuracy_multiclass: 0.2878 - val_wm_iou: 0.1669 - learning_rate: 1.0000e-04
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 691ms/step - csf_iou: 0.0106 - dice_coefficient_multiclass: 0.5090 - gm_iou: 0.4281 - iou_score_multiclass: 0.4056 - loss: 0.7441 - pixel_accuracy_multiclass: 0.9769 - wm_iou: 0.3844
# Epoch 11: val_iou_score_multiclass improved from 0.18938 to 0.27023, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 11: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.0136 - dice_coefficient_multiclass: 0.5169 - gm_iou: 0.4203 - iou_score_multiclass: 0.4124 - loss: 0.7340 - pixel_accuracy_multiclass: 0.9752 - wm_iou: 0.4095 - val_csf_iou: 0.0050 - val_dice_coefficient_multiclass: 0.3905 - val_gm_iou: 0.3423 - val_iou_score_multiclass: 0.2702 - val_loss: 1.3282 - val_pixel_accuracy_multiclass: 0.9125 - val_wm_iou: 0.2281 - learning_rate: 1.0000e-04
# Epoch 12/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - csf_iou: 2.5372e-05 - dice_coefficient_multiclass: 0.2918 - gm_iou: 0.1268 - iou_score_multiclass: 0.2258 - loss: 1.0714 - pixel_accuracy_multiclass: 0.9914 - wm_iou: 0.0548
# Epoch 12: val_iou_score_multiclass improved from 0.27023 to 0.27587, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 12: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 603ms/step - csf_iou: 2.5372e-05 - dice_coefficient_multiclass: 0.2918 - gm_iou: 0.1268 - iou_score_multiclass: 0.2258 - loss: 1.0714 - pixel_accuracy_multiclass: 0.9914 - wm_iou: 0.0548 - val_csf_iou: 0.0052 - val_dice_coefficient_multiclass: 0.3968 - val_gm_iou: 0.3439 - val_iou_score_multiclass: 0.2759 - val_loss: 1.3007 - val_pixel_accuracy_multiclass: 0.9206 - val_wm_iou: 0.2389 - learning_rate: 1.0000e-04
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 690ms/step - csf_iou: 0.0135 - dice_coefficient_multiclass: 0.5350 - gm_iou: 0.4673 - iou_score_multiclass: 0.4340 - loss: 0.6752 - pixel_accuracy_multiclass: 0.9790 - wm_iou: 0.4216
# Epoch 13: val_iou_score_multiclass improved from 0.27587 to 0.32142, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 13: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.0175 - dice_coefficient_multiclass: 0.5424 - gm_iou: 0.4594 - iou_score_multiclass: 0.4403 - loss: 0.6677 - pixel_accuracy_multiclass: 0.9775 - wm_iou: 0.4455 - val_csf_iou: 0.0086 - val_dice_coefficient_multiclass: 0.4424 - val_gm_iou: 0.3790 - val_iou_score_multiclass: 0.3214 - val_loss: 1.0872 - val_pixel_accuracy_multiclass: 0.9791 - val_wm_iou: 0.2846 - learning_rate: 1.0000e-04
# Epoch 14/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - csf_iou: 2.9096e-05 - dice_coefficient_multiclass: 0.3152 - gm_iou: 0.1515 - iou_score_multiclass: 0.2472 - loss: 0.9803 - pixel_accuracy_multiclass: 0.9924 - wm_iou: 0.0688
# Epoch 14: val_iou_score_multiclass improved from 0.32142 to 0.32343, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 14: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 608ms/step - csf_iou: 2.9096e-05 - dice_coefficient_multiclass: 0.3152 - gm_iou: 0.1515 - iou_score_multiclass: 0.2472 - loss: 0.9803 - pixel_accuracy_multiclass: 0.9924 - wm_iou: 0.0688 - val_csf_iou: 0.0089 - val_dice_coefficient_multiclass: 0.4450 - val_gm_iou: 0.3761 - val_iou_score_multiclass: 0.3234 - val_loss: 1.0821 - val_pixel_accuracy_multiclass: 0.9797 - val_wm_iou: 0.2956 - learning_rate: 1.0000e-04
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.0190 - dice_coefficient_multiclass: 0.5578 - gm_iou: 0.5021 - iou_score_multiclass: 0.4584 - loss: 0.6230 - pixel_accuracy_multiclass: 0.9802 - wm_iou: 0.4538
# Epoch 15: val_iou_score_multiclass improved from 0.32343 to 0.36771, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 15: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.0254 - dice_coefficient_multiclass: 0.5643 - gm_iou: 0.4917 - iou_score_multiclass: 0.4635 - loss: 0.6187 - pixel_accuracy_multiclass: 0.9788 - wm_iou: 0.4754 - val_csf_iou: 0.0142 - val_dice_coefficient_multiclass: 0.4867 - val_gm_iou: 0.4237 - val_iou_score_multiclass: 0.3677 - val_loss: 0.9137 - val_pixel_accuracy_multiclass: 0.9796 - val_wm_iou: 0.3361 - learning_rate: 1.0000e-04
# Epoch 16/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - csf_iou: 3.3214e-05 - dice_coefficient_multiclass: 0.3336 - gm_iou: 0.1755 - iou_score_multiclass: 0.2640 - loss: 0.9148 - pixel_accuracy_multiclass: 0.9929 - wm_iou: 0.0788
# Epoch 16: val_iou_score_multiclass improved from 0.36771 to 0.37363, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 16: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 608ms/step - csf_iou: 3.3214e-05 - dice_coefficient_multiclass: 0.3336 - gm_iou: 0.1755 - iou_score_multiclass: 0.2640 - loss: 0.9148 - pixel_accuracy_multiclass: 0.9929 - wm_iou: 0.0788 - val_csf_iou: 0.0145 - val_dice_coefficient_multiclass: 0.4931 - val_gm_iou: 0.4221 - val_iou_score_multiclass: 0.3736 - val_loss: 0.8975 - val_pixel_accuracy_multiclass: 0.9809 - val_wm_iou: 0.3588 - learning_rate: 1.0000e-04
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.0283 - dice_coefficient_multiclass: 0.5762 - gm_iou: 0.5275 - iou_score_multiclass: 0.4775 - loss: 0.5861 - pixel_accuracy_multiclass: 0.9810 - wm_iou: 0.4799
# Epoch 17: val_iou_score_multiclass improved from 0.37363 to 0.41911, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 17: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.0375 - dice_coefficient_multiclass: 0.5829 - gm_iou: 0.5152 - iou_score_multiclass: 0.4822 - loss: 0.5827 - pixel_accuracy_multiclass: 0.9798 - wm_iou: 0.5001 - val_csf_iou: 0.0204 - val_dice_coefficient_multiclass: 0.5337 - val_gm_iou: 0.4789 - val_iou_score_multiclass: 0.4191 - val_loss: 0.7597 - val_pixel_accuracy_multiclass: 0.9799 - val_wm_iou: 0.4045 - learning_rate: 1.0000e-04
# Epoch 18/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - csf_iou: 3.6919e-05 - dice_coefficient_multiclass: 0.3456 - gm_iou: 0.1919 - iou_score_multiclass: 0.2750 - loss: 0.8732 - pixel_accuracy_multiclass: 0.9934 - wm_iou: 0.0857
# Epoch 18: val_iou_score_multiclass improved from 0.41911 to 0.42522, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 18: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 620ms/step - csf_iou: 3.6919e-05 - dice_coefficient_multiclass: 0.3456 - gm_iou: 0.1919 - iou_score_multiclass: 0.2750 - loss: 0.8732 - pixel_accuracy_multiclass: 0.9934 - wm_iou: 0.0857 - val_csf_iou: 0.0206 - val_dice_coefficient_multiclass: 0.5398 - val_gm_iou: 0.4743 - val_iou_score_multiclass: 0.4252 - val_loss: 0.7470 - val_pixel_accuracy_multiclass: 0.9810 - val_wm_iou: 0.4321 - learning_rate: 1.0000e-04
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 693ms/step - csf_iou: 0.0366 - dice_coefficient_multiclass: 0.5900 - gm_iou: 0.5472 - iou_score_multiclass: 0.4917 - loss: 0.5600 - pixel_accuracy_multiclass: 0.9813 - wm_iou: 0.4977
# Epoch 19: val_iou_score_multiclass improved from 0.42522 to 0.44503, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 19: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.0478 - dice_coefficient_multiclass: 0.5965 - gm_iou: 0.5321 - iou_score_multiclass: 0.4959 - loss: 0.5571 - pixel_accuracy_multiclass: 0.9802 - wm_iou: 0.5175 - val_csf_iou: 0.0251 - val_dice_coefficient_multiclass: 0.5569 - val_gm_iou: 0.4966 - val_iou_score_multiclass: 0.4450 - val_loss: 0.6868 - val_pixel_accuracy_multiclass: 0.9800 - val_wm_iou: 0.4520 - learning_rate: 1.0000e-04
# Epoch 20/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 362ms/step - csf_iou: 4.0669e-05 - dice_coefficient_multiclass: 0.3554 - gm_iou: 0.2020 - iou_score_multiclass: 0.2838 - loss: 0.8412 - pixel_accuracy_multiclass: 0.9938 - wm_iou: 0.0952
# Prediction after epoch 20
#
#
# Epoch 20: val_iou_score_multiclass improved from 0.44503 to 0.44685, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 20: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 675ms/step - csf_iou: 4.0669e-05 - dice_coefficient_multiclass: 0.3554 - gm_iou: 0.2020 - iou_score_multiclass: 0.2838 - loss: 0.8412 - pixel_accuracy_multiclass: 0.9938 - wm_iou: 0.0952 - val_csf_iou: 0.0249 - val_dice_coefficient_multiclass: 0.5585 - val_gm_iou: 0.4931 - val_iou_score_multiclass: 0.4469 - val_loss: 0.6847 - val_pixel_accuracy_multiclass: 0.9801 - val_wm_iou: 0.4617 - learning_rate: 1.0000e-04
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.0403 - dice_coefficient_multiclass: 0.6000 - gm_iou: 0.5646 - iou_score_multiclass: 0.5030 - loss: 0.5396 - pixel_accuracy_multiclass: 0.9818 - wm_iou: 0.5129
# Epoch 21: val_iou_score_multiclass improved from 0.44685 to 0.45585, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 21: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.0538 - dice_coefficient_multiclass: 0.6071 - gm_iou: 0.5468 - iou_score_multiclass: 0.5074 - loss: 0.5367 - pixel_accuracy_multiclass: 0.9806 - wm_iou: 0.5344 - val_csf_iou: 0.0300 - val_dice_coefficient_multiclass: 0.5665 - val_gm_iou: 0.4991 - val_iou_score_multiclass: 0.4558 - val_loss: 0.6626 - val_pixel_accuracy_multiclass: 0.9780 - val_wm_iou: 0.4681 - learning_rate: 1.0000e-04
# Epoch 22/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 4s 374ms/step - csf_iou: 4.4617e-05 - dice_coefficient_multiclass: 0.3668 - gm_iou: 0.2128 - iou_score_multiclass: 0.2931 - loss: 0.8115 - pixel_accuracy_multiclass: 0.9944 - wm_iou: 0.1094
# Epoch 22: val_iou_score_multiclass improved from 0.45585 to 0.45876, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 22: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 605ms/step - csf_iou: 4.4617e-05 - dice_coefficient_multiclass: 0.3668 - gm_iou: 0.2128 - iou_score_multiclass: 0.2931 - loss: 0.8115 - pixel_accuracy_multiclass: 0.9944 - wm_iou: 0.1094 - val_csf_iou: 0.0303 - val_dice_coefficient_multiclass: 0.5690 - val_gm_iou: 0.4995 - val_iou_score_multiclass: 0.4588 - val_loss: 0.6572 - val_pixel_accuracy_multiclass: 0.9785 - val_wm_iou: 0.4769 - learning_rate: 1.0000e-04
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.0463 - dice_coefficient_multiclass: 0.6095 - gm_iou: 0.5760 - iou_score_multiclass: 0.5131 - loss: 0.5224 - pixel_accuracy_multiclass: 0.9819 - wm_iou: 0.5285
# Epoch 23: val_iou_score_multiclass improved from 0.45876 to 0.47102, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 23: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.0590 - dice_coefficient_multiclass: 0.6155 - gm_iou: 0.5605 - iou_score_multiclass: 0.5166 - loss: 0.5218 - pixel_accuracy_multiclass: 0.9808 - wm_iou: 0.5449 - val_csf_iou: 0.0335 - val_dice_coefficient_multiclass: 0.5793 - val_gm_iou: 0.5148 - val_iou_score_multiclass: 0.4710 - val_loss: 0.6232 - val_pixel_accuracy_multiclass: 0.9761 - val_wm_iou: 0.4872 - learning_rate: 1.0000e-04
# Epoch 24/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - csf_iou: 4.7432e-05 - dice_coefficient_multiclass: 0.3692 - gm_iou: 0.2232 - iou_score_multiclass: 0.2963 - loss: 0.7979 - pixel_accuracy_multiclass: 0.9947 - wm_iou: 0.1039
# Epoch 24: val_iou_score_multiclass improved from 0.47102 to 0.47174, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 24: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 590ms/step - csf_iou: 4.7432e-05 - dice_coefficient_multiclass: 0.3692 - gm_iou: 0.2232 - iou_score_multiclass: 0.2963 - loss: 0.7979 - pixel_accuracy_multiclass: 0.9947 - wm_iou: 0.1039 - val_csf_iou: 0.0335 - val_dice_coefficient_multiclass: 0.5798 - val_gm_iou: 0.5064 - val_iou_score_multiclass: 0.4717 - val_loss: 0.6232 - val_pixel_accuracy_multiclass: 0.9762 - val_wm_iou: 0.4969 - learning_rate: 1.0000e-04
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.0520 - dice_coefficient_multiclass: 0.6155 - gm_iou: 0.5821 - iou_score_multiclass: 0.5194 - loss: 0.5114 - pixel_accuracy_multiclass: 0.9816 - wm_iou: 0.5365
# Epoch 25: val_iou_score_multiclass improved from 0.47174 to 0.49922, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 25: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.0668 - dice_coefficient_multiclass: 0.6231 - gm_iou: 0.5663 - iou_score_multiclass: 0.5245 - loss: 0.5078 - pixel_accuracy_multiclass: 0.9809 - wm_iou: 0.5576 - val_csf_iou: 0.0392 - val_dice_coefficient_multiclass: 0.6034 - val_gm_iou: 0.5538 - val_iou_score_multiclass: 0.4992 - val_loss: 0.5691 - val_pixel_accuracy_multiclass: 0.9771 - val_wm_iou: 0.5307 - learning_rate: 1.0000e-04
# Epoch 26/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 4s 372ms/step - csf_iou: 5.0903e-05 - dice_coefficient_multiclass: 0.3780 - gm_iou: 0.2333 - iou_score_multiclass: 0.3037 - loss: 0.7800 - pixel_accuracy_multiclass: 0.9946 - wm_iou: 0.1139
# Epoch 26: val_iou_score_multiclass did not improve from 0.49922
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 498ms/step - csf_iou: 5.0903e-05 - dice_coefficient_multiclass: 0.3780 - gm_iou: 0.2333 - iou_score_multiclass: 0.3037 - loss: 0.7800 - pixel_accuracy_multiclass: 0.9946 - wm_iou: 0.1139 - val_csf_iou: 0.0394 - val_dice_coefficient_multiclass: 0.6020 - val_gm_iou: 0.5424 - val_iou_score_multiclass: 0.4975 - val_loss: 0.5720 - val_pixel_accuracy_multiclass: 0.9756 - val_wm_iou: 0.5347 - learning_rate: 1.0000e-04
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.0547 - dice_coefficient_multiclass: 0.6225 - gm_iou: 0.5982 - iou_score_multiclass: 0.5275 - loss: 0.4992 - pixel_accuracy_multiclass: 0.9819 - wm_iou: 0.5463
# Epoch 27: val_iou_score_multiclass improved from 0.49922 to 0.51422, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 27: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.0710 - dice_coefficient_multiclass: 0.6312 - gm_iou: 0.5807 - iou_score_multiclass: 0.5337 - loss: 0.4947 - pixel_accuracy_multiclass: 0.9811 - wm_iou: 0.5716 - val_csf_iou: 0.0435 - val_dice_coefficient_multiclass: 0.6161 - val_gm_iou: 0.5734 - val_iou_score_multiclass: 0.5142 - val_loss: 0.5377 - val_pixel_accuracy_multiclass: 0.9805 - val_wm_iou: 0.5554 - learning_rate: 1.0000e-04
# Epoch 28/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - csf_iou: 5.4260e-05 - dice_coefficient_multiclass: 0.3861 - gm_iou: 0.2383 - iou_score_multiclass: 0.3102 - loss: 0.7630 - pixel_accuracy_multiclass: 0.9943 - wm_iou: 0.1276
# Epoch 28: val_iou_score_multiclass did not improve from 0.51422
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 494ms/step - csf_iou: 5.4260e-05 - dice_coefficient_multiclass: 0.3861 - gm_iou: 0.2383 - iou_score_multiclass: 0.3102 - loss: 0.7630 - pixel_accuracy_multiclass: 0.9943 - wm_iou: 0.1276 - val_csf_iou: 0.0444 - val_dice_coefficient_multiclass: 0.6153 - val_gm_iou: 0.5620 - val_iou_score_multiclass: 0.5132 - val_loss: 0.5382 - val_pixel_accuracy_multiclass: 0.9787 - val_wm_iou: 0.5594 - learning_rate: 1.0000e-04
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 691ms/step - csf_iou: 0.0587 - dice_coefficient_multiclass: 0.6291 - gm_iou: 0.6074 - iou_score_multiclass: 0.5349 - loss: 0.4859 - pixel_accuracy_multiclass: 0.9824 - wm_iou: 0.5577
# Epoch 29: val_iou_score_multiclass improved from 0.51422 to 0.53589, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 29: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.0747 - dice_coefficient_multiclass: 0.6385 - gm_iou: 0.5926 - iou_score_multiclass: 0.5422 - loss: 0.4802 - pixel_accuracy_multiclass: 0.9818 - wm_iou: 0.5851 - val_csf_iou: 0.0507 - val_dice_coefficient_multiclass: 0.6343 - val_gm_iou: 0.6033 - val_iou_score_multiclass: 0.5359 - val_loss: 0.5028 - val_pixel_accuracy_multiclass: 0.9813 - val_wm_iou: 0.5889 - learning_rate: 1.0000e-04
# Epoch 30/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 362ms/step - csf_iou: 5.7261e-05 - dice_coefficient_multiclass: 0.3961 - gm_iou: 0.2489 - iou_score_multiclass: 0.3181 - loss: 0.7463 - pixel_accuracy_multiclass: 0.9944 - wm_iou: 0.1422
# Prediction after epoch 30
#
#
# Epoch 30: val_iou_score_multiclass did not improve from 0.53589
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 564ms/step - csf_iou: 5.7261e-05 - dice_coefficient_multiclass: 0.3961 - gm_iou: 0.2489 - iou_score_multiclass: 0.3181 - loss: 0.7463 - pixel_accuracy_multiclass: 0.9944 - wm_iou: 0.1422 - val_csf_iou: 0.0511 - val_dice_coefficient_multiclass: 0.6331 - val_gm_iou: 0.5948 - val_iou_score_multiclass: 0.5343 - val_loss: 0.5027 - val_pixel_accuracy_multiclass: 0.9804 - val_wm_iou: 0.5898 - learning_rate: 1.0000e-04
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 691ms/step - csf_iou: 0.0627 - dice_coefficient_multiclass: 0.6361 - gm_iou: 0.6189 - iou_score_multiclass: 0.5428 - loss: 0.4732 - pixel_accuracy_multiclass: 0.9829 - wm_iou: 0.5692
# Epoch 31: val_iou_score_multiclass improved from 0.53589 to 0.54991, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 31: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.0800 - dice_coefficient_multiclass: 0.6446 - gm_iou: 0.6019 - iou_score_multiclass: 0.5488 - loss: 0.4688 - pixel_accuracy_multiclass: 0.9821 - wm_iou: 0.5930 - val_csf_iou: 0.0590 - val_dice_coefficient_multiclass: 0.6465 - val_gm_iou: 0.6170 - val_iou_score_multiclass: 0.5499 - val_loss: 0.4800 - val_pixel_accuracy_multiclass: 0.9803 - val_wm_iou: 0.6088 - learning_rate: 1.0000e-04
# Epoch 32/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - csf_iou: 6.0490e-05 - dice_coefficient_multiclass: 0.4019 - gm_iou: 0.2553 - iou_score_multiclass: 0.3231 - loss: 0.7356 - pixel_accuracy_multiclass: 0.9942 - wm_iou: 0.1498
# Epoch 32: val_iou_score_multiclass improved from 0.54991 to 0.55159, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 32: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 609ms/step - csf_iou: 6.0490e-05 - dice_coefficient_multiclass: 0.4019 - gm_iou: 0.2553 - iou_score_multiclass: 0.3231 - loss: 0.7356 - pixel_accuracy_multiclass: 0.9942 - wm_iou: 0.1498 - val_csf_iou: 0.0600 - val_dice_coefficient_multiclass: 0.6479 - val_gm_iou: 0.6157 - val_iou_score_multiclass: 0.5516 - val_loss: 0.4745 - val_pixel_accuracy_multiclass: 0.9803 - val_wm_iou: 0.6147 - learning_rate: 1.0000e-04
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.0667 - dice_coefficient_multiclass: 0.6420 - gm_iou: 0.6289 - iou_score_multiclass: 0.5496 - loss: 0.4624 - pixel_accuracy_multiclass: 0.9834 - wm_iou: 0.5782
# Epoch 33: val_iou_score_multiclass improved from 0.55159 to 0.55404, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 33: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - csf_iou: 0.0849 - dice_coefficient_multiclass: 0.6507 - gm_iou: 0.6137 - iou_score_multiclass: 0.5559 - loss: 0.4570 - pixel_accuracy_multiclass: 0.9828 - wm_iou: 0.6005 - val_csf_iou: 0.0660 - val_dice_coefficient_multiclass: 0.6509 - val_gm_iou: 0.6166 - val_iou_score_multiclass: 0.5540 - val_loss: 0.4763 - val_pixel_accuracy_multiclass: 0.9782 - val_wm_iou: 0.6102 - learning_rate: 1.0000e-04
# Epoch 34/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 4s 368ms/step - csf_iou: 6.4069e-05 - dice_coefficient_multiclass: 0.4073 - gm_iou: 0.2650 - iou_score_multiclass: 0.3280 - loss: 0.7252 - pixel_accuracy_multiclass: 0.9942 - wm_iou: 0.1541
# Epoch 34: val_iou_score_multiclass did not improve from 0.55404
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 511ms/step - csf_iou: 6.4069e-05 - dice_coefficient_multiclass: 0.4073 - gm_iou: 0.2650 - iou_score_multiclass: 0.3280 - loss: 0.7252 - pixel_accuracy_multiclass: 0.9942 - wm_iou: 0.1541 - val_csf_iou: 0.0669 - val_dice_coefficient_multiclass: 0.6495 - val_gm_iou: 0.6085 - val_iou_score_multiclass: 0.5520 - val_loss: 0.4782 - val_pixel_accuracy_multiclass: 0.9774 - val_wm_iou: 0.6079 - learning_rate: 1.0000e-04
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.0709 - dice_coefficient_multiclass: 0.6453 - gm_iou: 0.6325 - iou_score_multiclass: 0.5531 - loss: 0.4568 - pixel_accuracy_multiclass: 0.9830 - wm_iou: 0.5803
# Epoch 35: val_iou_score_multiclass improved from 0.55404 to 0.56875, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 35: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.0900 - dice_coefficient_multiclass: 0.6544 - gm_iou: 0.6196 - iou_score_multiclass: 0.5597 - loss: 0.4499 - pixel_accuracy_multiclass: 0.9828 - wm_iou: 0.6008 - val_csf_iou: 0.0759 - val_dice_coefficient_multiclass: 0.6639 - val_gm_iou: 0.6376 - val_iou_score_multiclass: 0.5687 - val_loss: 0.4561 - val_pixel_accuracy_multiclass: 0.9786 - val_wm_iou: 0.6287 - learning_rate: 1.0000e-04
# Epoch 36/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 359ms/step - csf_iou: 6.7484e-05 - dice_coefficient_multiclass: 0.4136 - gm_iou: 0.2725 - iou_score_multiclass: 0.3333 - loss: 0.7142 - pixel_accuracy_multiclass: 0.9941 - wm_iou: 0.1627
# Epoch 36: val_iou_score_multiclass did not improve from 0.56875
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 501ms/step - csf_iou: 6.7484e-05 - dice_coefficient_multiclass: 0.4136 - gm_iou: 0.2725 - iou_score_multiclass: 0.3333 - loss: 0.7142 - pixel_accuracy_multiclass: 0.9941 - wm_iou: 0.1627 - val_csf_iou: 0.0767 - val_dice_coefficient_multiclass: 0.6576 - val_gm_iou: 0.6167 - val_iou_score_multiclass: 0.5602 - val_loss: 0.4711 - val_pixel_accuracy_multiclass: 0.9763 - val_wm_iou: 0.6139 - learning_rate: 1.0000e-04
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.0750 - dice_coefficient_multiclass: 0.6516 - gm_iou: 0.6413 - iou_score_multiclass: 0.5601 - loss: 0.4469 - pixel_accuracy_multiclass: 0.9833 - wm_iou: 0.5917
# Epoch 37: val_iou_score_multiclass improved from 0.56875 to 0.57710, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 37: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.0945 - dice_coefficient_multiclass: 0.6608 - gm_iou: 0.6284 - iou_score_multiclass: 0.5668 - loss: 0.4386 - pixel_accuracy_multiclass: 0.9833 - wm_iou: 0.6125 - val_csf_iou: 0.0809 - val_dice_coefficient_multiclass: 0.6711 - val_gm_iou: 0.6470 - val_iou_score_multiclass: 0.5771 - val_loss: 0.4376 - val_pixel_accuracy_multiclass: 0.9793 - val_wm_iou: 0.6431 - learning_rate: 1.0000e-04
# Epoch 38/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - csf_iou: 7.1141e-05 - dice_coefficient_multiclass: 0.4211 - gm_iou: 0.2805 - iou_score_multiclass: 0.3394 - loss: 0.6982 - pixel_accuracy_multiclass: 0.9947 - wm_iou: 0.1747
# Epoch 38: val_iou_score_multiclass did not improve from 0.57710
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 506ms/step - csf_iou: 7.1141e-05 - dice_coefficient_multiclass: 0.4211 - gm_iou: 0.2805 - iou_score_multiclass: 0.3394 - loss: 0.6982 - pixel_accuracy_multiclass: 0.9947 - wm_iou: 0.1747 - val_csf_iou: 0.0820 - val_dice_coefficient_multiclass: 0.6686 - val_gm_iou: 0.6377 - val_iou_score_multiclass: 0.5735 - val_loss: 0.4444 - val_pixel_accuracy_multiclass: 0.9781 - val_wm_iou: 0.6360 - learning_rate: 1.0000e-04
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 693ms/step - csf_iou: 0.0796 - dice_coefficient_multiclass: 0.6583 - gm_iou: 0.6542 - iou_score_multiclass: 0.5679 - loss: 0.4351 - pixel_accuracy_multiclass: 0.9842 - wm_iou: 0.6024
# Epoch 39: val_iou_score_multiclass improved from 0.57710 to 0.59157, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 39: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.1002 - dice_coefficient_multiclass: 0.6675 - gm_iou: 0.6394 - iou_score_multiclass: 0.5745 - loss: 0.4284 - pixel_accuracy_multiclass: 0.9837 - wm_iou: 0.6229 - val_csf_iou: 0.0920 - val_dice_coefficient_multiclass: 0.6840 - val_gm_iou: 0.6641 - val_iou_score_multiclass: 0.5916 - val_loss: 0.4117 - val_pixel_accuracy_multiclass: 0.9805 - val_wm_iou: 0.6664 - learning_rate: 1.0000e-04
# Epoch 40/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - csf_iou: 7.4399e-05 - dice_coefficient_multiclass: 0.4254 - gm_iou: 0.2907 - iou_score_multiclass: 0.3435 - loss: 0.6861 - pixel_accuracy_multiclass: 0.9952 - wm_iou: 0.1766
# Prediction after epoch 40
#
#
# Epoch 40: val_iou_score_multiclass did not improve from 0.59157
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 566ms/step - csf_iou: 7.4399e-05 - dice_coefficient_multiclass: 0.4254 - gm_iou: 0.2907 - iou_score_multiclass: 0.3435 - loss: 0.6861 - pixel_accuracy_multiclass: 0.9952 - wm_iou: 0.1766 - val_csf_iou: 0.0928 - val_dice_coefficient_multiclass: 0.6801 - val_gm_iou: 0.6509 - val_iou_score_multiclass: 0.5859 - val_loss: 0.4203 - val_pixel_accuracy_multiclass: 0.9790 - val_wm_iou: 0.6558 - learning_rate: 1.0000e-04
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.0831 - dice_coefficient_multiclass: 0.6626 - gm_iou: 0.6604 - iou_score_multiclass: 0.5728 - loss: 0.4273 - pixel_accuracy_multiclass: 0.9845 - wm_iou: 0.6095
# Epoch 41: val_iou_score_multiclass improved from 0.59157 to 0.61075, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 41: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.1048 - dice_coefficient_multiclass: 0.6725 - gm_iou: 0.6470 - iou_score_multiclass: 0.5802 - loss: 0.4198 - pixel_accuracy_multiclass: 0.9841 - wm_iou: 0.6307 - val_csf_iou: 0.1016 - val_dice_coefficient_multiclass: 0.6996 - val_gm_iou: 0.6978 - val_iou_score_multiclass: 0.6107 - val_loss: 0.3845 - val_pixel_accuracy_multiclass: 0.9830 - val_wm_iou: 0.6949 - learning_rate: 1.0000e-04
# Epoch 42/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 362ms/step - csf_iou: 7.7839e-05 - dice_coefficient_multiclass: 0.4281 - gm_iou: 0.3024 - iou_score_multiclass: 0.3465 - loss: 0.6780 - pixel_accuracy_multiclass: 0.9954 - wm_iou: 0.1728
# Epoch 42: val_iou_score_multiclass did not improve from 0.61075
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 500ms/step - csf_iou: 7.7839e-05 - dice_coefficient_multiclass: 0.4281 - gm_iou: 0.3024 - iou_score_multiclass: 0.3465 - loss: 0.6780 - pixel_accuracy_multiclass: 0.9954 - wm_iou: 0.1728 - val_csf_iou: 0.1025 - val_dice_coefficient_multiclass: 0.6940 - val_gm_iou: 0.6796 - val_iou_score_multiclass: 0.6025 - val_loss: 0.3971 - val_pixel_accuracy_multiclass: 0.9810 - val_wm_iou: 0.6789 - learning_rate: 1.0000e-04
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.0874 - dice_coefficient_multiclass: 0.6681 - gm_iou: 0.6681 - iou_score_multiclass: 0.5791 - loss: 0.4184 - pixel_accuracy_multiclass: 0.9848 - wm_iou: 0.6199
# Epoch 43: val_iou_score_multiclass improved from 0.61075 to 0.61882, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 43: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.1098 - dice_coefficient_multiclass: 0.6767 - gm_iou: 0.6519 - iou_score_multiclass: 0.5847 - loss: 0.4131 - pixel_accuracy_multiclass: 0.9842 - wm_iou: 0.6362 - val_csf_iou: 0.1115 - val_dice_coefficient_multiclass: 0.7074 - val_gm_iou: 0.7075 - val_iou_score_multiclass: 0.6188 - val_loss: 0.3725 - val_pixel_accuracy_multiclass: 0.9832 - val_wm_iou: 0.7039 - learning_rate: 1.0000e-04
# Epoch 44/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 4s 376ms/step - csf_iou: 8.1901e-05 - dice_coefficient_multiclass: 0.4325 - gm_iou: 0.3126 - iou_score_multiclass: 0.3507 - loss: 0.6685 - pixel_accuracy_multiclass: 0.9955 - wm_iou: 0.1754
# Epoch 44: val_iou_score_multiclass did not improve from 0.61882
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 496ms/step - csf_iou: 8.1901e-05 - dice_coefficient_multiclass: 0.4325 - gm_iou: 0.3126 - iou_score_multiclass: 0.3507 - loss: 0.6685 - pixel_accuracy_multiclass: 0.9955 - wm_iou: 0.1754 - val_csf_iou: 0.1121 - val_dice_coefficient_multiclass: 0.7033 - val_gm_iou: 0.6941 - val_iou_score_multiclass: 0.6128 - val_loss: 0.3823 - val_pixel_accuracy_multiclass: 0.9817 - val_wm_iou: 0.6917 - learning_rate: 1.0000e-04
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 693ms/step - csf_iou: 0.0917 - dice_coefficient_multiclass: 0.6727 - gm_iou: 0.6759 - iou_score_multiclass: 0.5843 - loss: 0.4106 - pixel_accuracy_multiclass: 0.9852 - wm_iou: 0.6259
# Epoch 45: val_iou_score_multiclass improved from 0.61882 to 0.62334, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 45: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.1152 - dice_coefficient_multiclass: 0.6811 - gm_iou: 0.6580 - iou_score_multiclass: 0.5895 - loss: 0.4058 - pixel_accuracy_multiclass: 0.9844 - wm_iou: 0.6410 - val_csf_iou: 0.1194 - val_dice_coefficient_multiclass: 0.7121 - val_gm_iou: 0.7106 - val_iou_score_multiclass: 0.6233 - val_loss: 0.3670 - val_pixel_accuracy_multiclass: 0.9826 - val_wm_iou: 0.7080 - learning_rate: 1.0000e-04
# Epoch 46/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - csf_iou: 8.5757e-05 - dice_coefficient_multiclass: 0.4358 - gm_iou: 0.3203 - iou_score_multiclass: 0.3539 - loss: 0.6623 - pixel_accuracy_multiclass: 0.9954 - wm_iou: 0.1768
# Epoch 46: val_iou_score_multiclass did not improve from 0.62334
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 503ms/step - csf_iou: 8.5757e-05 - dice_coefficient_multiclass: 0.4358 - gm_iou: 0.3203 - iou_score_multiclass: 0.3539 - loss: 0.6623 - pixel_accuracy_multiclass: 0.9954 - wm_iou: 0.1768 - val_csf_iou: 0.1187 - val_dice_coefficient_multiclass: 0.7052 - val_gm_iou: 0.6905 - val_iou_score_multiclass: 0.6136 - val_loss: 0.3824 - val_pixel_accuracy_multiclass: 0.9804 - val_wm_iou: 0.6893 - learning_rate: 1.0000e-04
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 695ms/step - csf_iou: 0.0954 - dice_coefficient_multiclass: 0.6764 - gm_iou: 0.6808 - iou_score_multiclass: 0.5886 - loss: 0.4052 - pixel_accuracy_multiclass: 0.9851 - wm_iou: 0.6322
# Epoch 47: val_iou_score_multiclass improved from 0.62334 to 0.63031, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 47: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.1197 - dice_coefficient_multiclass: 0.6852 - gm_iou: 0.6628 - iou_score_multiclass: 0.5941 - loss: 0.3997 - pixel_accuracy_multiclass: 0.9844 - wm_iou: 0.6482 - val_csf_iou: 0.1314 - val_dice_coefficient_multiclass: 0.7195 - val_gm_iou: 0.7142 - val_iou_score_multiclass: 0.6303 - val_loss: 0.3564 - val_pixel_accuracy_multiclass: 0.9823 - val_wm_iou: 0.7182 - learning_rate: 1.0000e-04
# Epoch 48/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - csf_iou: 8.9925e-05 - dice_coefficient_multiclass: 0.4420 - gm_iou: 0.3279 - iou_score_multiclass: 0.3591 - loss: 0.6502 - pixel_accuracy_multiclass: 0.9957 - wm_iou: 0.1869
# Epoch 48: val_iou_score_multiclass did not improve from 0.63031
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 491ms/step - csf_iou: 8.9925e-05 - dice_coefficient_multiclass: 0.4420 - gm_iou: 0.3279 - iou_score_multiclass: 0.3591 - loss: 0.6502 - pixel_accuracy_multiclass: 0.9957 - wm_iou: 0.1869 - val_csf_iou: 0.1327 - val_dice_coefficient_multiclass: 0.7182 - val_gm_iou: 0.7077 - val_iou_score_multiclass: 0.6280 - val_loss: 0.3598 - val_pixel_accuracy_multiclass: 0.9817 - val_wm_iou: 0.7135 - learning_rate: 1.0000e-04
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.1002 - dice_coefficient_multiclass: 0.6805 - gm_iou: 0.6867 - iou_score_multiclass: 0.5930 - loss: 0.3995 - pixel_accuracy_multiclass: 0.9850 - wm_iou: 0.6370
# Epoch 49: val_iou_score_multiclass improved from 0.63031 to 0.63129, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 49: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.1249 - dice_coefficient_multiclass: 0.6900 - gm_iou: 0.6686 - iou_score_multiclass: 0.5995 - loss: 0.3931 - pixel_accuracy_multiclass: 0.9844 - wm_iou: 0.6566 - val_csf_iou: 0.1382 - val_dice_coefficient_multiclass: 0.7215 - val_gm_iou: 0.7054 - val_iou_score_multiclass: 0.6313 - val_loss: 0.3537 - val_pixel_accuracy_multiclass: 0.9813 - val_wm_iou: 0.7229 - learning_rate: 1.0000e-04
# Epoch 50/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - csf_iou: 9.3855e-05 - dice_coefficient_multiclass: 0.4476 - gm_iou: 0.3290 - iou_score_multiclass: 0.3637 - loss: 0.6406 - pixel_accuracy_multiclass: 0.9957 - wm_iou: 0.2008
# Prediction after epoch 50
#
#
# Epoch 50: val_iou_score_multiclass did not improve from 0.63129
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 599ms/step - csf_iou: 9.3855e-05 - dice_coefficient_multiclass: 0.4476 - gm_iou: 0.3290 - iou_score_multiclass: 0.3637 - loss: 0.6406 - pixel_accuracy_multiclass: 0.9957 - wm_iou: 0.2008 - val_csf_iou: 0.1395 - val_dice_coefficient_multiclass: 0.7209 - val_gm_iou: 0.6992 - val_iou_score_multiclass: 0.6299 - val_loss: 0.3559 - val_pixel_accuracy_multiclass: 0.9806 - val_wm_iou: 0.7224 - learning_rate: 1.0000e-04
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 693ms/step - csf_iou: 0.1043 - dice_coefficient_multiclass: 0.6822 - gm_iou: 0.6857 - iou_score_multiclass: 0.5945 - loss: 0.3982 - pixel_accuracy_multiclass: 0.9841 - wm_iou: 0.6389
# Epoch 51: val_iou_score_multiclass improved from 0.63129 to 0.64314, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 51: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.1299 - dice_coefficient_multiclass: 0.6930 - gm_iou: 0.6702 - iou_score_multiclass: 0.6027 - loss: 0.3908 - pixel_accuracy_multiclass: 0.9836 - wm_iou: 0.6615 - val_csf_iou: 0.1490 - val_dice_coefficient_multiclass: 0.7317 - val_gm_iou: 0.7258 - val_iou_score_multiclass: 0.6431 - val_loss: 0.3382 - val_pixel_accuracy_multiclass: 0.9828 - val_wm_iou: 0.7361 - learning_rate: 1.0000e-04
# Epoch 52/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - csf_iou: 9.8553e-05 - dice_coefficient_multiclass: 0.4532 - gm_iou: 0.3411 - iou_score_multiclass: 0.3687 - loss: 0.6320 - pixel_accuracy_multiclass: 0.9957 - wm_iou: 0.2059
# Epoch 52: val_iou_score_multiclass did not improve from 0.64314
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 497ms/step - csf_iou: 9.8553e-05 - dice_coefficient_multiclass: 0.4532 - gm_iou: 0.3411 - iou_score_multiclass: 0.3687 - loss: 0.6320 - pixel_accuracy_multiclass: 0.9957 - wm_iou: 0.2059 - val_csf_iou: 0.1489 - val_dice_coefficient_multiclass: 0.7286 - val_gm_iou: 0.7113 - val_iou_score_multiclass: 0.6385 - val_loss: 0.3451 - val_pixel_accuracy_multiclass: 0.9812 - val_wm_iou: 0.7329 - learning_rate: 1.0000e-04
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 693ms/step - csf_iou: 0.1071 - dice_coefficient_multiclass: 0.6848 - gm_iou: 0.6885 - iou_score_multiclass: 0.5973 - loss: 0.3938 - pixel_accuracy_multiclass: 0.9840 - wm_iou: 0.6431
# Epoch 53: val_iou_score_multiclass improved from 0.64314 to 0.64954, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 53: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.1333 - dice_coefficient_multiclass: 0.6962 - gm_iou: 0.6740 - iou_score_multiclass: 0.6063 - loss: 0.3852 - pixel_accuracy_multiclass: 0.9837 - wm_iou: 0.6668 - val_csf_iou: 0.1586 - val_dice_coefficient_multiclass: 0.7378 - val_gm_iou: 0.7396 - val_iou_score_multiclass: 0.6495 - val_loss: 0.3293 - val_pixel_accuracy_multiclass: 0.9837 - val_wm_iou: 0.7351 - learning_rate: 1.0000e-04
# Epoch 54/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 4s 368ms/step - csf_iou: 1.0386e-04 - dice_coefficient_multiclass: 0.4599 - gm_iou: 0.3520 - iou_score_multiclass: 0.3747 - loss: 0.6228 - pixel_accuracy_multiclass: 0.9956 - wm_iou: 0.2157
# Epoch 54: val_iou_score_multiclass did not improve from 0.64954
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 505ms/step - csf_iou: 1.0386e-04 - dice_coefficient_multiclass: 0.4599 - gm_iou: 0.3520 - iou_score_multiclass: 0.3747 - loss: 0.6228 - pixel_accuracy_multiclass: 0.9956 - wm_iou: 0.2157 - val_csf_iou: 0.1589 - val_dice_coefficient_multiclass: 0.7362 - val_gm_iou: 0.7299 - val_iou_score_multiclass: 0.6470 - val_loss: 0.3325 - val_pixel_accuracy_multiclass: 0.9825 - val_wm_iou: 0.7350 - learning_rate: 1.0000e-04
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.1121 - dice_coefficient_multiclass: 0.6903 - gm_iou: 0.6973 - iou_score_multiclass: 0.6035 - loss: 0.3840 - pixel_accuracy_multiclass: 0.9848 - wm_iou: 0.6516
# Epoch 55: val_iou_score_multiclass did not improve from 0.64954
# ...
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.1562 - dice_coefficient_multiclass: 0.7238 - gm_iou: 0.7442 - iou_score_multiclass: 0.6419 - loss: 0.3344 - pixel_accuracy_multiclass: 0.9872 - wm_iou: 0.7015
# Epoch 81: val_iou_score_multiclass improved from 0.68580 to 0.68585, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 81: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.1893 - dice_coefficient_multiclass: 0.7343 - gm_iou: 0.7273 - iou_score_multiclass: 0.6497 - loss: 0.3266 - pixel_accuracy_multiclass: 0.9866 - wm_iou: 0.7171 - val_csf_iou: 0.2267 - val_dice_coefficient_multiclass: 0.7738 - val_gm_iou: 0.7774 - val_iou_score_multiclass: 0.6858 - val_loss: 0.2853 - val_pixel_accuracy_multiclass: 0.9853 - val_wm_iou: 0.7654 - learning_rate: 5.0000e-05
# Epoch 82/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 4s 376ms/step - csf_iou: 1.4973e-04 - dice_coefficient_multiclass: 0.5013 - gm_iou: 0.4151 - iou_score_multiclass: 0.4126 - loss: 0.5613 - pixel_accuracy_multiclass: 0.9957 - wm_iou: 0.2855
# Epoch 82: val_iou_score_multiclass did not improve from 0.68585
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 501ms/step - csf_iou: 1.4973e-04 - dice_coefficient_multiclass: 0.5013 - gm_iou: 0.4151 - iou_score_multiclass: 0.4126 - loss: 0.5613 - pixel_accuracy_multiclass: 0.9957 - wm_iou: 0.2855 - val_csf_iou: 0.2266 - val_dice_coefficient_multiclass: 0.7732 - val_gm_iou: 0.7751 - val_iou_score_multiclass: 0.6850 - val_loss: 0.2857 - val_pixel_accuracy_multiclass: 0.9852 - val_wm_iou: 0.7643 - learning_rate: 5.0000e-05
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.1597 - dice_coefficient_multiclass: 0.7257 - gm_iou: 0.7460 - iou_score_multiclass: 0.6440 - loss: 0.3315 - pixel_accuracy_multiclass: 0.9872 - wm_iou: 0.7039
# Epoch 83: val_iou_score_multiclass improved from 0.68585 to 0.68708, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 83: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.1929 - dice_coefficient_multiclass: 0.7362 - gm_iou: 0.7293 - iou_score_multiclass: 0.6519 - loss: 0.3235 - pixel_accuracy_multiclass: 0.9867 - wm_iou: 0.7195 - val_csf_iou: 0.2338 - val_dice_coefficient_multiclass: 0.7758 - val_gm_iou: 0.7761 - val_iou_score_multiclass: 0.6871 - val_loss: 0.2849 - val_pixel_accuracy_multiclass: 0.9849 - val_wm_iou: 0.7640 - learning_rate: 5.0000e-05
# Epoch 84/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 362ms/step - csf_iou: 1.5369e-04 - dice_coefficient_multiclass: 0.5042 - gm_iou: 0.4187 - iou_score_multiclass: 0.4154 - loss: 0.5580 - pixel_accuracy_multiclass: 0.9957 - wm_iou: 0.2917
# Epoch 84: val_iou_score_multiclass did not improve from 0.68708
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 506ms/step - csf_iou: 1.5369e-04 - dice_coefficient_multiclass: 0.5042 - gm_iou: 0.4187 - iou_score_multiclass: 0.4154 - loss: 0.5580 - pixel_accuracy_multiclass: 0.9957 - wm_iou: 0.2917 - val_csf_iou: 0.2342 - val_dice_coefficient_multiclass: 0.7758 - val_gm_iou: 0.7754 - val_iou_score_multiclass: 0.6870 - val_loss: 0.2841 - val_pixel_accuracy_multiclass: 0.9850 - val_wm_iou: 0.7638 - learning_rate: 5.0000e-05
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 693ms/step - csf_iou: 0.1641 - dice_coefficient_multiclass: 0.7276 - gm_iou: 0.7479 - iou_score_multiclass: 0.6460 - loss: 0.3290 - pixel_accuracy_multiclass: 0.9872 - wm_iou: 0.7051
# Epoch 85: val_iou_score_multiclass did not improve from 0.68708
#
# Epoch 85: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - csf_iou: 0.1982 - dice_coefficient_multiclass: 0.7385 - gm_iou: 0.7314 - iou_score_multiclass: 0.6544 - loss: 0.3205 - pixel_accuracy_multiclass: 0.9868 - wm_iou: 0.7214 - val_csf_iou: 0.2356 - val_dice_coefficient_multiclass: 0.7751 - val_gm_iou: 0.7719 - val_iou_score_multiclass: 0.6856 - val_loss: 0.2861 - val_pixel_accuracy_multiclass: 0.9847 - val_wm_iou: 0.7601 - learning_rate: 5.0000e-05
# Epoch 86/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - csf_iou: 1.5746e-04 - dice_coefficient_multiclass: 0.5071 - gm_iou: 0.4224 - iou_score_multiclass: 0.4181 - loss: 0.5527 - pixel_accuracy_multiclass: 0.9960 - wm_iou: 0.2980
# Epoch 86: val_iou_score_multiclass did not improve from 0.68708
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 497ms/step - csf_iou: 1.5746e-04 - dice_coefficient_multiclass: 0.5071 - gm_iou: 0.4224 - iou_score_multiclass: 0.4181 - loss: 0.5527 - pixel_accuracy_multiclass: 0.9960 - wm_iou: 0.2980 - val_csf_iou: 0.2359 - val_dice_coefficient_multiclass: 0.7746 - val_gm_iou: 0.7702 - val_iou_score_multiclass: 0.6849 - val_loss: 0.2868 - val_pixel_accuracy_multiclass: 0.9845 - val_wm_iou: 0.7585 - learning_rate: 2.5000e-05
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.1679 - dice_coefficient_multiclass: 0.7293 - gm_iou: 0.7483 - iou_score_multiclass: 0.6477 - loss: 0.3271 - pixel_accuracy_multiclass: 0.9873 - wm_iou: 0.7068
# Epoch 87: val_iou_score_multiclass improved from 0.68708 to 0.69357, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 87: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.2018 - dice_coefficient_multiclass: 0.7401 - gm_iou: 0.7322 - iou_score_multiclass: 0.6560 - loss: 0.3182 - pixel_accuracy_multiclass: 0.9869 - wm_iou: 0.7228 - val_csf_iou: 0.2375 - val_dice_coefficient_multiclass: 0.7805 - val_gm_iou: 0.7870 - val_iou_score_multiclass: 0.6936 - val_loss: 0.2755 - val_pixel_accuracy_multiclass: 0.9862 - val_wm_iou: 0.7749 - learning_rate: 2.5000e-05
# Epoch 88/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - csf_iou: 1.6026e-04 - dice_coefficient_multiclass: 0.5077 - gm_iou: 0.4248 - iou_score_multiclass: 0.4188 - loss: 0.5511 - pixel_accuracy_multiclass: 0.9960 - wm_iou: 0.2979
# Epoch 88: val_iou_score_multiclass did not improve from 0.69357
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 484ms/step - csf_iou: 1.6026e-04 - dice_coefficient_multiclass: 0.5077 - gm_iou: 0.4248 - iou_score_multiclass: 0.4188 - loss: 0.5511 - pixel_accuracy_multiclass: 0.9960 - wm_iou: 0.2979 - val_csf_iou: 0.2371 - val_dice_coefficient_multiclass: 0.7798 - val_gm_iou: 0.7850 - val_iou_score_multiclass: 0.6926 - val_loss: 0.2769 - val_pixel_accuracy_multiclass: 0.9860 - val_wm_iou: 0.7737 - learning_rate: 2.5000e-05
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.1703 - dice_coefficient_multiclass: 0.7312 - gm_iou: 0.7516 - iou_score_multiclass: 0.6501 - loss: 0.3240 - pixel_accuracy_multiclass: 0.9876 - wm_iou: 0.7104
# Epoch 89: val_iou_score_multiclass improved from 0.69357 to 0.69524, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 89: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.2047 - dice_coefficient_multiclass: 0.7418 - gm_iou: 0.7344 - iou_score_multiclass: 0.6581 - loss: 0.3160 - pixel_accuracy_multiclass: 0.9870 - wm_iou: 0.7257 - val_csf_iou: 0.2407 - val_dice_coefficient_multiclass: 0.7821 - val_gm_iou: 0.7896 - val_iou_score_multiclass: 0.6952 - val_loss: 0.2739 - val_pixel_accuracy_multiclass: 0.9863 - val_wm_iou: 0.7758 - learning_rate: 2.5000e-05
# Epoch 90/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - csf_iou: 1.6204e-04 - dice_coefficient_multiclass: 0.5089 - gm_iou: 0.4274 - iou_score_multiclass: 0.4200 - loss: 0.5489 - pixel_accuracy_multiclass: 0.9961 - wm_iou: 0.2995
# Prediction after epoch 90
#
#
# Epoch 90: val_iou_score_multiclass improved from 0.69524 to 0.69534, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 90: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 682ms/step - csf_iou: 1.6204e-04 - dice_coefficient_multiclass: 0.5089 - gm_iou: 0.4274 - iou_score_multiclass: 0.4200 - loss: 0.5489 - pixel_accuracy_multiclass: 0.9961 - wm_iou: 0.2995 - val_csf_iou: 0.2404 - val_dice_coefficient_multiclass: 0.7822 - val_gm_iou: 0.7897 - val_iou_score_multiclass: 0.6953 - val_loss: 0.2735 - val_pixel_accuracy_multiclass: 0.9864 - val_wm_iou: 0.7763 - learning_rate: 2.5000e-05
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.1717 - dice_coefficient_multiclass: 0.7320 - gm_iou: 0.7530 - iou_score_multiclass: 0.6510 - loss: 0.3228 - pixel_accuracy_multiclass: 0.9876 - wm_iou: 0.7112
# Epoch 91: val_iou_score_multiclass did not improve from 0.69534
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - csf_iou: 0.2059 - dice_coefficient_multiclass: 0.7427 - gm_iou: 0.7360 - iou_score_multiclass: 0.6592 - loss: 0.3145 - pixel_accuracy_multiclass: 0.9871 - wm_iou: 0.7273 - val_csf_iou: 0.2413 - val_dice_coefficient_multiclass: 0.7805 - val_gm_iou: 0.7832 - val_iou_score_multiclass: 0.6926 - val_loss: 0.2772 - val_pixel_accuracy_multiclass: 0.9857 - val_wm_iou: 0.7711 - learning_rate: 2.5000e-05
# Epoch 92/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 4s 366ms/step - csf_iou: 1.6449e-04 - dice_coefficient_multiclass: 0.5101 - gm_iou: 0.4287 - iou_score_multiclass: 0.4211 - loss: 0.5477 - pixel_accuracy_multiclass: 0.9961 - wm_iou: 0.3021
# Epoch 92: val_iou_score_multiclass did not improve from 0.69534
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 492ms/step - csf_iou: 1.6449e-04 - dice_coefficient_multiclass: 0.5101 - gm_iou: 0.4287 - iou_score_multiclass: 0.4211 - loss: 0.5477 - pixel_accuracy_multiclass: 0.9961 - wm_iou: 0.3021 - val_csf_iou: 0.2410 - val_dice_coefficient_multiclass: 0.7802 - val_gm_iou: 0.7824 - val_iou_score_multiclass: 0.6922 - val_loss: 0.2776 - val_pixel_accuracy_multiclass: 0.9857 - val_wm_iou: 0.7706 - learning_rate: 2.5000e-05
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.1734 - dice_coefficient_multiclass: 0.7332 - gm_iou: 0.7544 - iou_score_multiclass: 0.6524 - loss: 0.3210 - pixel_accuracy_multiclass: 0.9877 - wm_iou: 0.7131
# Epoch 93: val_iou_score_multiclass improved from 0.69534 to 0.69597, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 93: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.2080 - dice_coefficient_multiclass: 0.7437 - gm_iou: 0.7368 - iou_score_multiclass: 0.6602 - loss: 0.3131 - pixel_accuracy_multiclass: 0.9871 - wm_iou: 0.7280 - val_csf_iou: 0.2432 - val_dice_coefficient_multiclass: 0.7830 - val_gm_iou: 0.7885 - val_iou_score_multiclass: 0.6960 - val_loss: 0.2734 - val_pixel_accuracy_multiclass: 0.9862 - val_wm_iou: 0.7772 - learning_rate: 2.5000e-05
# Epoch 94/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - csf_iou: 1.6679e-04 - dice_coefficient_multiclass: 0.5106 - gm_iou: 0.4299 - iou_score_multiclass: 0.4217 - loss: 0.5474 - pixel_accuracy_multiclass: 0.9959 - wm_iou: 0.3028
# Epoch 94: val_iou_score_multiclass did not improve from 0.69597
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 498ms/step - csf_iou: 1.6679e-04 - dice_coefficient_multiclass: 0.5106 - gm_iou: 0.4299 - iou_score_multiclass: 0.4217 - loss: 0.5474 - pixel_accuracy_multiclass: 0.9959 - wm_iou: 0.3028 - val_csf_iou: 0.2429 - val_dice_coefficient_multiclass: 0.7822 - val_gm_iou: 0.7861 - val_iou_score_multiclass: 0.6948 - val_loss: 0.2748 - val_pixel_accuracy_multiclass: 0.9860 - val_wm_iou: 0.7754 - learning_rate: 2.5000e-05
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 693ms/step - csf_iou: 0.1756 - dice_coefficient_multiclass: 0.7343 - gm_iou: 0.7552 - iou_score_multiclass: 0.6536 - loss: 0.3197 - pixel_accuracy_multiclass: 0.9877 - wm_iou: 0.7147
# Epoch 95: val_iou_score_multiclass improved from 0.69597 to 0.69781, saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
#
# Epoch 95: finished saving model to best_model_vgg16unetpp_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - csf_iou: 0.2102 - dice_coefficient_multiclass: 0.7448 - gm_iou: 0.7382 - iou_score_multiclass: 0.6616 - loss: 0.3116 - pixel_accuracy_multiclass: 0.9872 - wm_iou: 0.7295 - val_csf_iou: 0.2436 - val_dice_coefficient_multiclass: 0.7842 - val_gm_iou: 0.7923 - val_iou_score_multiclass: 0.6978 - val_loss: 0.2703 - val_pixel_accuracy_multiclass: 0.9866 - val_wm_iou: 0.7802 - learning_rate: 2.5000e-05
# Epoch 96/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - csf_iou: 1.6813e-04 - dice_coefficient_multiclass: 0.5136 - gm_iou: 0.4343 - iou_score_multiclass: 0.4244 - loss: 0.5428 - pixel_accuracy_multiclass: 0.9962 - wm_iou: 0.3088
# Epoch 96: val_iou_score_multiclass did not improve from 0.69781
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 487ms/step - csf_iou: 1.6813e-04 - dice_coefficient_multiclass: 0.5136 - gm_iou: 0.4343 - iou_score_multiclass: 0.4244 - loss: 0.5428 - pixel_accuracy_multiclass: 0.9962 - wm_iou: 0.3088 - val_csf_iou: 0.2433 - val_dice_coefficient_multiclass: 0.7839 - val_gm_iou: 0.7910 - val_iou_score_multiclass: 0.6974 - val_loss: 0.2708 - val_pixel_accuracy_multiclass: 0.9866 - val_wm_iou: 0.7801 - learning_rate: 2.5000e-05
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - csf_iou: 0.1772 - dice_coefficient_multiclass: 0.7350 - gm_iou: 0.7559 - iou_score_multiclass: 0.6543 - loss: 0.3188 - pixel_accuracy_multiclass: 0.9877 - wm_iou: 0.7151
# Epoch 97: val_iou_score_multiclass did not improve from 0.69781
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - csf_iou: 0.2120 - dice_coefficient_multiclass: 0.7456 - gm_iou: 0.7386 - iou_score_multiclass: 0.6624 - loss: 0.3107 - pixel_accuracy_multiclass: 0.9872 - wm_iou: 0.7303 - val_csf_iou: 0.2462 - val_dice_coefficient_multiclass: 0.7839 - val_gm_iou: 0.7889 - val_iou_score_multiclass: 0.6967 - val_loss: 0.2719 - val_pixel_accuracy_multiclass: 0.9862 - val_wm_iou: 0.7766 - learning_rate: 2.5000e-05
# Epoch 98/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - csf_iou: 1.7076e-04 - dice_coefficient_multiclass: 0.5144 - gm_iou: 0.4343 - iou_score_multiclass: 0.4252 - loss: 0.5418 - pixel_accuracy_multiclass: 0.9960 - wm_iou: 0.3115
# Epoch 98: val_iou_score_multiclass did not improve from 0.69781
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 486ms/step - csf_iou: 1.7076e-04 - dice_coefficient_multiclass: 0.5144 - gm_iou: 0.4343 - iou_score_multiclass: 0.4252 - loss: 0.5418 - pixel_accuracy_multiclass: 0.9960 - wm_iou: 0.3115 - val_csf_iou: 0.2460 - val_dice_coefficient_multiclass: 0.7839 - val_gm_iou: 0.7889 - val_iou_score_multiclass: 0.6967 - val_loss: 0.2716 - val_pixel_accuracy_multiclass: 0.9863 - val_wm_iou: 0.7767 - learning_rate: 2.5000e-05
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 693ms/step - csf_iou: 0.1788 - dice_coefficient_multiclass: 0.7360 - gm_iou: 0.7572 - iou_score_multiclass: 0.6555 - loss: 0.3173 - pixel_accuracy_multiclass: 0.9877 - wm_iou: 0.7168
# Epoch 99: val_iou_score_multiclass did not improve from 0.69781
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - csf_iou: 0.2138 - dice_coefficient_multiclass: 0.7467 - gm_iou: 0.7401 - iou_score_multiclass: 0.6638 - loss: 0.3090 - pixel_accuracy_multiclass: 0.9872 - wm_iou: 0.7323 - val_csf_iou: 0.2477 - val_dice_coefficient_multiclass: 0.7846 - val_gm_iou: 0.7881 - val_iou_score_multiclass: 0.6974 - val_loss: 0.2709 - val_pixel_accuracy_multiclass: 0.9862 - val_wm_iou: 0.7782 - learning_rate: 2.5000e-05
# Epoch 100/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - csf_iou: 1.7293e-04 - dice_coefficient_multiclass: 0.5149 - gm_iou: 0.4380 - iou_score_multiclass: 0.4258 - loss: 0.5411 - pixel_accuracy_multiclass: 0.9962 - wm_iou: 0.3098
# Prediction after epoch 100
#
#
# Epoch 100: val_iou_score_multiclass did not improve from 0.69781
#
# Epoch 100: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 559ms/step - csf_iou: 1.7293e-04 - dice_coefficient_multiclass: 0.5149 - gm_iou: 0.4380 - iou_score_multiclass: 0.4258 - loss: 0.5411 - pixel_accuracy_multiclass: 0.9962 - wm_iou: 0.3098 - val_csf_iou: 0.2475 - val_dice_coefficient_multiclass: 0.7843 - val_gm_iou: 0.7874 - val_iou_score_multiclass: 0.6970 - val_loss: 0.2710 - val_pixel_accuracy_multiclass: 0.9862 - val_wm_iou: 0.7779 - learning_rate: 2.5000e-05
#
# Training time: 20.5 min

# %% [markdown]
# ## 13. Training Graphs

# %%
H = history.history

fig, axes = plt.subplots(4, 2, figsize=(14, 20))
fig.suptitle('VGG16-UNet++ (Multi-Class)  |  IBSR Tissue Segmentation  |  Training History',
             fontsize=15, fontweight='bold', y=0.99)

plot_specs = [
    ('loss', 'val_loss', 'Loss (Dice + CCE)', 'Loss'),
    ('dice_coefficient_multiclass', 'val_dice_coefficient_multiclass', 'Dice (macro-avg)', 'Dice'),
    ('iou_score_multiclass', 'val_iou_score_multiclass', 'IoU (macro-avg)', 'IoU'),
    ('pixel_accuracy_multiclass', 'val_pixel_accuracy_multiclass', 'Pixel Accuracy', 'Accuracy'),
    ('csf_iou', 'val_csf_iou', 'CSF IoU', 'IoU'),
    ('gm_iou', 'val_gm_iou', 'Grey Matter IoU', 'IoU'),
    ('wm_iou', 'val_wm_iou', 'White Matter IoU', 'IoU'),
]

for ax, (train_key, val_key, title, ylabel) in zip(axes.flatten(), plot_specs):
    epochs_range = range(1, len(H[train_key]) + 1)
    ax.plot(epochs_range, H[train_key], label='Train', color='steelblue', linewidth=2)
    ax.plot(epochs_range, H[val_key], label='Validation', color='darkorange', linewidth=2, linestyle='--')
    ax.set_title(title, fontsize=12, fontweight='bold')
    ax.set_xlabel('Epoch')
    ax.set_ylabel(ylabel)
    ax.legend(fontsize=10)
    ax.grid(True, alpha=0.3)

axes.flatten()[-1].axis('off')
plt.tight_layout()
plt.savefig('training_history_vgg16unetpp_multiclass_ibsr.png', dpi=150, bbox_inches='tight')
plt.show()
print('Plot saved ✓')
# Out:
# Plot saved ✓

# %% [markdown]
# ## 14. Best & Average Metrics Table

# %%
metric_spec = [
    ('Loss', 'loss', 'min'),
    ('Dice (macro-avg)', 'dice_coefficient_multiclass', 'max'),
    ('IoU (macro-avg)', 'iou_score_multiclass', 'max'),
    ('Pixel Accuracy', 'pixel_accuracy_multiclass', 'max'),
    ('CSF IoU', 'csf_iou', 'max'),
    ('Grey Matter IoU', 'gm_iou', 'max'),
    ('White Matter IoU', 'wm_iou', 'max'),
]

rows = []
for disp, key, mode in metric_spec:
    tr = np.asarray(H[key], dtype=np.float64)
    va = np.asarray(H['val_' + key], dtype=np.float64)
    pick = np.min if mode == 'min' else np.max
    rows.append({'Metric': disp, 'Train Best': pick(tr), 'Train Avg': tr.mean(),
                 'Val Best': pick(va), 'Val Avg': va.mean()})

report = pd.DataFrame(rows).set_index('Metric').round(4)

print('=' * 70)
print('   BEST & AVERAGE METRICS  —  VGG16-UNet++ Multi-Class  |  IBSR')
print('=' * 70)
print(report.to_string())
print('=' * 70)

best_epoch_iou = int(np.argmax(H['val_iou_score_multiclass'])) + 1
print(f'\nBest Val IoU (macro-avg): {max(H["val_iou_score_multiclass"]):.4f}  (epoch {best_epoch_iou})')
print(f'Best Val CSF IoU         : {max(H["val_csf_iou"]):.4f}')
print(f'Best Val Grey Matter IoU : {max(H["val_gm_iou"]):.4f}')
print(f'Best Val White Matter IoU: {max(H["val_wm_iou"]):.4f}')

report
# Out:
# ======================================================================
#    BEST & AVERAGE METRICS  —  VGG16-UNet++ Multi-Class  |  IBSR
# ======================================================================
#                   Train Best  Train Avg  Val Best  Val Avg
# Metric
# Loss                  0.3090     0.6076    0.2703   0.9397
# Dice (macro-avg)      0.7467     0.5408    0.7846   0.6419
# IoU (macro-avg)       0.6638     0.4543    0.6978   0.5513
# Pixel Accuracy        0.9962     0.9847    0.9866   0.8971
# CSF IoU               0.2138     0.0596    0.2477   0.1298
# Grey Matter IoU       0.7401     0.4642    0.7923   0.6309
# White Matter IoU      0.7323     0.4003    0.7802   0.6075
# ======================================================================
#
# Best Val IoU (macro-avg): 0.6978  (epoch 95)
# Best Val CSF IoU         : 0.2477
# Best Val Grey Matter IoU : 0.7923
# Best Val White Matter IoU: 0.7802
#                   Train Best  Train Avg  Val Best  Val Avg
# Metric
# Loss                  0.3090     0.6076    0.2703   0.9397
# Dice (macro-avg)      0.7467     0.5408    0.7846   0.6419
# IoU (macro-avg)       0.6638     0.4543    0.6978   0.5513
# Pixel Accuracy        0.9962     0.9847    0.9866   0.8971
# CSF IoU               0.2138     0.0596    0.2477   0.1298
# Grey Matter IoU       0.7401     0.4642    0.7923   0.6309
# White Matter IoU      0.7323     0.4003    0.7802   0.6075

# %% [markdown]
# ## 15. Load Best Model & Final Evaluation

# %%
best_model = tf.keras.models.load_model(
    'best_model_vgg16unetpp_multiclass_ibsr.keras',
    custom_objects={
        'combined_loss_multiclass': combined_loss_multiclass,
        'dice_coefficient_multiclass': dice_coefficient_multiclass,
        'iou_score_multiclass': iou_score_multiclass,
        'pixel_accuracy_multiclass': pixel_accuracy_multiclass,
        'csf_iou': csf_iou, 'gm_iou': gm_iou, 'wm_iou': wm_iou,
    }
)
print('Best model loaded ✓')
# Out:
# Best model loaded ✓

# %%
print('Evaluating best model on held-out test set...\n')
test_results = best_model.evaluate(test_dataset, verbose=1)
test_dict = dict(zip(best_model.metrics_names, test_results))

print('\n' + '=' * 60)
print('  FINAL TEST-SET METRICS  (VGG16-UNet++ Multi-Class | IBSR)')
print('=' * 60)
for k, v in test_dict.items():
    print(f'  {k:35s}: {v:.4f}')
print('=' * 60)

final_df = pd.DataFrame([{
    'Model': 'VGG16-UNet++ Multi-Class (IBSR)',
    'IoU (macro)': round(test_dict.get('iou_score_multiclass', float('nan')), 4),
    'Dice (macro)': round(test_dict.get('dice_coefficient_multiclass', float('nan')), 4),
    'CSF IoU': round(test_dict.get('csf_iou', float('nan')), 4),
    'GM IoU': round(test_dict.get('gm_iou', float('nan')), 4),
    'WM IoU': round(test_dict.get('wm_iou', float('nan')), 4),
    'Pixel Accuracy': round(test_dict.get('pixel_accuracy_multiclass', float('nan')), 4),
}]).set_index('Model')
final_df
# Out:
# Evaluating best model on held-out test set...
#
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - csf_iou: 0.2186 - dice_coefficient_multiclass: 0.7788 - gm_iou: 0.8088 - iou_score_multiclass: 0.6959 - loss: 0.2732 - pixel_accuracy_multiclass: 0.9873 - wm_iou: 0.7804
# 2026-06-29 10:14:57.017493: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-29 10:14:57.262944: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-29 10:14:58.413411: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-29 10:14:58.671344: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-29 10:14:59.738785: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-29 10:15:00.042725: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 7s/step - csf_iou: 0.1627 - dice_coefficient_multiclass: 0.7350 - gm_iou: 0.7414 - iou_score_multiclass: 0.6530 - loss: 0.2846 - pixel_accuracy_multiclass: 0.9888 - wm_iou: 0.7318
#
# ============================================================
#   FINAL TEST-SET METRICS  (VGG16-UNet++ Multi-Class | IBSR)
# ============================================================
#   loss                               : 0.2846
#   compile_metrics                    : 0.7350
# ============================================================
#                                  IoU (macro)  Dice (macro)  CSF IoU  GM IoU  \
# Model
# VGG16-UNet++ Multi-Class (IBSR)          NaN           NaN      NaN     NaN
#
#                                  WM IoU  Pixel Accuracy
# Model
# VGG16-UNet++ Multi-Class (IBSR)     NaN             NaN

# %% [markdown]
# ## 16. Test Predictions Visualization

# %%
print('Test set predictions:')
show_predictions(test_dataset, num=5, model_to_use=best_model)
# Out:
# Test set predictions:

# %% [markdown]
# ## 17. Save Final Model

# %%
best_model.save('ibsr_vgg16_unetpp_multiclass_final.keras')
print('Model saved ✓')
# Out:
# Model saved ✓
