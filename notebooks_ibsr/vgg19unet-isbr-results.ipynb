# %% [markdown]
# # Alzheimer's Disease Brain MRI — Multi-Class Tissue Segmentation
# ## VGG19 + UNet | 4-Class (Background / CSF / Grey Matter / White Matter) | IBSR Dataset
#
# **Dataset:** Internet Brain Segmentation Repository (IBSR) — 18 subjects, expert-annotated tri-class tissue segmentation (`segTRI`).
#
# **Why multi-class directly (no binary step):** The binary-then-multiclass pipeline was already validated on OASIS-1. Since IBSR's `segTRI` masks use the same 4-label convention (0=background, 1=CSF, 2=GM, 3=WM), we go directly to multi-class here rather than re-proving the pipeline at the binary level.
#
# **Note:** EarlyStopping disabled — model trains for the full configured epochs as instructed.
#
# **Note on CSF class:** IBSR's CSF label is far sparser (~0.17% of voxels) than OASIS-1's (~7.5%) — expect CSF IoU to be a harder, noisier metric here purely due to extreme class imbalance, not a pipeline issue.
#
# **Encoder:** VGG19 (instead of VGG16) — adds `block3_conv4`, `block4_conv4`, `block5_conv4` vs VGG16's 3-conv blocks, giving a deeper encoder with the same spatial resolution stages.

# %% [markdown]
# ## 1. Import Libraries

# %%
import os
import re
import cv2
import random
import shutil
import tarfile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import (
    Input, Conv2D, UpSampling2D, concatenate, BatchNormalization, Dropout, Activation
)
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG19
from tensorflow.keras import callbacks
from sklearn.model_selection import train_test_split
from tqdm.auto import tqdm
import time
import datetime

# !pip install nibabel -q
import nibabel as nib

print('TensorFlow version:', tf.__version__)
print('GPUs available:', tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.19.0
# GPUs available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 2. Configuration & Extraction

# %%
# ─── Paths — adjust dataset slug if different ─────────────────────────────────
IBSR_TGZ_PATH = '/kaggle/input/datasets/maheswarimudadla/ibsr-dataset/IBSR_V2.0_nifti_stripped.tgz'
EXTRACT_DIR   = '/kaggle/working/ibsr_extracted'
IBSR_ROOT     = os.path.join(EXTRACT_DIR, 'IBSR_nifti_stripped')

PROCESSED_DIR   = 'ibsr_processed'
IMAGE_FOLDER    = os.path.join(PROCESSED_DIR, 'images')
MASK_FOLDER     = os.path.join(PROCESSED_DIR, 'masks')
TRAIN_IMG_DIR   = os.path.join(PROCESSED_DIR, 'train', 'images')
TRAIN_MASK_DIR  = os.path.join(PROCESSED_DIR, 'train', 'masks')
TEST_IMG_DIR    = os.path.join(PROCESSED_DIR, 'test',  'images')
TEST_MASK_DIR   = os.path.join(PROCESSED_DIR, 'test',  'masks')

# ─── Hyperparameters ──────────────────────────────────────────────────────────
IMG_SIZE    = (224, 224)
BATCH_SIZE  = 16
EPOCHS      = 100
SEED        = 42
TEST_SPLIT  = 0.15
NUM_CLASSES = 4   # 0=background, 1=CSF, 2=Grey Matter, 3=White Matter
CLASS_NAMES = ['Background', 'CSF', 'Grey Matter', 'White Matter']

print('Config set ✓')
# Out:
# Config set ✓

# %%
# ─── Extract the .tgz if not already done ─────────────────────────────────────
if not os.path.exists(IBSR_ROOT):
    os.makedirs(EXTRACT_DIR, exist_ok=True)
    print('Extracting IBSR archive...')
    with tarfile.open(IBSR_TGZ_PATH, 'r:gz') as tar:
        tar.extractall(path=EXTRACT_DIR)
    print('Extraction done ✓')
else:
    print('Already extracted ✓')

subject_folders = sorted([
    d for d in os.listdir(IBSR_ROOT)
    if os.path.isdir(os.path.join(IBSR_ROOT, d)) and d.startswith('IBSR_')
])
print(f'Found {len(subject_folders)} subjects: {subject_folders}')
# Out:
# Already extracted ✓
# Found 18 subjects: ['IBSR_01', 'IBSR_02', 'IBSR_03', 'IBSR_04', 'IBSR_05', 'IBSR_06', 'IBSR_07', 'IBSR_08', 'IBSR_09', 'IBSR_10', 'IBSR_11', 'IBSR_12', 'IBSR_13', 'IBSR_14', 'IBSR_15', 'IBSR_16', 'IBSR_17', 'IBSR_18']

# %% [markdown]
# ## 3. Extract 2D Slices — Keep All 4 Tissue Labels

# %%
def make_dir(path):
    os.makedirs(path, exist_ok=True)

for d in [IMAGE_FOLDER, MASK_FOLDER,
          TRAIN_IMG_DIR, TRAIN_MASK_DIR,
          TEST_IMG_DIR,  TEST_MASK_DIR]:
    make_dir(d)

print('Directories ready ✓')
# Out:
# Directories ready ✓

# %%
def normalize_slice(arr):
    """Min-max normalise a 2-D array to [0, 255] uint8 — for the BRAIN IMAGE only."""
    mn, mx = arr.min(), arr.max()
    if mx - mn == 0:
        return np.zeros_like(arr, dtype=np.uint8)
    return ((arr - mn) / (mx - mn) * 255).astype(np.uint8)


def extract_slices_ibsr(subject_dir, subject_name, img_out, mask_out, step=2):
    """
    IBSR file naming: <subject>_ana_strip.nii.gz (brain, skull-stripped)
                       <subject>_segTRI_ana.nii   (4-class tissue mask)
    Both are (256, 128, 256, 1) — squeeze the trailing singleton dim.
    Mask labels kept as raw integers 0/1/2/3 (NOT thresholded to binary).
    """
    brain_path = os.path.join(subject_dir, f'{subject_name}_ana_strip.nii.gz')
    seg_path   = os.path.join(subject_dir, f'{subject_name}_segTRI_ana.nii')

    if not os.path.exists(brain_path) or not os.path.exists(seg_path):
        print(f'  Skipping {subject_name} — missing file(s)')
        return 0

    brain_vol = np.squeeze(nib.load(brain_path).get_fdata())
    seg_vol   = np.squeeze(nib.load(seg_path).get_fdata())

    saved = 0
    for i in range(0, brain_vol.shape[1], step):
        b_sl   = brain_vol[:, i, :]
        seg_sl = seg_vol[:, i, :]

        if b_sl.max() == 0:
            continue

        img_arr  = normalize_slice(b_sl)
        mask_arr = np.round(seg_sl).astype(np.uint8)
        mask_arr = np.clip(mask_arr, 0, NUM_CLASSES - 1)

        fname = f'{subject_name}_sl{i:03d}.png'
        cv2.imwrite(os.path.join(img_out,  fname), img_arr)
        cv2.imwrite(os.path.join(mask_out, fname), mask_arr)
        saved += 1

    return saved


# ─── Clear old slices (fresh run) ──────────────────────────────────────────────
for folder in [IMAGE_FOLDER, MASK_FOLDER]:
    if os.path.exists(folder):
        shutil.rmtree(folder)
    os.makedirs(folder)

# ─── Extract from all 18 subjects ──────────────────────────────────────────────
total_slices = 0
for subj_name in tqdm(subject_folders, desc='Extracting slices'):
    subj_dir = os.path.join(IBSR_ROOT, subj_name)
    total_slices += extract_slices_ibsr(subj_dir, subj_name, IMAGE_FOLDER, MASK_FOLDER, step=1)

print(f'\nTotal slices extracted : {total_slices}')
print(f'Images saved           : {len(os.listdir(IMAGE_FOLDER))}')
print(f'Masks  saved           : {len(os.listdir(MASK_FOLDER))}')
print()
print('Note: step=1 (every slice) since IBSR only has 18 subjects.')
# Out:
# Extracting slices:   0%|          | 0/18 [00:00<?, ?it/s]
#   Skipping IBSR_02 — missing file(s)
#   Skipping IBSR_03 — missing file(s)
#   Skipping IBSR_04 — missing file(s)
#   Skipping IBSR_05 — missing file(s)
#   Skipping IBSR_07 — missing file(s)
#   Skipping IBSR_08 — missing file(s)
#   Skipping IBSR_09 — missing file(s)
#   Skipping IBSR_10 — missing file(s)
#   Skipping IBSR_11 — missing file(s)
#   Skipping IBSR_12 — missing file(s)
#   Skipping IBSR_13 — missing file(s)
#   Skipping IBSR_14 — missing file(s)
#   Skipping IBSR_15 — missing file(s)
#   Skipping IBSR_16 — missing file(s)
#   Skipping IBSR_17 — missing file(s)
#   Skipping IBSR_18 — missing file(s)
#
# Total slices extracted : 236
# Images saved           : 236
# Masks  saved           : 236
#
# Note: step=1 (every slice) since IBSR only has 18 subjects.

# %% [markdown]
# ## 4. Verify Label Distribution & Visualize

# %%
sample_mask_files = random.sample(os.listdir(MASK_FOLDER), min(20, len(os.listdir(MASK_FOLDER))))
all_vals = set()
for f in sample_mask_files:
    m = cv2.imread(os.path.join(MASK_FOLDER, f), cv2.IMREAD_GRAYSCALE)
    all_vals.update(np.unique(m).tolist())

print('Unique label values found across sample masks:', sorted(all_vals))
print('Expected: [0, 1, 2, 3]  (Background, CSF, Grey Matter, White Matter)')
# Out:
# Unique label values found across sample masks: [0, 1, 2, 3]
# Expected: [0, 1, 2, 3]  (Background, CSF, Grey Matter, White Matter)

# %%
CLASS_COLORS = ['black', 'cyan', 'orange', 'magenta']
cmap_classes = mcolors.ListedColormap(CLASS_COLORS)

def visualize_sample_multiclass(image_name, img_dir=IMAGE_FOLDER, mask_dir=MASK_FOLDER):
    img  = cv2.imread(os.path.join(img_dir,  image_name), cv2.IMREAD_GRAYSCALE)
    mask = cv2.imread(os.path.join(mask_dir, image_name), cv2.IMREAD_GRAYSCALE)

    fig, axes = plt.subplots(1, 2, figsize=(12, 6))
    axes[0].imshow(img, cmap='gray')
    axes[0].set_title('Brain MRI Slice', fontsize=13)

    im = axes[1].imshow(mask, cmap=cmap_classes, vmin=0, vmax=NUM_CLASSES - 1)
    axes[1].set_title('Tissue Labels (CSF / GM / WM)', fontsize=13)
    cbar = plt.colorbar(im, ax=axes[1], ticks=range(NUM_CLASSES))
    cbar.ax.set_yticklabels(CLASS_NAMES)

    for ax in axes: ax.axis('off')
    plt.suptitle(image_name, fontsize=10, color='gray')
    plt.tight_layout()
    plt.show()


all_images = os.listdir(IMAGE_FOLDER)
for _ in range(4):
    visualize_sample_multiclass(random.choice(all_images))

# %% [markdown]
# ## 5. Train / Test Split

# %%
images = sorted([f for f in os.listdir(IMAGE_FOLDER) if f.endswith('.png')])
masks  = sorted([f for f in os.listdir(MASK_FOLDER)  if f.endswith('.png')])

assert images == masks, 'Image-mask mismatch! Check filenames.'

train_imgs, test_imgs = train_test_split(images, test_size=TEST_SPLIT, random_state=SEED)
print(f'Train: {len(train_imgs)}  |  Test: {len(test_imgs)}')

def copy_files(file_list, src_img, src_mask, dst_img, dst_mask):
    for f in tqdm(file_list, leave=False):
        shutil.copy(os.path.join(src_img,  f), os.path.join(dst_img,  f))
        shutil.copy(os.path.join(src_mask, f), os.path.join(dst_mask, f))

copy_files(train_imgs, IMAGE_FOLDER, MASK_FOLDER, TRAIN_IMG_DIR, TRAIN_MASK_DIR)
copy_files(test_imgs,  IMAGE_FOLDER, MASK_FOLDER, TEST_IMG_DIR,  TEST_MASK_DIR)
print('Files copied ✓')
# Out:
# Train: 200  |  Test: 36
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/36 [00:00<?, ?it/s]
# Files copied ✓

# %% [markdown]
# ## 6. tf.data Pipeline — one-hot encoded masks

# %%
def load_image(img_path, mask_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE, method='bilinear')
    img = tf.cast(img, tf.float32) / 255.0

    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=1)
    mask = tf.image.resize(mask, IMG_SIZE, method='nearest')
    mask = tf.cast(mask, tf.int32)
    mask = tf.squeeze(mask, axis=-1)
    mask = tf.one_hot(mask, depth=NUM_CLASSES)
    mask = tf.cast(mask, tf.float32)

    return img, mask


def augment(img, mask):
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_left_right(img)
        mask = tf.image.flip_left_right(mask)
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_up_down(img)
        mask = tf.image.flip_up_down(mask)
    img = tf.image.random_brightness(img, max_delta=0.05)
    img = tf.clip_by_value(img, 0.0, 1.0)
    return img, mask


def build_dataset(img_dir, mask_dir, augment_data=False, batch=BATCH_SIZE):
    img_files  = sorted([os.path.join(img_dir,  f) for f in os.listdir(img_dir)  if f.endswith('.png')])
    mask_files = sorted([os.path.join(mask_dir, f) for f in os.listdir(mask_dir) if f.endswith('.png')])

    ds = tf.data.Dataset.from_tensor_slices((img_files, mask_files))
    ds = ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
    if augment_data:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch).prefetch(tf.data.AUTOTUNE)
    return ds


train_dataset = build_dataset(TRAIN_IMG_DIR, TRAIN_MASK_DIR, augment_data=True)
test_dataset  = build_dataset(TEST_IMG_DIR,  TEST_MASK_DIR,  augment_data=False)

print('Datasets ready ✓')
for imgs, masks in train_dataset.take(1):
    print('Batch shapes →  images:', imgs.shape, ' masks:', masks.shape)
# Out:
# Datasets ready ✓
# Batch shapes →  images: (16, 224, 224, 3)  masks: (16, 224, 224, 4)

# %% [markdown]
# ## 7. Model — VGG19 Encoder + UNet Decoder, 4-class softmax output
#
# **VGG19 vs VGG16 encoder differences:**
# | Stage | VGG16 skip layer | VGG19 skip layer |
# |-------|-----------------|------------------|
# | Stage 1 (112×112) | `block1_conv2` | `block1_conv2` |
# | Stage 2 (56×56)   | `block2_conv2` | `block2_conv2` |
# | Stage 3 (28×28)   | `block3_conv3` | `block3_conv4` |
# | Stage 4 (14×14)   | `block4_conv3` | `block4_conv4` |
# | Bottleneck (7×7)  | `block5_conv3` | `block5_conv4` |

# %%
def conv_block(x, filters, name_prefix):
    x = Conv2D(filters, (3,3), padding='same', name=f'{name_prefix}_c1')(x)
    x = BatchNormalization(name=f'{name_prefix}_bn1')(x)
    x = Activation('relu', name=f'{name_prefix}_act1')(x)
    x = Conv2D(filters, (3,3), padding='same', name=f'{name_prefix}_c2')(x)
    x = BatchNormalization(name=f'{name_prefix}_bn2')(x)
    x = Activation('relu', name=f'{name_prefix}_act2')(x)
    return x


def decoder_block(x, skip, filters, name_prefix):
    x = UpSampling2D((2, 2), name=f'{name_prefix}_up')(x)
    x = concatenate([x, skip], name=f'{name_prefix}_cat')
    x = Dropout(0.2, name=f'{name_prefix}_drop')(x)
    x = conv_block(x, filters, name_prefix)
    return x


def build_vgg19_unet_multiclass(input_shape=(224, 224, 3), num_classes=4, freeze_encoder=True):
    inputs = Input(shape=input_shape, name='input')
    # Load VGG19 pretrained on ImageNet
    base = VGG19(include_top=False, weights='imagenet', input_tensor=inputs)

    if freeze_encoder:
        for layer in base.layers:
            layer.trainable = False

    # ─── Encoder skip connections (VGG19 uses 4-conv blocks for blocks 3-5) ───
    s1 = base.get_layer('block1_conv2').output   # 224×224, 64 ch
    s2 = base.get_layer('block2_conv2').output   # 112×112, 128 ch
    s3 = base.get_layer('block3_conv4').output   # 56×56,   256 ch  ← VGG19: conv4 not conv3
    s4 = base.get_layer('block4_conv4').output   # 28×28,   512 ch  ← VGG19: conv4 not conv3
    b  = base.get_layer('block5_conv4').output   # 14×14,   512 ch  ← VGG19: conv4 not conv3

    # ─── Decoder ──────────────────────────────────────────────────────────────
    d4 = decoder_block(b,  s4, 512, 'dec4')
    d3 = decoder_block(d4, s3, 256, 'dec3')
    d2 = decoder_block(d3, s2, 128, 'dec2')
    d1 = decoder_block(d2, s1,  64, 'dec1')

    # Softmax over num_classes
    output = Conv2D(num_classes, (1, 1), activation='softmax', name='output')(d1)

    model = Model(inputs=inputs, outputs=output, name='VGG19_UNet_MultiClass')
    return model


model = build_vgg19_unet_multiclass(input_shape=(*IMG_SIZE, 3), num_classes=NUM_CLASSES, freeze_encoder=True)
print('Model built ✓')
print(f'Total parameters      : {model.count_params():,}')
print(f'Trainable parameters  : {sum([K.count_params(w) for w in model.trainable_weights]):,}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Model built ✓
# Total parameters      : 30,208,708
# Trainable parameters  : 10,180,484

# %% [markdown]
# ## 8. Custom Metrics & Loss — categorical versions

# %%
def dice_coefficient_multiclass(y_true, y_pred, smooth=1.0):
    y_true_f = K.reshape(y_true, [-1, NUM_CLASSES])
    y_pred_f = K.reshape(y_pred, [-1, NUM_CLASSES])
    intersection = K.sum(y_true_f * y_pred_f, axis=0)
    union = K.sum(y_true_f, axis=0) + K.sum(y_pred_f, axis=0)
    dice_per_class = (2.0 * intersection + smooth) / (union + smooth)
    return K.mean(dice_per_class)


def dice_loss_multiclass(y_true, y_pred):
    return 1.0 - dice_coefficient_multiclass(y_true, y_pred)


def iou_score_multiclass(y_true, y_pred, smooth=1.0):
    y_true_f = K.reshape(y_true, [-1, NUM_CLASSES])
    y_pred_f = K.reshape(y_pred, [-1, NUM_CLASSES])
    intersection = K.sum(y_true_f * y_pred_f, axis=0)
    total = K.sum(y_true_f, axis=0) + K.sum(y_pred_f, axis=0) - intersection
    iou_per_class = (intersection + smooth) / (total + smooth)
    return K.mean(iou_per_class)


def csf_iou(y_true, y_pred, smooth=1.0):
    t = y_true[..., 1]; p = y_pred[..., 1]
    intersection = K.sum(t * p)
    union = K.sum(t) + K.sum(p) - intersection
    return (intersection + smooth) / (union + smooth)


def gm_iou(y_true, y_pred, smooth=1.0):
    t = y_true[..., 2]; p = y_pred[..., 2]
    intersection = K.sum(t * p)
    union = K.sum(t) + K.sum(p) - intersection
    return (intersection + smooth) / (union + smooth)


def wm_iou(y_true, y_pred, smooth=1.0):
    t = y_true[..., 3]; p = y_pred[..., 3]
    intersection = K.sum(t * p)
    union = K.sum(t) + K.sum(p) - intersection
    return (intersection + smooth) / (union + smooth)


def pixel_accuracy_multiclass(y_true, y_pred):
    true_labels = K.argmax(y_true, axis=-1)
    pred_labels = K.argmax(y_pred, axis=-1)
    correct = K.cast(K.equal(true_labels, pred_labels), K.floatx())
    return K.mean(correct)


def combined_loss_multiclass(y_true, y_pred):
    return dice_loss_multiclass(y_true, y_pred) + tf.keras.losses.categorical_crossentropy(y_true, y_pred)


model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=combined_loss_multiclass,
    metrics=[dice_coefficient_multiclass, iou_score_multiclass, pixel_accuracy_multiclass,
             csf_iou, gm_iou, wm_iou]
)

print('Model compiled ✓')
# Out:
# Model compiled ✓

# %% [markdown]
# ## 9. Model Summary

# %%
model.summary()

try:
    tf.keras.utils.plot_model(
        model, to_file='vgg19_unet_multiclass_ibsr_architecture.png',
        show_shapes=True, show_layer_names=True, rankdir='TB', dpi=64
    )
    print('Architecture diagram saved ✓')
except Exception as e:
    print('Architecture plot skipped:', str(e)[:150])
# Out:
# Model: "VGG19_UNet_MultiClass"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 224, 224,  │          0 │ -                 │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 224, 224,  │      1,792 │ input[0][0]       │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 224, 224,  │     36,928 │ block1_conv1[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 112, 112,  │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 112, 112,  │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 112, 112,  │    147,584 │ block2_conv1[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 56, 56,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 56, 56,    │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 56, 56,    │    590,080 │ block3_conv1[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 56, 56,    │    590,080 │ block3_conv2[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv4        │ (None, 56, 56,    │    590,080 │ block3_conv3[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 28, 28,    │          0 │ block3_conv4[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 28, 28,    │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 28, 28,    │  2,359,808 │ block4_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 28, 28,    │  2,359,808 │ block4_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv4        │ (None, 28, 28,    │  2,359,808 │ block4_conv3[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 14, 14,    │          0 │ block4_conv4[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 14, 14,    │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 14, 14,    │  2,359,808 │ block5_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 14, 14,    │  2,359,808 │ block5_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv4        │ (None, 14, 14,    │  2,359,808 │ block5_conv3[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_up             │ (None, 28, 28,    │          0 │ block5_conv4[0][… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_cat            │ (None, 28, 28,    │          0 │ dec4_up[0][0],    │
# │ (Concatenate)       │ 1024)             │            │ block4_conv4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_drop (Dropout) │ (None, 28, 28,    │          0 │ dec4_cat[0][0]    │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_c1 (Conv2D)    │ (None, 28, 28,    │  4,719,104 │ dec4_drop[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_bn1            │ (None, 28, 28,    │      2,048 │ dec4_c1[0][0]     │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_act1           │ (None, 28, 28,    │          0 │ dec4_bn1[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_c2 (Conv2D)    │ (None, 28, 28,    │  2,359,808 │ dec4_act1[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_bn2            │ (None, 28, 28,    │      2,048 │ dec4_c2[0][0]     │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_act2           │ (None, 28, 28,    │          0 │ dec4_bn2[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_up             │ (None, 56, 56,    │          0 │ dec4_act2[0][0]   │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_cat            │ (None, 56, 56,    │          0 │ dec3_up[0][0],    │
# │ (Concatenate)       │ 768)              │            │ block3_conv4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_drop (Dropout) │ (None, 56, 56,    │          0 │ dec3_cat[0][0]    │
# │                     │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_c1 (Conv2D)    │ (None, 56, 56,    │  1,769,728 │ dec3_drop[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_bn1            │ (None, 56, 56,    │      1,024 │ dec3_c1[0][0]     │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_act1           │ (None, 56, 56,    │          0 │ dec3_bn1[0][0]    │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_c2 (Conv2D)    │ (None, 56, 56,    │    590,080 │ dec3_act1[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_bn2            │ (None, 56, 56,    │      1,024 │ dec3_c2[0][0]     │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_act2           │ (None, 56, 56,    │          0 │ dec3_bn2[0][0]    │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_up             │ (None, 112, 112,  │          0 │ dec3_act2[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_cat            │ (None, 112, 112,  │          0 │ dec2_up[0][0],    │
# │ (Concatenate)       │ 384)              │            │ block2_conv2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_drop (Dropout) │ (None, 112, 112,  │          0 │ dec2_cat[0][0]    │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_c1 (Conv2D)    │ (None, 112, 112,  │    442,496 │ dec2_drop[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_bn1            │ (None, 112, 112,  │        512 │ dec2_c1[0][0]     │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_act1           │ (None, 112, 112,  │          0 │ dec2_bn1[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_c2 (Conv2D)    │ (None, 112, 112,  │    147,584 │ dec2_act1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_bn2            │ (None, 112, 112,  │        512 │ dec2_c2[0][0]     │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_act2           │ (None, 112, 112,  │          0 │ dec2_bn2[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_up             │ (None, 224, 224,  │          0 │ dec2_act2[0][0]   │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_cat            │ (None, 224, 224,  │          0 │ dec1_up[0][0],    │
# │ (Concatenate)       │ 192)              │            │ block1_conv2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_drop (Dropout) │ (None, 224, 224,  │          0 │ dec1_cat[0][0]    │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_c1 (Conv2D)    │ (None, 224, 224,  │    110,656 │ dec1_drop[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_bn1            │ (None, 224, 224,  │        256 │ dec1_c1[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_act1           │ (None, 224, 224,  │          0 │ dec1_bn1[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_c2 (Conv2D)    │ (None, 224, 224,  │     36,928 │ dec1_act1[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_bn2            │ (None, 224, 224,  │        256 │ dec1_c2[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_act2           │ (None, 224, 224,  │          0 │ dec1_bn2[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Conv2D)     │ (None, 224, 224,  │        260 │ dec1_act2[0][0]   │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 30,208,708 (115.24 MB)
#  Trainable params: 10,180,484 (38.84 MB)
#  Non-trainable params: 20,028,224 (76.40 MB)
# Architecture diagram saved ✓

# %% [markdown]
# ## 10. Callbacks (EarlyStopping disabled)

# %%
def decode_mask(onehot_mask):
    return tf.argmax(onehot_mask, axis=-1)


def colorize_mask(label_map):
    colors = np.array([[0,0,0], [0,255,255], [255,165,0], [255,0,255]], dtype=np.uint8)
    label_map = np.array(label_map).astype(int)
    return colors[label_map]


def show_predictions(dataset, num=3, model_to_use=None):
    m = model_to_use or model
    for imgs, masks in dataset.take(1):
        preds = m.predict(imgs, verbose=0)
        for i in range(min(num, len(imgs))):
            gt_labels   = decode_mask(masks[i]).numpy()
            pred_labels = decode_mask(preds[i]).numpy()
            fig, axes = plt.subplots(1, 3, figsize=(13, 4.5))
            axes[0].imshow(imgs[i].numpy());            axes[0].set_title('Input MRI')
            axes[1].imshow(colorize_mask(gt_labels));   axes[1].set_title('Ground Truth')
            axes[2].imshow(colorize_mask(pred_labels)); axes[2].set_title('Prediction')
            for ax in axes: ax.axis('off')
            plt.tight_layout()
            plt.show()


class DisplayCallback(callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % 10 == 0:
            show_predictions(test_dataset, num=2)
            print(f'Prediction after epoch {epoch + 1}\n')


logdir = os.path.join('logs', datetime.datetime.now().strftime('%Y%m%d-%H%M%S'))

callbacks_list = [
    DisplayCallback(),
    callbacks.TensorBoard(logdir, histogram_freq=1),
    callbacks.ModelCheckpoint('best_model_vgg19unet_multiclass_ibsr.keras', verbose=1,
                               save_best_only=True, monitor='val_iou_score_multiclass', mode='max'),
    callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-7, verbose=1),
]

print('Callbacks ready ✓ (no EarlyStopping — will run all', EPOCHS, 'epochs)')
# Out:
# Callbacks ready ✓ (no EarlyStopping — will run all 100 epochs)

# %% [markdown]
# ## 11. Initial Predictions (before training)

# %%
print('Predictions before training:')
show_predictions(test_dataset, num=2)
# Out:
# Predictions before training:

# %% [markdown]
# ## 12. Training

# %%
steps_per_epoch  = max(1, len(os.listdir(TRAIN_IMG_DIR)) // BATCH_SIZE)
validation_steps = max(1, len(os.listdir(TEST_IMG_DIR))  // BATCH_SIZE)

print(f'Steps per epoch  : {steps_per_epoch}')
print(f'Validation steps : {validation_steps}')

start_time = time.time()

history = model.fit(
    train_dataset, validation_data=test_dataset, epochs=EPOCHS,
    steps_per_epoch=steps_per_epoch, validation_steps=validation_steps,
    callbacks=callbacks_list
)

elapsed = time.time() - start_time
print(f'\nTraining time: {elapsed/60:.1f} min')
# Out:
# Steps per epoch  : 12
# Validation steps : 2
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0021 - dice_coefficient_multiclass: 0.1562 - gm_iou: 0.0623 - iou_score_multiclass: 0.0933 - loss: 2.5017 - pixel_accuracy_multiclass: 0.2472 - wm_iou: 0.0554
# Epoch 1: val_iou_score_multiclass improved from None to 0.04094, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 1: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - csf_iou: 0.0027 - dice_coefficient_multiclass: 0.1917 - gm_iou: 0.0959 - iou_score_multiclass: 0.1174 - loss: 2.2563 - pixel_accuracy_multiclass: 0.3419 - wm_iou: 0.0725 - val_csf_iou: 8.4748e-06 - val_dice_coefficient_multiclass: 0.0704 - val_gm_iou: 0.1622 - val_iou_score_multiclass: 0.0409 - val_loss: 8.9848 - val_pixel_accuracy_multiclass: 0.0931 - val_wm_iou: 1.6577e-05 - learning_rate: 1.0000e-04
# Epoch 2/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1:34 9s/step - csf_iou: 8.1035e-06 - dice_coefficient_multiclass: 0.1646 - gm_iou: 0.0705 - iou_score_multiclass: 0.1046 - loss: 2.0829 - pixel_accuracy_multiclass: 0.4470 - wm_iou: 0.0119
# Epoch 2: val_iou_score_multiclass did not improve from 0.04094
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 13s 434ms/step - csf_iou: 8.1035e-06 - dice_coefficient_multiclass: 0.1646 - gm_iou: 0.0705 - iou_score_multiclass: 0.1046 - loss: 2.0829 - pixel_accuracy_multiclass: 0.4470 - wm_iou: 0.0119 - val_csf_iou: 8.4099e-06 - val_dice_coefficient_multiclass: 0.0701 - val_gm_iou: 0.1617 - val_iou_score_multiclass: 0.0407 - val_loss: 9.4045 - val_pixel_accuracy_multiclass: 0.0931 - val_wm_iou: 1.4955e-05 - learning_rate: 1.0000e-04
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0018 - dice_coefficient_multiclass: 0.2921 - gm_iou: 0.2230 - iou_score_multiclass: 0.1930 - loss: 1.6343 - pixel_accuracy_multiclass: 0.6458 - wm_iou: 0.1117
# Epoch 3: val_iou_score_multiclass improved from 0.04094 to 0.04779, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 3: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 761ms/step - csf_iou: 0.0026 - dice_coefficient_multiclass: 0.3084 - gm_iou: 0.2324 - iou_score_multiclass: 0.2063 - loss: 1.5513 - pixel_accuracy_multiclass: 0.7145 - wm_iou: 0.1282 - val_csf_iou: 3.1828e-04 - val_dice_coefficient_multiclass: 0.0804 - val_gm_iou: 0.1888 - val_iou_score_multiclass: 0.0478 - val_loss: 11.2442 - val_pixel_accuracy_multiclass: 0.0918 - val_wm_iou: 1.4474e-04 - learning_rate: 1.0000e-04
# Epoch 4/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - csf_iou: 1.0399e-05 - dice_coefficient_multiclass: 0.2004 - gm_iou: 0.0933 - iou_score_multiclass: 0.1347 - loss: 1.7227 - pixel_accuracy_multiclass: 0.7825 - wm_iou: 0.0143
# Epoch 4: val_iou_score_multiclass improved from 0.04779 to 0.04850, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 4: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 500ms/step - csf_iou: 1.0399e-05 - dice_coefficient_multiclass: 0.2004 - gm_iou: 0.0933 - iou_score_multiclass: 0.1347 - loss: 1.7227 - pixel_accuracy_multiclass: 0.7825 - wm_iou: 0.0143 - val_csf_iou: 4.0467e-04 - val_dice_coefficient_multiclass: 0.0815 - val_gm_iou: 0.1911 - val_iou_score_multiclass: 0.0485 - val_loss: 11.3905 - val_pixel_accuracy_multiclass: 0.0914 - val_wm_iou: 2.0262e-04 - learning_rate: 1.0000e-04
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0024 - dice_coefficient_multiclass: 0.3512 - gm_iou: 0.2949 - iou_score_multiclass: 0.2458 - loss: 1.3130 - pixel_accuracy_multiclass: 0.8788 - wm_iou: 0.1444
# Epoch 5: val_iou_score_multiclass improved from 0.04850 to 0.05129, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 5: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 762ms/step - csf_iou: 0.0032 - dice_coefficient_multiclass: 0.3615 - gm_iou: 0.2954 - iou_score_multiclass: 0.2538 - loss: 1.2845 - pixel_accuracy_multiclass: 0.8966 - wm_iou: 0.1642 - val_csf_iou: 0.0010 - val_dice_coefficient_multiclass: 0.0910 - val_gm_iou: 0.1569 - val_iou_score_multiclass: 0.0513 - val_loss: 11.1200 - val_pixel_accuracy_multiclass: 0.0787 - val_wm_iou: 0.0435 - learning_rate: 1.0000e-04
# Epoch 6/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - csf_iou: 1.2352e-05 - dice_coefficient_multiclass: 0.2197 - gm_iou: 0.1010 - iou_score_multiclass: 0.1528 - loss: 1.5534 - pixel_accuracy_multiclass: 0.9289 - wm_iou: 0.0182
# Epoch 6: val_iou_score_multiclass improved from 0.05129 to 0.05352, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 6: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 501ms/step - csf_iou: 1.2352e-05 - dice_coefficient_multiclass: 0.2197 - gm_iou: 0.1010 - iou_score_multiclass: 0.1528 - loss: 1.5534 - pixel_accuracy_multiclass: 0.9289 - wm_iou: 0.0182 - val_csf_iou: 0.0011 - val_dice_coefficient_multiclass: 0.0949 - val_gm_iou: 0.1586 - val_iou_score_multiclass: 0.0535 - val_loss: 11.0408 - val_pixel_accuracy_multiclass: 0.0806 - val_wm_iou: 0.0503 - learning_rate: 1.0000e-04
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0027 - dice_coefficient_multiclass: 0.3847 - gm_iou: 0.3246 - iou_score_multiclass: 0.2761 - loss: 1.1814 - pixel_accuracy_multiclass: 0.9385 - wm_iou: 0.1871
# Epoch 7: val_iou_score_multiclass improved from 0.05352 to 0.07133, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 7: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 759ms/step - csf_iou: 0.0036 - dice_coefficient_multiclass: 0.3888 - gm_iou: 0.3167 - iou_score_multiclass: 0.2787 - loss: 1.1760 - pixel_accuracy_multiclass: 0.9403 - wm_iou: 0.2017 - val_csf_iou: 0.0010 - val_dice_coefficient_multiclass: 0.1248 - val_gm_iou: 0.1883 - val_iou_score_multiclass: 0.0713 - val_loss: 6.0860 - val_pixel_accuracy_multiclass: 0.1007 - val_wm_iou: 0.0753 - learning_rate: 5.0000e-05
# Epoch 8/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - csf_iou: 1.3350e-05 - dice_coefficient_multiclass: 0.2261 - gm_iou: 0.0989 - iou_score_multiclass: 0.1595 - loss: 1.4914 - pixel_accuracy_multiclass: 0.9560 - wm_iou: 0.0215
# Epoch 8: val_iou_score_multiclass improved from 0.07133 to 0.07274, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 8: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 515ms/step - csf_iou: 1.3350e-05 - dice_coefficient_multiclass: 0.2261 - gm_iou: 0.0989 - iou_score_multiclass: 0.1595 - loss: 1.4914 - pixel_accuracy_multiclass: 0.9560 - wm_iou: 0.0215 - val_csf_iou: 0.0010 - val_dice_coefficient_multiclass: 0.1272 - val_gm_iou: 0.1896 - val_iou_score_multiclass: 0.0727 - val_loss: 5.8966 - val_pixel_accuracy_multiclass: 0.1018 - val_wm_iou: 0.0777 - learning_rate: 5.0000e-05
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - csf_iou: 0.0028 - dice_coefficient_multiclass: 0.3971 - gm_iou: 0.3353 - iou_score_multiclass: 0.2882 - loss: 1.1303 - pixel_accuracy_multiclass: 0.9521 - wm_iou: 0.2033
# Epoch 9: val_iou_score_multiclass improved from 0.07274 to 0.10931, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 9: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 766ms/step - csf_iou: 0.0037 - dice_coefficient_multiclass: 0.4010 - gm_iou: 0.3284 - iou_score_multiclass: 0.2905 - loss: 1.1264 - pixel_accuracy_multiclass: 0.9520 - wm_iou: 0.2171 - val_csf_iou: 0.0010 - val_dice_coefficient_multiclass: 0.1881 - val_gm_iou: 0.2190 - val_iou_score_multiclass: 0.1093 - val_loss: 3.2197 - val_pixel_accuracy_multiclass: 0.1290 - val_wm_iou: 0.1127 - learning_rate: 5.0000e-05
# Epoch 10/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - csf_iou: 1.4057e-05 - dice_coefficient_multiclass: 0.2316 - gm_iou: 0.1019 - iou_score_multiclass: 0.1652 - loss: 1.4416 - pixel_accuracy_multiclass: 0.9684 - wm_iou: 0.0218
# Prediction after epoch 10
#
#
# Epoch 10: val_iou_score_multiclass improved from 0.10931 to 0.11189, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 10: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 568ms/step - csf_iou: 1.4057e-05 - dice_coefficient_multiclass: 0.2316 - gm_iou: 0.1019 - iou_score_multiclass: 0.1652 - loss: 1.4416 - pixel_accuracy_multiclass: 0.9684 - wm_iou: 0.0218 - val_csf_iou: 0.0011 - val_dice_coefficient_multiclass: 0.1922 - val_gm_iou: 0.2200 - val_iou_score_multiclass: 0.1119 - val_loss: 3.1460 - val_pixel_accuracy_multiclass: 0.1306 - val_wm_iou: 0.1160 - learning_rate: 5.0000e-05
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0030 - dice_coefficient_multiclass: 0.4097 - gm_iou: 0.3553 - iou_score_multiclass: 0.3003 - loss: 1.0872 - pixel_accuracy_multiclass: 0.9595 - wm_iou: 0.2155
# Epoch 11: val_iou_score_multiclass improved from 0.11189 to 0.16355, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 11: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 752ms/step - csf_iou: 0.0039 - dice_coefficient_multiclass: 0.4135 - gm_iou: 0.3479 - iou_score_multiclass: 0.3026 - loss: 1.0835 - pixel_accuracy_multiclass: 0.9586 - wm_iou: 0.2294 - val_csf_iou: 0.0013 - val_dice_coefficient_multiclass: 0.2665 - val_gm_iou: 0.2592 - val_iou_score_multiclass: 0.1636 - val_loss: 2.1863 - val_pixel_accuracy_multiclass: 0.3076 - val_wm_iou: 0.1493 - learning_rate: 5.0000e-05
# Epoch 12/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - csf_iou: 1.4578e-05 - dice_coefficient_multiclass: 0.2394 - gm_iou: 0.1080 - iou_score_multiclass: 0.1721 - loss: 1.3955 - pixel_accuracy_multiclass: 0.9768 - wm_iou: 0.0245
# Epoch 12: val_iou_score_multiclass improved from 0.16355 to 0.16499, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 12: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 511ms/step - csf_iou: 1.4578e-05 - dice_coefficient_multiclass: 0.2394 - gm_iou: 0.1080 - iou_score_multiclass: 0.1721 - loss: 1.3955 - pixel_accuracy_multiclass: 0.9768 - wm_iou: 0.0245 - val_csf_iou: 0.0013 - val_dice_coefficient_multiclass: 0.2685 - val_gm_iou: 0.2579 - val_iou_score_multiclass: 0.1650 - val_loss: 2.1650 - val_pixel_accuracy_multiclass: 0.3955 - val_wm_iou: 0.1516 - learning_rate: 5.0000e-05
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - csf_iou: 0.0032 - dice_coefficient_multiclass: 0.4221 - gm_iou: 0.3749 - iou_score_multiclass: 0.3127 - loss: 1.0449 - pixel_accuracy_multiclass: 0.9646 - wm_iou: 0.2276
# Epoch 13: val_iou_score_multiclass improved from 0.16499 to 0.22425, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 13: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 766ms/step - csf_iou: 0.0042 - dice_coefficient_multiclass: 0.4257 - gm_iou: 0.3662 - iou_score_multiclass: 0.3148 - loss: 1.0409 - pixel_accuracy_multiclass: 0.9633 - wm_iou: 0.2417 - val_csf_iou: 0.0016 - val_dice_coefficient_multiclass: 0.3399 - val_gm_iou: 0.3234 - val_iou_score_multiclass: 0.2242 - val_loss: 1.6624 - val_pixel_accuracy_multiclass: 0.7664 - val_wm_iou: 0.1814 - learning_rate: 5.0000e-05
# Epoch 14/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - csf_iou: 1.5279e-05 - dice_coefficient_multiclass: 0.2471 - gm_iou: 0.1143 - iou_score_multiclass: 0.1795 - loss: 1.3456 - pixel_accuracy_multiclass: 0.9829 - wm_iou: 0.0260
# Epoch 14: val_iou_score_multiclass improved from 0.22425 to 0.22700, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 14: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 509ms/step - csf_iou: 1.5279e-05 - dice_coefficient_multiclass: 0.2471 - gm_iou: 0.1143 - iou_score_multiclass: 0.1795 - loss: 1.3456 - pixel_accuracy_multiclass: 0.9829 - wm_iou: 0.0260 - val_csf_iou: 0.0016 - val_dice_coefficient_multiclass: 0.3431 - val_gm_iou: 0.3240 - val_iou_score_multiclass: 0.2270 - val_loss: 1.6430 - val_pixel_accuracy_multiclass: 0.7702 - val_wm_iou: 0.1847 - learning_rate: 5.0000e-05
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0035 - dice_coefficient_multiclass: 0.4340 - gm_iou: 0.3927 - iou_score_multiclass: 0.3250 - loss: 1.0006 - pixel_accuracy_multiclass: 0.9686 - wm_iou: 0.2388
# Epoch 15: val_iou_score_multiclass improved from 0.22700 to 0.27412, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 15: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 757ms/step - csf_iou: 0.0047 - dice_coefficient_multiclass: 0.4382 - gm_iou: 0.3839 - iou_score_multiclass: 0.3276 - loss: 0.9953 - pixel_accuracy_multiclass: 0.9670 - wm_iou: 0.2539 - val_csf_iou: 0.0025 - val_dice_coefficient_multiclass: 0.3936 - val_gm_iou: 0.3826 - val_iou_score_multiclass: 0.2741 - val_loss: 1.3554 - val_pixel_accuracy_multiclass: 0.9082 - val_wm_iou: 0.2145 - learning_rate: 5.0000e-05
# Epoch 16/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - csf_iou: 1.6140e-05 - dice_coefficient_multiclass: 0.2559 - gm_iou: 0.1210 - iou_score_multiclass: 0.1880 - loss: 1.2925 - pixel_accuracy_multiclass: 0.9865 - wm_iou: 0.0287
# Epoch 16: val_iou_score_multiclass improved from 0.27412 to 0.27671, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 16: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 517ms/step - csf_iou: 1.6140e-05 - dice_coefficient_multiclass: 0.2559 - gm_iou: 0.1210 - iou_score_multiclass: 0.1880 - loss: 1.2925 - pixel_accuracy_multiclass: 0.9865 - wm_iou: 0.0287 - val_csf_iou: 0.0026 - val_dice_coefficient_multiclass: 0.3964 - val_gm_iou: 0.3826 - val_iou_score_multiclass: 0.2767 - val_loss: 1.3407 - val_pixel_accuracy_multiclass: 0.9181 - val_wm_iou: 0.2185 - learning_rate: 5.0000e-05
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0039 - dice_coefficient_multiclass: 0.4475 - gm_iou: 0.4116 - iou_score_multiclass: 0.3392 - loss: 0.9524 - pixel_accuracy_multiclass: 0.9713 - wm_iou: 0.2531
# Epoch 17: val_iou_score_multiclass improved from 0.27671 to 0.32969, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 17: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 774ms/step - csf_iou: 0.0052 - dice_coefficient_multiclass: 0.4519 - gm_iou: 0.4018 - iou_score_multiclass: 0.3420 - loss: 0.9462 - pixel_accuracy_multiclass: 0.9694 - wm_iou: 0.2692 - val_csf_iou: 0.0045 - val_dice_coefficient_multiclass: 0.4475 - val_gm_iou: 0.4499 - val_iou_score_multiclass: 0.3297 - val_loss: 1.0852 - val_pixel_accuracy_multiclass: 0.9621 - val_wm_iou: 0.2508 - learning_rate: 5.0000e-05
# Epoch 18/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - csf_iou: 1.7226e-05 - dice_coefficient_multiclass: 0.2654 - gm_iou: 0.1295 - iou_score_multiclass: 0.1976 - loss: 1.2361 - pixel_accuracy_multiclass: 0.9878 - wm_iou: 0.0304
# Epoch 18: val_iou_score_multiclass improved from 0.32969 to 0.33197, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 18: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 512ms/step - csf_iou: 1.7226e-05 - dice_coefficient_multiclass: 0.2654 - gm_iou: 0.1295 - iou_score_multiclass: 0.1976 - loss: 1.2361 - pixel_accuracy_multiclass: 0.9878 - wm_iou: 0.0304 - val_csf_iou: 0.0048 - val_dice_coefficient_multiclass: 0.4498 - val_gm_iou: 0.4493 - val_iou_score_multiclass: 0.3320 - val_loss: 1.0762 - val_pixel_accuracy_multiclass: 0.9628 - val_wm_iou: 0.2553 - learning_rate: 5.0000e-05
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0044 - dice_coefficient_multiclass: 0.4615 - gm_iou: 0.4298 - iou_score_multiclass: 0.3542 - loss: 0.9022 - pixel_accuracy_multiclass: 0.9733 - wm_iou: 0.2683
# Epoch 19: val_iou_score_multiclass improved from 0.33197 to 0.37420, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 19: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 770ms/step - csf_iou: 0.0059 - dice_coefficient_multiclass: 0.4661 - gm_iou: 0.4199 - iou_score_multiclass: 0.3573 - loss: 0.8956 - pixel_accuracy_multiclass: 0.9712 - wm_iou: 0.2852 - val_csf_iou: 0.0066 - val_dice_coefficient_multiclass: 0.4876 - val_gm_iou: 0.5124 - val_iou_score_multiclass: 0.3742 - val_loss: 0.9361 - val_pixel_accuracy_multiclass: 0.9706 - val_wm_iou: 0.2826 - learning_rate: 5.0000e-05
# Epoch 20/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - csf_iou: 1.8586e-05 - dice_coefficient_multiclass: 0.2770 - gm_iou: 0.1434 - iou_score_multiclass: 0.2086 - loss: 1.1756 - pixel_accuracy_multiclass: 0.9895 - wm_iou: 0.0326
# Prediction after epoch 20
#
#
# Epoch 20: val_iou_score_multiclass improved from 0.37420 to 0.38000, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 20: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 572ms/step - csf_iou: 1.8586e-05 - dice_coefficient_multiclass: 0.2770 - gm_iou: 0.1434 - iou_score_multiclass: 0.2086 - loss: 1.1756 - pixel_accuracy_multiclass: 0.9895 - wm_iou: 0.0326 - val_csf_iou: 0.0068 - val_dice_coefficient_multiclass: 0.4931 - val_gm_iou: 0.5170 - val_iou_score_multiclass: 0.3800 - val_loss: 0.9195 - val_pixel_accuracy_multiclass: 0.9711 - val_wm_iou: 0.2920 - learning_rate: 5.0000e-05
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - csf_iou: 0.0049 - dice_coefficient_multiclass: 0.4758 - gm_iou: 0.4494 - iou_score_multiclass: 0.3698 - loss: 0.8534 - pixel_accuracy_multiclass: 0.9750 - wm_iou: 0.2848
# Epoch 21: val_iou_score_multiclass improved from 0.38000 to 0.43042, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 21: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 771ms/step - csf_iou: 0.0065 - dice_coefficient_multiclass: 0.4804 - gm_iou: 0.4393 - iou_score_multiclass: 0.3728 - loss: 0.8475 - pixel_accuracy_multiclass: 0.9728 - wm_iou: 0.3020 - val_csf_iou: 0.0094 - val_dice_coefficient_multiclass: 0.5360 - val_gm_iou: 0.5872 - val_iou_score_multiclass: 0.4304 - val_loss: 0.7649 - val_pixel_accuracy_multiclass: 0.9732 - val_wm_iou: 0.3390 - learning_rate: 5.0000e-05
# Epoch 22/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - csf_iou: 2.0270e-05 - dice_coefficient_multiclass: 0.2884 - gm_iou: 0.1559 - iou_score_multiclass: 0.2197 - loss: 1.1204 - pixel_accuracy_multiclass: 0.9902 - wm_iou: 0.0359
# Epoch 22: val_iou_score_multiclass improved from 0.43042 to 0.43407, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 22: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 507ms/step - csf_iou: 2.0270e-05 - dice_coefficient_multiclass: 0.2884 - gm_iou: 0.1559 - iou_score_multiclass: 0.2197 - loss: 1.1204 - pixel_accuracy_multiclass: 0.9902 - wm_iou: 0.0359 - val_csf_iou: 0.0096 - val_dice_coefficient_multiclass: 0.5396 - val_gm_iou: 0.5884 - val_iou_score_multiclass: 0.4341 - val_loss: 0.7557 - val_pixel_accuracy_multiclass: 0.9735 - val_wm_iou: 0.3488 - learning_rate: 5.0000e-05
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0055 - dice_coefficient_multiclass: 0.4894 - gm_iou: 0.4709 - iou_score_multiclass: 0.3849 - loss: 0.8089 - pixel_accuracy_multiclass: 0.9764 - wm_iou: 0.3000
# Epoch 23: val_iou_score_multiclass improved from 0.43407 to 0.44014, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 23: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 766ms/step - csf_iou: 0.0073 - dice_coefficient_multiclass: 0.4941 - gm_iou: 0.4604 - iou_score_multiclass: 0.3880 - loss: 0.8036 - pixel_accuracy_multiclass: 0.9742 - wm_iou: 0.3184 - val_csf_iou: 0.0096 - val_dice_coefficient_multiclass: 0.5459 - val_gm_iou: 0.5878 - val_iou_score_multiclass: 0.4401 - val_loss: 0.7364 - val_pixel_accuracy_multiclass: 0.9744 - val_wm_iou: 0.3707 - learning_rate: 5.0000e-05
# Epoch 24/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - csf_iou: 2.2239e-05 - dice_coefficient_multiclass: 0.2998 - gm_iou: 0.1705 - iou_score_multiclass: 0.2308 - loss: 1.0678 - pixel_accuracy_multiclass: 0.9902 - wm_iou: 0.0389
# Epoch 24: val_iou_score_multiclass improved from 0.44014 to 0.44244, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 24: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 512ms/step - csf_iou: 2.2239e-05 - dice_coefficient_multiclass: 0.2998 - gm_iou: 0.1705 - iou_score_multiclass: 0.2308 - loss: 1.0678 - pixel_accuracy_multiclass: 0.9902 - wm_iou: 0.0389 - val_csf_iou: 0.0096 - val_dice_coefficient_multiclass: 0.5483 - val_gm_iou: 0.5860 - val_iou_score_multiclass: 0.4424 - val_loss: 0.7324 - val_pixel_accuracy_multiclass: 0.9746 - val_wm_iou: 0.3803 - learning_rate: 5.0000e-05
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0061 - dice_coefficient_multiclass: 0.5021 - gm_iou: 0.4921 - iou_score_multiclass: 0.3990 - loss: 0.7704 - pixel_accuracy_multiclass: 0.9773 - wm_iou: 0.3151
# Epoch 25: val_iou_score_multiclass improved from 0.44244 to 0.45608, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 25: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 759ms/step - csf_iou: 0.0080 - dice_coefficient_multiclass: 0.5065 - gm_iou: 0.4806 - iou_score_multiclass: 0.4018 - loss: 0.7667 - pixel_accuracy_multiclass: 0.9751 - wm_iou: 0.3336 - val_csf_iou: 0.0096 - val_dice_coefficient_multiclass: 0.5606 - val_gm_iou: 0.5992 - val_iou_score_multiclass: 0.4561 - val_loss: 0.7014 - val_pixel_accuracy_multiclass: 0.9756 - val_wm_iou: 0.4126 - learning_rate: 5.0000e-05
# Epoch 26/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - csf_iou: 2.4353e-05 - dice_coefficient_multiclass: 0.3091 - gm_iou: 0.1802 - iou_score_multiclass: 0.2401 - loss: 1.0255 - pixel_accuracy_multiclass: 0.9906 - wm_iou: 0.0429
# Epoch 26: val_iou_score_multiclass improved from 0.45608 to 0.45671, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 26: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 517ms/step - csf_iou: 2.4353e-05 - dice_coefficient_multiclass: 0.3091 - gm_iou: 0.1802 - iou_score_multiclass: 0.2401 - loss: 1.0255 - pixel_accuracy_multiclass: 0.9906 - wm_iou: 0.0429 - val_csf_iou: 0.0096 - val_dice_coefficient_multiclass: 0.5612 - val_gm_iou: 0.5971 - val_iou_score_multiclass: 0.4567 - val_loss: 0.6996 - val_pixel_accuracy_multiclass: 0.9756 - val_wm_iou: 0.4160 - learning_rate: 5.0000e-05
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0066 - dice_coefficient_multiclass: 0.5129 - gm_iou: 0.5111 - iou_score_multiclass: 0.4113 - loss: 0.7388 - pixel_accuracy_multiclass: 0.9781 - wm_iou: 0.3285
# Epoch 27: val_iou_score_multiclass improved from 0.45671 to 0.46590, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 27: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 764ms/step - csf_iou: 0.0087 - dice_coefficient_multiclass: 0.5172 - gm_iou: 0.4986 - iou_score_multiclass: 0.4138 - loss: 0.7367 - pixel_accuracy_multiclass: 0.9758 - wm_iou: 0.3477 - val_csf_iou: 0.0103 - val_dice_coefficient_multiclass: 0.5692 - val_gm_iou: 0.6017 - val_iou_score_multiclass: 0.4659 - val_loss: 0.6788 - val_pixel_accuracy_multiclass: 0.9759 - val_wm_iou: 0.4369 - learning_rate: 5.0000e-05
# Epoch 28/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - csf_iou: 2.6272e-05 - dice_coefficient_multiclass: 0.3188 - gm_iou: 0.1944 - iou_score_multiclass: 0.2491 - loss: 0.9879 - pixel_accuracy_multiclass: 0.9913 - wm_iou: 0.0464
# Epoch 28: val_iou_score_multiclass improved from 0.46590 to 0.46622, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 28: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 498ms/step - csf_iou: 2.6272e-05 - dice_coefficient_multiclass: 0.3188 - gm_iou: 0.1944 - iou_score_multiclass: 0.2491 - loss: 0.9879 - pixel_accuracy_multiclass: 0.9913 - wm_iou: 0.0464 - val_csf_iou: 0.0104 - val_dice_coefficient_multiclass: 0.5696 - val_gm_iou: 0.5991 - val_iou_score_multiclass: 0.4662 - val_loss: 0.6772 - val_pixel_accuracy_multiclass: 0.9759 - val_wm_iou: 0.4394 - learning_rate: 5.0000e-05
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - csf_iou: 0.0073 - dice_coefficient_multiclass: 0.5227 - gm_iou: 0.5271 - iou_score_multiclass: 0.4224 - loss: 0.7126 - pixel_accuracy_multiclass: 0.9788 - wm_iou: 0.3428
# Epoch 29: val_iou_score_multiclass improved from 0.46622 to 0.47632, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 29: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 761ms/step - csf_iou: 0.0096 - dice_coefficient_multiclass: 0.5268 - gm_iou: 0.5140 - iou_score_multiclass: 0.4246 - loss: 0.7116 - pixel_accuracy_multiclass: 0.9765 - wm_iou: 0.3621 - val_csf_iou: 0.0114 - val_dice_coefficient_multiclass: 0.5779 - val_gm_iou: 0.6122 - val_iou_score_multiclass: 0.4763 - val_loss: 0.6554 - val_pixel_accuracy_multiclass: 0.9762 - val_wm_iou: 0.4538 - learning_rate: 5.0000e-05
# Epoch 30/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - csf_iou: 2.7889e-05 - dice_coefficient_multiclass: 0.3255 - gm_iou: 0.2041 - iou_score_multiclass: 0.2557 - loss: 0.9624 - pixel_accuracy_multiclass: 0.9914 - wm_iou: 0.0487
# Prediction after epoch 30
#
#
# Epoch 30: val_iou_score_multiclass did not improve from 0.47632
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 489ms/step - csf_iou: 2.7889e-05 - dice_coefficient_multiclass: 0.3255 - gm_iou: 0.2041 - iou_score_multiclass: 0.2557 - loss: 0.9624 - pixel_accuracy_multiclass: 0.9914 - wm_iou: 0.0487 - val_csf_iou: 0.0115 - val_dice_coefficient_multiclass: 0.5773 - val_gm_iou: 0.6052 - val_iou_score_multiclass: 0.4755 - val_loss: 0.6566 - val_pixel_accuracy_multiclass: 0.9758 - val_wm_iou: 0.4560 - learning_rate: 5.0000e-05
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0082 - dice_coefficient_multiclass: 0.5313 - gm_iou: 0.5420 - iou_score_multiclass: 0.4321 - loss: 0.6909 - pixel_accuracy_multiclass: 0.9793 - wm_iou: 0.3550
# Epoch 31: val_iou_score_multiclass improved from 0.47632 to 0.48863, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 31: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 764ms/step - csf_iou: 0.0107 - dice_coefficient_multiclass: 0.5355 - gm_iou: 0.5282 - iou_score_multiclass: 0.4344 - loss: 0.6900 - pixel_accuracy_multiclass: 0.9772 - wm_iou: 0.3752 - val_csf_iou: 0.0130 - val_dice_coefficient_multiclass: 0.5878 - val_gm_iou: 0.6306 - val_iou_score_multiclass: 0.4886 - val_loss: 0.6231 - val_pixel_accuracy_multiclass: 0.9780 - val_wm_iou: 0.4696 - learning_rate: 5.0000e-05
# Epoch 32/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - csf_iou: 2.9313e-05 - dice_coefficient_multiclass: 0.3318 - gm_iou: 0.2127 - iou_score_multiclass: 0.2617 - loss: 0.9385 - pixel_accuracy_multiclass: 0.9917 - wm_iou: 0.0518
# Epoch 32: val_iou_score_multiclass did not improve from 0.48863
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 426ms/step - csf_iou: 2.9313e-05 - dice_coefficient_multiclass: 0.3318 - gm_iou: 0.2127 - iou_score_multiclass: 0.2617 - loss: 0.9385 - pixel_accuracy_multiclass: 0.9917 - wm_iou: 0.0518 - val_csf_iou: 0.0132 - val_dice_coefficient_multiclass: 0.5870 - val_gm_iou: 0.6228 - val_iou_score_multiclass: 0.4874 - val_loss: 0.6250 - val_pixel_accuracy_multiclass: 0.9776 - val_wm_iou: 0.4715 - learning_rate: 5.0000e-05
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0093 - dice_coefficient_multiclass: 0.5395 - gm_iou: 0.5552 - iou_score_multiclass: 0.4412 - loss: 0.6710 - pixel_accuracy_multiclass: 0.9800 - wm_iou: 0.3676
# Epoch 33: val_iou_score_multiclass improved from 0.48863 to 0.49521, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 33: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 750ms/step - csf_iou: 0.0122 - dice_coefficient_multiclass: 0.5435 - gm_iou: 0.5410 - iou_score_multiclass: 0.4433 - loss: 0.6713 - pixel_accuracy_multiclass: 0.9778 - wm_iou: 0.3874 - val_csf_iou: 0.0148 - val_dice_coefficient_multiclass: 0.5931 - val_gm_iou: 0.6445 - val_iou_score_multiclass: 0.4952 - val_loss: 0.6062 - val_pixel_accuracy_multiclass: 0.9790 - val_wm_iou: 0.4728 - learning_rate: 5.0000e-05
# Epoch 34/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - csf_iou: 3.0415e-05 - dice_coefficient_multiclass: 0.3376 - gm_iou: 0.2235 - iou_score_multiclass: 0.2672 - loss: 0.9191 - pixel_accuracy_multiclass: 0.9920 - wm_iou: 0.0531
# Epoch 34: val_iou_score_multiclass did not improve from 0.49521
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 427ms/step - csf_iou: 3.0415e-05 - dice_coefficient_multiclass: 0.3376 - gm_iou: 0.2235 - iou_score_multiclass: 0.2672 - loss: 0.9191 - pixel_accuracy_multiclass: 0.9920 - wm_iou: 0.0531 - val_csf_iou: 0.0151 - val_dice_coefficient_multiclass: 0.5933 - val_gm_iou: 0.6364 - val_iou_score_multiclass: 0.4950 - val_loss: 0.6060 - val_pixel_accuracy_multiclass: 0.9788 - val_wm_iou: 0.4785 - learning_rate: 5.0000e-05
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0108 - dice_coefficient_multiclass: 0.5464 - gm_iou: 0.5667 - iou_score_multiclass: 0.4490 - loss: 0.6551 - pixel_accuracy_multiclass: 0.9804 - wm_iou: 0.3783
# Epoch 35: val_iou_score_multiclass improved from 0.49521 to 0.49724, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 35: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 751ms/step - csf_iou: 0.0142 - dice_coefficient_multiclass: 0.5502 - gm_iou: 0.5515 - iou_score_multiclass: 0.4508 - loss: 0.6559 - pixel_accuracy_multiclass: 0.9783 - wm_iou: 0.3975 - val_csf_iou: 0.0165 - val_dice_coefficient_multiclass: 0.5947 - val_gm_iou: 0.6535 - val_iou_score_multiclass: 0.4972 - val_loss: 0.5984 - val_pixel_accuracy_multiclass: 0.9793 - val_wm_iou: 0.4658 - learning_rate: 5.0000e-05
# Epoch 36/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - csf_iou: 3.1318e-05 - dice_coefficient_multiclass: 0.3426 - gm_iou: 0.2280 - iou_score_multiclass: 0.2717 - loss: 0.9050 - pixel_accuracy_multiclass: 0.9919 - wm_iou: 0.0580
# Epoch 36: val_iou_score_multiclass improved from 0.49724 to 0.49827, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 36: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 503ms/step - csf_iou: 3.1318e-05 - dice_coefficient_multiclass: 0.3426 - gm_iou: 0.2280 - iou_score_multiclass: 0.2717 - loss: 0.9050 - pixel_accuracy_multiclass: 0.9919 - wm_iou: 0.0580 - val_csf_iou: 0.0169 - val_dice_coefficient_multiclass: 0.5958 - val_gm_iou: 0.6501 - val_iou_score_multiclass: 0.4983 - val_loss: 0.5959 - val_pixel_accuracy_multiclass: 0.9795 - val_wm_iou: 0.4720 - learning_rate: 5.0000e-05
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0126 - dice_coefficient_multiclass: 0.5527 - gm_iou: 0.5775 - iou_score_multiclass: 0.4559 - loss: 0.6413 - pixel_accuracy_multiclass: 0.9807 - wm_iou: 0.3868
# Epoch 37: val_iou_score_multiclass improved from 0.49827 to 0.49957, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 37: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 766ms/step - csf_iou: 0.0167 - dice_coefficient_multiclass: 0.5568 - gm_iou: 0.5614 - iou_score_multiclass: 0.4578 - loss: 0.6419 - pixel_accuracy_multiclass: 0.9789 - wm_iou: 0.4068 - val_csf_iou: 0.0188 - val_dice_coefficient_multiclass: 0.5967 - val_gm_iou: 0.6558 - val_iou_score_multiclass: 0.4996 - val_loss: 0.5866 - val_pixel_accuracy_multiclass: 0.9797 - val_wm_iou: 0.4638 - learning_rate: 5.0000e-05
# Epoch 38/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - csf_iou: 3.2093e-05 - dice_coefficient_multiclass: 0.3473 - gm_iou: 0.2370 - iou_score_multiclass: 0.2760 - loss: 0.8892 - pixel_accuracy_multiclass: 0.9922 - wm_iou: 0.0597
# Epoch 38: val_iou_score_multiclass improved from 0.49957 to 0.50053, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 38: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 506ms/step - csf_iou: 3.2093e-05 - dice_coefficient_multiclass: 0.3473 - gm_iou: 0.2370 - iou_score_multiclass: 0.2760 - loss: 0.8892 - pixel_accuracy_multiclass: 0.9922 - wm_iou: 0.0597 - val_csf_iou: 0.0191 - val_dice_coefficient_multiclass: 0.5977 - val_gm_iou: 0.6530 - val_iou_score_multiclass: 0.5005 - val_loss: 0.5843 - val_pixel_accuracy_multiclass: 0.9799 - val_wm_iou: 0.4692 - learning_rate: 5.0000e-05
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - csf_iou: 0.0148 - dice_coefficient_multiclass: 0.5579 - gm_iou: 0.5843 - iou_score_multiclass: 0.4615 - loss: 0.6297 - pixel_accuracy_multiclass: 0.9811 - wm_iou: 0.3947
# Epoch 39: val_iou_score_multiclass improved from 0.50053 to 0.50765, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 39: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 749ms/step - csf_iou: 0.0197 - dice_coefficient_multiclass: 0.5628 - gm_iou: 0.5694 - iou_score_multiclass: 0.4640 - loss: 0.6296 - pixel_accuracy_multiclass: 0.9793 - wm_iou: 0.4155 - val_csf_iou: 0.0217 - val_dice_coefficient_multiclass: 0.6041 - val_gm_iou: 0.6605 - val_iou_score_multiclass: 0.5076 - val_loss: 0.5720 - val_pixel_accuracy_multiclass: 0.9804 - val_wm_iou: 0.4829 - learning_rate: 5.0000e-05
# Epoch 40/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - csf_iou: 3.2906e-05 - dice_coefficient_multiclass: 0.3522 - gm_iou: 0.2445 - iou_score_multiclass: 0.2803 - loss: 0.8753 - pixel_accuracy_multiclass: 0.9925 - wm_iou: 0.0630
# Prediction after epoch 40
#
#
# Epoch 40: val_iou_score_multiclass did not improve from 0.50765
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 488ms/step - csf_iou: 3.2906e-05 - dice_coefficient_multiclass: 0.3522 - gm_iou: 0.2445 - iou_score_multiclass: 0.2803 - loss: 0.8753 - pixel_accuracy_multiclass: 0.9925 - wm_iou: 0.0630 - val_csf_iou: 0.0220 - val_dice_coefficient_multiclass: 0.6038 - val_gm_iou: 0.6586 - val_iou_score_multiclass: 0.5072 - val_loss: 0.5714 - val_pixel_accuracy_multiclass: 0.9804 - val_wm_iou: 0.4816 - learning_rate: 5.0000e-05
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0173 - dice_coefficient_multiclass: 0.5632 - gm_iou: 0.5923 - iou_score_multiclass: 0.4670 - loss: 0.6185 - pixel_accuracy_multiclass: 0.9814 - wm_iou: 0.4014
# Epoch 41: val_iou_score_multiclass improved from 0.50765 to 0.51389, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 41: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 753ms/step - csf_iou: 0.0230 - dice_coefficient_multiclass: 0.5682 - gm_iou: 0.5762 - iou_score_multiclass: 0.4695 - loss: 0.6186 - pixel_accuracy_multiclass: 0.9795 - wm_iou: 0.4224 - val_csf_iou: 0.0247 - val_dice_coefficient_multiclass: 0.6095 - val_gm_iou: 0.6674 - val_iou_score_multiclass: 0.5139 - val_loss: 0.5559 - val_pixel_accuracy_multiclass: 0.9809 - val_wm_iou: 0.4894 - learning_rate: 5.0000e-05
# Epoch 42/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - csf_iou: 3.3556e-05 - dice_coefficient_multiclass: 0.3557 - gm_iou: 0.2530 - iou_score_multiclass: 0.2837 - loss: 0.8642 - pixel_accuracy_multiclass: 0.9929 - wm_iou: 0.0631
# Epoch 42: val_iou_score_multiclass did not improve from 0.51389
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 424ms/step - csf_iou: 3.3556e-05 - dice_coefficient_multiclass: 0.3557 - gm_iou: 0.2530 - iou_score_multiclass: 0.2837 - loss: 0.8642 - pixel_accuracy_multiclass: 0.9929 - wm_iou: 0.0631 - val_csf_iou: 0.0249 - val_dice_coefficient_multiclass: 0.6085 - val_gm_iou: 0.6672 - val_iou_score_multiclass: 0.5128 - val_loss: 0.5565 - val_pixel_accuracy_multiclass: 0.9808 - val_wm_iou: 0.4842 - learning_rate: 5.0000e-05
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0193 - dice_coefficient_multiclass: 0.5673 - gm_iou: 0.5977 - iou_score_multiclass: 0.4713 - loss: 0.6096 - pixel_accuracy_multiclass: 0.9815 - wm_iou: 0.4068
# Epoch 43: val_iou_score_multiclass improved from 0.51389 to 0.51894, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 43: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 763ms/step - csf_iou: 0.0255 - dice_coefficient_multiclass: 0.5728 - gm_iou: 0.5823 - iou_score_multiclass: 0.4742 - loss: 0.6088 - pixel_accuracy_multiclass: 0.9798 - wm_iou: 0.4285 - val_csf_iou: 0.0284 - val_dice_coefficient_multiclass: 0.6148 - val_gm_iou: 0.6535 - val_iou_score_multiclass: 0.5189 - val_loss: 0.5472 - val_pixel_accuracy_multiclass: 0.9798 - val_wm_iou: 0.5109 - learning_rate: 5.0000e-05
# Epoch 44/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - csf_iou: 3.4397e-05 - dice_coefficient_multiclass: 0.3602 - gm_iou: 0.2583 - iou_score_multiclass: 0.2876 - loss: 0.8540 - pixel_accuracy_multiclass: 0.9929 - wm_iou: 0.0676
# Epoch 44: val_iou_score_multiclass improved from 0.51894 to 0.51895, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 44: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 507ms/step - csf_iou: 3.4397e-05 - dice_coefficient_multiclass: 0.3602 - gm_iou: 0.2583 - iou_score_multiclass: 0.2876 - loss: 0.8540 - pixel_accuracy_multiclass: 0.9929 - wm_iou: 0.0676 - val_csf_iou: 0.0286 - val_dice_coefficient_multiclass: 0.6148 - val_gm_iou: 0.6522 - val_iou_score_multiclass: 0.5190 - val_loss: 0.5455 - val_pixel_accuracy_multiclass: 0.9800 - val_wm_iou: 0.5113 - learning_rate: 5.0000e-05
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0210 - dice_coefficient_multiclass: 0.5713 - gm_iou: 0.6039 - iou_score_multiclass: 0.4757 - loss: 0.6008 - pixel_accuracy_multiclass: 0.9817 - wm_iou: 0.4125
# Epoch 45: val_iou_score_multiclass improved from 0.51895 to 0.52107, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 45: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 760ms/step - csf_iou: 0.0277 - dice_coefficient_multiclass: 0.5768 - gm_iou: 0.5891 - iou_score_multiclass: 0.4787 - loss: 0.5996 - pixel_accuracy_multiclass: 0.9803 - wm_iou: 0.4332 - val_csf_iou: 0.0321 - val_dice_coefficient_multiclass: 0.6173 - val_gm_iou: 0.6438 - val_iou_score_multiclass: 0.5211 - val_loss: 0.5427 - val_pixel_accuracy_multiclass: 0.9784 - val_wm_iou: 0.5182 - learning_rate: 5.0000e-05
# Epoch 46/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - csf_iou: 3.5262e-05 - dice_coefficient_multiclass: 0.3631 - gm_iou: 0.2647 - iou_score_multiclass: 0.2906 - loss: 0.8462 - pixel_accuracy_multiclass: 0.9926 - wm_iou: 0.0675
# Epoch 46: val_iou_score_multiclass did not improve from 0.52107
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 419ms/step - csf_iou: 3.5262e-05 - dice_coefficient_multiclass: 0.3631 - gm_iou: 0.2647 - iou_score_multiclass: 0.2906 - loss: 0.8462 - pixel_accuracy_multiclass: 0.9926 - wm_iou: 0.0675 - val_csf_iou: 0.0326 - val_dice_coefficient_multiclass: 0.6140 - val_gm_iou: 0.6286 - val_iou_score_multiclass: 0.5167 - val_loss: 0.5503 - val_pixel_accuracy_multiclass: 0.9773 - val_wm_iou: 0.5143 - learning_rate: 5.0000e-05
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0226 - dice_coefficient_multiclass: 0.5748 - gm_iou: 0.6078 - iou_score_multiclass: 0.4795 - loss: 0.5942 - pixel_accuracy_multiclass: 0.9815 - wm_iou: 0.4186
# Epoch 47: val_iou_score_multiclass improved from 0.52107 to 0.53246, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 47: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 769ms/step - csf_iou: 0.0288 - dice_coefficient_multiclass: 0.5801 - gm_iou: 0.5938 - iou_score_multiclass: 0.4823 - loss: 0.5925 - pixel_accuracy_multiclass: 0.9802 - wm_iou: 0.4383 - val_csf_iou: 0.0335 - val_dice_coefficient_multiclass: 0.6262 - val_gm_iou: 0.6718 - val_iou_score_multiclass: 0.5325 - val_loss: 0.5154 - val_pixel_accuracy_multiclass: 0.9817 - val_wm_iou: 0.5291 - learning_rate: 5.0000e-05
# Epoch 48/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - csf_iou: 3.5775e-05 - dice_coefficient_multiclass: 0.3655 - gm_iou: 0.2692 - iou_score_multiclass: 0.2928 - loss: 0.8353 - pixel_accuracy_multiclass: 0.9933 - wm_iou: 0.0690
# Epoch 48: val_iou_score_multiclass did not improve from 0.53246
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 427ms/step - csf_iou: 3.5775e-05 - dice_coefficient_multiclass: 0.3655 - gm_iou: 0.2692 - iou_score_multiclass: 0.2928 - loss: 0.8353 - pixel_accuracy_multiclass: 0.9933 - wm_iou: 0.0690 - val_csf_iou: 0.0345 - val_dice_coefficient_multiclass: 0.6238 - val_gm_iou: 0.6534 - val_iou_score_multiclass: 0.5288 - val_loss: 0.5220 - val_pixel_accuracy_multiclass: 0.9801 - val_wm_iou: 0.5306 - learning_rate: 5.0000e-05
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0241 - dice_coefficient_multiclass: 0.5793 - gm_iou: 0.6137 - iou_score_multiclass: 0.4843 - loss: 0.5847 - pixel_accuracy_multiclass: 0.9819 - wm_iou: 0.4268
# Epoch 49: val_iou_score_multiclass improved from 0.53246 to 0.53432, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 49: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 767ms/step - csf_iou: 0.0311 - dice_coefficient_multiclass: 0.5849 - gm_iou: 0.5996 - iou_score_multiclass: 0.4874 - loss: 0.5831 - pixel_accuracy_multiclass: 0.9805 - wm_iou: 0.4469 - val_csf_iou: 0.0334 - val_dice_coefficient_multiclass: 0.6271 - val_gm_iou: 0.6856 - val_iou_score_multiclass: 0.5343 - val_loss: 0.5106 - val_pixel_accuracy_multiclass: 0.9821 - val_wm_iou: 0.5205 - learning_rate: 5.0000e-05
# Epoch 50/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - csf_iou: 3.6889e-05 - dice_coefficient_multiclass: 0.3695 - gm_iou: 0.2732 - iou_score_multiclass: 0.2961 - loss: 0.8269 - pixel_accuracy_multiclass: 0.9931 - wm_iou: 0.0737
# Prediction after epoch 50
#
#
# Epoch 50: val_iou_score_multiclass improved from 0.53432 to 0.53477, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 50: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 566ms/step - csf_iou: 3.6889e-05 - dice_coefficient_multiclass: 0.3695 - gm_iou: 0.2732 - iou_score_multiclass: 0.2961 - loss: 0.8269 - pixel_accuracy_multiclass: 0.9931 - wm_iou: 0.0737 - val_csf_iou: 0.0339 - val_dice_coefficient_multiclass: 0.6276 - val_gm_iou: 0.6829 - val_iou_score_multiclass: 0.5348 - val_loss: 0.5084 - val_pixel_accuracy_multiclass: 0.9825 - val_wm_iou: 0.5238 - learning_rate: 5.0000e-05
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - csf_iou: 0.0246 - dice_coefficient_multiclass: 0.5818 - gm_iou: 0.6193 - iou_score_multiclass: 0.4874 - loss: 0.5775 - pixel_accuracy_multiclass: 0.9824 - wm_iou: 0.4296
# Epoch 51: val_iou_score_multiclass improved from 0.53477 to 0.53942, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 51: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 755ms/step - csf_iou: 0.0327 - dice_coefficient_multiclass: 0.5879 - gm_iou: 0.6031 - iou_score_multiclass: 0.4907 - loss: 0.5760 - pixel_accuracy_multiclass: 0.9809 - wm_iou: 0.4519 - val_csf_iou: 0.0366 - val_dice_coefficient_multiclass: 0.6319 - val_gm_iou: 0.6872 - val_iou_score_multiclass: 0.5394 - val_loss: 0.5032 - val_pixel_accuracy_multiclass: 0.9817 - val_wm_iou: 0.5318 - learning_rate: 5.0000e-05
# Epoch 52/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - csf_iou: 3.8008e-05 - dice_coefficient_multiclass: 0.3721 - gm_iou: 0.2830 - iou_score_multiclass: 0.2991 - loss: 0.8180 - pixel_accuracy_multiclass: 0.9935 - wm_iou: 0.0712
# Epoch 52: val_iou_score_multiclass improved from 0.53942 to 0.53980, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 52: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 501ms/step - csf_iou: 3.8008e-05 - dice_coefficient_multiclass: 0.3721 - gm_iou: 0.2830 - iou_score_multiclass: 0.2991 - loss: 0.8180 - pixel_accuracy_multiclass: 0.9935 - wm_iou: 0.0712 - val_csf_iou: 0.0364 - val_dice_coefficient_multiclass: 0.6321 - val_gm_iou: 0.6887 - val_iou_score_multiclass: 0.5398 - val_loss: 0.5019 - val_pixel_accuracy_multiclass: 0.9820 - val_wm_iou: 0.5319 - learning_rate: 5.0000e-05
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0254 - dice_coefficient_multiclass: 0.5857 - gm_iou: 0.6273 - iou_score_multiclass: 0.4921 - loss: 0.5690 - pixel_accuracy_multiclass: 0.9829 - wm_iou: 0.4361
# Epoch 53: val_iou_score_multiclass improved from 0.53980 to 0.54395, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 53: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 15s 755ms/step - csf_iou: 0.0338 - dice_coefficient_multiclass: 0.5916 - gm_iou: 0.6106 - iou_score_multiclass: 0.4951 - loss: 0.5672 - pixel_accuracy_multiclass: 0.9816 - wm_iou: 0.4572 - val_csf_iou: 0.0393 - val_dice_coefficient_multiclass: 0.6361 - val_gm_iou: 0.6858 - val_iou_score_multiclass: 0.5439 - val_loss: 0.4965 - val_pixel_accuracy_multiclass: 0.9815 - val_wm_iou: 0.5451 - learning_rate: 5.0000e-05
# Epoch 54/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - csf_iou: 3.8983e-05 - dice_coefficient_multiclass: 0.3756 - gm_iou: 0.2882 - iou_score_multiclass: 0.3022 - loss: 0.8084 - pixel_accuracy_multiclass: 0.9937 - wm_iou: 0.0742
# Epoch 54: val_iou_score_multiclass did not improve from 0.54395
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 421ms/step - csf_iou: 3.8983e-05 - dice_coefficient_multiclass: 0.3756 - gm_iou: 0.2882 - iou_score_multiclass: 0.3022 - loss: 0.8084 - pixel_accuracy_multiclass: 0.9937 - wm_iou: 0.0742 - val_csf_iou: 0.0392 - val_dice_coefficient_multiclass: 0.6355 - val_gm_iou: 0.6820 - val_iou_score_multiclass: 0.5431 - val_loss: 0.4985 - val_pixel_accuracy_multiclass: 0.9812 - val_wm_iou: 0.5455 - learning_rate: 5.0000e-05
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0267 - dice_coefficient_multiclass: 0.5887 - gm_iou: 0.6311 - iou_score_multiclass: 0.4955 - loss: 0.5631 - pixel_accuracy_multiclass: 0.9828 - wm_iou: 0.4415
# Epoch 55: val_iou_score_multiclass improved from 0.54395 to 0.54799, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 55: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 758ms/step - csf_iou: 0.0351 - dice_coefficient_multiclass: 0.5948 - gm_iou: 0.6159 - iou_score_multiclass: 0.4987 - loss: 0.5605 - pixel_accuracy_multiclass: 0.9817 - wm_iou: 0.4622 - val_csf_iou: 0.0404 - val_dice_coefficient_multiclass: 0.6396 - val_gm_iou: 0.6865 - val_iou_score_multiclass: 0.5480 - val_loss: 0.4880 - val_pixel_accuracy_multiclass: 0.9822 - val_wm_iou: 0.5566 - learning_rate: 5.0000e-05
# Epoch 56/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - csf_iou: 3.9755e-05 - dice_coefficient_multiclass: 0.3768 - gm_iou: 0.2890 - iou_score_multiclass: 0.3034 - loss: 0.8033 - pixel_accuracy_multiclass: 0.9938 - wm_iou: 0.0756
# Epoch 56: val_iou_score_multiclass did not improve from 0.54799
# ...
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0400 - dice_coefficient_multiclass: 0.6210 - gm_iou: 0.6784 - iou_score_multiclass: 0.5324 - loss: 0.4962 - pixel_accuracy_multiclass: 0.9841 - wm_iou: 0.4971
# Epoch 81: val_iou_score_multiclass did not improve from 0.57878
#
# Epoch 81: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 691ms/step - csf_iou: 0.0511 - dice_coefficient_multiclass: 0.6279 - gm_iou: 0.6653 - iou_score_multiclass: 0.5366 - loss: 0.4920 - pixel_accuracy_multiclass: 0.9833 - wm_iou: 0.5171 - val_csf_iou: 0.0570 - val_dice_coefficient_multiclass: 0.6660 - val_gm_iou: 0.7179 - val_iou_score_multiclass: 0.5787 - val_loss: 0.4458 - val_pixel_accuracy_multiclass: 0.9816 - val_wm_iou: 0.6092 - learning_rate: 5.0000e-05
# Epoch 82/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - csf_iou: 5.4130e-05 - dice_coefficient_multiclass: 0.4142 - gm_iou: 0.3582 - iou_score_multiclass: 0.3377 - loss: 0.7203 - pixel_accuracy_multiclass: 0.9945 - wm_iou: 0.1039
# Epoch 82: val_iou_score_multiclass did not improve from 0.57878
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 428ms/step - csf_iou: 5.4130e-05 - dice_coefficient_multiclass: 0.4142 - gm_iou: 0.3582 - iou_score_multiclass: 0.3377 - loss: 0.7203 - pixel_accuracy_multiclass: 0.9945 - wm_iou: 0.1039 - val_csf_iou: 0.0573 - val_dice_coefficient_multiclass: 0.6641 - val_gm_iou: 0.7104 - val_iou_score_multiclass: 0.5759 - val_loss: 0.4496 - val_pixel_accuracy_multiclass: 0.9811 - val_wm_iou: 0.6052 - learning_rate: 2.5000e-05
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0416 - dice_coefficient_multiclass: 0.6245 - gm_iou: 0.6830 - iou_score_multiclass: 0.5364 - loss: 0.4902 - pixel_accuracy_multiclass: 0.9845 - wm_iou: 0.5054
# Epoch 83: val_iou_score_multiclass improved from 0.57878 to 0.58248, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 83: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 776ms/step - csf_iou: 0.0539 - dice_coefficient_multiclass: 0.6313 - gm_iou: 0.6684 - iou_score_multiclass: 0.5401 - loss: 0.4858 - pixel_accuracy_multiclass: 0.9839 - wm_iou: 0.5235 - val_csf_iou: 0.0555 - val_dice_coefficient_multiclass: 0.6680 - val_gm_iou: 0.7411 - val_iou_score_multiclass: 0.5825 - val_loss: 0.4349 - val_pixel_accuracy_multiclass: 0.9839 - val_wm_iou: 0.6042 - learning_rate: 2.5000e-05
# Epoch 84/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - csf_iou: 5.4597e-05 - dice_coefficient_multiclass: 0.4132 - gm_iou: 0.3614 - iou_score_multiclass: 0.3374 - loss: 0.7186 - pixel_accuracy_multiclass: 0.9946 - wm_iou: 0.0992
# Epoch 84: val_iou_score_multiclass did not improve from 0.58248
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 429ms/step - csf_iou: 5.4597e-05 - dice_coefficient_multiclass: 0.4132 - gm_iou: 0.3614 - iou_score_multiclass: 0.3374 - loss: 0.7186 - pixel_accuracy_multiclass: 0.9946 - wm_iou: 0.0992 - val_csf_iou: 0.0552 - val_dice_coefficient_multiclass: 0.6678 - val_gm_iou: 0.7394 - val_iou_score_multiclass: 0.5822 - val_loss: 0.4362 - val_pixel_accuracy_multiclass: 0.9837 - val_wm_iou: 0.6056 - learning_rate: 2.5000e-05
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0413 - dice_coefficient_multiclass: 0.6254 - gm_iou: 0.6876 - iou_score_multiclass: 0.5377 - loss: 0.4873 - pixel_accuracy_multiclass: 0.9849 - wm_iou: 0.5053
# Epoch 85: val_iou_score_multiclass did not improve from 0.58248
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 672ms/step - csf_iou: 0.0539 - dice_coefficient_multiclass: 0.6324 - gm_iou: 0.6713 - iou_score_multiclass: 0.5416 - loss: 0.4833 - pixel_accuracy_multiclass: 0.9840 - wm_iou: 0.5254 - val_csf_iou: 0.0562 - val_dice_coefficient_multiclass: 0.6676 - val_gm_iou: 0.7300 - val_iou_score_multiclass: 0.5813 - val_loss: 0.4359 - val_pixel_accuracy_multiclass: 0.9839 - val_wm_iou: 0.6096 - learning_rate: 2.5000e-05
# Epoch 86/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - csf_iou: 5.4904e-05 - dice_coefficient_multiclass: 0.4149 - gm_iou: 0.3687 - iou_score_multiclass: 0.3393 - loss: 0.7136 - pixel_accuracy_multiclass: 0.9952 - wm_iou: 0.0983
# Epoch 86: val_iou_score_multiclass did not improve from 0.58248
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 422ms/step - csf_iou: 5.4904e-05 - dice_coefficient_multiclass: 0.4149 - gm_iou: 0.3687 - iou_score_multiclass: 0.3393 - loss: 0.7136 - pixel_accuracy_multiclass: 0.9952 - wm_iou: 0.0983 - val_csf_iou: 0.0562 - val_dice_coefficient_multiclass: 0.6668 - val_gm_iou: 0.7261 - val_iou_score_multiclass: 0.5802 - val_loss: 0.4385 - val_pixel_accuracy_multiclass: 0.9835 - val_wm_iou: 0.6092 - learning_rate: 2.5000e-05
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - csf_iou: 0.0425 - dice_coefficient_multiclass: 0.6273 - gm_iou: 0.6896 - iou_score_multiclass: 0.5399 - loss: 0.4838 - pixel_accuracy_multiclass: 0.9851 - wm_iou: 0.5100
# Epoch 87: val_iou_score_multiclass improved from 0.58248 to 0.58342, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 87: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 750ms/step - csf_iou: 0.0551 - dice_coefficient_multiclass: 0.6344 - gm_iou: 0.6728 - iou_score_multiclass: 0.5437 - loss: 0.4803 - pixel_accuracy_multiclass: 0.9841 - wm_iou: 0.5306 - val_csf_iou: 0.0555 - val_dice_coefficient_multiclass: 0.6687 - val_gm_iou: 0.7430 - val_iou_score_multiclass: 0.5834 - val_loss: 0.4332 - val_pixel_accuracy_multiclass: 0.9845 - val_wm_iou: 0.6066 - learning_rate: 2.5000e-05
# Epoch 88/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - csf_iou: 5.5808e-05 - dice_coefficient_multiclass: 0.4164 - gm_iou: 0.3715 - iou_score_multiclass: 0.3406 - loss: 0.7112 - pixel_accuracy_multiclass: 0.9951 - wm_iou: 0.0996
# Epoch 88: val_iou_score_multiclass improved from 0.58342 to 0.58346, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 88: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 513ms/step - csf_iou: 5.5808e-05 - dice_coefficient_multiclass: 0.4164 - gm_iou: 0.3715 - iou_score_multiclass: 0.3406 - loss: 0.7112 - pixel_accuracy_multiclass: 0.9951 - wm_iou: 0.0996 - val_csf_iou: 0.0555 - val_dice_coefficient_multiclass: 0.6688 - val_gm_iou: 0.7422 - val_iou_score_multiclass: 0.5835 - val_loss: 0.4333 - val_pixel_accuracy_multiclass: 0.9846 - val_wm_iou: 0.6076 - learning_rate: 2.5000e-05
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0428 - dice_coefficient_multiclass: 0.6284 - gm_iou: 0.6941 - iou_score_multiclass: 0.5413 - loss: 0.4810 - pixel_accuracy_multiclass: 0.9855 - wm_iou: 0.5101
# Epoch 89: val_iou_score_multiclass did not improve from 0.58346
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 677ms/step - csf_iou: 0.0555 - dice_coefficient_multiclass: 0.6357 - gm_iou: 0.6765 - iou_score_multiclass: 0.5454 - loss: 0.4772 - pixel_accuracy_multiclass: 0.9844 - wm_iou: 0.5322 - val_csf_iou: 0.0559 - val_dice_coefficient_multiclass: 0.6689 - val_gm_iou: 0.7384 - val_iou_score_multiclass: 0.5833 - val_loss: 0.4352 - val_pixel_accuracy_multiclass: 0.9840 - val_wm_iou: 0.6104 - learning_rate: 2.5000e-05
# Epoch 90/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - csf_iou: 5.6664e-05 - dice_coefficient_multiclass: 0.4187 - gm_iou: 0.3728 - iou_score_multiclass: 0.3425 - loss: 0.7074 - pixel_accuracy_multiclass: 0.9950 - wm_iou: 0.1038
# Prediction after epoch 90
#
#
# Epoch 90: val_iou_score_multiclass did not improve from 0.58346
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 482ms/step - csf_iou: 5.6664e-05 - dice_coefficient_multiclass: 0.4187 - gm_iou: 0.3728 - iou_score_multiclass: 0.3425 - loss: 0.7074 - pixel_accuracy_multiclass: 0.9950 - wm_iou: 0.1038 - val_csf_iou: 0.0560 - val_dice_coefficient_multiclass: 0.6687 - val_gm_iou: 0.7374 - val_iou_score_multiclass: 0.5830 - val_loss: 0.4354 - val_pixel_accuracy_multiclass: 0.9840 - val_wm_iou: 0.6102 - learning_rate: 2.5000e-05
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - csf_iou: 0.0434 - dice_coefficient_multiclass: 0.6297 - gm_iou: 0.6948 - iou_score_multiclass: 0.5427 - loss: 0.4789 - pixel_accuracy_multiclass: 0.9854 - wm_iou: 0.5134
# Epoch 91: val_iou_score_multiclass improved from 0.58346 to 0.58470, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 91: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 759ms/step - csf_iou: 0.0563 - dice_coefficient_multiclass: 0.6368 - gm_iou: 0.6783 - iou_score_multiclass: 0.5467 - loss: 0.4750 - pixel_accuracy_multiclass: 0.9845 - wm_iou: 0.5341 - val_csf_iou: 0.0563 - val_dice_coefficient_multiclass: 0.6699 - val_gm_iou: 0.7447 - val_iou_score_multiclass: 0.5847 - val_loss: 0.4325 - val_pixel_accuracy_multiclass: 0.9843 - val_wm_iou: 0.6088 - learning_rate: 2.5000e-05
# Epoch 92/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - csf_iou: 5.7273e-05 - dice_coefficient_multiclass: 0.4194 - gm_iou: 0.3739 - iou_score_multiclass: 0.3432 - loss: 0.7062 - pixel_accuracy_multiclass: 0.9950 - wm_iou: 0.1045
# Epoch 92: val_iou_score_multiclass did not improve from 0.58470
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 435ms/step - csf_iou: 5.7273e-05 - dice_coefficient_multiclass: 0.4194 - gm_iou: 0.3739 - iou_score_multiclass: 0.3432 - loss: 0.7062 - pixel_accuracy_multiclass: 0.9950 - wm_iou: 0.1045 - val_csf_iou: 0.0564 - val_dice_coefficient_multiclass: 0.6698 - val_gm_iou: 0.7436 - val_iou_score_multiclass: 0.5845 - val_loss: 0.4327 - val_pixel_accuracy_multiclass: 0.9843 - val_wm_iou: 0.6092 - learning_rate: 2.5000e-05
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - csf_iou: 0.0441 - dice_coefficient_multiclass: 0.6311 - gm_iou: 0.6971 - iou_score_multiclass: 0.5443 - loss: 0.4765 - pixel_accuracy_multiclass: 0.9855 - wm_iou: 0.5160
# Epoch 93: val_iou_score_multiclass improved from 0.58470 to 0.58496, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 93: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 761ms/step - csf_iou: 0.0572 - dice_coefficient_multiclass: 0.6383 - gm_iou: 0.6803 - iou_score_multiclass: 0.5483 - loss: 0.4725 - pixel_accuracy_multiclass: 0.9846 - wm_iou: 0.5368 - val_csf_iou: 0.0567 - val_dice_coefficient_multiclass: 0.6702 - val_gm_iou: 0.7433 - val_iou_score_multiclass: 0.5850 - val_loss: 0.4314 - val_pixel_accuracy_multiclass: 0.9845 - val_wm_iou: 0.6105 - learning_rate: 2.5000e-05
# Epoch 94/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - csf_iou: 5.7817e-05 - dice_coefficient_multiclass: 0.4208 - gm_iou: 0.3781 - iou_score_multiclass: 0.3446 - loss: 0.7029 - pixel_accuracy_multiclass: 0.9951 - wm_iou: 0.1048
# Epoch 94: val_iou_score_multiclass did not improve from 0.58496
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 424ms/step - csf_iou: 5.7817e-05 - dice_coefficient_multiclass: 0.4208 - gm_iou: 0.3781 - iou_score_multiclass: 0.3446 - loss: 0.7029 - pixel_accuracy_multiclass: 0.9951 - wm_iou: 0.1048 - val_csf_iou: 0.0567 - val_dice_coefficient_multiclass: 0.6699 - val_gm_iou: 0.7414 - val_iou_score_multiclass: 0.5845 - val_loss: 0.4322 - val_pixel_accuracy_multiclass: 0.9844 - val_wm_iou: 0.6108 - learning_rate: 2.5000e-05
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - csf_iou: 0.0445 - dice_coefficient_multiclass: 0.6321 - gm_iou: 0.6985 - iou_score_multiclass: 0.5456 - loss: 0.4742 - pixel_accuracy_multiclass: 0.9856 - wm_iou: 0.5184
# Epoch 95: val_iou_score_multiclass improved from 0.58496 to 0.58533, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 95: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 751ms/step - csf_iou: 0.0577 - dice_coefficient_multiclass: 0.6394 - gm_iou: 0.6820 - iou_score_multiclass: 0.5496 - loss: 0.4702 - pixel_accuracy_multiclass: 0.9847 - wm_iou: 0.5388 - val_csf_iou: 0.0571 - val_dice_coefficient_multiclass: 0.6706 - val_gm_iou: 0.7424 - val_iou_score_multiclass: 0.5853 - val_loss: 0.4313 - val_pixel_accuracy_multiclass: 0.9843 - val_wm_iou: 0.6120 - learning_rate: 2.5000e-05
# Epoch 96/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - csf_iou: 5.8484e-05 - dice_coefficient_multiclass: 0.4223 - gm_iou: 0.3794 - iou_score_multiclass: 0.3458 - loss: 0.6999 - pixel_accuracy_multiclass: 0.9952 - wm_iou: 0.1073
# Epoch 96: val_iou_score_multiclass did not improve from 0.58533
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 418ms/step - csf_iou: 5.8484e-05 - dice_coefficient_multiclass: 0.4223 - gm_iou: 0.3794 - iou_score_multiclass: 0.3458 - loss: 0.6999 - pixel_accuracy_multiclass: 0.9952 - wm_iou: 0.1073 - val_csf_iou: 0.0572 - val_dice_coefficient_multiclass: 0.6704 - val_gm_iou: 0.7407 - val_iou_score_multiclass: 0.5850 - val_loss: 0.4318 - val_pixel_accuracy_multiclass: 0.9842 - val_wm_iou: 0.6125 - learning_rate: 2.5000e-05
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - csf_iou: 0.0451 - dice_coefficient_multiclass: 0.6332 - gm_iou: 0.6998 - iou_score_multiclass: 0.5467 - loss: 0.4726 - pixel_accuracy_multiclass: 0.9856 - wm_iou: 0.5201
# Epoch 97: val_iou_score_multiclass improved from 0.58533 to 0.58639, saving model to best_model_vgg19unet_multiclass_ibsr.keras
#
# Epoch 97: finished saving model to best_model_vgg19unet_multiclass_ibsr.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 745ms/step - csf_iou: 0.0587 - dice_coefficient_multiclass: 0.6405 - gm_iou: 0.6831 - iou_score_multiclass: 0.5508 - loss: 0.4685 - pixel_accuracy_multiclass: 0.9846 - wm_iou: 0.5409 - val_csf_iou: 0.0579 - val_dice_coefficient_multiclass: 0.6715 - val_gm_iou: 0.7439 - val_iou_score_multiclass: 0.5864 - val_loss: 0.4292 - val_pixel_accuracy_multiclass: 0.9844 - val_wm_iou: 0.6134 - learning_rate: 2.5000e-05
# Epoch 98/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - csf_iou: 5.9124e-05 - dice_coefficient_multiclass: 0.4234 - gm_iou: 0.3820 - iou_score_multiclass: 0.3469 - loss: 0.6975 - pixel_accuracy_multiclass: 0.9951 - wm_iou: 0.1080
# Epoch 98: val_iou_score_multiclass did not improve from 0.58639
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 414ms/step - csf_iou: 5.9124e-05 - dice_coefficient_multiclass: 0.4234 - gm_iou: 0.3820 - iou_score_multiclass: 0.3469 - loss: 0.6975 - pixel_accuracy_multiclass: 0.9951 - wm_iou: 0.1080 - val_csf_iou: 0.0580 - val_dice_coefficient_multiclass: 0.6713 - val_gm_iou: 0.7421 - val_iou_score_multiclass: 0.5860 - val_loss: 0.4296 - val_pixel_accuracy_multiclass: 0.9844 - val_wm_iou: 0.6136 - learning_rate: 2.5000e-05
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - csf_iou: 0.0457 - dice_coefficient_multiclass: 0.6340 - gm_iou: 0.7012 - iou_score_multiclass: 0.5477 - loss: 0.4707 - pixel_accuracy_multiclass: 0.9856 - wm_iou: 0.5215
# Epoch 99: val_iou_score_multiclass did not improve from 0.58639
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 669ms/step - csf_iou: 0.0592 - dice_coefficient_multiclass: 0.6414 - gm_iou: 0.6843 - iou_score_multiclass: 0.5519 - loss: 0.4666 - pixel_accuracy_multiclass: 0.9847 - wm_iou: 0.5424 - val_csf_iou: 0.0580 - val_dice_coefficient_multiclass: 0.6714 - val_gm_iou: 0.7431 - val_iou_score_multiclass: 0.5861 - val_loss: 0.4304 - val_pixel_accuracy_multiclass: 0.9842 - val_wm_iou: 0.6131 - learning_rate: 2.5000e-05
# Epoch 100/100
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - csf_iou: 5.9781e-05 - dice_coefficient_multiclass: 0.4239 - gm_iou: 0.3835 - iou_score_multiclass: 0.3475 - loss: 0.6963 - pixel_accuracy_multiclass: 0.9951 - wm_iou: 0.1079
# Prediction after epoch 100
#
#
# Epoch 100: val_iou_score_multiclass did not improve from 0.58639
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 478ms/step - csf_iou: 5.9781e-05 - dice_coefficient_multiclass: 0.4239 - gm_iou: 0.3835 - iou_score_multiclass: 0.3475 - loss: 0.6963 - pixel_accuracy_multiclass: 0.9951 - wm_iou: 0.1079 - val_csf_iou: 0.0581 - val_dice_coefficient_multiclass: 0.6712 - val_gm_iou: 0.7415 - val_iou_score_multiclass: 0.5859 - val_loss: 0.4308 - val_pixel_accuracy_multiclass: 0.9842 - val_wm_iou: 0.6136 - learning_rate: 2.5000e-05
#
# Training time: 12.2 min

# %% [markdown]
# ## 13. Training Graphs

# %%
H = history.history

fig, axes = plt.subplots(4, 2, figsize=(14, 20))
fig.suptitle('VGG19-UNet (Multi-Class)  |  IBSR Tissue Segmentation  |  Training History',
             fontsize=15, fontweight='bold', y=0.99)

plot_specs = [
    ('loss', 'val_loss', 'Loss (Dice + CCE)', 'Loss'),
    ('dice_coefficient_multiclass', 'val_dice_coefficient_multiclass', 'Dice (macro-avg)', 'Dice'),
    ('iou_score_multiclass', 'val_iou_score_multiclass', 'IoU (macro-avg)', 'IoU'),
    ('pixel_accuracy_multiclass', 'val_pixel_accuracy_multiclass', 'Pixel Accuracy', 'Accuracy'),
    ('csf_iou', 'val_csf_iou', 'CSF IoU', 'IoU'),
    ('gm_iou', 'val_gm_iou', 'Grey Matter IoU', 'IoU'),
    ('wm_iou', 'val_wm_iou', 'White Matter IoU', 'IoU'),
]

for ax, (train_key, val_key, title, ylabel) in zip(axes.flatten(), plot_specs):
    epochs_range = range(1, len(H[train_key]) + 1)
    ax.plot(epochs_range, H[train_key], label='Train', color='steelblue', linewidth=2)
    ax.plot(epochs_range, H[val_key], label='Validation', color='darkorange', linewidth=2, linestyle='--')
    ax.set_title(title, fontsize=12, fontweight='bold')
    ax.set_xlabel('Epoch')
    ax.set_ylabel(ylabel)
    ax.legend(fontsize=10)
    ax.grid(True, alpha=0.3)

axes.flatten()[-1].axis('off')

plt.tight_layout()
plt.savefig('training_history_vgg19unet_multiclass_ibsr.png', dpi=150, bbox_inches='tight')
plt.show()
print('Plot saved ✓')
# Out:
# Plot saved ✓

# %% [markdown]
# ## 14. Best & Average Metrics Table

# %%
metric_spec = [
    ('Loss', 'loss', 'min'),
    ('Dice (macro-avg)', 'dice_coefficient_multiclass', 'max'),
    ('IoU (macro-avg)', 'iou_score_multiclass', 'max'),
    ('Pixel Accuracy', 'pixel_accuracy_multiclass', 'max'),
    ('CSF IoU', 'csf_iou', 'max'),
    ('Grey Matter IoU', 'gm_iou', 'max'),
    ('White Matter IoU', 'wm_iou', 'max'),
]

rows = []
for disp, key, mode in metric_spec:
    tr = np.asarray(H[key], dtype=np.float64)
    va = np.asarray(H['val_' + key], dtype=np.float64)
    pick = np.min if mode == 'min' else np.max
    rows.append({'Metric': disp, 'Train Best': pick(tr), 'Train Avg': tr.mean(),
                 'Val Best': pick(va), 'Val Avg': va.mean()})

report = pd.DataFrame(rows).set_index('Metric').round(4)

print('=' * 70)
print('   BEST & AVERAGE METRICS  —  VGG19-UNet Multi-Class  |  IBSR')
print('=' * 70)
print(report.to_string())
print('=' * 70)

best_epoch_iou = int(np.argmax(H['val_iou_score_multiclass'])) + 1
print(f'\nBest Val IoU (macro-avg): {max(H["val_iou_score_multiclass"]):.4f}  (epoch {best_epoch_iou})')
print(f'Best Val CSF IoU         : {max(H["val_csf_iou"]):.4f}')
print(f'Best Val Grey Matter IoU : {max(H["val_gm_iou"]):.4f}')
print(f'Best Val White Matter IoU: {max(H["val_wm_iou"]):.4f}')

report
# Out:
# ======================================================================
#    BEST & AVERAGE METRICS  —  VGG19-UNet Multi-Class  |  IBSR
# ======================================================================
#                   Train Best  Train Avg  Val Best  Val Avg
# Metric
# Loss                  0.4666     0.8252    0.4292   1.3694
# Dice (macro-avg)      0.6414     0.4496    0.6715   0.5565
# IoU (macro-avg)       0.5519     0.3647    0.5864   0.4668
# Pixel Accuracy        0.9952     0.9667    0.9846   0.8743
# CSF IoU               0.0592     0.0148    0.0581   0.0315
# Grey Matter IoU       0.6843     0.4055    0.7447   0.6072
# White Matter IoU      0.5424     0.2389    0.6136   0.4606
# ======================================================================
#
# Best Val IoU (macro-avg): 0.5864  (epoch 97)
# Best Val CSF IoU         : 0.0581
# Best Val Grey Matter IoU : 0.7447
# Best Val White Matter IoU: 0.6136
#                   Train Best  Train Avg  Val Best  Val Avg
# Metric
# Loss                  0.4666     0.8252    0.4292   1.3694
# Dice (macro-avg)      0.6414     0.4496    0.6715   0.5565
# IoU (macro-avg)       0.5519     0.3647    0.5864   0.4668
# Pixel Accuracy        0.9952     0.9667    0.9846   0.8743
# CSF IoU               0.0592     0.0148    0.0581   0.0315
# Grey Matter IoU       0.6843     0.4055    0.7447   0.6072
# White Matter IoU      0.5424     0.2389    0.6136   0.4606

# %% [markdown]
# ## 15. Load Best Model & Final Evaluation

# %%
best_model = tf.keras.models.load_model(
    'best_model_vgg19unet_multiclass_ibsr.keras',
    custom_objects={
        'combined_loss_multiclass': combined_loss_multiclass,
        'dice_coefficient_multiclass': dice_coefficient_multiclass,
        'iou_score_multiclass': iou_score_multiclass,
        'pixel_accuracy_multiclass': pixel_accuracy_multiclass,
        'csf_iou': csf_iou, 'gm_iou': gm_iou, 'wm_iou': wm_iou,
    }
)
print('Best model loaded ✓')
# Out:
# Best model loaded ✓

# %%
print('Evaluating best model on held-out test set...\n')
test_results = best_model.evaluate(test_dataset, verbose=1)
test_dict = dict(zip(best_model.metrics_names, test_results))

print('\n' + '=' * 60)
print('  FINAL TEST-SET METRICS  (VGG19-UNet Multi-Class | IBSR)')
print('=' * 60)
for k, v in test_dict.items():
    print(f'  {k:35s}: {v:.4f}')
print('=' * 60)

final_df = pd.DataFrame([{
    'Model': 'VGG19-UNet Multi-Class (IBSR)',
    'IoU (macro)': round(test_dict.get('iou_score_multiclass', float('nan')), 4),
    'Dice (macro)': round(test_dict.get('dice_coefficient_multiclass', float('nan')), 4),
    'CSF IoU': round(test_dict.get('csf_iou', float('nan')), 4),
    'GM IoU': round(test_dict.get('gm_iou', float('nan')), 4),
    'WM IoU': round(test_dict.get('wm_iou', float('nan')), 4),
    'Pixel Accuracy': round(test_dict.get('pixel_accuracy_multiclass', float('nan')), 4),
}]).set_index('Model')
final_df
# Out:
# Evaluating best model on held-out test set...
#
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 793ms/step - csf_iou: 0.0387 - dice_coefficient_multiclass: 0.6318 - gm_iou: 0.6850 - iou_score_multiclass: 0.5453 - loss: 0.4407 - pixel_accuracy_multiclass: 0.9868 - wm_iou: 0.5260
#
# ============================================================
#   FINAL TEST-SET METRICS  (VGG19-UNet Multi-Class | IBSR)
# ============================================================
#   loss                               : 0.4407
#   compile_metrics                    : 0.6318
# ============================================================
#                                IoU (macro)  Dice (macro)  CSF IoU  GM IoU  \
# Model
# VGG19-UNet Multi-Class (IBSR)          NaN           NaN      NaN     NaN
#
#                                WM IoU  Pixel Accuracy
# Model
# VGG19-UNet Multi-Class (IBSR)     NaN             NaN

# %% [markdown]
# ## 16. Test Predictions Visualization

# %%
print('Test set predictions:')
show_predictions(test_dataset, num=5, model_to_use=best_model)
# Out:
# Test set predictions:

# %% [markdown]
# ## 17. Save Final Model

# %%
best_model.save('ibsr_vgg19_unet_multiclass_final.keras')
print('Model saved ✓')
# Out:
# Model saved ✓
