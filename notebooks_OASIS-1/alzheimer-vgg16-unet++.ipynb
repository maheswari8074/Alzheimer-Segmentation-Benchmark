# %% [markdown]
# # Alzheimer's Disease Brain MRI Segmentation
# ## VGG16 + UNet++ | OASIS disc1 + disc2
# Full pipeline: data loading → preprocessing → model training → metrics → visualizations

# %% [markdown]
# ## 1. Import Libraries

# %%
import os
import cv2
import random
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, UpSampling2D,
    concatenate, BatchNormalization, Dropout, Activation
)
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG16
from tensorflow.keras import callbacks
from sklearn.model_selection import train_test_split
from tqdm.auto import tqdm
import time
import datetime

# !pip install nibabel -q
import nibabel as nib

print('TensorFlow version:', tf.__version__)
print('GPUs available:', tf.config.list_physical_devices('GPU'))
# Out:
# 2026-06-22 15:55:04.124046: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1782143704.310701      58 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1782143704.366543      58 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1782143704.812958      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782143704.812999      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782143704.813002      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782143704.813004      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow version: 2.19.0
# GPUs available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 2. Configuration

# %%
# ─── Paths ────────────────────────────────────────────────────────────────────
# Both OASIS discs added as Kaggle inputs separately ─ adjust slugs if different
ROOTS = [
    '/kaggle/input/datasets/maheswarimudadla/oasis-disc1/disc1',
    '/kaggle/input/datasets/maheswarimudadla/disc2-oasis1/disc2',
]

PROCESSED_DIR   = 'oasis_processed'
IMAGE_FOLDER    = os.path.join(PROCESSED_DIR, 'images')
MASK_FOLDER     = os.path.join(PROCESSED_DIR, 'masks')
TRAIN_IMG_DIR   = os.path.join(PROCESSED_DIR, 'train', 'images')
TRAIN_MASK_DIR  = os.path.join(PROCESSED_DIR, 'train', 'masks')
TEST_IMG_DIR    = os.path.join(PROCESSED_DIR, 'test',  'images')
TEST_MASK_DIR   = os.path.join(PROCESSED_DIR, 'test',  'masks')

# ─── Hyperparameters ──────────────────────────────────────────────────────────
IMG_SIZE    = (224, 224)
BATCH_SIZE  = 16
EPOCHS      = 100
SEED        = 42
TEST_SPLIT  = 0.15

print('Config set ✓')
# Out:
# Config set ✓

# %% [markdown]
# ## 3. Load & Preprocess OASIS Data (disc1 + disc2)
# OASIS stores brain volumes as Analyze `.img/.hdr` pairs. We slice along the axial axis and save each 2-D slice as a PNG.

# %%
def make_dir(path):
    os.makedirs(path, exist_ok=True)

for d in [IMAGE_FOLDER, MASK_FOLDER,
          TRAIN_IMG_DIR, TRAIN_MASK_DIR,
          TEST_IMG_DIR,  TEST_MASK_DIR]:
    make_dir(d)

print('Directories ready ✓')
# Out:
# Directories ready ✓

# %%
def normalize_slice(arr):
    """Min-max normalise a 2-D array to [0, 255] uint8."""
    mn, mx = arr.min(), arr.max()
    if mx - mn == 0:
        return np.zeros_like(arr, dtype=np.uint8)
    return ((arr - mn) / (mx - mn) * 255).astype(np.uint8)


def extract_slices(subject_dir, img_out, mask_out, step=2):
    """
    For one OASIS subject directory, find the T88 masked brain volume
    and the FSL_SEG tissue mask, then save every `step`-th coronal slice.
    Returns number of slices saved.
    """
    subject_name = os.path.basename(subject_dir)
    t88_dir = os.path.join(subject_dir, 'PROCESSED', 'MPRAGE', 'T88_111')
    fsl_dir = os.path.join(subject_dir, 'FSL_SEG')

    if not os.path.isdir(t88_dir) or not os.path.isdir(fsl_dir):
        return 0

    brain_img_path = None
    for f in os.listdir(t88_dir):
        if f.endswith('masked_gfc.img'):
            brain_img_path = os.path.join(t88_dir, f)
            break

    seg_img_path = None
    for f in os.listdir(fsl_dir):
        if f.endswith('fseg.img'):
            seg_img_path = os.path.join(fsl_dir, f)
            break

    if brain_img_path is None or seg_img_path is None:
        return 0

    brain_vol = np.squeeze(nib.load(brain_img_path).get_fdata())
    seg_vol   = np.squeeze(nib.load(seg_img_path).get_fdata())

    saved = 0
    for i in range(0, brain_vol.shape[1], step):
        b_sl   = brain_vol[:, i, :]
        seg_sl = seg_vol[:, i, :]

        if b_sl.max() == 0:
            continue

        img_arr  = normalize_slice(b_sl)
        mask_arr = (seg_sl > 0).astype(np.uint8) * 255

        fname = f"{subject_name}_sl{i:03d}.png"
        cv2.imwrite(os.path.join(img_out,  fname), img_arr)
        cv2.imwrite(os.path.join(mask_out, fname), mask_arr)
        saved += 1

    return saved


# ─── Clear old slices (fresh run) ──────────────────────────────────────────────
for folder in [IMAGE_FOLDER, MASK_FOLDER]:
    if os.path.exists(folder):
        shutil.rmtree(folder)
    os.makedirs(folder)

# ─── Gather subjects from both discs ───────────────────────────────────────────
subject_dirs = []
for root in ROOTS:
    if os.path.exists(root):
        dirs = [
            os.path.join(root, d)
            for d in os.listdir(root)
            if os.path.isdir(os.path.join(root, d)) and d.startswith('OAS')
        ]
        subject_dirs += dirs
        print(f'{root} → {len(dirs)} subjects')

print(f'\nTotal subjects: {len(subject_dirs)}')

# ─── Extract ────────────────────────────────────────────────────────────────────
total_slices = 0
for subj in tqdm(subject_dirs, desc='Extracting slices'):
    total_slices += extract_slices(subj, IMAGE_FOLDER, MASK_FOLDER)

print(f'\nTotal slices extracted : {total_slices}')
print(f'Images saved           : {len(os.listdir(IMAGE_FOLDER))}')
print(f'Masks  saved           : {len(os.listdir(MASK_FOLDER))}')
# Out:
# /kaggle/input/datasets/maheswarimudadla/oasis-disc1/disc1 → 39 subjects
# /kaggle/input/datasets/maheswarimudadla/disc2-oasis1/disc2 → 38 subjects
#
# Total subjects: 77
# Extracting slices:   0%|          | 0/77 [00:00<?, ?it/s]
# Total slices extracted : 6622
# Images saved           : 6622
# Masks  saved           : 6622

# %% [markdown]
# ## 4. Data Visualisation

# %%
def visualize_sample(image_name, img_dir=IMAGE_FOLDER, mask_dir=MASK_FOLDER):
    img  = cv2.imread(os.path.join(img_dir,  image_name), cv2.IMREAD_GRAYSCALE)
    mask = cv2.imread(os.path.join(mask_dir, image_name), cv2.IMREAD_GRAYSCALE)

    overlay = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
    overlay[mask > 127, 0] = 255
    overlay[mask > 127, 1] = 0
    overlay[mask > 127, 2] = 0

    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    axes[0].imshow(img,     cmap='gray');  axes[0].set_title('Brain MRI Slice',      fontsize=13)
    axes[1].imshow(mask,    cmap='gray');  axes[1].set_title('Ground Truth Mask',    fontsize=13)
    axes[2].imshow(overlay);               axes[2].set_title('Overlay (red = mask)', fontsize=13)
    for ax in axes: ax.axis('off')
    plt.suptitle(image_name, fontsize=10, color='gray')
    plt.tight_layout()
    plt.show()


all_images = os.listdir(IMAGE_FOLDER)
for _ in range(4):
    visualize_sample(random.choice(all_images))

# %% [markdown]
# ## 5. Train / Test Split

# %%
images = sorted([f for f in os.listdir(IMAGE_FOLDER) if f.endswith('.png')])
masks  = sorted([f for f in os.listdir(MASK_FOLDER)  if f.endswith('.png')])

assert images == masks, 'Image-mask mismatch! Check filenames.'

train_imgs, test_imgs = train_test_split(images, test_size=TEST_SPLIT, random_state=SEED)
print(f'Train: {len(train_imgs)}  |  Test: {len(test_imgs)}')

def copy_files(file_list, src_img, src_mask, dst_img, dst_mask):
    for f in tqdm(file_list, leave=False):
        shutil.copy(os.path.join(src_img,  f), os.path.join(dst_img,  f))
        shutil.copy(os.path.join(src_mask, f), os.path.join(dst_mask, f))

copy_files(train_imgs, IMAGE_FOLDER, MASK_FOLDER, TRAIN_IMG_DIR, TRAIN_MASK_DIR)
copy_files(test_imgs,  IMAGE_FOLDER, MASK_FOLDER, TEST_IMG_DIR,  TEST_MASK_DIR)
print('Files copied ✓')
# Out:
# Train: 5628  |  Test: 994
#   0%|          | 0/5628 [00:00<?, ?it/s]
#   0%|          | 0/994 [00:00<?, ?it/s]
# Files copied ✓

# %% [markdown]
# ## 6. tf.data Pipeline

# %%
def load_image(img_path, mask_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE)
    img = tf.cast(img, tf.float32) / 255.0

    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=1)
    mask = tf.image.resize(mask, IMG_SIZE, method='nearest')
    mask = tf.cast(mask, tf.float32) / 255.0

    return img, mask


def augment(img, mask):
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_left_right(img)
        mask = tf.image.flip_left_right(mask)
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_up_down(img)
        mask = tf.image.flip_up_down(mask)
    img = tf.image.random_brightness(img, max_delta=0.05)
    img = tf.clip_by_value(img, 0.0, 1.0)
    return img, mask


def build_dataset(img_dir, mask_dir, augment_data=False, batch=BATCH_SIZE):
    img_files  = sorted([os.path.join(img_dir,  f) for f in os.listdir(img_dir)  if f.endswith('.png')])
    mask_files = sorted([os.path.join(mask_dir, f) for f in os.listdir(mask_dir) if f.endswith('.png')])

    ds = tf.data.Dataset.from_tensor_slices((img_files, mask_files))
    ds = ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
    if augment_data:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch).prefetch(tf.data.AUTOTUNE)
    return ds


train_dataset = build_dataset(TRAIN_IMG_DIR, TRAIN_MASK_DIR, augment_data=True)
test_dataset  = build_dataset(TEST_IMG_DIR,  TEST_MASK_DIR,  augment_data=False)

print('Datasets ready ✓')
for imgs, masks in train_dataset.take(1):
    print('Batch shapes →  images:', imgs.shape, ' masks:', masks.shape)
# Out:
# I0000 00:00:1782143750.469242      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Datasets ready ✓
# Batch shapes →  images: (16, 224, 224, 3)  masks: (16, 224, 224, 1)

# %% [markdown]
# ## 7. Model — VGG16 Encoder + UNet++ (Nested) Decoder
# **Key difference vs plain UNet:** UNet++ adds *dense nested skip pathways* between encoder and decoder stages. Instead of a single skip connection per level, intermediate nodes `X(i,j)` aggregate features from the previous node at the same depth AND the upsampled node one level deeper — this redundant, multi-scale connectivity reduces the semantic gap between encoder and decoder features and tends to improve segmentation of fine boundaries.

# %%
def conv_block(x, filters, name_prefix):
    """Two Conv2D + BN + ReLU layers — the basic node operation in UNet++."""
    x = Conv2D(filters, (3,3), padding='same', name=f'{name_prefix}_c1')(x)
    x = BatchNormalization(name=f'{name_prefix}_bn1')(x)
    x = Activation('relu', name=f'{name_prefix}_act1')(x)
    x = Conv2D(filters, (3,3), padding='same', name=f'{name_prefix}_c2')(x)
    x = BatchNormalization(name=f'{name_prefix}_bn2')(x)
    x = Activation('relu', name=f'{name_prefix}_act2')(x)
    return x


def up(x, name):
    return UpSampling2D((2, 2), name=name)(x)


def build_vgg16_unetpp(input_shape=(224, 224, 3), freeze_encoder=True, deep_supervision=False):
    """
    VGG16 encoder (ImageNet weights) as backbone X(i,0) column,
    UNet++ nested dense decoder for X(i,j) with j>0.

    Encoder depths (i = 0..4), matching VGG16 blocks:
      X(0,0) = block1_conv2   224x224,  64ch
      X(1,0) = block2_conv2   112x112, 128ch
      X(2,0) = block3_conv3    56x56,  256ch
      X(3,0) = block4_conv3    28x28,  512ch
      X(4,0) = block5_conv3    14x14,  512ch  (bottleneck)
    """
    inputs = Input(shape=input_shape, name='input')
    base = VGG16(include_top=False, weights='imagenet', input_tensor=inputs)

    if freeze_encoder:
        for layer in base.layers:
            layer.trainable = False

    # ── Backbone column (j = 0) ───────────────────────────────────────────────
    X00 = base.get_layer('block1_conv2').output   # 224x224,  64
    X10 = base.get_layer('block2_conv2').output   # 112x112, 128
    X20 = base.get_layer('block3_conv3').output   #  56x56,  256
    X30 = base.get_layer('block4_conv3').output   #  28x28,  512
    X40 = base.get_layer('block5_conv3').output   #  14x14,  512

    F = [64, 128, 256, 512, 512]   # channel width per depth level

    # ── Nested dense decoder ────────────────────────────────────────────────
    # j = 1
    X01 = conv_block(concatenate([X00, up(X10, 'up10_01')]), F[0], 'X01')
    X11 = conv_block(concatenate([X10, up(X20, 'up20_11')]), F[1], 'X11')
    X21 = conv_block(concatenate([X20, up(X30, 'up30_21')]), F[2], 'X21')
    X31 = conv_block(concatenate([X30, up(X40, 'up40_31')]), F[3], 'X31')

    # j = 2
    X02 = conv_block(concatenate([X00, X01, up(X11, 'up11_02')]), F[0], 'X02')
    X12 = conv_block(concatenate([X10, X11, up(X21, 'up21_12')]), F[1], 'X12')
    X22 = conv_block(concatenate([X20, X21, up(X31, 'up31_22')]), F[2], 'X22')

    # j = 3
    X03 = conv_block(concatenate([X00, X01, X02, up(X12, 'up12_03')]), F[0], 'X03')
    X13 = conv_block(concatenate([X10, X11, X12, up(X22, 'up22_13')]), F[1], 'X13')

    # j = 4 (final, full-resolution node)
    X04 = conv_block(concatenate([X00, X01, X02, X03, up(X13, 'up13_04')]), F[0], 'X04')

    # ── Output(s) ──────────────────────────────────────────────────────────
    out4 = Conv2D(1, (1,1), activation='sigmoid', name='output')(X04)

    if deep_supervision:
        # Auxiliary outputs at X01, X02, X03 — averaged with main output during training
        out1 = Conv2D(1, (1,1), activation='sigmoid', name='out1')(X01)
        out2 = Conv2D(1, (1,1), activation='sigmoid', name='out2')(X02)
        out3 = Conv2D(1, (1,1), activation='sigmoid', name='out3')(X03)
        model = Model(inputs=inputs, outputs=[out1, out2, out3, out4], name='VGG16_UNetPP_DS')
    else:
        model = Model(inputs=inputs, outputs=out4, name='VGG16_UNetPP')

    return model


# Single-output mode keeps metric/callback code identical to the plain UNet notebook.
# Flip to True if you want deep supervision (then loss/metrics need per-output weighting).
DEEP_SUPERVISION = False

model = build_vgg16_unetpp(input_shape=(*IMG_SIZE, 3), freeze_encoder=True, deep_supervision=DEEP_SUPERVISION)
print('Model built ✓')
print(f'Total parameters      : {model.count_params():,}')
print(f'Trainable parameters  : {sum([K.count_params(w) for w in model.trainable_weights]):,}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model built ✓
# Total parameters      : 30,140,545
# Trainable parameters  : 15,419,201

# %% [markdown]
# ## 8. Custom Metrics & Loss

# %%
def dice_coefficient(y_true, y_pred, smooth=1.0):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_loss(y_true, y_pred):
    return 1.0 - dice_coefficient(y_true, y_pred)


def iou_score(y_true, y_pred, smooth=1.0):
    """Intersection over Union (Jaccard Index)"""
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)


def precision_smooth(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return intersection / (K.sum(y_pred_f) + K.epsilon())


def recall_smooth(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return intersection / (K.sum(y_true_f) + K.epsilon())


def pixel_accuracy(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    tp = K.sum(K.round(K.clip(y_true_f * y_pred_f, 0, 1)))
    tn = K.sum(K.round(K.clip((1 - y_true_f) * (1 - y_pred_f), 0, 1)))
    total = K.cast(tf.size(y_true_f), K.floatx())
    return (tp + tn) / total


def combined_loss(y_true, y_pred):
    return dice_loss(y_true, y_pred) + tf.keras.losses.binary_crossentropy(y_true, y_pred)


model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=combined_loss,
    metrics=[dice_coefficient, iou_score, precision_smooth, recall_smooth, pixel_accuracy]
)

print('Model compiled ✓')
# Out:
# Model compiled ✓

# %% [markdown]
# ## 9. Model Summary & Architecture Plot

# %%
model.summary()

tf.keras.utils.plot_model(
    model,
    to_file='vgg16_unetpp_architecture.png',
    show_shapes=True,
    show_layer_names=True,
    rankdir='TB',
    dpi=60
)
# Out:
# Model: "VGG16_UNetPP"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 224, 224,  │          0 │ -                 │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 224, 224,  │      1,792 │ input[0][0]       │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 224, 224,  │     36,928 │ block1_conv1[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 112, 112,  │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 112, 112,  │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 112, 112,  │    147,584 │ block2_conv1[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 56, 56,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 56, 56,    │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 56, 56,    │    590,080 │ block3_conv1[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 56, 56,    │    590,080 │ block3_conv2[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 28, 28,    │          0 │ block3_conv3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 28, 28,    │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 28, 28,    │  2,359,808 │ block4_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 28, 28,    │  2,359,808 │ block4_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 14, 14,    │          0 │ block4_conv3[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 14, 14,    │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 14, 14,    │  2,359,808 │ block5_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 14, 14,    │  2,359,808 │ block5_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up40_31             │ (None, 28, 28,    │          0 │ block5_conv3[0][… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up30_21             │ (None, 56, 56,    │          0 │ block4_conv3[0][… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 28, 28,    │          0 │ block4_conv3[0][… │
# │ (Concatenate)       │ 1024)             │            │ up40_31[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up20_11             │ (None, 112, 112,  │          0 │ block3_conv3[0][… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 56, 56,    │          0 │ block3_conv3[0][… │
# │ (Concatenate)       │ 768)              │            │ up30_21[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_c1 (Conv2D)     │ (None, 28, 28,    │  4,719,104 │ concatenate_3[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up10_01             │ (None, 224, 224,  │          0 │ block2_conv2[0][… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 112, 112,  │          0 │ block2_conv2[0][… │
# │ (Concatenate)       │ 384)              │            │ up20_11[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_c1 (Conv2D)     │ (None, 56, 56,    │  1,769,728 │ concatenate_2[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_bn1             │ (None, 28, 28,    │      2,048 │ X31_c1[0][0]      │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 224, 224,  │          0 │ block1_conv2[0][… │
# │ (Concatenate)       │ 192)              │            │ up10_01[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_c1 (Conv2D)     │ (None, 112, 112,  │    442,496 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_bn1             │ (None, 56, 56,    │      1,024 │ X21_c1[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_act1            │ (None, 28, 28,    │          0 │ X31_bn1[0][0]     │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_c1 (Conv2D)     │ (None, 224, 224,  │    110,656 │ concatenate[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_bn1             │ (None, 112, 112,  │        512 │ X11_c1[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_act1            │ (None, 56, 56,    │          0 │ X21_bn1[0][0]     │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_c2 (Conv2D)     │ (None, 28, 28,    │  2,359,808 │ X31_act1[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_bn1             │ (None, 224, 224,  │        256 │ X01_c1[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_act1            │ (None, 112, 112,  │          0 │ X11_bn1[0][0]     │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_c2 (Conv2D)     │ (None, 56, 56,    │    590,080 │ X21_act1[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_bn2             │ (None, 28, 28,    │      2,048 │ X31_c2[0][0]      │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_act1            │ (None, 224, 224,  │          0 │ X01_bn1[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_c2 (Conv2D)     │ (None, 112, 112,  │    147,584 │ X11_act1[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_bn2             │ (None, 56, 56,    │      1,024 │ X21_c2[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_act2            │ (None, 28, 28,    │          0 │ X31_bn2[0][0]     │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_c2 (Conv2D)     │ (None, 224, 224,  │     36,928 │ X01_act1[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_bn2             │ (None, 112, 112,  │        512 │ X11_c2[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_act2            │ (None, 56, 56,    │          0 │ X21_bn2[0][0]     │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up31_22             │ (None, 56, 56,    │          0 │ X31_act2[0][0]    │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_bn2             │ (None, 224, 224,  │        256 │ X01_c2[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_act2            │ (None, 112, 112,  │          0 │ X11_bn2[0][0]     │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up21_12             │ (None, 112, 112,  │          0 │ X21_act2[0][0]    │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 56, 56,    │          0 │ block3_conv3[0][… │
# │ (Concatenate)       │ 1024)             │            │ X21_act2[0][0],   │
# │                     │                   │            │ up31_22[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_act2            │ (None, 224, 224,  │          0 │ X01_bn2[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up11_02             │ (None, 224, 224,  │          0 │ X11_act2[0][0]    │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 112, 112,  │          0 │ block2_conv2[0][… │
# │ (Concatenate)       │ 512)              │            │ X11_act2[0][0],   │
# │                     │                   │            │ up21_12[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_c1 (Conv2D)     │ (None, 56, 56,    │  2,359,552 │ concatenate_6[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 224, 224,  │          0 │ block1_conv2[0][… │
# │ (Concatenate)       │ 256)              │            │ X01_act2[0][0],   │
# │                     │                   │            │ up11_02[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_c1 (Conv2D)     │ (None, 112, 112,  │    589,952 │ concatenate_5[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_bn1             │ (None, 56, 56,    │      1,024 │ X22_c1[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_c1 (Conv2D)     │ (None, 224, 224,  │    147,520 │ concatenate_4[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_bn1             │ (None, 112, 112,  │        512 │ X12_c1[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_act1            │ (None, 56, 56,    │          0 │ X22_bn1[0][0]     │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_bn1             │ (None, 224, 224,  │        256 │ X02_c1[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_act1            │ (None, 112, 112,  │          0 │ X12_bn1[0][0]     │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_c2 (Conv2D)     │ (None, 56, 56,    │    590,080 │ X22_act1[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_act1            │ (None, 224, 224,  │          0 │ X02_bn1[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_c2 (Conv2D)     │ (None, 112, 112,  │    147,584 │ X12_act1[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_bn2             │ (None, 56, 56,    │      1,024 │ X22_c2[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_c2 (Conv2D)     │ (None, 224, 224,  │     36,928 │ X02_act1[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_bn2             │ (None, 112, 112,  │        512 │ X12_c2[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_act2            │ (None, 56, 56,    │          0 │ X22_bn2[0][0]     │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_bn2             │ (None, 224, 224,  │        256 │ X02_c2[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_act2            │ (None, 112, 112,  │          0 │ X12_bn2[0][0]     │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up22_13             │ (None, 112, 112,  │          0 │ X22_act2[0][0]    │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_act2            │ (None, 224, 224,  │          0 │ X02_bn2[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up12_03             │ (None, 224, 224,  │          0 │ X12_act2[0][0]    │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 112, 112,  │          0 │ block2_conv2[0][… │
# │ (Concatenate)       │ 640)              │            │ X11_act2[0][0],   │
# │                     │                   │            │ X12_act2[0][0],   │
# │                     │                   │            │ up22_13[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 224, 224,  │          0 │ block1_conv2[0][… │
# │ (Concatenate)       │ 320)              │            │ X01_act2[0][0],   │
# │                     │                   │            │ X02_act2[0][0],   │
# │                     │                   │            │ up12_03[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_c1 (Conv2D)     │ (None, 112, 112,  │    737,408 │ concatenate_8[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_c1 (Conv2D)     │ (None, 224, 224,  │    184,384 │ concatenate_7[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_bn1             │ (None, 112, 112,  │        512 │ X13_c1[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_bn1             │ (None, 224, 224,  │        256 │ X03_c1[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_act1            │ (None, 112, 112,  │          0 │ X13_bn1[0][0]     │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_act1            │ (None, 224, 224,  │          0 │ X03_bn1[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_c2 (Conv2D)     │ (None, 112, 112,  │    147,584 │ X13_act1[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_c2 (Conv2D)     │ (None, 224, 224,  │     36,928 │ X03_act1[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_bn2             │ (None, 112, 112,  │        512 │ X13_c2[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_bn2             │ (None, 224, 224,  │        256 │ X03_c2[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_act2            │ (None, 112, 112,  │          0 │ X13_bn2[0][0]     │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_act2            │ (None, 224, 224,  │          0 │ X03_bn2[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up13_04             │ (None, 224, 224,  │          0 │ X13_act2[0][0]    │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 224, 224,  │          0 │ block1_conv2[0][… │
# │ (Concatenate)       │ 384)              │            │ X01_act2[0][0],   │
# │                     │                   │            │ X02_act2[0][0],   │
# │                     │                   │            │ X03_act2[0][0],   │
# │                     │                   │            │ up13_04[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_c1 (Conv2D)     │ (None, 224, 224,  │    221,248 │ concatenate_9[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_bn1             │ (None, 224, 224,  │        256 │ X04_c1[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_act1            │ (None, 224, 224,  │          0 │ X04_bn1[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_c2 (Conv2D)     │ (None, 224, 224,  │     36,928 │ X04_act1[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_bn2             │ (None, 224, 224,  │        256 │ X04_c2[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_act2            │ (None, 224, 224,  │          0 │ X04_bn2[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Conv2D)     │ (None, 224, 224,  │         65 │ X04_act2[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 30,140,545 (114.98 MB)
#  Trainable params: 15,419,201 (58.82 MB)
#  Non-trainable params: 14,721,344 (56.16 MB)

# %% [markdown]
# ## 10. Callbacks

# %%
def create_mask(pred):
    return tf.math.round(pred)


def show_predictions(dataset, num=3, model_to_use=None):
    m = model_to_use or model
    for imgs, masks in dataset.take(1):
        preds = m.predict(imgs, verbose=0)
        for i in range(min(num, len(imgs))):
            pred_mask = create_mask(preds[i])
            fig, axes = plt.subplots(1, 3, figsize=(12, 4))
            axes[0].imshow(imgs[i].numpy());            axes[0].set_title('Input MRI')
            axes[1].imshow(masks[i].numpy()[..., 0], cmap='gray'); axes[1].set_title('Ground Truth')
            axes[2].imshow(pred_mask.numpy()[..., 0], cmap='gray'); axes[2].set_title('Prediction')
            for ax in axes: ax.axis('off')
            plt.tight_layout()
            plt.show()


class DisplayCallback(callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % 10 == 0:
            show_predictions(test_dataset, num=2)
            print(f'Prediction after epoch {epoch + 1}\n')


logdir = os.path.join('logs', datetime.datetime.now().strftime('%Y%m%d-%H%M%S'))

callbacks_list = [
    DisplayCallback(),
    callbacks.TensorBoard(logdir, histogram_freq=1),
    callbacks.ModelCheckpoint('best_model_unetpp.keras', verbose=1, save_best_only=True,
                               monitor='val_iou_score', mode='max'),
    callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5,
                                 min_lr=1e-7, verbose=1),
    # callbacks.EarlyStopping(monitor='val_iou_score', patience=15, mode='max',
    #                          restore_best_weights=True, verbose=1),
]

print('Callbacks ready ✓')
# Out:
# Callbacks ready ✓

# %% [markdown]
# ## 11. Initial Predictions (before training)

# %%
print('Predictions before training:')
show_predictions(test_dataset, num=2)
# Out:
# Predictions before training:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1782143755.500673     134 service.cc:152] XLA service 0x7dc6ec009ec0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1782143755.500706     134 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1782143755.953208     134 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1782143785.753596     134 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %% [markdown]
# ## 12. Training

# %%
steps_per_epoch  = len(os.listdir(TRAIN_IMG_DIR)) // BATCH_SIZE
validation_steps = len(os.listdir(TEST_IMG_DIR))  // BATCH_SIZE

print(f'Steps per epoch  : {steps_per_epoch}')
print(f'Validation steps : {validation_steps}')

start_time = time.time()

history = model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=EPOCHS,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps,
    callbacks=callbacks_list
)

elapsed = time.time() - start_time
print(f'\nTraining time: {elapsed/60:.1f} min')
# Out:
# Steps per epoch  : 351
# Validation steps : 62
# Epoch 1/100
# 2026-06-22 15:56:46.925218: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng2{k2=3,k3=0} for conv %cudnn-conv-bw-input.17 = (f32[16,384,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,224,224]{3,2,1,0} %bitcast.26028, f32[64,384,3,3]{3,2,1,0} %bitcast.19078), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/VGG16_UNetPP_1/X04_c1_1/convolution/Conv2DBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-22 15:56:46.991786: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.066687001s
# Trying algorithm eng2{k2=3,k3=0} for conv %cudnn-conv-bw-input.17 = (f32[16,384,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,224,224]{3,2,1,0} %bitcast.26028, f32[64,384,3,3]{3,2,1,0} %bitcast.19078), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/VGG16_UNetPP_1/X04_c1_1/convolution/Conv2DBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.8515 - iou_score: 0.7686 - loss: 0.2623 - pixel_accuracy: 0.9724 - precision_smooth: 0.7832 - recall_smooth: 0.9643
# Epoch 1: val_iou_score improved from None to 0.92733, saving model to best_model_unetpp.keras
#
# Epoch 1: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 307s 704ms/step - dice_coefficient: 0.9062 - iou_score: 0.8427 - loss: 0.1484 - pixel_accuracy: 0.9930 - precision_smooth: 0.8509 - recall_smooth: 0.9869 - val_dice_coefficient: 0.9623 - val_iou_score: 0.9273 - val_loss: 0.0634 - val_pixel_accuracy: 0.9984 - val_precision_smooth: 0.9307 - val_recall_smooth: 0.9961 - learning_rate: 1.0000e-04
# Epoch 2/100
# 2026-06-22 16:01:42.613171: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 16:01:42.861986: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 16:01:49.384095: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 16:01:49.658549: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 16:01:57.219613: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 16:01:57.527663: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 5:56:43 61s/step - dice_coefficient: 0.8365 - iou_score: 0.7190 - loss: 0.2130 - pixel_accuracy: 0.9987 - precision_smooth: 0.7218 - recall_smooth: 0.9945
# Epoch 2: val_iou_score did not improve from 0.92733
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 81s 58ms/step - dice_coefficient: 0.8365 - iou_score: 0.7190 - loss: 0.2130 - pixel_accuracy: 0.9987 - precision_smooth: 0.7218 - recall_smooth: 0.9945 - val_dice_coefficient: 0.9622 - val_iou_score: 0.9272 - val_loss: 0.0635 - val_pixel_accuracy: 0.9984 - val_precision_smooth: 0.9308 - val_recall_smooth: 0.9958 - learning_rate: 1.0000e-04
# Epoch 3/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9486 - iou_score: 0.9068 - loss: 0.0748 - pixel_accuracy: 0.9984 - precision_smooth: 0.9110 - recall_smooth: 0.9951
# Epoch 3: val_iou_score improved from 0.92733 to 0.96245, saving model to best_model_unetpp.keras
#
# Epoch 3: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 245s 697ms/step - dice_coefficient: 0.9528 - iou_score: 0.9142 - loss: 0.0681 - pixel_accuracy: 0.9985 - precision_smooth: 0.9181 - recall_smooth: 0.9954 - val_dice_coefficient: 0.9809 - val_iou_score: 0.9625 - val_loss: 0.0323 - val_pixel_accuracy: 0.9987 - val_precision_smooth: 0.9651 - val_recall_smooth: 0.9971 - learning_rate: 1.0000e-04
# Epoch 4/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:53 495ms/step - dice_coefficient: 0.8873 - iou_score: 0.7975 - loss: 0.1447 - pixel_accuracy: 0.9990 - precision_smooth: 0.8007 - recall_smooth: 0.9950
# Epoch 4: val_iou_score did not improve from 0.96245
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - dice_coefficient: 0.8873 - iou_score: 0.7975 - loss: 0.1447 - pixel_accuracy: 0.9990 - precision_smooth: 0.8007 - recall_smooth: 0.9950 - val_dice_coefficient: 0.9804 - val_iou_score: 0.9616 - val_loss: 0.0330 - val_pixel_accuracy: 0.9988 - val_precision_smooth: 0.9645 - val_recall_smooth: 0.9969 - learning_rate: 1.0000e-04
# Epoch 5/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9658 - iou_score: 0.9364 - loss: 0.0490 - pixel_accuracy: 0.9987 - precision_smooth: 0.9397 - recall_smooth: 0.9963
# Epoch 5: val_iou_score improved from 0.96245 to 0.97617, saving model to best_model_unetpp.keras
#
# Epoch 5: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 244s 696ms/step - dice_coefficient: 0.9682 - iou_score: 0.9406 - loss: 0.0454 - pixel_accuracy: 0.9988 - precision_smooth: 0.9438 - recall_smooth: 0.9964 - val_dice_coefficient: 0.9879 - val_iou_score: 0.9762 - val_loss: 0.0206 - val_pixel_accuracy: 0.9989 - val_precision_smooth: 0.9781 - val_recall_smooth: 0.9980 - learning_rate: 1.0000e-04
# Epoch 6/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:55 500ms/step - dice_coefficient: 0.9188 - iou_score: 0.8499 - loss: 0.1035 - pixel_accuracy: 0.9991 - precision_smooth: 0.8541 - recall_smooth: 0.9942
# Epoch 6: val_iou_score did not improve from 0.97617
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - dice_coefficient: 0.9188 - iou_score: 0.8499 - loss: 0.1035 - pixel_accuracy: 0.9991 - precision_smooth: 0.8541 - recall_smooth: 0.9942 - val_dice_coefficient: 0.9872 - val_iou_score: 0.9747 - val_loss: 0.0218 - val_pixel_accuracy: 0.9989 - val_precision_smooth: 0.9769 - val_recall_smooth: 0.9978 - learning_rate: 1.0000e-04
# Epoch 7/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9760 - iou_score: 0.9545 - loss: 0.0343 - pixel_accuracy: 0.9989 - precision_smooth: 0.9573 - recall_smooth: 0.9969
# Epoch 7: val_iou_score improved from 0.97617 to 0.98152, saving model to best_model_unetpp.keras
#
# Epoch 7: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 301s 696ms/step - dice_coefficient: 0.9774 - iou_score: 0.9571 - loss: 0.0322 - pixel_accuracy: 0.9990 - precision_smooth: 0.9598 - recall_smooth: 0.9971 - val_dice_coefficient: 0.9907 - val_iou_score: 0.9815 - val_loss: 0.0161 - val_pixel_accuracy: 0.9991 - val_precision_smooth: 0.9828 - val_recall_smooth: 0.9987 - learning_rate: 1.0000e-04
# Epoch 8/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:55 500ms/step - dice_coefficient: 0.9405 - iou_score: 0.8876 - loss: 0.0756 - pixel_accuracy: 0.9993 - precision_smooth: 0.8902 - recall_smooth: 0.9968
# Epoch 8: val_iou_score did not improve from 0.98152
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - dice_coefficient: 0.9405 - iou_score: 0.8876 - loss: 0.0756 - pixel_accuracy: 0.9993 - precision_smooth: 0.8902 - recall_smooth: 0.9968 - val_dice_coefficient: 0.9905 - val_iou_score: 0.9811 - val_loss: 0.0163 - val_pixel_accuracy: 0.9991 - val_precision_smooth: 0.9826 - val_recall_smooth: 0.9984 - learning_rate: 1.0000e-04
# Epoch 9/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9825 - iou_score: 0.9665 - loss: 0.0249 - pixel_accuracy: 0.9991 - precision_smooth: 0.9688 - recall_smooth: 0.9975
# Epoch 9: val_iou_score improved from 0.98152 to 0.98839, saving model to best_model_unetpp.keras
#
# Epoch 9: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 301s 696ms/step - dice_coefficient: 0.9834 - iou_score: 0.9681 - loss: 0.0236 - pixel_accuracy: 0.9992 - precision_smooth: 0.9704 - recall_smooth: 0.9976 - val_dice_coefficient: 0.9942 - val_iou_score: 0.9884 - val_loss: 0.0106 - val_pixel_accuracy: 0.9991 - val_precision_smooth: 0.9890 - val_recall_smooth: 0.9993 - learning_rate: 1.0000e-04
# Epoch 10/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:55 501ms/step - dice_coefficient: 0.9552 - iou_score: 0.9142 - loss: 0.0568 - pixel_accuracy: 0.9995 - precision_smooth: 0.9160 - recall_smooth: 0.9979
# Prediction after epoch 10
#
#
# Epoch 10: val_iou_score improved from 0.98839 to 0.98846, saving model to best_model_unetpp.keras
#
# Epoch 10: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - dice_coefficient: 0.9552 - iou_score: 0.9142 - loss: 0.0568 - pixel_accuracy: 0.9995 - precision_smooth: 0.9160 - recall_smooth: 0.9979 - val_dice_coefficient: 0.9942 - val_iou_score: 0.9885 - val_loss: 0.0106 - val_pixel_accuracy: 0.9990 - val_precision_smooth: 0.9891 - val_recall_smooth: 0.9994 - learning_rate: 1.0000e-04
# Epoch 11/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9870 - iou_score: 0.9748 - loss: 0.0185 - pixel_accuracy: 0.9993 - precision_smooth: 0.9766 - recall_smooth: 0.9981
# Epoch 11: val_iou_score improved from 0.98846 to 0.99142, saving model to best_model_unetpp.keras
#
# Epoch 11: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 244s 696ms/step - dice_coefficient: 0.9876 - iou_score: 0.9759 - loss: 0.0176 - pixel_accuracy: 0.9994 - precision_smooth: 0.9777 - recall_smooth: 0.9981 - val_dice_coefficient: 0.9957 - val_iou_score: 0.9914 - val_loss: 0.0076 - val_pixel_accuracy: 0.9994 - val_precision_smooth: 0.9922 - val_recall_smooth: 0.9992 - learning_rate: 1.0000e-04
# Epoch 12/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:53 496ms/step - dice_coefficient: 0.9657 - iou_score: 0.9337 - loss: 0.0433 - pixel_accuracy: 0.9996 - precision_smooth: 0.9356 - recall_smooth: 0.9978
# Epoch 12: val_iou_score did not improve from 0.99142
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - dice_coefficient: 0.9657 - iou_score: 0.9337 - loss: 0.0433 - pixel_accuracy: 0.9996 - precision_smooth: 0.9356 - recall_smooth: 0.9978 - val_dice_coefficient: 0.9956 - val_iou_score: 0.9913 - val_loss: 0.0076 - val_pixel_accuracy: 0.9995 - val_precision_smooth: 0.9922 - val_recall_smooth: 0.9991 - learning_rate: 1.0000e-04
# Epoch 13/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9902 - iou_score: 0.9808 - loss: 0.0139 - pixel_accuracy: 0.9995 - precision_smooth: 0.9823 - recall_smooth: 0.9985
# Epoch 13: val_iou_score improved from 0.99142 to 0.99381, saving model to best_model_unetpp.keras
#
# Epoch 13: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 244s 697ms/step - dice_coefficient: 0.9905 - iou_score: 0.9815 - loss: 0.0134 - pixel_accuracy: 0.9995 - precision_smooth: 0.9830 - recall_smooth: 0.9985 - val_dice_coefficient: 0.9969 - val_iou_score: 0.9938 - val_loss: 0.0055 - val_pixel_accuracy: 0.9995 - val_precision_smooth: 0.9942 - val_recall_smooth: 0.9996 - learning_rate: 1.0000e-04
# Epoch 14/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:56 505ms/step - dice_coefficient: 0.9736 - iou_score: 0.9486 - loss: 0.0332 - pixel_accuracy: 0.9998 - precision_smooth: 0.9498 - recall_smooth: 0.9987
# Epoch 14: val_iou_score improved from 0.99381 to 0.99384, saving model to best_model_unetpp.keras
#
# Epoch 14: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 22s 61ms/step - dice_coefficient: 0.9736 - iou_score: 0.9486 - loss: 0.0332 - pixel_accuracy: 0.9998 - precision_smooth: 0.9498 - recall_smooth: 0.9987 - val_dice_coefficient: 0.9969 - val_iou_score: 0.9938 - val_loss: 0.0054 - val_pixel_accuracy: 0.9996 - val_precision_smooth: 0.9944 - val_recall_smooth: 0.9994 - learning_rate: 1.0000e-04
# Epoch 15/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9924 - iou_score: 0.9852 - loss: 0.0107 - pixel_accuracy: 0.9996 - precision_smooth: 0.9863 - recall_smooth: 0.9988
# Epoch 15: val_iou_score improved from 0.99384 to 0.99522, saving model to best_model_unetpp.keras
#
# Epoch 15: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 244s 696ms/step - dice_coefficient: 0.9927 - iou_score: 0.9857 - loss: 0.0102 - pixel_accuracy: 0.9997 - precision_smooth: 0.9868 - recall_smooth: 0.9988 - val_dice_coefficient: 0.9976 - val_iou_score: 0.9952 - val_loss: 0.0042 - val_pixel_accuracy: 0.9996 - val_precision_smooth: 0.9955 - val_recall_smooth: 0.9998 - learning_rate: 1.0000e-04
# Epoch 16/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:54 498ms/step - dice_coefficient: 0.9792 - iou_score: 0.9593 - loss: 0.0261 - pixel_accuracy: 0.9998 - precision_smooth: 0.9604 - recall_smooth: 0.9989
# Epoch 16: val_iou_score improved from 0.99522 to 0.99529, saving model to best_model_unetpp.keras
#
# Epoch 16: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 22s 61ms/step - dice_coefficient: 0.9792 - iou_score: 0.9593 - loss: 0.0261 - pixel_accuracy: 0.9998 - precision_smooth: 0.9604 - recall_smooth: 0.9989 - val_dice_coefficient: 0.9976 - val_iou_score: 0.9953 - val_loss: 0.0041 - val_pixel_accuracy: 0.9997 - val_precision_smooth: 0.9956 - val_recall_smooth: 0.9997 - learning_rate: 1.0000e-04
# Epoch 17/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9942 - iou_score: 0.9886 - loss: 0.0081 - pixel_accuracy: 0.9998 - precision_smooth: 0.9894 - recall_smooth: 0.9991
# Epoch 17: val_iou_score improved from 0.99529 to 0.99682, saving model to best_model_unetpp.keras
#
# Epoch 17: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 244s 697ms/step - dice_coefficient: 0.9944 - iou_score: 0.9889 - loss: 0.0078 - pixel_accuracy: 0.9998 - precision_smooth: 0.9898 - recall_smooth: 0.9992 - val_dice_coefficient: 0.9984 - val_iou_score: 0.9968 - val_loss: 0.0028 - val_pixel_accuracy: 0.9998 - val_precision_smooth: 0.9970 - val_recall_smooth: 0.9998 - learning_rate: 1.0000e-04
# Epoch 18/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:56 503ms/step - dice_coefficient: 0.9837 - iou_score: 0.9679 - loss: 0.0204 - pixel_accuracy: 0.9999 - precision_smooth: 0.9685 - recall_smooth: 0.9994
# Epoch 18: val_iou_score did not improve from 0.99682
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - dice_coefficient: 0.9837 - iou_score: 0.9679 - loss: 0.0204 - pixel_accuracy: 0.9999 - precision_smooth: 0.9685 - recall_smooth: 0.9994 - val_dice_coefficient: 0.9984 - val_iou_score: 0.9968 - val_loss: 0.0028 - val_pixel_accuracy: 0.9998 - val_precision_smooth: 0.9970 - val_recall_smooth: 0.9998 - learning_rate: 1.0000e-04
# Epoch 19/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9955 - iou_score: 0.9911 - loss: 0.0062 - pixel_accuracy: 0.9999 - precision_smooth: 0.9917 - recall_smooth: 0.9994
# Epoch 19: val_iou_score improved from 0.99682 to 0.99729, saving model to best_model_unetpp.keras
#
# Epoch 19: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 244s 696ms/step - dice_coefficient: 0.9956 - iou_score: 0.9914 - loss: 0.0060 - pixel_accuracy: 0.9999 - precision_smooth: 0.9920 - recall_smooth: 0.9994 - val_dice_coefficient: 0.9986 - val_iou_score: 0.9973 - val_loss: 0.0023 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9974 - val_recall_smooth: 0.9998 - learning_rate: 1.0000e-04
# Epoch 20/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:52 494ms/step - dice_coefficient: 0.9871 - iou_score: 0.9745 - loss: 0.0161 - pixel_accuracy: 1.0000 - precision_smooth: 0.9749 - recall_smooth: 0.9996
# Prediction after epoch 20
#
#
# Epoch 20: val_iou_score did not improve from 0.99729
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 22s 60ms/step - dice_coefficient: 0.9871 - iou_score: 0.9745 - loss: 0.0161 - pixel_accuracy: 1.0000 - precision_smooth: 0.9749 - recall_smooth: 0.9996 - val_dice_coefficient: 0.9986 - val_iou_score: 0.9972 - val_loss: 0.0024 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9974 - val_recall_smooth: 0.9998 - learning_rate: 1.0000e-04
# Epoch 21/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9964 - iou_score: 0.9930 - loss: 0.0049 - pixel_accuracy: 0.9999 - precision_smooth: 0.9934 - recall_smooth: 0.9995
# Epoch 21: val_iou_score improved from 0.99729 to 0.99800, saving model to best_model_unetpp.keras
#
# Epoch 21: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 245s 697ms/step - dice_coefficient: 0.9965 - iou_score: 0.9931 - loss: 0.0048 - pixel_accuracy: 0.9999 - precision_smooth: 0.9936 - recall_smooth: 0.9995 - val_dice_coefficient: 0.9990 - val_iou_score: 0.9980 - val_loss: 0.0017 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9981 - val_recall_smooth: 0.9999 - learning_rate: 1.0000e-04
# Epoch 22/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:55 502ms/step - dice_coefficient: 0.9897 - iou_score: 0.9796 - loss: 0.0129 - pixel_accuracy: 1.0000 - precision_smooth: 0.9800 - recall_smooth: 0.9996
# Epoch 22: val_iou_score did not improve from 0.99800
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - dice_coefficient: 0.9897 - iou_score: 0.9796 - loss: 0.0129 - pixel_accuracy: 1.0000 - precision_smooth: 0.9800 - recall_smooth: 0.9996 - val_dice_coefficient: 0.9990 - val_iou_score: 0.9980 - val_loss: 0.0017 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9981 - val_recall_smooth: 0.9999 - learning_rate: 1.0000e-04
# Epoch 23/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9972 - iou_score: 0.9944 - loss: 0.0039 - pixel_accuracy: 0.9999 - precision_smooth: 0.9948 - recall_smooth: 0.9996
# Epoch 23: val_iou_score improved from 0.99800 to 0.99860, saving model to best_model_unetpp.keras
#
# Epoch 23: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 244s 697ms/step - dice_coefficient: 0.9972 - iou_score: 0.9945 - loss: 0.0038 - pixel_accuracy: 0.9999 - precision_smooth: 0.9949 - recall_smooth: 0.9996 - val_dice_coefficient: 0.9993 - val_iou_score: 0.9986 - val_loss: 0.0012 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9987 - val_recall_smooth: 0.9999 - learning_rate: 1.0000e-04
# Epoch 24/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:51 491ms/step - dice_coefficient: 0.9914 - iou_score: 0.9830 - loss: 0.0108 - pixel_accuracy: 0.9999 - precision_smooth: 0.9838 - recall_smooth: 0.9992
# Epoch 24: val_iou_score did not improve from 0.99860
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - dice_coefficient: 0.9914 - iou_score: 0.9830 - loss: 0.0108 - pixel_accuracy: 0.9999 - precision_smooth: 0.9838 - recall_smooth: 0.9992 - val_dice_coefficient: 0.9992 - val_iou_score: 0.9985 - val_loss: 0.0013 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9986 - val_recall_smooth: 0.9999 - learning_rate: 1.0000e-04
# Epoch 25/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9977 - iou_score: 0.9955 - loss: 0.0031 - pixel_accuracy: 0.9999 - precision_smooth: 0.9958 - recall_smooth: 0.9997
# Epoch 25: val_iou_score improved from 0.99860 to 0.99863, saving model to best_model_unetpp.keras
#
# Epoch 25: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 245s 697ms/step - dice_coefficient: 0.9978 - iou_score: 0.9956 - loss: 0.0030 - pixel_accuracy: 0.9999 - precision_smooth: 0.9959 - recall_smooth: 0.9997 - val_dice_coefficient: 0.9993 - val_iou_score: 0.9986 - val_loss: 0.0012 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9987 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-04
# Epoch 26/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:53 497ms/step - dice_coefficient: 0.9932 - iou_score: 0.9865 - loss: 0.0085 - pixel_accuracy: 1.0000 - precision_smooth: 0.9867 - recall_smooth: 0.9997
# Epoch 26: val_iou_score did not improve from 0.99863
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - dice_coefficient: 0.9932 - iou_score: 0.9865 - loss: 0.0085 - pixel_accuracy: 1.0000 - precision_smooth: 0.9867 - recall_smooth: 0.9997 - val_dice_coefficient: 0.9993 - val_iou_score: 0.9986 - val_loss: 0.0012 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9986 - val_recall_smooth: 0.9999 - learning_rate: 1.0000e-04
# Epoch 27/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9981 - iou_score: 0.9962 - loss: 0.0026 - pixel_accuracy: 0.9999 - precision_smooth: 0.9965 - recall_smooth: 0.9997
# Epoch 27: val_iou_score did not improve from 0.99863
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 693ms/step - dice_coefficient: 0.9981 - iou_score: 0.9962 - loss: 0.0027 - pixel_accuracy: 0.9999 - precision_smooth: 0.9965 - recall_smooth: 0.9997 - val_dice_coefficient: 0.9990 - val_iou_score: 0.9980 - val_loss: 0.0019 - val_pixel_accuracy: 0.9998 - val_precision_smooth: 0.9981 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-04
# Epoch 28/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:56 505ms/step - dice_coefficient: 0.9940 - iou_score: 0.9880 - loss: 0.0076 - pixel_accuracy: 0.9999 - precision_smooth: 0.9881 - recall_smooth: 0.9998
# Epoch 28: val_iou_score did not improve from 0.99863
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - dice_coefficient: 0.9940 - iou_score: 0.9880 - loss: 0.0076 - pixel_accuracy: 0.9999 - precision_smooth: 0.9881 - recall_smooth: 0.9998 - val_dice_coefficient: 0.9991 - val_iou_score: 0.9983 - val_loss: 0.0016 - val_pixel_accuracy: 0.9998 - val_precision_smooth: 0.9983 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-04
# Epoch 29/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9985 - iou_score: 0.9970 - loss: 0.0021 - pixel_accuracy: 1.0000 - precision_smooth: 0.9972 - recall_smooth: 0.9998
# Epoch 29: val_iou_score improved from 0.99863 to 0.99907, saving model to best_model_unetpp.keras
#
# Epoch 29: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 244s 696ms/step - dice_coefficient: 0.9985 - iou_score: 0.9970 - loss: 0.0021 - pixel_accuracy: 1.0000 - precision_smooth: 0.9972 - recall_smooth: 0.9998 - val_dice_coefficient: 0.9995 - val_iou_score: 0.9991 - val_loss: 8.0897e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9991 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-05
# Epoch 30/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:55 501ms/step - dice_coefficient: 0.9950 - iou_score: 0.9901 - loss: 0.0062 - pixel_accuracy: 1.0000 - precision_smooth: 0.9903 - recall_smooth: 0.9998
# Prediction after epoch 30
#
#
# Epoch 30: val_iou_score did not improve from 0.99907
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 22s 61ms/step - dice_coefficient: 0.9950 - iou_score: 0.9901 - loss: 0.0062 - pixel_accuracy: 1.0000 - precision_smooth: 0.9903 - recall_smooth: 0.9998 - val_dice_coefficient: 0.9995 - val_iou_score: 0.9991 - val_loss: 8.2015e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9991 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-05
# Epoch 31/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9987 - iou_score: 0.9973 - loss: 0.0018 - pixel_accuracy: 1.0000 - precision_smooth: 0.9975 - recall_smooth: 0.9998
# Epoch 31: val_iou_score improved from 0.99907 to 0.99936, saving model to best_model_unetpp.keras
#
# Epoch 31: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 244s 697ms/step - dice_coefficient: 0.9986 - iou_score: 0.9973 - loss: 0.0018 - pixel_accuracy: 1.0000 - precision_smooth: 0.9975 - recall_smooth: 0.9998 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9994 - val_loss: 5.3628e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-05
# Epoch 32/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:54 498ms/step - dice_coefficient: 0.9955 - iou_score: 0.9911 - loss: 0.0056 - pixel_accuracy: 1.0000 - precision_smooth: 0.9913 - recall_smooth: 0.9998
# Epoch 32: val_iou_score did not improve from 0.99936
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - dice_coefficient: 0.9955 - iou_score: 0.9911 - loss: 0.0056 - pixel_accuracy: 1.0000 - precision_smooth: 0.9913 - recall_smooth: 0.9998 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9994 - val_loss: 5.4423e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-05
# Epoch 33/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9988 - iou_score: 0.9976 - loss: 0.0016 - pixel_accuracy: 1.0000 - precision_smooth: 0.9977 - recall_smooth: 0.9999
# Epoch 33: val_iou_score improved from 0.99936 to 0.99941, saving model to best_model_unetpp.keras
#
# Epoch 33: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 244s 696ms/step - dice_coefficient: 0.9988 - iou_score: 0.9976 - loss: 0.0016 - pixel_accuracy: 1.0000 - precision_smooth: 0.9977 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9994 - val_loss: 5.0749e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-05
# Epoch 34/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:53 497ms/step - dice_coefficient: 0.9959 - iou_score: 0.9918 - loss: 0.0052 - pixel_accuracy: 1.0000 - precision_smooth: 0.9922 - recall_smooth: 0.9995
# Epoch 34: val_iou_score did not improve from 0.99941
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - dice_coefficient: 0.9959 - iou_score: 0.9918 - loss: 0.0052 - pixel_accuracy: 1.0000 - precision_smooth: 0.9922 - recall_smooth: 0.9995 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9994 - val_loss: 5.1099e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-05
# Epoch 35/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9989 - iou_score: 0.9979 - loss: 0.0014 - pixel_accuracy: 1.0000 - precision_smooth: 0.9980 - recall_smooth: 0.9999
# Epoch 35: val_iou_score did not improve from 0.99941
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 693ms/step - dice_coefficient: 0.9989 - iou_score: 0.9979 - loss: 0.0014 - pixel_accuracy: 1.0000 - precision_smooth: 0.9980 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 5.8190e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9993 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-05
# Epoch 36/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:55 500ms/step - dice_coefficient: 0.9964 - iou_score: 0.9929 - loss: 0.0045 - pixel_accuracy: 1.0000 - precision_smooth: 0.9931 - recall_smooth: 0.9998
# Epoch 36: val_iou_score did not improve from 0.99941
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - dice_coefficient: 0.9964 - iou_score: 0.9929 - loss: 0.0045 - pixel_accuracy: 1.0000 - precision_smooth: 0.9931 - recall_smooth: 0.9998 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.1257e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9993 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-05
# Epoch 37/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9991 - iou_score: 0.9981 - loss: 0.0013 - pixel_accuracy: 1.0000 - precision_smooth: 0.9982 - recall_smooth: 0.9999
# Epoch 37: val_iou_score improved from 0.99941 to 0.99953, saving model to best_model_unetpp.keras
#
# Epoch 37: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 244s 696ms/step - dice_coefficient: 0.9990 - iou_score: 0.9981 - loss: 0.0013 - pixel_accuracy: 1.0000 - precision_smooth: 0.9982 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9995 - val_loss: 4.0393e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9995 - val_recall_smooth: 1.0000 - learning_rate: 2.5000e-05
# Epoch 38/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:53 495ms/step - dice_coefficient: 0.9966 - iou_score: 0.9932 - loss: 0.0043 - pixel_accuracy: 1.0000 - precision_smooth: 0.9936 - recall_smooth: 0.9997
# Epoch 38: val_iou_score did not improve from 0.99953
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - dice_coefficient: 0.9966 - iou_score: 0.9932 - loss: 0.0043 - pixel_accuracy: 1.0000 - precision_smooth: 0.9936 - recall_smooth: 0.9997 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9995 - val_loss: 4.1537e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9995 - val_recall_smooth: 1.0000 - learning_rate: 2.5000e-05
# Epoch 39/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9991 - iou_score: 0.9983 - loss: 0.0012 - pixel_accuracy: 1.0000 - precision_smooth: 0.9983 - recall_smooth: 0.9999
# Epoch 39: val_iou_score did not improve from 0.99953
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 693ms/step - dice_coefficient: 0.9991 - iou_score: 0.9982 - loss: 0.0012 - pixel_accuracy: 1.0000 - precision_smooth: 0.9983 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9995 - val_loss: 4.3897e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9995 - val_recall_smooth: 1.0000 - learning_rate: 2.5000e-05
# Epoch 40/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:53 495ms/step - dice_coefficient: 0.9969 - iou_score: 0.9939 - loss: 0.0038 - pixel_accuracy: 1.0000 - precision_smooth: 0.9939 - recall_smooth: 1.0000
# Prediction after epoch 40
#
#
# Epoch 40: val_iou_score did not improve from 0.99953
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 22s 61ms/step - dice_coefficient: 0.9969 - iou_score: 0.9939 - loss: 0.0038 - pixel_accuracy: 1.0000 - precision_smooth: 0.9939 - recall_smooth: 1.0000 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9995 - val_loss: 4.3021e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9995 - val_recall_smooth: 1.0000 - learning_rate: 2.5000e-05
# Epoch 41/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9992 - iou_score: 0.9984 - loss: 0.0011 - pixel_accuracy: 1.0000 - precision_smooth: 0.9985 - recall_smooth: 0.9999
# Epoch 41: val_iou_score did not improve from 0.99953
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 693ms/step - dice_coefficient: 0.9992 - iou_score: 0.9983 - loss: 0.0011 - pixel_accuracy: 1.0000 - precision_smooth: 0.9984 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9994 - val_loss: 5.3931e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 2.5000e-05
# Epoch 42/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:53 496ms/step - dice_coefficient: 0.9971 - iou_score: 0.9943 - loss: 0.0036 - pixel_accuracy: 1.0000 - precision_smooth: 0.9944 - recall_smooth: 0.9999
# Epoch 42: val_iou_score did not improve from 0.99953
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - dice_coefficient: 0.9971 - iou_score: 0.9943 - loss: 0.0036 - pixel_accuracy: 1.0000 - precision_smooth: 0.9944 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9994 - val_loss: 5.0360e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 2.5000e-05
# Epoch 43/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9992 - iou_score: 0.9985 - loss: 0.0010 - pixel_accuracy: 1.0000 - precision_smooth: 0.9986 - recall_smooth: 0.9999
# Epoch 43: val_iou_score improved from 0.99953 to 0.99956, saving model to best_model_unetpp.keras
#
# Epoch 43: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 244s 696ms/step - dice_coefficient: 0.9992 - iou_score: 0.9984 - loss: 0.0010 - pixel_accuracy: 1.0000 - precision_smooth: 0.9985 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.8677e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.2500e-05
# Epoch 44/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:54 499ms/step - dice_coefficient: 0.9973 - iou_score: 0.9946 - loss: 0.0034 - pixel_accuracy: 1.0000 - precision_smooth: 0.9946 - recall_smooth: 1.0000
# Epoch 44: val_iou_score did not improve from 0.99956
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - dice_coefficient: 0.9973 - iou_score: 0.9946 - loss: 0.0034 - pixel_accuracy: 1.0000 - precision_smooth: 0.9946 - recall_smooth: 1.0000 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.9144e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.2500e-05
# Epoch 45/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9993 - iou_score: 0.9986 - loss: 9.6845e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9986 - recall_smooth: 0.9999
# Epoch 45: val_iou_score improved from 0.99956 to 0.99958, saving model to best_model_unetpp.keras
#
# Epoch 45: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 245s 698ms/step - dice_coefficient: 0.9993 - iou_score: 0.9985 - loss: 9.8950e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9986 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.6773e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.2500e-05
# Epoch 46/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:55 500ms/step - dice_coefficient: 0.9974 - iou_score: 0.9947 - loss: 0.0033 - pixel_accuracy: 1.0000 - precision_smooth: 0.9949 - recall_smooth: 0.9999
# Epoch 46: val_iou_score did not improve from 0.99958
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - dice_coefficient: 0.9974 - iou_score: 0.9947 - loss: 0.0033 - pixel_accuracy: 1.0000 - precision_smooth: 0.9949 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.7209e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.2500e-05
# Epoch 47/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9993 - iou_score: 0.9986 - loss: 9.2627e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9987 - recall_smooth: 0.9999
# Epoch 47: val_iou_score did not improve from 0.99958
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 693ms/step - dice_coefficient: 0.9993 - iou_score: 0.9986 - loss: 9.4690e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9987 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9995 - val_loss: 4.2260e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9995 - val_recall_smooth: 1.0000 - learning_rate: 1.2500e-05
# Epoch 48/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:54 500ms/step - dice_coefficient: 0.9975 - iou_score: 0.9950 - loss: 0.0031 - pixel_accuracy: 1.0000 - precision_smooth: 0.9951 - recall_smooth: 0.9999
# Epoch 48: val_iou_score did not improve from 0.99958
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - dice_coefficient: 0.9975 - iou_score: 0.9950 - loss: 0.0031 - pixel_accuracy: 1.0000 - precision_smooth: 0.9951 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9995 - val_loss: 4.2839e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9995 - val_recall_smooth: 1.0000 - learning_rate: 6.2500e-06
# Epoch 49/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9993 - iou_score: 0.9987 - loss: 8.8441e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9987 - recall_smooth: 0.9999
# Epoch 49: val_iou_score did not improve from 0.99958
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 693ms/step - dice_coefficient: 0.9993 - iou_score: 0.9986 - loss: 9.1015e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9987 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9995 - val_loss: 4.5023e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9995 - val_recall_smooth: 1.0000 - learning_rate: 6.2500e-06
# Epoch 50/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:56 505ms/step - dice_coefficient: 0.9976 - iou_score: 0.9951 - loss: 0.0030 - pixel_accuracy: 1.0000 - precision_smooth: 0.9952 - recall_smooth: 0.9999
# Prediction after epoch 50
#
#
# Epoch 50: val_iou_score did not improve from 0.99958
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 22s 60ms/step - dice_coefficient: 0.9976 - iou_score: 0.9951 - loss: 0.0030 - pixel_accuracy: 1.0000 - precision_smooth: 0.9952 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9995 - val_loss: 4.5239e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9995 - val_recall_smooth: 1.0000 - learning_rate: 6.2500e-06
# Epoch 51/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9994 - iou_score: 0.9987 - loss: 8.5519e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9988 - recall_smooth: 0.9999
# Epoch 51: val_iou_score did not improve from 0.99958
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 693ms/step - dice_coefficient: 0.9993 - iou_score: 0.9987 - loss: 8.7742e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9987 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.9713e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 6.2500e-06
# Epoch 52/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:55 503ms/step - dice_coefficient: 0.9977 - iou_score: 0.9953 - loss: 0.0029 - pixel_accuracy: 1.0000 - precision_smooth: 0.9953 - recall_smooth: 1.0000
# Epoch 52: val_iou_score did not improve from 0.99958
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - dice_coefficient: 0.9977 - iou_score: 0.9953 - loss: 0.0029 - pixel_accuracy: 1.0000 - precision_smooth: 0.9953 - recall_smooth: 1.0000 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9995 - val_loss: 4.2298e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9995 - val_recall_smooth: 1.0000 - learning_rate: 6.2500e-06
# Epoch 53/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9994 - iou_score: 0.9987 - loss: 8.3944e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9988 - recall_smooth: 0.9999
# Epoch 53: val_iou_score did not improve from 0.99958
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 693ms/step - dice_coefficient: 0.9994 - iou_score: 0.9987 - loss: 8.6173e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9988 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 4.0365e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 3.1250e-06
# Epoch 54/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:56 504ms/step - dice_coefficient: 0.9977 - iou_score: 0.9954 - loss: 0.0029 - pixel_accuracy: 1.0000 - precision_smooth: 0.9954 - recall_smooth: 1.0000
# Epoch 54: val_iou_score did not improve from 0.99958
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - dice_coefficient: 0.9977 - iou_score: 0.9954 - loss: 0.0029 - pixel_accuracy: 1.0000 - precision_smooth: 0.9954 - recall_smooth: 1.0000 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 4.0860e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 3.1250e-06
# Epoch 55/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 8.2451e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9988 - recall_smooth: 0.9999
# Epoch 55: val_iou_score improved from 0.99958 to 0.99961, saving model to best_model_unetpp.keras
#
# Epoch 55: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 244s 696ms/step - dice_coefficient: 0.9994 - iou_score: 0.9987 - loss: 8.4840e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9988 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.4622e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 3.1250e-06
# Epoch 56/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:53 495ms/step - dice_coefficient: 0.9977 - iou_score: 0.9955 - loss: 0.0028 - pixel_accuracy: 1.0000 - precision_smooth: 0.9955 - recall_smooth: 1.0000
# Epoch 56: val_iou_score did not improve from 0.99961
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - dice_coefficient: 0.9977 - iou_score: 0.9955 - loss: 0.0028 - pixel_accuracy: 1.0000 - precision_smooth: 0.9955 - recall_smooth: 1.0000 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.4890e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 3.1250e-06
# Epoch 57/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 8.0494e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9988 - recall_smooth: 0.9999
# Epoch 57: val_iou_score did not improve from 0.99961
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 693ms/step - dice_coefficient: 0.9994 - iou_score: 0.9987 - loss: 8.3378e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9988 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9995 - val_loss: 4.3264e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9995 - val_recall_smooth: 1.0000 - learning_rate: 3.1250e-06
# Epoch 58/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:52 493ms/step - dice_coefficient: 0.9977 - iou_score: 0.9955 - loss: 0.0028 - pixel_accuracy: 1.0000 - precision_smooth: 0.9955 - recall_smooth: 0.9999
# Epoch 58: val_iou_score did not improve from 0.99961
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - dice_coefficient: 0.9977 - iou_score: 0.9955 - loss: 0.0028 - pixel_accuracy: 1.0000 - precision_smooth: 0.9955 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9995 - val_loss: 4.3907e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9995 - val_recall_smooth: 1.0000 - learning_rate: 1.5625e-06
# Epoch 59/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 7.9255e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 1.0000
# Epoch 59: val_iou_score improved from 0.99961 to 0.99962, saving model to best_model_unetpp.keras
#
# Epoch 59: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 244s 696ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 8.1277e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9988 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.4009e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.5625e-06
# Epoch 60/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:56 504ms/step - dice_coefficient: 0.9978 - iou_score: 0.9955 - loss: 0.0028 - pixel_accuracy: 1.0000 - precision_smooth: 0.9956 - recall_smooth: 0.9999
# Prediction after epoch 60
#
#
# Epoch 60: val_iou_score did not improve from 0.99962
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 22s 61ms/step - dice_coefficient: 0.9978 - iou_score: 0.9955 - loss: 0.0028 - pixel_accuracy: 1.0000 - precision_smooth: 0.9956 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.4229e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.5625e-06
# Epoch 61/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 7.8406e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 0.9999
# Epoch 61: val_iou_score improved from 0.99962 to 0.99965, saving model to best_model_unetpp.keras
#
# Epoch 61: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 244s 697ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 8.0749e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9988 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.1615e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9997 - val_recall_smooth: 1.0000 - learning_rate: 1.5625e-06
# Epoch 62/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:54 498ms/step - dice_coefficient: 0.9978 - iou_score: 0.9956 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9956 - recall_smooth: 1.0000
# Epoch 62: val_iou_score did not improve from 0.99965
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - dice_coefficient: 0.9978 - iou_score: 0.9956 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9956 - recall_smooth: 1.0000 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.1840e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.5625e-06
# Epoch 63/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 7.7599e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 0.9999
# Epoch 63: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 693ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 8.0198e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9988 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.6441e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 7.8125e-07
# Epoch 64/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:52 494ms/step - dice_coefficient: 0.9978 - iou_score: 0.9956 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 1.0000
# Epoch 64: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - dice_coefficient: 0.9978 - iou_score: 0.9956 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 1.0000 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.6765e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 7.8125e-07
# Epoch 65/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 7.7239e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 1.0000
# Epoch 65: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 692ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 7.9773e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9988 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.5958e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 7.8125e-07
# Epoch 66/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:56 504ms/step - dice_coefficient: 0.9978 - iou_score: 0.9956 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9956 - recall_smooth: 1.0000
# Epoch 66: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - dice_coefficient: 0.9978 - iou_score: 0.9956 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9956 - recall_smooth: 1.0000 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.6331e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 7.8125e-07
# Epoch 67/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 7.6929e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 1.0000
# Epoch 67: val_iou_score did not improve from 0.99965
#
# ...
# Epoch 76/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:52 493ms/step - dice_coefficient: 0.9978 - iou_score: 0.9957 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 1.0000
# Epoch 76: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - dice_coefficient: 0.9978 - iou_score: 0.9957 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 1.0000 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.2788e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.9531e-07
# Epoch 77/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9994 - iou_score: 0.9989 - loss: 7.6118e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 1.0000
# Epoch 77: val_iou_score did not improve from 0.99965
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 1e-07.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 693ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 7.8896e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.4321e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.9531e-07
# Epoch 78/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:51 490ms/step - dice_coefficient: 0.9978 - iou_score: 0.9956 - loss: 0.0028 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 0.9999
# Epoch 78: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - dice_coefficient: 0.9978 - iou_score: 0.9956 - loss: 0.0028 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.4681e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 79/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9994 - iou_score: 0.9989 - loss: 7.6437e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 1.0000
# Epoch 79: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 694ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 7.8619e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.2417e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 80/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:55 502ms/step - dice_coefficient: 0.9978 - iou_score: 0.9957 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 1.0000
# Prediction after epoch 80
#
#
# Epoch 80: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 22s 62ms/step - dice_coefficient: 0.9978 - iou_score: 0.9957 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 1.0000 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.2834e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 81/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - dice_coefficient: 0.9994 - iou_score: 0.9989 - loss: 7.5982e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 1.0000
# Epoch 81: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 693ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 7.8291e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.2700e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 82/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:53 495ms/step - dice_coefficient: 0.9978 - iou_score: 0.9957 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 0.9999
# Epoch 82: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - dice_coefficient: 0.9978 - iou_score: 0.9957 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.3030e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 83/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9994 - iou_score: 0.9989 - loss: 7.6011e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 1.0000
# Epoch 83: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 694ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 7.8682e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.2658e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 84/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:52 493ms/step - dice_coefficient: 0.9979 - iou_score: 0.9957 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 1.0000
# Epoch 84: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - dice_coefficient: 0.9979 - iou_score: 0.9957 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 1.0000 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.3070e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 85/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9994 - iou_score: 0.9989 - loss: 7.5600e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 1.0000
# Epoch 85: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 694ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 7.7849e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 1.0000 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.2590e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 86/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:55 501ms/step - dice_coefficient: 0.9979 - iou_score: 0.9957 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 1.0000
# Epoch 86: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - dice_coefficient: 0.9979 - iou_score: 0.9957 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 1.0000 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.2949e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 87/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9994 - iou_score: 0.9989 - loss: 7.5818e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 1.0000
# Epoch 87: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 693ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 7.8168e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.2329e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 88/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:53 496ms/step - dice_coefficient: 0.9978 - iou_score: 0.9957 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 0.9999
# Epoch 88: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - dice_coefficient: 0.9978 - iou_score: 0.9957 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.2690e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 89/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9994 - iou_score: 0.9989 - loss: 7.6353e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 0.9999
# Epoch 89: val_iou_score improved from 0.99965 to 0.99965, saving model to best_model_unetpp.keras
#
# Epoch 89: finished saving model to best_model_unetpp.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 245s 698ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 7.8407e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.1707e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9997 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 90/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:54 499ms/step - dice_coefficient: 0.9978 - iou_score: 0.9956 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 0.9999
# Prediction after epoch 90
#
#
# Epoch 90: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 22s 62ms/step - dice_coefficient: 0.9978 - iou_score: 0.9956 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.2154e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 91/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9994 - iou_score: 0.9989 - loss: 7.6080e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 0.9999
# Epoch 91: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 693ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 7.8647e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.3083e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 92/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:55 502ms/step - dice_coefficient: 0.9979 - iou_score: 0.9957 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 1.0000
# Epoch 92: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - dice_coefficient: 0.9979 - iou_score: 0.9957 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 1.0000 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.3514e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 93/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9994 - iou_score: 0.9989 - loss: 7.5626e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 1.0000
# Epoch 93: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 693ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 7.8097e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.3126e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 94/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:54 498ms/step - dice_coefficient: 0.9978 - iou_score: 0.9956 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 0.9999
# Epoch 94: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - dice_coefficient: 0.9978 - iou_score: 0.9956 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.3557e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 95/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9994 - iou_score: 0.9989 - loss: 7.5597e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 1.0000
# Epoch 95: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 694ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 7.8220e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.2388e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 96/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:51 491ms/step - dice_coefficient: 0.9978 - iou_score: 0.9957 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9958 - recall_smooth: 0.9999
# Epoch 96: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - dice_coefficient: 0.9978 - iou_score: 0.9957 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9958 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.2792e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 97/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9994 - iou_score: 0.9989 - loss: 7.5810e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 1.0000
# Epoch 97: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 694ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 7.8379e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.2853e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 98/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:53 496ms/step - dice_coefficient: 0.9978 - iou_score: 0.9957 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9958 - recall_smooth: 0.9999
# Epoch 98: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - dice_coefficient: 0.9978 - iou_score: 0.9957 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9958 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.3163e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 99/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - dice_coefficient: 0.9994 - iou_score: 0.9989 - loss: 7.5306e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 1.0000
# Epoch 99: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 243s 694ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 7.7868e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9989 - recall_smooth: 1.0000 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.2618e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 100/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:53 494ms/step - dice_coefficient: 0.9978 - iou_score: 0.9957 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 0.9999
# Prediction after epoch 100
#
#
# Epoch 100: val_iou_score did not improve from 0.99965
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 22s 61ms/step - dice_coefficient: 0.9978 - iou_score: 0.9957 - loss: 0.0027 - pixel_accuracy: 1.0000 - precision_smooth: 0.9957 - recall_smooth: 0.9999 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9996 - val_loss: 3.3041e-04 - val_pixel_accuracy: 1.0000 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
#
# Training time: 224.8 min

# %% [markdown]
# ## 13. Training Graphs

# %%
H = history.history

fig, axes = plt.subplots(3, 2, figsize=(14, 16))
fig.suptitle('VGG16-UNet++  |  Alzheimer MRI Segmentation  |  Training History',
             fontsize=15, fontweight='bold', y=0.98)

plot_specs = [
    ('loss',             'val_loss',             'Loss (Dice + BCE)',      'Loss',     'upper right'),
    ('dice_coefficient', 'val_dice_coefficient', 'Dice Coefficient',       'Dice',     'lower right'),
    ('iou_score',        'val_iou_score',        'IoU / Jaccard Index',    'IoU',      'lower right'),
    ('precision_smooth', 'val_precision_smooth', 'Precision',              'Precision','lower right'),
    ('recall_smooth',    'val_recall_smooth',    'Recall',                 'Recall',   'lower right'),
    ('pixel_accuracy',   'val_pixel_accuracy',   'Pixel Accuracy',         'Accuracy', 'lower right'),
]

for ax, (train_key, val_key, title, ylabel, loc) in zip(axes.flatten(), plot_specs):
    epochs_range = range(1, len(H[train_key]) + 1)
    ax.plot(epochs_range, H[train_key], label='Train',      color='steelblue',   linewidth=2)
    ax.plot(epochs_range, H[val_key],   label='Validation', color='darkorange',  linewidth=2, linestyle='--')
    ax.set_title(title, fontsize=12, fontweight='bold')
    ax.set_xlabel('Epoch')
    ax.set_ylabel(ylabel)
    ax.legend(loc=loc, fontsize=10)
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('training_history_unetpp.png', dpi=150, bbox_inches='tight')
plt.show()
print('Plot saved → training_history_unetpp.png')
# Out:
# Plot saved → training_history_unetpp.png

# %% [markdown]
# ## 14. Best & Average Metrics Table

# %%
metric_spec = [
    ('Loss',           'loss',             'min'),
    ('Dice',           'dice_coefficient', 'max'),
    ('IoU (Jaccard)',  'iou_score',        'max'),
    ('Precision',      'precision_smooth', 'max'),
    ('Recall',         'recall_smooth',    'max'),
    ('Pixel Accuracy', 'pixel_accuracy',   'max'),
]

rows = []
for disp, key, mode in metric_spec:
    tr = np.asarray(H[key],          dtype=np.float64)
    va = np.asarray(H['val_' + key], dtype=np.float64)
    pick = np.min if mode == 'min' else np.max
    rows.append({
        'Metric':     disp,
        'Train Best': pick(tr), 'Train Avg': tr.mean(),
        'Val Best':   pick(va), 'Val Avg':   va.mean(),
    })

def f1_curve(p, r):
    p = np.asarray(p, dtype=np.float64); r = np.asarray(r, dtype=np.float64)
    return 2.0 * p * r / (p + r + 1e-7)

tr_f1 = f1_curve(H['precision_smooth'],     H['recall_smooth'])
va_f1 = f1_curve(H['val_precision_smooth'], H['val_recall_smooth'])
rows.append({'Metric': 'F1-Score',
             'Train Best': tr_f1.max(), 'Train Avg': tr_f1.mean(),
             'Val Best':   va_f1.max(), 'Val Avg':   va_f1.mean()})

report = pd.DataFrame(rows).set_index('Metric').round(4)

print('=' * 68)
print('   BEST & AVERAGE METRICS  —  VGG16-UNet++  |  OASIS disc1+disc2')
print('=' * 68)
print(report.to_string())
print('=' * 68)

best_epoch_iou  = int(np.argmax(H['val_iou_score']))  + 1
best_epoch_dice = int(np.argmax(H['val_dice_coefficient'])) + 1
print(f'\nBest Val IoU : {max(H["val_iou_score"]):.4f}  (epoch {best_epoch_iou})')
print(f'Best Val Dice: {max(H["val_dice_coefficient"]):.4f}  (epoch {best_epoch_dice})')

report
# Out:
# ====================================================================
#    BEST & AVERAGE METRICS  —  VGG16-UNet++  |  OASIS disc1+disc2
# ====================================================================
#                 Train Best  Train Avg  Val Best  Val Avg
# Metric
# Loss                0.0008     0.0131    0.0003   0.0037
# Dice                0.9994     0.9902    0.9998   0.9978
# IoU (Jaccard)       0.9988     0.9818    0.9996   0.9957
# Precision           0.9989     0.9823    0.9997   0.9960
# Recall              1.0000     0.9993    1.0000   0.9997
# Pixel Accuracy      1.0000     0.9998    1.0000   0.9998
# F1-Score            0.9994     0.9903    0.9998   0.9978
# ====================================================================
#
# Best Val IoU : 0.9996  (epoch 89)
# Best Val Dice: 0.9998  (epoch 89)
#                 Train Best  Train Avg  Val Best  Val Avg
# Metric
# Loss                0.0008     0.0131    0.0003   0.0037
# Dice                0.9994     0.9902    0.9998   0.9978
# IoU (Jaccard)       0.9988     0.9818    0.9996   0.9957
# Precision           0.9989     0.9823    0.9997   0.9960
# Recall              1.0000     0.9993    1.0000   0.9997
# Pixel Accuracy      1.0000     0.9998    1.0000   0.9998
# F1-Score            0.9994     0.9903    0.9998   0.9978

# %% [markdown]
# ## 15. Load Best Model & Final Evaluation

# %%
best_model = tf.keras.models.load_model(
    'best_model_unetpp.keras',
    custom_objects={
        'combined_loss':   combined_loss,
        'dice_coefficient': dice_coefficient,
        'iou_score':        iou_score,
        'precision_smooth': precision_smooth,
        'recall_smooth':    recall_smooth,
        'pixel_accuracy':   pixel_accuracy,
    }
)
print('Best model loaded ✓')
best_model.summary()
# Out:
# Best model loaded ✓
# Model: "VGG16_UNetPP"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 224, 224,  │          0 │ -                 │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 224, 224,  │      1,792 │ input[0][0]       │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 224, 224,  │     36,928 │ block1_conv1[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 112, 112,  │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 112, 112,  │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 112, 112,  │    147,584 │ block2_conv1[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 56, 56,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 56, 56,    │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 56, 56,    │    590,080 │ block3_conv1[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 56, 56,    │    590,080 │ block3_conv2[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 28, 28,    │          0 │ block3_conv3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 28, 28,    │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 28, 28,    │  2,359,808 │ block4_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 28, 28,    │  2,359,808 │ block4_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 14, 14,    │          0 │ block4_conv3[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 14, 14,    │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 14, 14,    │  2,359,808 │ block5_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 14, 14,    │  2,359,808 │ block5_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up40_31             │ (None, 28, 28,    │          0 │ block5_conv3[0][… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up30_21             │ (None, 56, 56,    │          0 │ block4_conv3[0][… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 28, 28,    │          0 │ block4_conv3[0][… │
# │ (Concatenate)       │ 1024)             │            │ up40_31[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up20_11             │ (None, 112, 112,  │          0 │ block3_conv3[0][… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 56, 56,    │          0 │ block3_conv3[0][… │
# │ (Concatenate)       │ 768)              │            │ up30_21[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_c1 (Conv2D)     │ (None, 28, 28,    │  4,719,104 │ concatenate_3[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up10_01             │ (None, 224, 224,  │          0 │ block2_conv2[0][… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 112, 112,  │          0 │ block2_conv2[0][… │
# │ (Concatenate)       │ 384)              │            │ up20_11[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_c1 (Conv2D)     │ (None, 56, 56,    │  1,769,728 │ concatenate_2[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_bn1             │ (None, 28, 28,    │      2,048 │ X31_c1[0][0]      │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 224, 224,  │          0 │ block1_conv2[0][… │
# │ (Concatenate)       │ 192)              │            │ up10_01[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_c1 (Conv2D)     │ (None, 112, 112,  │    442,496 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_bn1             │ (None, 56, 56,    │      1,024 │ X21_c1[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_act1            │ (None, 28, 28,    │          0 │ X31_bn1[0][0]     │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_c1 (Conv2D)     │ (None, 224, 224,  │    110,656 │ concatenate[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_bn1             │ (None, 112, 112,  │        512 │ X11_c1[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_act1            │ (None, 56, 56,    │          0 │ X21_bn1[0][0]     │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_c2 (Conv2D)     │ (None, 28, 28,    │  2,359,808 │ X31_act1[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_bn1             │ (None, 224, 224,  │        256 │ X01_c1[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_act1            │ (None, 112, 112,  │          0 │ X11_bn1[0][0]     │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_c2 (Conv2D)     │ (None, 56, 56,    │    590,080 │ X21_act1[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_bn2             │ (None, 28, 28,    │      2,048 │ X31_c2[0][0]      │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_act1            │ (None, 224, 224,  │          0 │ X01_bn1[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_c2 (Conv2D)     │ (None, 112, 112,  │    147,584 │ X11_act1[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_bn2             │ (None, 56, 56,    │      1,024 │ X21_c2[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X31_act2            │ (None, 28, 28,    │          0 │ X31_bn2[0][0]     │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_c2 (Conv2D)     │ (None, 224, 224,  │     36,928 │ X01_act1[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_bn2             │ (None, 112, 112,  │        512 │ X11_c2[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X21_act2            │ (None, 56, 56,    │          0 │ X21_bn2[0][0]     │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up31_22             │ (None, 56, 56,    │          0 │ X31_act2[0][0]    │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_bn2             │ (None, 224, 224,  │        256 │ X01_c2[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X11_act2            │ (None, 112, 112,  │          0 │ X11_bn2[0][0]     │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up21_12             │ (None, 112, 112,  │          0 │ X21_act2[0][0]    │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 56, 56,    │          0 │ block3_conv3[0][… │
# │ (Concatenate)       │ 1024)             │            │ X21_act2[0][0],   │
# │                     │                   │            │ up31_22[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X01_act2            │ (None, 224, 224,  │          0 │ X01_bn2[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up11_02             │ (None, 224, 224,  │          0 │ X11_act2[0][0]    │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 112, 112,  │          0 │ block2_conv2[0][… │
# │ (Concatenate)       │ 512)              │            │ X11_act2[0][0],   │
# │                     │                   │            │ up21_12[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_c1 (Conv2D)     │ (None, 56, 56,    │  2,359,552 │ concatenate_6[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 224, 224,  │          0 │ block1_conv2[0][… │
# │ (Concatenate)       │ 256)              │            │ X01_act2[0][0],   │
# │                     │                   │            │ up11_02[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_c1 (Conv2D)     │ (None, 112, 112,  │    589,952 │ concatenate_5[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_bn1             │ (None, 56, 56,    │      1,024 │ X22_c1[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_c1 (Conv2D)     │ (None, 224, 224,  │    147,520 │ concatenate_4[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_bn1             │ (None, 112, 112,  │        512 │ X12_c1[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_act1            │ (None, 56, 56,    │          0 │ X22_bn1[0][0]     │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_bn1             │ (None, 224, 224,  │        256 │ X02_c1[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_act1            │ (None, 112, 112,  │          0 │ X12_bn1[0][0]     │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_c2 (Conv2D)     │ (None, 56, 56,    │    590,080 │ X22_act1[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_act1            │ (None, 224, 224,  │          0 │ X02_bn1[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_c2 (Conv2D)     │ (None, 112, 112,  │    147,584 │ X12_act1[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_bn2             │ (None, 56, 56,    │      1,024 │ X22_c2[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_c2 (Conv2D)     │ (None, 224, 224,  │     36,928 │ X02_act1[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_bn2             │ (None, 112, 112,  │        512 │ X12_c2[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X22_act2            │ (None, 56, 56,    │          0 │ X22_bn2[0][0]     │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_bn2             │ (None, 224, 224,  │        256 │ X02_c2[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X12_act2            │ (None, 112, 112,  │          0 │ X12_bn2[0][0]     │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up22_13             │ (None, 112, 112,  │          0 │ X22_act2[0][0]    │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X02_act2            │ (None, 224, 224,  │          0 │ X02_bn2[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up12_03             │ (None, 224, 224,  │          0 │ X12_act2[0][0]    │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 112, 112,  │          0 │ block2_conv2[0][… │
# │ (Concatenate)       │ 640)              │            │ X11_act2[0][0],   │
# │                     │                   │            │ X12_act2[0][0],   │
# │                     │                   │            │ up22_13[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 224, 224,  │          0 │ block1_conv2[0][… │
# │ (Concatenate)       │ 320)              │            │ X01_act2[0][0],   │
# │                     │                   │            │ X02_act2[0][0],   │
# │                     │                   │            │ up12_03[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_c1 (Conv2D)     │ (None, 112, 112,  │    737,408 │ concatenate_8[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_c1 (Conv2D)     │ (None, 224, 224,  │    184,384 │ concatenate_7[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_bn1             │ (None, 112, 112,  │        512 │ X13_c1[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_bn1             │ (None, 224, 224,  │        256 │ X03_c1[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_act1            │ (None, 112, 112,  │          0 │ X13_bn1[0][0]     │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_act1            │ (None, 224, 224,  │          0 │ X03_bn1[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_c2 (Conv2D)     │ (None, 112, 112,  │    147,584 │ X13_act1[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_c2 (Conv2D)     │ (None, 224, 224,  │     36,928 │ X03_act1[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_bn2             │ (None, 112, 112,  │        512 │ X13_c2[0][0]      │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_bn2             │ (None, 224, 224,  │        256 │ X03_c2[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X13_act2            │ (None, 112, 112,  │          0 │ X13_bn2[0][0]     │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X03_act2            │ (None, 224, 224,  │          0 │ X03_bn2[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up13_04             │ (None, 224, 224,  │          0 │ X13_act2[0][0]    │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 224, 224,  │          0 │ block1_conv2[0][… │
# │ (Concatenate)       │ 384)              │            │ X01_act2[0][0],   │
# │                     │                   │            │ X02_act2[0][0],   │
# │                     │                   │            │ X03_act2[0][0],   │
# │                     │                   │            │ up13_04[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_c1 (Conv2D)     │ (None, 224, 224,  │    221,248 │ concatenate_9[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_bn1             │ (None, 224, 224,  │        256 │ X04_c1[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_act1            │ (None, 224, 224,  │          0 │ X04_bn1[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_c2 (Conv2D)     │ (None, 224, 224,  │     36,928 │ X04_act1[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_bn2             │ (None, 224, 224,  │        256 │ X04_c2[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ X04_act2            │ (None, 224, 224,  │          0 │ X04_bn2[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Conv2D)     │ (None, 224, 224,  │         65 │ X04_act2[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 60,978,949 (232.62 MB)
#  Trainable params: 15,419,201 (58.82 MB)
#  Non-trainable params: 14,721,344 (56.16 MB)
#  Optimizer params: 30,838,404 (117.64 MB)

# %%
print('Evaluating best model on held-out test set...\n')
test_results = best_model.evaluate(test_dataset, verbose=1)
test_dict    = dict(zip(best_model.metrics_names, test_results))

label_map = {
    'loss': 'Loss', 'dice_coefficient': 'Dice', 'iou_score': 'IoU (Jaccard)',
    'precision_smooth': 'Precision', 'recall_smooth': 'Recall', 'pixel_accuracy': 'Pixel Accuracy'
}

P = test_dict.get('precision_smooth', 0)
R = test_dict.get('recall_smooth',    0)
f1 = 2 * P * R / (P + R + 1e-7)

print('\n' + '=' * 60)
print('  FINAL TEST-SET METRICS  (VGG16-UNet++ | OASIS disc1+disc2)')
print('=' * 60)
for k, v in test_dict.items():
    print(f'  {label_map.get(k, k):20s}: {v:.4f}')
print(f'  {"F1-Score":20s}: {f1:.4f}')
print('=' * 60)

final_df = pd.DataFrame([{
    'Model':      'VGG16-UNet++ (OASIS disc1+disc2)',
    'IoU':        round(test_dict.get('iou_score', float('nan')), 4),
    'Dice':       round(test_dict.get('dice_coefficient', float('nan')), 4),
    'Precision':  round(P, 4),
    'Recall':     round(R, 4),
    'Accuracy':   round(test_dict.get('pixel_accuracy', float('nan')), 4),
    'F1':         round(f1, 4),
}]).set_index('Model')
final_df
# Out:
# Evaluating best model on held-out test set...
#
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - dice_coefficient: 0.9998 - iou_score: 0.9997 - loss: 3.0109e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9997 - recall_smooth: 1.0000
# 2026-06-22 19:41:38.302276: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 19:41:38.547972: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 19:41:40.353380: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 19:41:40.609686: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 19:41:42.855343: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 19:41:43.157776: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 29s 388ms/step - dice_coefficient: 0.9998 - iou_score: 0.9996 - loss: 3.1726e-04 - pixel_accuracy: 1.0000 - precision_smooth: 0.9996 - recall_smooth: 1.0000
#
# ============================================================
#   FINAL TEST-SET METRICS  (VGG16-UNet++ | OASIS disc1+disc2)
# ============================================================
#   Loss                : 0.0003
#   compile_metrics     : 0.9998
#   F1-Score            : 0.0000
# ============================================================
#                                   IoU  Dice  Precision  Recall  Accuracy   F1
# Model
# VGG16-UNet++ (OASIS disc1+disc2)  NaN   NaN          0       0       NaN  0.0

# %% [markdown]
# ## 16. Test Predictions Visualization

# %%
print('Test set predictions:')
show_predictions(test_dataset, num=5, model_to_use=best_model)
# Out:
# Test set predictions:

# %% [markdown]
# ## 17. Detailed Prediction Grid

# %%
def prediction_grid(dataset, best_model, n_rows=4):
    for imgs, masks in dataset.take(1):
        preds = best_model.predict(imgs[:n_rows], verbose=0)

        fig, axes = plt.subplots(n_rows, 4, figsize=(16, 4 * n_rows))
        col_titles = ['Input MRI', 'Ground Truth', 'Prediction', 'Overlay']
        for col, t in enumerate(col_titles):
            axes[0, col].set_title(t, fontsize=12, fontweight='bold')

        for row in range(n_rows):
            img   = imgs[row].numpy()
            gt    = masks[row].numpy()[..., 0]
            pred  = create_mask(preds[row]).numpy()[..., 0]

            ov = (img * 255).astype(np.uint8)
            ov[pred > 0.5, 0] = 255
            ov[pred > 0.5, 1] = 0
            ov[pred > 0.5, 2] = 0

            inter = np.sum(gt * pred)
            union = np.sum(gt) + np.sum(pred) - inter
            sample_iou = (inter + 1) / (union + 1)

            axes[row, 0].imshow(img)
            axes[row, 1].imshow(gt,   cmap='gray')
            axes[row, 2].imshow(pred, cmap='gray')
            axes[row, 2].set_xlabel(f'IoU: {sample_iou:.3f}', fontsize=10, color='green')
            axes[row, 3].imshow(ov)

            for col in range(4):
                axes[row, col].axis('off')

        plt.suptitle('VGG16-UNet++ — Alzheimer Brain MRI Segmentation Results',
                     fontsize=14, fontweight='bold')
        plt.tight_layout()
        plt.savefig('prediction_grid_unetpp.png', dpi=150, bbox_inches='tight')
        plt.show()
        print('Grid saved → prediction_grid_unetpp.png')


prediction_grid(test_dataset, best_model, n_rows=4)
# Out:
# 2026-06-22 19:41:53.348761: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 19:41:53.593985: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 19:41:56.630558: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 19:41:56.888315: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 19:42:00.377373: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-22 19:42:00.681059: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Grid saved → prediction_grid_unetpp.png

# %% [markdown]
# ## 18. IoU Distribution Plot

# %%
iou_scores = []

for imgs, masks in test_dataset:
    preds = best_model.predict(imgs, verbose=0)
    for i in range(len(imgs)):
        gt   = masks[i].numpy()[..., 0]
        pred = (preds[i][..., 0] > 0.5).astype(float)
        inter = np.sum(gt * pred)
        union = np.sum(gt) + np.sum(pred) - inter
        iou_scores.append((inter + 1) / (union + 1))

iou_arr = np.array(iou_scores)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].hist(iou_arr, bins=30, color='steelblue', edgecolor='white', alpha=0.85)
axes[0].axvline(iou_arr.mean(), color='red', linestyle='--', linewidth=2,
                label=f'Mean IoU: {iou_arr.mean():.3f}')
axes[0].axvline(np.median(iou_arr), color='orange', linestyle='--', linewidth=2,
                label=f'Median IoU: {np.median(iou_arr):.3f}')
axes[0].set_xlabel('IoU Score', fontsize=12)
axes[0].set_ylabel('Count', fontsize=12)
axes[0].set_title('IoU Distribution (Test Set)', fontsize=13, fontweight='bold')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

sorted_iou = np.sort(iou_arr)
cdf = np.arange(1, len(sorted_iou) + 1) / len(sorted_iou)
axes[1].plot(sorted_iou, cdf, color='darkorange', linewidth=2)
axes[1].axvline(0.5, color='gray', linestyle=':', label='IoU = 0.5')
pct_above_50 = np.mean(iou_arr > 0.5) * 100
axes[1].set_xlabel('IoU Score', fontsize=12)
axes[1].set_ylabel('Cumulative Fraction', fontsize=12)
axes[1].set_title(f'CDF of IoU  ({pct_above_50:.1f}% slices > 0.5)', fontsize=13, fontweight='bold')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.suptitle('Per-Sample IoU Analysis', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('iou_distribution_unetpp.png', dpi=150, bbox_inches='tight')
plt.show()

print(f'\nIoU Stats — Mean: {iou_arr.mean():.4f}  |  Std: {iou_arr.std():.4f}')
print(f'             Min : {iou_arr.min():.4f}  |  Max: {iou_arr.max():.4f}')
print(f'% slices IoU > 0.5 : {pct_above_50:.1f}%')
# Out:
# IoU Stats — Mean: 0.9999  |  Std: 0.0003
#              Min : 0.9941  |  Max: 1.0000
# % slices IoU > 0.5 : 100.0%

# %% [markdown]
# ## 19. Save Final Model

# %%
best_model.save('alzheimer_vgg16_unetpp_final.keras')
print('Model saved → alzheimer_vgg16_unetpp_final.keras')
# Out:
# Model saved → alzheimer_vgg16_unetpp_final.keras
