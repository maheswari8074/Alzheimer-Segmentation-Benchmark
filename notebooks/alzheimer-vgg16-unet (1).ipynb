# %% [markdown]
# # Alzheimer's Disease Brain MRI Segmentation
# ## VGG16 + UNet | OASIS Dataset
# Full pipeline: data loading → preprocessing → model training → metrics → visualizations

# %% [markdown]
# ## 1. Import Libraries

# %%
import os
print(os.listdir('/kaggle/input/datasets/maheswarimudadla/oasis-disc1'))
# Out:
# ['disc1']

# %%
import os

def print_tree(path, max_depth=5):
    for root, dirs, files in os.walk(path):
        level = root.replace(path, '').count(os.sep)
        if level > max_depth:
            break
        indent = '  ' * level
        print(f'{indent}{os.path.basename(root)}/')
        if level < max_depth:
            for f in files[:2]:
                print(f'{indent}  {f}')

print_tree('/kaggle/input/datasets')
# Out:
# datasets/
#   maheswarimudadla/
#     disc2-oasis1/
#       disc2/
#         OAS1_0057_MR1/
#           OAS1_0057_MR1.txt
#           OAS1_0057_MR1.xml
#           PROCESSED/

# %%
import os
import cv2
import random
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, UpSampling2D,
    concatenate, BatchNormalization, Dropout, Activation
)
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG16
from tensorflow.keras import callbacks
from sklearn.model_selection import train_test_split
from tqdm.auto import tqdm
import time
import datetime

print('TensorFlow version:', tf.__version__)
print('GPUs available:', tf.config.list_physical_devices('GPU'))
# Out:
# 2026-06-16 09:33:24.322373: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1781602404.504518      58 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1781602404.565192      58 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1781602404.992214      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781602404.992254      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781602404.992257      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781602404.992260      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow version: 2.19.0
# GPUs available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 2. Configuration

# %%
# ─── Paths ────────────────────────────────────────────────────────────────────
# OASIS disc1 unzipped structure:
#   /kaggle/input/<your-dataset-name>/disc1/OAS1_XXXX_MR1/
#       processed/
#           ├── mpr-1/
#           │   ├── anon.img
#           │   └── anon.hdr
#           └── T88_111/
#               └── OAS1_XXXX_MR1_mpr_n4_anon_111_t88_masked_gfc_fseg.img  ← seg mask
#
# Adjust OASIS_ROOT to wherever your dataset lives in Kaggle input

OASIS_ROOT = '/kaggle/input/datasets/maheswarimudadla/oasis-disc1/disc1'
PROCESSED_DIR   = 'oasis_processed'
IMAGE_FOLDER    = os.path.join(PROCESSED_DIR, 'images')
MASK_FOLDER     = os.path.join(PROCESSED_DIR, 'masks')
TRAIN_IMG_DIR   = os.path.join(PROCESSED_DIR, 'train', 'images')
TRAIN_MASK_DIR  = os.path.join(PROCESSED_DIR, 'train', 'masks')
TEST_IMG_DIR    = os.path.join(PROCESSED_DIR, 'test',  'images')
TEST_MASK_DIR   = os.path.join(PROCESSED_DIR, 'test',  'masks')

# ─── Hyperparameters ──────────────────────────────────────────────────────────
IMG_SIZE    = (224, 224)
BATCH_SIZE  = 16
EPOCHS      = 100
SEED        = 42
TEST_SPLIT  = 0.15

print('Config set ✓')
# Out:
# Config set ✓

# %% [markdown]
# ## 3. Load & Preprocess OASIS Data
# OASIS stores brain volumes as Analyze `.img/.hdr` pairs. We slice along the axial axis and save each 2-D slice as a PNG.

# %%
# Install nibabel to read Analyze / NIfTI files
# !pip install nibabel -q
import nibabel as nib

# %%
def make_dir(path):
    os.makedirs(path, exist_ok=True)

for d in [IMAGE_FOLDER, MASK_FOLDER,
          TRAIN_IMG_DIR, TRAIN_MASK_DIR,
          TEST_IMG_DIR,  TEST_MASK_DIR]:
    make_dir(d)

print('Directories ready ✓')
# Out:
# Directories ready ✓

# %%
def normalize_slice(arr):
    """Min-max normalise a 2-D array to [0, 255] uint8."""
    mn, mx = arr.min(), arr.max()
    if mx - mn == 0:
        return np.zeros_like(arr, dtype=np.uint8)
    return ((arr - mn) / (mx - mn) * 255).astype(np.uint8)


def extract_slices(subject_dir, img_out, mask_out, axis=1, step=2):
    """
    For one OASIS subject directory, find:
      - The T88 masked image  (brain volume)
      - The fseg mask         (tissue segmentation)
    and save every `step`-th axial slice to img_out / mask_out.
    Returns number of slices saved.
    """
    subject_name = os.path.basename(subject_dir)
   # NEW
    t88_dir = os.path.join(subject_dir, 'PROCESSED', 'T88_111')

    if not os.path.isdir(t88_dir):
        return 0

    # Find brain image and segmentation mask
    brain_img_path = seg_mask_path = None
    for fname in os.listdir(t88_dir):
        if fname.endswith('masked_gfc.img'):
            brain_img_path = os.path.join(t88_dir, fname)
        if fname.endswith('fseg.img'):
            seg_mask_path  = os.path.join(t88_dir, fname)

    if brain_img_path is None or seg_mask_path is None:
        return 0

    brain_vol = nib.load(brain_img_path).get_fdata()
    seg_vol   = nib.load(seg_mask_path).get_fdata()

    saved = 0
    for i in range(0, brain_vol.shape[axis], step):
        # Take axial slice
        if axis == 0: b_sl = brain_vol[i, :, :]
        elif axis == 1: b_sl = brain_vol[:, i, :]
        else: b_sl = brain_vol[:, :, i]

        seg_sl = seg_vol[:, i, :] if axis == 1 else seg_vol[:, :, i]

        # Skip empty slices (mostly background)
        if b_sl.max() == 0:
            continue

        img_arr  = normalize_slice(b_sl)
        # Binary mask: any labelled tissue (WM=3, GM=2, CSF=1) → 1
        mask_arr = (seg_sl > 0).astype(np.uint8) * 255

        fname = f"{subject_name}_sl{i:03d}.png"
        cv2.imwrite(os.path.join(img_out,  fname), img_arr)
        cv2.imwrite(os.path.join(mask_out, fname), mask_arr)
        saved += 1

    return saved


# ─── Process all subjects ─────────────────────────────────────────────────────
total_slices = 0
subject_dirs = [
    os.path.join(OASIS_ROOT, d)
    for d in os.listdir(OASIS_ROOT)
    if os.path.isdir(os.path.join(OASIS_ROOT, d)) and d.startswith('OAS')
]

print(f'Found {len(subject_dirs)} subjects')

for subj in tqdm(subject_dirs, desc='Extracting slices'):
    total_slices += extract_slices(subj, IMAGE_FOLDER, MASK_FOLDER)

print(f'\nTotal slices extracted : {total_slices}')
print(f'Images saved           : {len(os.listdir(IMAGE_FOLDER))}')
print(f'Masks  saved           : {len(os.listdir(MASK_FOLDER))}')
# Out:
# Found 39 subjects
# Extracting slices:   0%|          | 0/39 [00:00<?, ?it/s]
# Total slices extracted : 0
# Images saved           : 0
# Masks  saved           : 0

# %% [markdown]
# ## 4. Data Visualisation

# %%
import os

# Look inside one subject
base = '/kaggle/input/datasets/maheswarimudadla/oasis-disc1/disc1'
subjects = os.listdir(base)
print('Total subjects:', len(subjects))

# Pick first subject and print full tree
subj = os.path.join(base, subjects[0])
for root, dirs, files in os.walk(subj):
    level = root.replace(subj, '').count(os.sep)
    indent = '  ' * level
    print(f'{indent}{os.path.basename(root)}/')
    for f in files:
        print(f'{indent}  {f}')
# Out:
# Total subjects: 39
# OAS1_0023_MR1/
#   OAS1_0023_MR1.xml
#   OAS1_0023_MR1.txt
#   PROCESSED/
#     MPRAGE/
#       OAS1_0023_MR1_mpr_n4_anon_atl.lst
#       OAS1_0023_MR1_mpr_n4_anon.lst
#       T88_111/
#         OAS1_0023_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
#         OAS1_0023_MR1_mpr_n4_anon_111_t88_gfc.hdr
#         OAS1_0023_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
#         OAS1_0023_MR1_mpr_n4_anon_111_t88_masked_gfc.hdr
#         OAS1_0023_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
#         OAS1_0023_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
#         OAS1_0023_MR1_mpr_n4_anon_111_t88_gfc.img
#         OAS1_0023_MR1_mpr_n4_anon_111_t88_masked_gfc.img
#         t4_files/
#           OAS1_0023_MR1_mpr-2_anon_to_OAS1_0023_MR1_mpr-1_anon_t4
#           OAS1_0023_MR1_mpr-2_anon_to_711-2C_t4
#           OAS1_0023_MR1_mpr-1_anon_to_711-2C_t4
#           OAS1_0023_MR1_mpr-4_anon_to_711-2C_t4
#           OAS1_0023_MR1_mpr-4_anon_to_OAS1_0023_MR1_mpr-1_anon_t4
#           OAS1_0023_MR1_mpr-3_anon_to_711-2C_t4
#           OAS1_0023_MR1_mpr-3_anon_to_OAS1_0023_MR1_mpr-1_anon_t4
#       SUBJ_111/
#         OAS1_0023_MR1_mpr_n4_anon_sbj_111.hdr
#         OAS1_0023_MR1_mpr_n4_anon_sbj_111_sag_88.gif
#         OAS1_0023_MR1_mpr_n4_anon_sbj_111.img
#   FSL_SEG/
#     OAS1_0023_MR1_mpr_n4_anon_111_t88_masked_gfc_fseg.txt
#     OAS1_0023_MR1_mpr_n4_anon_111_t88_masked_gfc_fseg.hdr
#     OAS1_0023_MR1_mpr_n4_anon_111_t88_masked_gfc_fseg_tra_90.gif
#     OAS1_0023_MR1_mpr_n4_anon_111_t88_masked_gfc_fseg.img
#   RAW/
#     OAS1_0023_MR1_mpr-2_anon.img
#     OAS1_0023_MR1_mpr-1_anon.img
#     OAS1_0023_MR1_mpr-1_anon.hdr
#     OAS1_0023_MR1_mpr-2_anon.hdr
#     OAS1_0023_MR1_mpr-4_anon_sag_66.gif
#     OAS1_0023_MR1_mpr-4_anon.img
#     OAS1_0023_MR1_mpr-3_anon.hdr
#     OAS1_0023_MR1_mpr-4_anon.hdr
#     OAS1_0023_MR1_mpr-2_anon_sag_66.gif
#     OAS1_0023_MR1_mpr-3_anon.img
#     OAS1_0023_MR1_mpr-3_anon_sag_66.gif
#     OAS1_0023_MR1_mpr-1_anon_sag_66.gif

# %%
import nibabel as nib
import cv2
import numpy as np
import os
import shutil
from tqdm.auto import tqdm

def normalize_slice(arr):
    mn, mx = arr.min(), arr.max()
    if mx - mn == 0:
        return np.zeros_like(arr, dtype=np.uint8)
    return ((arr - mn) / (mx - mn) * 255).astype(np.uint8)

def extract_slices(subject_dir, img_out, mask_out, step=2):
    subject_name = os.path.basename(subject_dir)
    t88_dir = os.path.join(subject_dir, 'PROCESSED', 'MPRAGE', 'T88_111')
    fsl_dir = os.path.join(subject_dir, 'FSL_SEG')
    if not os.path.isdir(t88_dir) or not os.path.isdir(fsl_dir):
        return 0
    brain_img_path = None
    for f in os.listdir(t88_dir):
        if f.endswith('masked_gfc.img'):
            brain_img_path = os.path.join(t88_dir, f)
            break
    seg_img_path = None
    for f in os.listdir(fsl_dir):
        if f.endswith('fseg.img'):
            seg_img_path = os.path.join(fsl_dir, f)
            break
    if brain_img_path is None or seg_img_path is None:
        return 0
    brain_vol = np.squeeze(nib.load(brain_img_path).get_fdata())
    seg_vol   = np.squeeze(nib.load(seg_img_path).get_fdata())
    saved = 0
    for i in range(0, brain_vol.shape[1], step):
        b_sl   = brain_vol[:, i, :]
        seg_sl = seg_vol[:, i, :]
        if b_sl.max() == 0:
            continue
        img_arr  = normalize_slice(b_sl)
        mask_arr = (seg_sl > 0).astype(np.uint8) * 255
        fname = f'{subject_name}_sl{i:03d}.png'
        cv2.imwrite(os.path.join(img_out,  fname), img_arr)
        cv2.imwrite(os.path.join(mask_out, fname), mask_arr)
        saved += 1
    return saved

# ── Clear old slices ───────────────────────────────────────────────────────────
for folder in [IMAGE_FOLDER, MASK_FOLDER]:
    if os.path.exists(folder):
        shutil.rmtree(folder)
    os.makedirs(folder)
print('Old slices cleared ✓')

# ── Load subjects from both discs ──────────────────────────────────────────────
ROOTS = [
    '/kaggle/input/datasets/maheswarimudadla/oasis-disc1/disc1',
    '/kaggle/input/datasets/maheswarimudadla/disc2-oasis1/disc2',
]
subject_dirs = []
for root in ROOTS:
    if os.path.exists(root):
        dirs = [
            os.path.join(root, d)
            for d in os.listdir(root)
            if os.path.isdir(os.path.join(root, d)) and d.startswith('OAS')
        ]
        subject_dirs += dirs
        print(f'{root} → {len(dirs)} subjects')

print(f'\nTotal subjects: {len(subject_dirs)}')

# ── Extract ────────────────────────────────────────────────────────────────────
total_slices = 0
for subj in tqdm(subject_dirs, desc='Extracting slices'):
    total_slices += extract_slices(subj, IMAGE_FOLDER, MASK_FOLDER)

print(f'\nTotal slices extracted : {total_slices}')
print(f'Images saved           : {len(os.listdir(IMAGE_FOLDER))}')
print(f'Masks  saved           : {len(os.listdir(MASK_FOLDER))}')
# Out:
# Old slices cleared ✓
# /kaggle/input/datasets/maheswarimudadla/oasis-disc1/disc1 → 39 subjects
# /kaggle/input/datasets/maheswarimudadla/disc2-oasis1/disc2 → 38 subjects
#
# Total subjects: 77
# Extracting slices:   0%|          | 0/77 [00:00<?, ?it/s]
# Total slices extracted : 6622
# Images saved           : 6622
# Masks  saved           : 6622

# %%
def extract_slices(subject_dir, img_out, mask_out, step=2):
    subject_name = os.path.basename(subject_dir)

    t88_dir = os.path.join(subject_dir, 'PROCESSED', 'MPRAGE', 'T88_111')
    fsl_dir = os.path.join(subject_dir, 'FSL_SEG')

    if not os.path.isdir(t88_dir) or not os.path.isdir(fsl_dir):
        return 0

    brain_img_path = None
    for f in os.listdir(t88_dir):
        if f.endswith('masked_gfc.img'):
            brain_img_path = os.path.join(t88_dir, f)
            break

    seg_img_path = None
    for f in os.listdir(fsl_dir):
        if f.endswith('fseg.img'):
            seg_img_path = os.path.join(fsl_dir, f)
            break

    if brain_img_path is None or seg_img_path is None:
        return 0

    # ── Squeeze the 4th dimension ──────────────────────────────────────────────
    brain_vol = np.squeeze(nib.load(brain_img_path).get_fdata())  # → (176,208,176)
    seg_vol   = np.squeeze(nib.load(seg_img_path).get_fdata())    # → (176,208,176)

    saved = 0
    for i in range(0, brain_vol.shape[1], step):
        b_sl   = brain_vol[:, i, :]
        seg_sl = seg_vol[:, i, :]

        if b_sl.max() == 0:
            continue

        img_arr  = normalize_slice(b_sl)
        mask_arr = (seg_sl > 0).astype(np.uint8) * 255

        fname = f'{subject_name}_sl{i:03d}.png'
        cv2.imwrite(os.path.join(img_out,  fname), img_arr)
        cv2.imwrite(os.path.join(mask_out, fname), mask_arr)
        saved += 1

    return saved

# %%
def visualize_sample(image_name, img_dir=IMAGE_FOLDER, mask_dir=MASK_FOLDER):
    img  = cv2.imread(os.path.join(img_dir,  image_name), cv2.IMREAD_GRAYSCALE)
    mask = cv2.imread(os.path.join(mask_dir, image_name), cv2.IMREAD_GRAYSCALE)

    overlay = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
    overlay[mask > 127, 0] = 255  # red channel highlight
    overlay[mask > 127, 1] = 0
    overlay[mask > 127, 2] = 0

    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    axes[0].imshow(img,     cmap='gray');  axes[0].set_title('Brain MRI Slice',      fontsize=13)
    axes[1].imshow(mask,    cmap='gray');  axes[1].set_title('Ground Truth Mask',    fontsize=13)
    axes[2].imshow(overlay);               axes[2].set_title('Overlay (red = mask)', fontsize=13)
    for ax in axes: ax.axis('off')
    plt.suptitle(image_name, fontsize=10, color='gray')
    plt.tight_layout()
    plt.show()


all_images = os.listdir(IMAGE_FOLDER)
for _ in range(4):
    visualize_sample(random.choice(all_images))

# %% [markdown]
# ## 5. Train / Test Split

# %%
images = sorted([f for f in os.listdir(IMAGE_FOLDER) if f.endswith('.png')])
masks  = sorted([f for f in os.listdir(MASK_FOLDER)  if f.endswith('.png')])

assert images == masks, 'Image-mask mismatch! Check filenames.'

train_imgs, test_imgs = train_test_split(images, test_size=TEST_SPLIT, random_state=SEED)
print(f'Train: {len(train_imgs)}  |  Test: {len(test_imgs)}')

def copy_files(file_list, src_img, src_mask, dst_img, dst_mask):
    for f in tqdm(file_list, leave=False):
        shutil.copy(os.path.join(src_img,  f), os.path.join(dst_img,  f))
        shutil.copy(os.path.join(src_mask, f), os.path.join(dst_mask, f))

copy_files(train_imgs, IMAGE_FOLDER, MASK_FOLDER, TRAIN_IMG_DIR, TRAIN_MASK_DIR)
copy_files(test_imgs,  IMAGE_FOLDER, MASK_FOLDER, TEST_IMG_DIR,  TEST_MASK_DIR)
print('Files copied ✓')
# Out:
# Train: 5628  |  Test: 994
#   0%|          | 0/5628 [00:00<?, ?it/s]
#   0%|          | 0/994 [00:00<?, ?it/s]
# Files copied ✓

# %% [markdown]
# ## 6. tf.data Pipeline

# %%
def load_image(img_path, mask_path):
    # ── Image ──────────────────────────────────────────────────────────────────
    img = tf.io.read_file(img_path)
    img = tf.image.decode_png(img, channels=3)   # grayscale → 3-ch for VGG16
    img = tf.image.resize(img, IMG_SIZE)
    img = tf.cast(img, tf.float32) / 255.0

    # ── Mask ───────────────────────────────────────────────────────────────────
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=1)
    mask = tf.image.resize(mask, IMG_SIZE, method='nearest')
    mask = tf.cast(mask, tf.float32) / 255.0

    return img, mask


def augment(img, mask):
    """Random flip + brightness jitter (applied consistently to img; mask only flipped)"""
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_left_right(img)
        mask = tf.image.flip_left_right(mask)
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_up_down(img)
        mask = tf.image.flip_up_down(mask)
    img = tf.image.random_brightness(img, max_delta=0.1)
    img = tf.clip_by_value(img, 0.0, 1.0)
    return img, mask


def build_dataset(img_dir, mask_dir, augment_data=False, batch=BATCH_SIZE):
    img_files  = sorted([os.path.join(img_dir,  f) for f in os.listdir(img_dir)  if f.endswith('.png')])
    mask_files = sorted([os.path.join(mask_dir, f) for f in os.listdir(mask_dir) if f.endswith('.png')])

    ds = tf.data.Dataset.from_tensor_slices((img_files, mask_files))
    ds = ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
    if augment_data:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch).prefetch(tf.data.AUTOTUNE)
    return ds


train_dataset = build_dataset(TRAIN_IMG_DIR, TRAIN_MASK_DIR, augment_data=True)
test_dataset  = build_dataset(TEST_IMG_DIR,  TEST_MASK_DIR,  augment_data=False)

print('Datasets ready ✓')
for imgs, masks in train_dataset.take(1):
    print('Batch shapes →  images:', imgs.shape, ' masks:', masks.shape)
# Out:
# I0000 00:00:1781602451.660940      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Datasets ready ✓
# Batch shapes →  images: (16, 224, 224, 3)  masks: (16, 224, 224, 1)

# %% [markdown]
# ## 7. Model — VGG16 Encoder + UNet Decoder

# %%
def conv_block(x, filters, name_prefix):
    """Two Conv2D + BN + ReLU layers."""
    x = Conv2D(filters, (3,3), padding='same', name=f'{name_prefix}_c1')(x)
    x = BatchNormalization(name=f'{name_prefix}_bn1')(x)
    x = Activation('relu', name=f'{name_prefix}_act1')(x)
    x = Conv2D(filters, (3,3), padding='same', name=f'{name_prefix}_c2')(x)
    x = BatchNormalization(name=f'{name_prefix}_bn2')(x)
    x = Activation('relu', name=f'{name_prefix}_act2')(x)
    return x


def decoder_block(x, skip, filters, name_prefix):
    """Upsample → concatenate skip → conv_block."""
    x = UpSampling2D((2, 2), name=f'{name_prefix}_up')(x)
    x = concatenate([x, skip], name=f'{name_prefix}_cat')
    x = Dropout(0.2, name=f'{name_prefix}_drop')(x)
    x = conv_block(x, filters, name_prefix)
    return x


def build_vgg16_unet(input_shape=(224, 224, 3), freeze_encoder=True):
    """
    VGG16 encoder (ImageNet weights) + symmetric UNet decoder.
    Skip connections taken from VGG16's block outputs.
    """
    inputs = Input(shape=input_shape, name='input')

    # ── Encoder (VGG16) ────────────────────────────────────────────────────────
    base = VGG16(include_top=False, weights='imagenet', input_tensor=inputs)

    if freeze_encoder:
        for layer in base.layers:
            layer.trainable = False

    # Skip connections at progressively deeper resolutions
    s1 = base.get_layer('block1_conv2').output   # 224×224,  64 ch
    s2 = base.get_layer('block2_conv2').output   # 112×112, 128 ch
    s3 = base.get_layer('block3_conv3').output   #  56×56,  256 ch
    s4 = base.get_layer('block4_conv3').output   #  28×28,  512 ch

    # Bottleneck
    b  = base.get_layer('block5_conv3').output   #  14×14,  512 ch

    # ── Decoder ────────────────────────────────────────────────────────────────
    d4 = decoder_block(b,  s4, 512, 'dec4')      #  28×28
    d3 = decoder_block(d4, s3, 256, 'dec3')      #  56×56
    d2 = decoder_block(d3, s2, 128, 'dec2')      # 112×112
    d1 = decoder_block(d2, s1,  64, 'dec1')      # 224×224

    # ── Output ─────────────────────────────────────────────────────────────────
    output = Conv2D(1, (1, 1), activation='sigmoid', name='output')(d1)

    model = Model(inputs=inputs, outputs=output, name='VGG16_UNet')
    return model


model = build_vgg16_unet(input_shape=(*IMG_SIZE, 3), freeze_encoder=True)
print('Model built ✓')
print(f'Total parameters      : {model.count_params():,}')
print(f'Trainable parameters  : {sum([K.count_params(w) for w in model.trainable_weights]):,}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model built ✓
# Total parameters      : 24,898,817
# Trainable parameters  : 10,180,289

# %% [markdown]
# ## 8. Custom Metrics & Loss

# %%
def dice_coefficient(y_true, y_pred, smooth=1.0):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_loss(y_true, y_pred):
    return 1.0 - dice_coefficient(y_true, y_pred)


def iou_score(y_true, y_pred, smooth=1.0):
    """Intersection over Union  (Jaccard Index)"""
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)


def precision_smooth(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return intersection / (K.sum(y_pred_f) + K.epsilon())


def recall_smooth(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return intersection / (K.sum(y_true_f) + K.epsilon())


def pixel_accuracy(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    tp = K.sum(K.round(K.clip(y_true_f * y_pred_f, 0, 1)))
    tn = K.sum(K.round(K.clip((1 - y_true_f) * (1 - y_pred_f), 0, 1)))
    total = K.cast(tf.size(y_true_f), K.floatx())
    return (tp + tn) / total


# Combined loss: Dice + Binary Cross-Entropy
def combined_loss(y_true, y_pred):
    return dice_loss(y_true, y_pred) + tf.keras.losses.binary_crossentropy(y_true, y_pred)


model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=combined_loss,
    metrics=[dice_coefficient, iou_score, precision_smooth, recall_smooth, pixel_accuracy]
)

print('Model compiled ✓')
# Out:
# Model compiled ✓

# %% [markdown]
# ## 9. Model Summary & Architecture Plot

# %%
model.summary()

tf.keras.utils.plot_model(
    model,
    to_file='vgg16_unet_architecture.png',
    show_shapes=True,
    show_layer_names=True,
    rankdir='TB',
    dpi=64
)
# Out:
# Model: "VGG16_UNet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 224, 224,  │          0 │ -                 │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 224, 224,  │      1,792 │ input[0][0]       │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 224, 224,  │     36,928 │ block1_conv1[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 112, 112,  │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 112, 112,  │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 112, 112,  │    147,584 │ block2_conv1[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 56, 56,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 56, 56,    │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 56, 56,    │    590,080 │ block3_conv1[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 56, 56,    │    590,080 │ block3_conv2[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 28, 28,    │          0 │ block3_conv3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 28, 28,    │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 28, 28,    │  2,359,808 │ block4_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 28, 28,    │  2,359,808 │ block4_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 14, 14,    │          0 │ block4_conv3[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 14, 14,    │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 14, 14,    │  2,359,808 │ block5_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 14, 14,    │  2,359,808 │ block5_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_up             │ (None, 28, 28,    │          0 │ block5_conv3[0][… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_cat            │ (None, 28, 28,    │          0 │ dec4_up[0][0],    │
# │ (Concatenate)       │ 1024)             │            │ block4_conv3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_drop (Dropout) │ (None, 28, 28,    │          0 │ dec4_cat[0][0]    │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_c1 (Conv2D)    │ (None, 28, 28,    │  4,719,104 │ dec4_drop[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_bn1            │ (None, 28, 28,    │      2,048 │ dec4_c1[0][0]     │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_act1           │ (None, 28, 28,    │          0 │ dec4_bn1[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_c2 (Conv2D)    │ (None, 28, 28,    │  2,359,808 │ dec4_act1[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_bn2            │ (None, 28, 28,    │      2,048 │ dec4_c2[0][0]     │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_act2           │ (None, 28, 28,    │          0 │ dec4_bn2[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_up             │ (None, 56, 56,    │          0 │ dec4_act2[0][0]   │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_cat            │ (None, 56, 56,    │          0 │ dec3_up[0][0],    │
# │ (Concatenate)       │ 768)              │            │ block3_conv3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_drop (Dropout) │ (None, 56, 56,    │          0 │ dec3_cat[0][0]    │
# │                     │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_c1 (Conv2D)    │ (None, 56, 56,    │  1,769,728 │ dec3_drop[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_bn1            │ (None, 56, 56,    │      1,024 │ dec3_c1[0][0]     │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_act1           │ (None, 56, 56,    │          0 │ dec3_bn1[0][0]    │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_c2 (Conv2D)    │ (None, 56, 56,    │    590,080 │ dec3_act1[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_bn2            │ (None, 56, 56,    │      1,024 │ dec3_c2[0][0]     │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_act2           │ (None, 56, 56,    │          0 │ dec3_bn2[0][0]    │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_up             │ (None, 112, 112,  │          0 │ dec3_act2[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_cat            │ (None, 112, 112,  │          0 │ dec2_up[0][0],    │
# │ (Concatenate)       │ 384)              │            │ block2_conv2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_drop (Dropout) │ (None, 112, 112,  │          0 │ dec2_cat[0][0]    │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_c1 (Conv2D)    │ (None, 112, 112,  │    442,496 │ dec2_drop[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_bn1            │ (None, 112, 112,  │        512 │ dec2_c1[0][0]     │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_act1           │ (None, 112, 112,  │          0 │ dec2_bn1[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_c2 (Conv2D)    │ (None, 112, 112,  │    147,584 │ dec2_act1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_bn2            │ (None, 112, 112,  │        512 │ dec2_c2[0][0]     │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_act2           │ (None, 112, 112,  │          0 │ dec2_bn2[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_up             │ (None, 224, 224,  │          0 │ dec2_act2[0][0]   │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_cat            │ (None, 224, 224,  │          0 │ dec1_up[0][0],    │
# │ (Concatenate)       │ 192)              │            │ block1_conv2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_drop (Dropout) │ (None, 224, 224,  │          0 │ dec1_cat[0][0]    │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_c1 (Conv2D)    │ (None, 224, 224,  │    110,656 │ dec1_drop[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_bn1            │ (None, 224, 224,  │        256 │ dec1_c1[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_act1           │ (None, 224, 224,  │          0 │ dec1_bn1[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_c2 (Conv2D)    │ (None, 224, 224,  │     36,928 │ dec1_act1[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_bn2            │ (None, 224, 224,  │        256 │ dec1_c2[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_act2           │ (None, 224, 224,  │          0 │ dec1_bn2[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Conv2D)     │ (None, 224, 224,  │         65 │ dec1_act2[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,898,817 (94.98 MB)
#  Trainable params: 10,180,289 (38.83 MB)
#  Non-trainable params: 14,718,528 (56.15 MB)

# %% [markdown]
# ## 10. Callbacks

# %%
def create_mask(pred):
    return tf.math.round(pred)


def show_predictions(dataset, num=3, model_to_use=None):
    m = model_to_use or model
    for imgs, masks in dataset.take(1):
        preds = m.predict(imgs, verbose=0)
        for i in range(min(num, len(imgs))):
            pred_mask = create_mask(preds[i])
            fig, axes = plt.subplots(1, 3, figsize=(12, 4))
            axes[0].imshow(imgs[i].numpy());            axes[0].set_title('Input MRI')
            axes[1].imshow(masks[i].numpy()[..., 0], cmap='gray'); axes[1].set_title('Ground Truth')
            axes[2].imshow(pred_mask.numpy()[..., 0], cmap='gray'); axes[2].set_title('Prediction')
            for ax in axes: ax.axis('off')
            plt.tight_layout()
            plt.show()


class DisplayCallback(callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % 10 == 0:
            show_predictions(test_dataset, num=2)
            print(f'Prediction after epoch {epoch + 1}\n')


logdir = os.path.join('logs', datetime.datetime.now().strftime('%Y%m%d-%H%M%S'))

callbacks_list = [
    DisplayCallback(),
    callbacks.TensorBoard(logdir, histogram_freq=1),
    callbacks.ModelCheckpoint('best_model.keras', verbose=1, save_best_only=True,
                               monitor='val_iou_score', mode='max'),
    callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5,
                                 min_lr=1e-7, verbose=1),
    callbacks.EarlyStopping(monitor='val_iou_score', patience=15, mode='max',
                             restore_best_weights=True, verbose=1),
]

print('Callbacks ready ✓')
# Out:
# Callbacks ready ✓

# %% [markdown]
# ## 11. Initial Predictions (before training)

# %%
print('Predictions before training:')
show_predictions(test_dataset, num=2)
# Out:
# Predictions before training:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781602455.440055     130 service.cc:152] XLA service 0x7e3104015d00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1781602455.440109     130 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1781602455.724491     130 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1781602469.653017     130 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %% [markdown]
# ## 12. Training

# %%
steps_per_epoch  = len(os.listdir(TRAIN_IMG_DIR)) // BATCH_SIZE
validation_steps = len(os.listdir(TEST_IMG_DIR))  // BATCH_SIZE

print(f'Steps per epoch  : {steps_per_epoch}')
print(f'Validation steps : {validation_steps}')

start_time = time.time()

history = model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=EPOCHS,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps,
    callbacks=callbacks_list
)

elapsed = time.time() - start_time
print(f'\nTraining time: {elapsed/60:.1f} min')
# Out:
# Steps per epoch  : 351
# Validation steps : 62
# Epoch 1/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - dice_coefficient: 0.8452 - iou_score: 0.7636 - loss: 0.2674 - pixel_accuracy: 0.9669 - precision_smooth: 0.8121 - recall_smooth: 0.9096
# Epoch 1: val_iou_score improved from None to 0.95960, saving model to best_model.keras
#
# Epoch 1: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 128s 285ms/step - dice_coefficient: 0.9091 - iou_score: 0.8501 - loss: 0.1444 - pixel_accuracy: 0.9890 - precision_smooth: 0.8740 - recall_smooth: 0.9662 - val_dice_coefficient: 0.9794 - val_iou_score: 0.9596 - val_loss: 0.0354 - val_pixel_accuracy: 0.9977 - val_precision_smooth: 0.9662 - val_recall_smooth: 0.9929 - learning_rate: 1.0000e-04
# Epoch 2/100
# 2026-06-16 09:36:47.153610: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-16 09:36:47.401865: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 2:38:11 27s/step - dice_coefficient: 0.8346 - iou_score: 0.7162 - loss: 0.2175 - pixel_accuracy: 0.9974 - precision_smooth: 0.7185 - recall_smooth: 0.9956
# Epoch 2: val_iou_score did not improve from 0.95960
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 38s 30ms/step - dice_coefficient: 0.8346 - iou_score: 0.7162 - loss: 0.2175 - pixel_accuracy: 0.9974 - precision_smooth: 0.7185 - recall_smooth: 0.9956 - val_dice_coefficient: 0.9793 - val_iou_score: 0.9595 - val_loss: 0.0355 - val_pixel_accuracy: 0.9976 - val_precision_smooth: 0.9670 - val_recall_smooth: 0.9919 - learning_rate: 1.0000e-04
# Epoch 3/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - dice_coefficient: 0.9574 - iou_score: 0.9225 - loss: 0.0629 - pixel_accuracy: 0.9972 - precision_smooth: 0.9331 - recall_smooth: 0.9886
# Epoch 3: val_iou_score improved from 0.95960 to 0.97932, saving model to best_model.keras
#
# Epoch 3: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 279ms/step - dice_coefficient: 0.9638 - iou_score: 0.9334 - loss: 0.0538 - pixel_accuracy: 0.9973 - precision_smooth: 0.9434 - recall_smooth: 0.9893 - val_dice_coefficient: 0.9895 - val_iou_score: 0.9793 - val_loss: 0.0187 - val_pixel_accuracy: 0.9981 - val_precision_smooth: 0.9863 - val_recall_smooth: 0.9929 - learning_rate: 1.0000e-04
# Epoch 4/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:10 202ms/step - dice_coefficient: 0.9361 - iou_score: 0.8798 - loss: 0.0820 - pixel_accuracy: 0.9985 - precision_smooth: 0.8849 - recall_smooth: 0.9935
# Epoch 4: val_iou_score did not improve from 0.97932
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - dice_coefficient: 0.9361 - iou_score: 0.8798 - loss: 0.0820 - pixel_accuracy: 0.9985 - precision_smooth: 0.8849 - recall_smooth: 0.9935 - val_dice_coefficient: 0.9895 - val_iou_score: 0.9793 - val_loss: 0.0188 - val_pixel_accuracy: 0.9981 - val_precision_smooth: 0.9864 - val_recall_smooth: 0.9926 - learning_rate: 1.0000e-04
# Epoch 5/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - dice_coefficient: 0.9788 - iou_score: 0.9592 - loss: 0.0329 - pixel_accuracy: 0.9977 - precision_smooth: 0.9677 - recall_smooth: 0.9911
# Epoch 5: val_iou_score improved from 0.97932 to 0.98576, saving model to best_model.keras
#
# Epoch 5: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 278ms/step - dice_coefficient: 0.9801 - iou_score: 0.9617 - loss: 0.0310 - pixel_accuracy: 0.9977 - precision_smooth: 0.9698 - recall_smooth: 0.9915 - val_dice_coefficient: 0.9928 - val_iou_score: 0.9858 - val_loss: 0.0133 - val_pixel_accuracy: 0.9983 - val_precision_smooth: 0.9905 - val_recall_smooth: 0.9952 - learning_rate: 1.0000e-04
# Epoch 6/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:11 205ms/step - dice_coefficient: 0.9574 - iou_score: 0.9183 - loss: 0.0549 - pixel_accuracy: 0.9986 - precision_smooth: 0.9216 - recall_smooth: 0.9961
# Epoch 6: val_iou_score did not improve from 0.98576
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - dice_coefficient: 0.9574 - iou_score: 0.9183 - loss: 0.0549 - pixel_accuracy: 0.9986 - precision_smooth: 0.9216 - recall_smooth: 0.9961 - val_dice_coefficient: 0.9928 - val_iou_score: 0.9857 - val_loss: 0.0133 - val_pixel_accuracy: 0.9983 - val_precision_smooth: 0.9904 - val_recall_smooth: 0.9953 - learning_rate: 1.0000e-04
# Epoch 7/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - dice_coefficient: 0.9852 - iou_score: 0.9712 - loss: 0.0237 - pixel_accuracy: 0.9980 - precision_smooth: 0.9781 - recall_smooth: 0.9929
# Epoch 7: val_iou_score improved from 0.98576 to 0.98893, saving model to best_model.keras
#
# Epoch 7: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 279ms/step - dice_coefficient: 0.9859 - iou_score: 0.9725 - loss: 0.0228 - pixel_accuracy: 0.9980 - precision_smooth: 0.9792 - recall_smooth: 0.9930 - val_dice_coefficient: 0.9944 - val_iou_score: 0.9889 - val_loss: 0.0105 - val_pixel_accuracy: 0.9985 - val_precision_smooth: 0.9937 - val_recall_smooth: 0.9952 - learning_rate: 1.0000e-04
# Epoch 8/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:10 201ms/step - dice_coefficient: 0.9692 - iou_score: 0.9402 - loss: 0.0399 - pixel_accuracy: 0.9987 - precision_smooth: 0.9483 - recall_smooth: 0.9909
# Epoch 8: val_iou_score improved from 0.98893 to 0.98894, saving model to best_model.keras
#
# Epoch 8: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - dice_coefficient: 0.9692 - iou_score: 0.9402 - loss: 0.0399 - pixel_accuracy: 0.9987 - precision_smooth: 0.9483 - recall_smooth: 0.9909 - val_dice_coefficient: 0.9944 - val_iou_score: 0.9889 - val_loss: 0.0105 - val_pixel_accuracy: 0.9985 - val_precision_smooth: 0.9936 - val_recall_smooth: 0.9953 - learning_rate: 1.0000e-04
# Epoch 9/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - dice_coefficient: 0.9886 - iou_score: 0.9776 - loss: 0.0187 - pixel_accuracy: 0.9982 - precision_smooth: 0.9835 - recall_smooth: 0.9939
# Epoch 9: val_iou_score improved from 0.98894 to 0.99045, saving model to best_model.keras
#
# Epoch 9: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 279ms/step - dice_coefficient: 0.9889 - iou_score: 0.9782 - loss: 0.0184 - pixel_accuracy: 0.9981 - precision_smooth: 0.9840 - recall_smooth: 0.9940 - val_dice_coefficient: 0.9952 - val_iou_score: 0.9905 - val_loss: 0.0094 - val_pixel_accuracy: 0.9985 - val_precision_smooth: 0.9933 - val_recall_smooth: 0.9971 - learning_rate: 1.0000e-04
# Epoch 10/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:11 205ms/step - dice_coefficient: 0.9759 - iou_score: 0.9530 - loss: 0.0314 - pixel_accuracy: 0.9989 - precision_smooth: 0.9586 - recall_smooth: 0.9939
# Prediction after epoch 10
#
#
# Epoch 10: val_iou_score did not improve from 0.99045
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - dice_coefficient: 0.9759 - iou_score: 0.9530 - loss: 0.0314 - pixel_accuracy: 0.9989 - precision_smooth: 0.9586 - recall_smooth: 0.9939 - val_dice_coefficient: 0.9952 - val_iou_score: 0.9904 - val_loss: 0.0094 - val_pixel_accuracy: 0.9985 - val_precision_smooth: 0.9933 - val_recall_smooth: 0.9971 - learning_rate: 1.0000e-04
# Epoch 11/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - dice_coefficient: 0.9906 - iou_score: 0.9816 - loss: 0.0158 - pixel_accuracy: 0.9982 - precision_smooth: 0.9868 - recall_smooth: 0.9946
# Epoch 11: val_iou_score improved from 0.99045 to 0.99196, saving model to best_model.keras
#
# Epoch 11: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 279ms/step - dice_coefficient: 0.9908 - iou_score: 0.9818 - loss: 0.0157 - pixel_accuracy: 0.9982 - precision_smooth: 0.9871 - recall_smooth: 0.9946 - val_dice_coefficient: 0.9960 - val_iou_score: 0.9920 - val_loss: 0.0082 - val_pixel_accuracy: 0.9986 - val_precision_smooth: 0.9944 - val_recall_smooth: 0.9976 - learning_rate: 1.0000e-04
# Epoch 12/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:10 202ms/step - dice_coefficient: 0.9803 - iou_score: 0.9614 - loss: 0.0259 - pixel_accuracy: 0.9989 - precision_smooth: 0.9650 - recall_smooth: 0.9961
# Epoch 12: val_iou_score did not improve from 0.99196
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - dice_coefficient: 0.9803 - iou_score: 0.9614 - loss: 0.0259 - pixel_accuracy: 0.9989 - precision_smooth: 0.9650 - recall_smooth: 0.9961 - val_dice_coefficient: 0.9959 - val_iou_score: 0.9919 - val_loss: 0.0082 - val_pixel_accuracy: 0.9986 - val_precision_smooth: 0.9944 - val_recall_smooth: 0.9975 - learning_rate: 1.0000e-04
# Epoch 13/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9921 - iou_score: 0.9844 - loss: 0.0137 - pixel_accuracy: 0.9983 - precision_smooth: 0.9891 - recall_smooth: 0.9951
# Epoch 13: val_iou_score improved from 0.99196 to 0.99267, saving model to best_model.keras
#
# Epoch 13: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 279ms/step - dice_coefficient: 0.9923 - iou_score: 0.9847 - loss: 0.0135 - pixel_accuracy: 0.9983 - precision_smooth: 0.9894 - recall_smooth: 0.9952 - val_dice_coefficient: 0.9963 - val_iou_score: 0.9927 - val_loss: 0.0075 - val_pixel_accuracy: 0.9987 - val_precision_smooth: 0.9948 - val_recall_smooth: 0.9978 - learning_rate: 1.0000e-04
# Epoch 14/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:11 204ms/step - dice_coefficient: 0.9836 - iou_score: 0.9678 - loss: 0.0217 - pixel_accuracy: 0.9990 - precision_smooth: 0.9732 - recall_smooth: 0.9943
# Epoch 14: val_iou_score did not improve from 0.99267
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - dice_coefficient: 0.9836 - iou_score: 0.9678 - loss: 0.0217 - pixel_accuracy: 0.9990 - precision_smooth: 0.9732 - recall_smooth: 0.9943 - val_dice_coefficient: 0.9963 - val_iou_score: 0.9926 - val_loss: 0.0076 - val_pixel_accuracy: 0.9986 - val_precision_smooth: 0.9947 - val_recall_smooth: 0.9979 - learning_rate: 1.0000e-04
# Epoch 15/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - dice_coefficient: 0.9933 - iou_score: 0.9866 - loss: 0.0120 - pixel_accuracy: 0.9984 - precision_smooth: 0.9909 - recall_smooth: 0.9956
# Epoch 15: val_iou_score improved from 0.99267 to 0.99320, saving model to best_model.keras
#
# Epoch 15: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 278ms/step - dice_coefficient: 0.9933 - iou_score: 0.9866 - loss: 0.0121 - pixel_accuracy: 0.9984 - precision_smooth: 0.9910 - recall_smooth: 0.9956 - val_dice_coefficient: 0.9966 - val_iou_score: 0.9932 - val_loss: 0.0071 - val_pixel_accuracy: 0.9987 - val_precision_smooth: 0.9951 - val_recall_smooth: 0.9981 - learning_rate: 1.0000e-04
# Epoch 16/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:09 199ms/step - dice_coefficient: 0.9862 - iou_score: 0.9728 - loss: 0.0184 - pixel_accuracy: 0.9990 - precision_smooth: 0.9766 - recall_smooth: 0.9960
# Epoch 16: val_iou_score did not improve from 0.99320
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - dice_coefficient: 0.9862 - iou_score: 0.9728 - loss: 0.0184 - pixel_accuracy: 0.9990 - precision_smooth: 0.9766 - recall_smooth: 0.9960 - val_dice_coefficient: 0.9965 - val_iou_score: 0.9931 - val_loss: 0.0073 - val_pixel_accuracy: 0.9986 - val_precision_smooth: 0.9949 - val_recall_smooth: 0.9982 - learning_rate: 1.0000e-04
# Epoch 17/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - dice_coefficient: 0.9940 - iou_score: 0.9881 - loss: 0.0109 - pixel_accuracy: 0.9985 - precision_smooth: 0.9922 - recall_smooth: 0.9959
# Epoch 17: val_iou_score improved from 0.99320 to 0.99402, saving model to best_model.keras
#
# Epoch 17: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 279ms/step - dice_coefficient: 0.9940 - iou_score: 0.9881 - loss: 0.0110 - pixel_accuracy: 0.9984 - precision_smooth: 0.9922 - recall_smooth: 0.9958 - val_dice_coefficient: 0.9970 - val_iou_score: 0.9940 - val_loss: 0.0063 - val_pixel_accuracy: 0.9988 - val_precision_smooth: 0.9960 - val_recall_smooth: 0.9980 - learning_rate: 1.0000e-04
# Epoch 18/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:10 200ms/step - dice_coefficient: 0.9885 - iou_score: 0.9772 - loss: 0.0155 - pixel_accuracy: 0.9991 - precision_smooth: 0.9813 - recall_smooth: 0.9957
# Epoch 18: val_iou_score improved from 0.99402 to 0.99412, saving model to best_model.keras
#
# Epoch 18: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - dice_coefficient: 0.9885 - iou_score: 0.9772 - loss: 0.0155 - pixel_accuracy: 0.9991 - precision_smooth: 0.9813 - recall_smooth: 0.9957 - val_dice_coefficient: 0.9971 - val_iou_score: 0.9941 - val_loss: 0.0062 - val_pixel_accuracy: 0.9988 - val_precision_smooth: 0.9963 - val_recall_smooth: 0.9978 - learning_rate: 1.0000e-04
# Epoch 19/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9947 - iou_score: 0.9894 - loss: 0.0099 - pixel_accuracy: 0.9985 - precision_smooth: 0.9933 - recall_smooth: 0.9961
# Epoch 19: val_iou_score did not improve from 0.99412
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 97s 275ms/step - dice_coefficient: 0.9947 - iou_score: 0.9895 - loss: 0.0098 - pixel_accuracy: 0.9985 - precision_smooth: 0.9933 - recall_smooth: 0.9961 - val_dice_coefficient: 0.9970 - val_iou_score: 0.9939 - val_loss: 0.0066 - val_pixel_accuracy: 0.9987 - val_precision_smooth: 0.9953 - val_recall_smooth: 0.9986 - learning_rate: 1.0000e-04
# Epoch 20/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:09 199ms/step - dice_coefficient: 0.9896 - iou_score: 0.9795 - loss: 0.0142 - pixel_accuracy: 0.9991 - precision_smooth: 0.9849 - recall_smooth: 0.9944
# Prediction after epoch 20
#
#
# Epoch 20: val_iou_score did not improve from 0.99412
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - dice_coefficient: 0.9896 - iou_score: 0.9795 - loss: 0.0142 - pixel_accuracy: 0.9991 - precision_smooth: 0.9849 - recall_smooth: 0.9944 - val_dice_coefficient: 0.9969 - val_iou_score: 0.9939 - val_loss: 0.0067 - val_pixel_accuracy: 0.9987 - val_precision_smooth: 0.9953 - val_recall_smooth: 0.9986 - learning_rate: 1.0000e-04
# Epoch 21/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - dice_coefficient: 0.9953 - iou_score: 0.9906 - loss: 0.0090 - pixel_accuracy: 0.9986 - precision_smooth: 0.9941 - recall_smooth: 0.9964
# Epoch 21: val_iou_score improved from 0.99412 to 0.99482, saving model to best_model.keras
#
# Epoch 21: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 278ms/step - dice_coefficient: 0.9952 - iou_score: 0.9905 - loss: 0.0091 - pixel_accuracy: 0.9986 - precision_smooth: 0.9941 - recall_smooth: 0.9964 - val_dice_coefficient: 0.9974 - val_iou_score: 0.9948 - val_loss: 0.0056 - val_pixel_accuracy: 0.9989 - val_precision_smooth: 0.9964 - val_recall_smooth: 0.9984 - learning_rate: 1.0000e-04
# Epoch 22/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:10 200ms/step - dice_coefficient: 0.9901 - iou_score: 0.9804 - loss: 0.0140 - pixel_accuracy: 0.9989 - precision_smooth: 0.9869 - recall_smooth: 0.9933
# Epoch 22: val_iou_score did not improve from 0.99482
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - dice_coefficient: 0.9901 - iou_score: 0.9804 - loss: 0.0140 - pixel_accuracy: 0.9989 - precision_smooth: 0.9869 - recall_smooth: 0.9933 - val_dice_coefficient: 0.9973 - val_iou_score: 0.9946 - val_loss: 0.0059 - val_pixel_accuracy: 0.9988 - val_precision_smooth: 0.9961 - val_recall_smooth: 0.9985 - learning_rate: 1.0000e-04
# Epoch 23/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - dice_coefficient: 0.9955 - iou_score: 0.9911 - loss: 0.0087 - pixel_accuracy: 0.9986 - precision_smooth: 0.9946 - recall_smooth: 0.9965
# Epoch 23: val_iou_score improved from 0.99482 to 0.99525, saving model to best_model.keras
#
# Epoch 23: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 279ms/step - dice_coefficient: 0.9955 - iou_score: 0.9911 - loss: 0.0087 - pixel_accuracy: 0.9986 - precision_smooth: 0.9946 - recall_smooth: 0.9965 - val_dice_coefficient: 0.9976 - val_iou_score: 0.9952 - val_loss: 0.0052 - val_pixel_accuracy: 0.9989 - val_precision_smooth: 0.9968 - val_recall_smooth: 0.9985 - learning_rate: 1.0000e-04
# Epoch 24/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:10 200ms/step - dice_coefficient: 0.9918 - iou_score: 0.9838 - loss: 0.0114 - pixel_accuracy: 0.9991 - precision_smooth: 0.9895 - recall_smooth: 0.9942
# Epoch 24: val_iou_score improved from 0.99525 to 0.99528, saving model to best_model.keras
#
# Epoch 24: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - dice_coefficient: 0.9918 - iou_score: 0.9838 - loss: 0.0114 - pixel_accuracy: 0.9991 - precision_smooth: 0.9895 - recall_smooth: 0.9942 - val_dice_coefficient: 0.9976 - val_iou_score: 0.9953 - val_loss: 0.0051 - val_pixel_accuracy: 0.9989 - val_precision_smooth: 0.9968 - val_recall_smooth: 0.9985 - learning_rate: 1.0000e-04
# Epoch 25/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9960 - iou_score: 0.9921 - loss: 0.0078 - pixel_accuracy: 0.9987 - precision_smooth: 0.9953 - recall_smooth: 0.9968
# Epoch 25: val_iou_score improved from 0.99528 to 0.99555, saving model to best_model.keras
#
# Epoch 25: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 279ms/step - dice_coefficient: 0.9960 - iou_score: 0.9920 - loss: 0.0079 - pixel_accuracy: 0.9987 - precision_smooth: 0.9952 - recall_smooth: 0.9967 - val_dice_coefficient: 0.9978 - val_iou_score: 0.9956 - val_loss: 0.0048 - val_pixel_accuracy: 0.9990 - val_precision_smooth: 0.9971 - val_recall_smooth: 0.9984 - learning_rate: 1.0000e-04
# Epoch 26/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:10 203ms/step - dice_coefficient: 0.9924 - iou_score: 0.9848 - loss: 0.0108 - pixel_accuracy: 0.9991 - precision_smooth: 0.9907 - recall_smooth: 0.9940
# Epoch 26: val_iou_score improved from 0.99555 to 0.99560, saving model to best_model.keras
#
# Epoch 26: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - dice_coefficient: 0.9924 - iou_score: 0.9848 - loss: 0.0108 - pixel_accuracy: 0.9991 - precision_smooth: 0.9907 - recall_smooth: 0.9940 - val_dice_coefficient: 0.9978 - val_iou_score: 0.9956 - val_loss: 0.0047 - val_pixel_accuracy: 0.9990 - val_precision_smooth: 0.9972 - val_recall_smooth: 0.9984 - learning_rate: 1.0000e-04
# Epoch 27/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9964 - iou_score: 0.9928 - loss: 0.0072 - pixel_accuracy: 0.9988 - precision_smooth: 0.9958 - recall_smooth: 0.9970
# Epoch 27: val_iou_score improved from 0.99560 to 0.99585, saving model to best_model.keras
#
# Epoch 27: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 278ms/step - dice_coefficient: 0.9963 - iou_score: 0.9927 - loss: 0.0073 - pixel_accuracy: 0.9987 - precision_smooth: 0.9957 - recall_smooth: 0.9969 - val_dice_coefficient: 0.9979 - val_iou_score: 0.9959 - val_loss: 0.0044 - val_pixel_accuracy: 0.9991 - val_precision_smooth: 0.9973 - val_recall_smooth: 0.9986 - learning_rate: 1.0000e-04
# Epoch 28/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:11 205ms/step - dice_coefficient: 0.9926 - iou_score: 0.9854 - loss: 0.0108 - pixel_accuracy: 0.9990 - precision_smooth: 0.9923 - recall_smooth: 0.9930
# Epoch 28: val_iou_score improved from 0.99585 to 0.99595, saving model to best_model.keras
#
# Epoch 28: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - dice_coefficient: 0.9926 - iou_score: 0.9854 - loss: 0.0108 - pixel_accuracy: 0.9990 - precision_smooth: 0.9923 - recall_smooth: 0.9930 - val_dice_coefficient: 0.9980 - val_iou_score: 0.9959 - val_loss: 0.0043 - val_pixel_accuracy: 0.9991 - val_precision_smooth: 0.9975 - val_recall_smooth: 0.9985 - learning_rate: 1.0000e-04
# Epoch 29/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - dice_coefficient: 0.9966 - iou_score: 0.9933 - loss: 0.0067 - pixel_accuracy: 0.9988 - precision_smooth: 0.9962 - recall_smooth: 0.9971
# Epoch 29: val_iou_score improved from 0.99595 to 0.99595, saving model to best_model.keras
#
# Epoch 29: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 279ms/step - dice_coefficient: 0.9967 - iou_score: 0.9933 - loss: 0.0067 - pixel_accuracy: 0.9988 - precision_smooth: 0.9962 - recall_smooth: 0.9971 - val_dice_coefficient: 0.9980 - val_iou_score: 0.9959 - val_loss: 0.0044 - val_pixel_accuracy: 0.9991 - val_precision_smooth: 0.9968 - val_recall_smooth: 0.9991 - learning_rate: 1.0000e-04
# Epoch 30/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:09 200ms/step - dice_coefficient: 0.9941 - iou_score: 0.9882 - loss: 0.0084 - pixel_accuracy: 0.9992 - precision_smooth: 0.9906 - recall_smooth: 0.9976
# Prediction after epoch 30
#
#
# Epoch 30: val_iou_score improved from 0.99595 to 0.99603, saving model to best_model.keras
#
# Epoch 30: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - dice_coefficient: 0.9941 - iou_score: 0.9882 - loss: 0.0084 - pixel_accuracy: 0.9992 - precision_smooth: 0.9906 - recall_smooth: 0.9976 - val_dice_coefficient: 0.9980 - val_iou_score: 0.9960 - val_loss: 0.0043 - val_pixel_accuracy: 0.9991 - val_precision_smooth: 0.9970 - val_recall_smooth: 0.9991 - learning_rate: 1.0000e-04
# Epoch 31/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - dice_coefficient: 0.9970 - iou_score: 0.9941 - loss: 0.0060 - pixel_accuracy: 0.9989 - precision_smooth: 0.9966 - recall_smooth: 0.9974
# Epoch 31: val_iou_score improved from 0.99603 to 0.99640, saving model to best_model.keras
#
# Epoch 31: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 279ms/step - dice_coefficient: 0.9970 - iou_score: 0.9939 - loss: 0.0062 - pixel_accuracy: 0.9989 - precision_smooth: 0.9966 - recall_smooth: 0.9973 - val_dice_coefficient: 0.9982 - val_iou_score: 0.9964 - val_loss: 0.0039 - val_pixel_accuracy: 0.9992 - val_precision_smooth: 0.9972 - val_recall_smooth: 0.9992 - learning_rate: 1.0000e-04
# Epoch 32/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:10 203ms/step - dice_coefficient: 0.9945 - iou_score: 0.9890 - loss: 0.0080 - pixel_accuracy: 0.9992 - precision_smooth: 0.9919 - recall_smooth: 0.9971
# Epoch 32: val_iou_score improved from 0.99640 to 0.99652, saving model to best_model.keras
#
# Epoch 32: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - dice_coefficient: 0.9945 - iou_score: 0.9890 - loss: 0.0080 - pixel_accuracy: 0.9992 - precision_smooth: 0.9919 - recall_smooth: 0.9971 - val_dice_coefficient: 0.9983 - val_iou_score: 0.9965 - val_loss: 0.0037 - val_pixel_accuracy: 0.9992 - val_precision_smooth: 0.9974 - val_recall_smooth: 0.9991 - learning_rate: 1.0000e-04
# Epoch 33/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - dice_coefficient: 0.9973 - iou_score: 0.9946 - loss: 0.0055 - pixel_accuracy: 0.9990 - precision_smooth: 0.9970 - recall_smooth: 0.9976
# Epoch 33: val_iou_score improved from 0.99652 to 0.99736, saving model to best_model.keras
#
# Epoch 33: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 278ms/step - dice_coefficient: 0.9973 - iou_score: 0.9946 - loss: 0.0055 - pixel_accuracy: 0.9990 - precision_smooth: 0.9970 - recall_smooth: 0.9976 - val_dice_coefficient: 0.9987 - val_iou_score: 0.9974 - val_loss: 0.0027 - val_pixel_accuracy: 0.9995 - val_precision_smooth: 0.9983 - val_recall_smooth: 0.9991 - learning_rate: 1.0000e-04
# Epoch 34/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:11 205ms/step - dice_coefficient: 0.9953 - iou_score: 0.9905 - loss: 0.0069 - pixel_accuracy: 0.9993 - precision_smooth: 0.9939 - recall_smooth: 0.9966
# Epoch 34: val_iou_score improved from 0.99736 to 0.99746, saving model to best_model.keras
#
# Epoch 34: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - dice_coefficient: 0.9953 - iou_score: 0.9905 - loss: 0.0069 - pixel_accuracy: 0.9993 - precision_smooth: 0.9939 - recall_smooth: 0.9966 - val_dice_coefficient: 0.9987 - val_iou_score: 0.9975 - val_loss: 0.0026 - val_pixel_accuracy: 0.9995 - val_precision_smooth: 0.9985 - val_recall_smooth: 0.9990 - learning_rate: 1.0000e-04
# Epoch 35/100
# 257/351 ━━━━━━━━━━━━━━━━━━━━ 23s 247ms/step - dice_coefficient: 0.9977 - iou_score: 0.9953 - loss: 0.0048 - pixel_accuracy: 0.9991 - precision_smooth: 0.9975 - recall_smooth: 0.9978
# Epoch 35: val_iou_score did not improve from 0.99746
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 97s 276ms/step - dice_coefficient: 0.9976 - iou_score: 0.9953 - loss: 0.0048 - pixel_accuracy: 0.9991 - precision_smooth: 0.9974 - recall_smooth: 0.9979 - val_dice_coefficient: 0.9986 - val_iou_score: 0.9973 - val_loss: 0.0029 - val_pixel_accuracy: 0.9994 - val_precision_smooth: 0.9976 - val_recall_smooth: 0.9996 - learning_rate: 1.0000e-04
# Epoch 36/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:10 200ms/step - dice_coefficient: 0.9958 - iou_score: 0.9916 - loss: 0.0062 - pixel_accuracy: 0.9994 - precision_smooth: 0.9945 - recall_smooth: 0.9971
# Epoch 36: val_iou_score did not improve from 0.99746
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - dice_coefficient: 0.9958 - iou_score: 0.9916 - loss: 0.0062 - pixel_accuracy: 0.9994 - precision_smooth: 0.9945 - recall_smooth: 0.9971 - val_dice_coefficient: 0.9985 - val_iou_score: 0.9971 - val_loss: 0.0032 - val_pixel_accuracy: 0.9993 - val_precision_smooth: 0.9974 - val_recall_smooth: 0.9997 - learning_rate: 1.0000e-04
# Epoch 37/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - dice_coefficient: 0.9980 - iou_score: 0.9960 - loss: 0.0041 - pixel_accuracy: 0.9993 - precision_smooth: 0.9978 - recall_smooth: 0.9982
# Epoch 37: val_iou_score improved from 0.99746 to 0.99757, saving model to best_model.keras
#
# Epoch 37: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 279ms/step - dice_coefficient: 0.9979 - iou_score: 0.9959 - loss: 0.0042 - pixel_accuracy: 0.9993 - precision_smooth: 0.9978 - recall_smooth: 0.9981 - val_dice_coefficient: 0.9988 - val_iou_score: 0.9976 - val_loss: 0.0027 - val_pixel_accuracy: 0.9994 - val_precision_smooth: 0.9978 - val_recall_smooth: 0.9998 - learning_rate: 1.0000e-04
# Epoch 38/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:11 205ms/step - dice_coefficient: 0.9962 - iou_score: 0.9924 - loss: 0.0057 - pixel_accuracy: 0.9995 - precision_smooth: 0.9953 - recall_smooth: 0.9971
# Epoch 38: val_iou_score did not improve from 0.99757
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - dice_coefficient: 0.9962 - iou_score: 0.9924 - loss: 0.0057 - pixel_accuracy: 0.9995 - precision_smooth: 0.9953 - recall_smooth: 0.9971 - val_dice_coefficient: 0.9987 - val_iou_score: 0.9974 - val_loss: 0.0029 - val_pixel_accuracy: 0.9994 - val_precision_smooth: 0.9976 - val_recall_smooth: 0.9998 - learning_rate: 1.0000e-04
# Epoch 39/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9982 - iou_score: 0.9964 - loss: 0.0036 - pixel_accuracy: 0.9994 - precision_smooth: 0.9981 - recall_smooth: 0.9984
# Epoch 39: val_iou_score improved from 0.99757 to 0.99840, saving model to best_model.keras
#
# Epoch 39: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 279ms/step - dice_coefficient: 0.9982 - iou_score: 0.9964 - loss: 0.0037 - pixel_accuracy: 0.9994 - precision_smooth: 0.9980 - recall_smooth: 0.9983 - val_dice_coefficient: 0.9992 - val_iou_score: 0.9984 - val_loss: 0.0016 - val_pixel_accuracy: 0.9997 - val_precision_smooth: 0.9987 - val_recall_smooth: 0.9997 - learning_rate: 5.0000e-05
# Epoch 40/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:11 204ms/step - dice_coefficient: 0.9972 - iou_score: 0.9944 - loss: 0.0039 - pixel_accuracy: 0.9997 - precision_smooth: 0.9965 - recall_smooth: 0.9980
# Prediction after epoch 40
#
#
# Epoch 40: val_iou_score improved from 0.99840 to 0.99845, saving model to best_model.keras
#
# Epoch 40: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - dice_coefficient: 0.9972 - iou_score: 0.9944 - loss: 0.0039 - pixel_accuracy: 0.9997 - precision_smooth: 0.9965 - recall_smooth: 0.9980 - val_dice_coefficient: 0.9992 - val_iou_score: 0.9985 - val_loss: 0.0016 - val_pixel_accuracy: 0.9997 - val_precision_smooth: 0.9988 - val_recall_smooth: 0.9997 - learning_rate: 5.0000e-05
# Epoch 41/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9984 - iou_score: 0.9969 - loss: 0.0032 - pixel_accuracy: 0.9994 - precision_smooth: 0.9983 - recall_smooth: 0.9985
# Epoch 41: val_iou_score did not improve from 0.99845
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 97s 276ms/step - dice_coefficient: 0.9984 - iou_score: 0.9968 - loss: 0.0033 - pixel_accuracy: 0.9994 - precision_smooth: 0.9983 - recall_smooth: 0.9985 - val_dice_coefficient: 0.9992 - val_iou_score: 0.9984 - val_loss: 0.0017 - val_pixel_accuracy: 0.9997 - val_precision_smooth: 0.9986 - val_recall_smooth: 0.9998 - learning_rate: 5.0000e-05
# Epoch 42/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:11 203ms/step - dice_coefficient: 0.9974 - iou_score: 0.9947 - loss: 0.0038 - pixel_accuracy: 0.9997 - precision_smooth: 0.9965 - recall_smooth: 0.9982
# Epoch 42: val_iou_score improved from 0.99845 to 0.99854, saving model to best_model.keras
#
# Epoch 42: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - dice_coefficient: 0.9974 - iou_score: 0.9947 - loss: 0.0038 - pixel_accuracy: 0.9997 - precision_smooth: 0.9965 - recall_smooth: 0.9982 - val_dice_coefficient: 0.9993 - val_iou_score: 0.9985 - val_loss: 0.0015 - val_pixel_accuracy: 0.9997 - val_precision_smooth: 0.9987 - val_recall_smooth: 0.9998 - learning_rate: 5.0000e-05
# Epoch 43/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9985 - iou_score: 0.9971 - loss: 0.0030 - pixel_accuracy: 0.9995 - precision_smooth: 0.9984 - recall_smooth: 0.9986
# Epoch 43: val_iou_score improved from 0.99854 to 0.99894, saving model to best_model.keras
#
# Epoch 43: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 278ms/step - dice_coefficient: 0.9985 - iou_score: 0.9970 - loss: 0.0031 - pixel_accuracy: 0.9995 - precision_smooth: 0.9984 - recall_smooth: 0.9986 - val_dice_coefficient: 0.9995 - val_iou_score: 0.9989 - val_loss: 0.0011 - val_pixel_accuracy: 0.9998 - val_precision_smooth: 0.9991 - val_recall_smooth: 0.9998 - learning_rate: 5.0000e-05
# Epoch 44/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:11 205ms/step - dice_coefficient: 0.9966 - iou_score: 0.9931 - loss: 0.0054 - pixel_accuracy: 0.9994 - precision_smooth: 0.9977 - recall_smooth: 0.9954
# Epoch 44: val_iou_score did not improve from 0.99894
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - dice_coefficient: 0.9966 - iou_score: 0.9931 - loss: 0.0054 - pixel_accuracy: 0.9994 - precision_smooth: 0.9977 - recall_smooth: 0.9954 - val_dice_coefficient: 0.9994 - val_iou_score: 0.9989 - val_loss: 0.0011 - val_pixel_accuracy: 0.9998 - val_precision_smooth: 0.9990 - val_recall_smooth: 0.9998 - learning_rate: 5.0000e-05
# Epoch 45/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9987 - iou_score: 0.9974 - loss: 0.0027 - pixel_accuracy: 0.9995 - precision_smooth: 0.9986 - recall_smooth: 0.9988
# Epoch 45: val_iou_score did not improve from 0.99894
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 97s 276ms/step - dice_coefficient: 0.9986 - iou_score: 0.9973 - loss: 0.0028 - pixel_accuracy: 0.9995 - precision_smooth: 0.9986 - recall_smooth: 0.9987 - val_dice_coefficient: 0.9993 - val_iou_score: 0.9987 - val_loss: 0.0013 - val_pixel_accuracy: 0.9997 - val_precision_smooth: 0.9988 - val_recall_smooth: 0.9999 - learning_rate: 5.0000e-05
# Epoch 46/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:11 205ms/step - dice_coefficient: 0.9981 - iou_score: 0.9963 - loss: 0.0026 - pixel_accuracy: 0.9998 - precision_smooth: 0.9971 - recall_smooth: 0.9992
# Epoch 46: val_iou_score did not improve from 0.99894
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - dice_coefficient: 0.9981 - iou_score: 0.9963 - loss: 0.0026 - pixel_accuracy: 0.9998 - precision_smooth: 0.9971 - recall_smooth: 0.9992 - val_dice_coefficient: 0.9993 - val_iou_score: 0.9987 - val_loss: 0.0013 - val_pixel_accuracy: 0.9997 - val_precision_smooth: 0.9988 - val_recall_smooth: 0.9999 - learning_rate: 5.0000e-05
# Epoch 47/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9988 - iou_score: 0.9976 - loss: 0.0025 - pixel_accuracy: 0.9996 - precision_smooth: 0.9987 - recall_smooth: 0.9989
# Epoch 47: val_iou_score improved from 0.99894 to 0.99898, saving model to best_model.keras
#
# Epoch 47: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 278ms/step - dice_coefficient: 0.9987 - iou_score: 0.9974 - loss: 0.0027 - pixel_accuracy: 0.9995 - precision_smooth: 0.9987 - recall_smooth: 0.9988 - val_dice_coefficient: 0.9995 - val_iou_score: 0.9990 - val_loss: 0.0010 - val_pixel_accuracy: 0.9998 - val_precision_smooth: 0.9991 - val_recall_smooth: 0.9999 - learning_rate: 5.0000e-05
# Epoch 48/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:11 205ms/step - dice_coefficient: 0.9979 - iou_score: 0.9957 - loss: 0.0031 - pixel_accuracy: 0.9997 - precision_smooth: 0.9978 - recall_smooth: 0.9979
# Epoch 48: val_iou_score improved from 0.99898 to 0.99898, saving model to best_model.keras
#
# Epoch 48: finished saving model to best_model.keras
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - dice_coefficient: 0.9979 - iou_score: 0.9957 - loss: 0.0031 - pixel_accuracy: 0.9997 - precision_smooth: 0.9978 - recall_smooth: 0.9979 - val_dice_coefficient: 0.9995 - val_iou_score: 0.9990 - val_loss: 0.0010 - val_pixel_accuracy: 0.9998 - val_precision_smooth: 0.9991 - val_recall_smooth: 0.9999 - learning_rate: 5.0000e-05
# Epoch 49/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9989 - iou_score: 0.9978 - loss: 0.0022 - pixel_accuracy: 0.9996 - precision_smooth: 0.9989 - recall_smooth: 0.9990
# Epoch 49: val_iou_score improved from 0.99898 to 0.99919, saving model to best_model.keras
#
# Epoch 49: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 278ms/step - dice_coefficient: 0.9989 - iou_score: 0.9977 - loss: 0.0024 - pixel_accuracy: 0.9996 - precision_smooth: 0.9988 - recall_smooth: 0.9989 - val_dice_coefficient: 0.9996 - val_iou_score: 0.9992 - val_loss: 8.1705e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9993 - val_recall_smooth: 0.9999 - learning_rate: 2.5000e-05
# Epoch 50/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:09 199ms/step - dice_coefficient: 0.9987 - iou_score: 0.9973 - loss: 0.0018 - pixel_accuracy: 0.9999 - precision_smooth: 0.9978 - recall_smooth: 0.9995
# Prediction after epoch 50
#
#
# Epoch 50: val_iou_score improved from 0.99919 to 0.99920, saving model to best_model.keras
#
# Epoch 50: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - dice_coefficient: 0.9987 - iou_score: 0.9973 - loss: 0.0018 - pixel_accuracy: 0.9999 - precision_smooth: 0.9978 - recall_smooth: 0.9995 - val_dice_coefficient: 0.9996 - val_iou_score: 0.9992 - val_loss: 8.0243e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9993 - val_recall_smooth: 0.9999 - learning_rate: 2.5000e-05
# Epoch 51/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9989 - iou_score: 0.9979 - loss: 0.0022 - pixel_accuracy: 0.9996 - precision_smooth: 0.9989 - recall_smooth: 0.9990
# Epoch 51: val_iou_score improved from 0.99920 to 0.99921, saving model to best_model.keras
#
# Epoch 51: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 278ms/step - dice_coefficient: 0.9989 - iou_score: 0.9978 - loss: 0.0023 - pixel_accuracy: 0.9996 - precision_smooth: 0.9989 - recall_smooth: 0.9989 - val_dice_coefficient: 0.9996 - val_iou_score: 0.9992 - val_loss: 7.9271e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9993 - val_recall_smooth: 0.9999 - learning_rate: 2.5000e-05
# Epoch 52/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:09 199ms/step - dice_coefficient: 0.9986 - iou_score: 0.9971 - loss: 0.0020 - pixel_accuracy: 0.9998 - precision_smooth: 0.9980 - recall_smooth: 0.9991
# Epoch 52: val_iou_score did not improve from 0.99921
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - dice_coefficient: 0.9986 - iou_score: 0.9971 - loss: 0.0020 - pixel_accuracy: 0.9998 - precision_smooth: 0.9980 - recall_smooth: 0.9991 - val_dice_coefficient: 0.9996 - val_iou_score: 0.9992 - val_loss: 8.2814e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9993 - val_recall_smooth: 0.9999 - learning_rate: 2.5000e-05
# Epoch 53/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9990 - iou_score: 0.9980 - loss: 0.0021 - pixel_accuracy: 0.9996 - precision_smooth: 0.9990 - recall_smooth: 0.9991
# Epoch 53: val_iou_score did not improve from 0.99921
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 97s 276ms/step - dice_coefficient: 0.9990 - iou_score: 0.9979 - loss: 0.0022 - pixel_accuracy: 0.9996 - precision_smooth: 0.9989 - recall_smooth: 0.9990 - val_dice_coefficient: 0.9996 - val_iou_score: 0.9992 - val_loss: 8.2832e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9993 - val_recall_smooth: 0.9999 - learning_rate: 2.5000e-05
# Epoch 54/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:09 199ms/step - dice_coefficient: 0.9974 - iou_score: 0.9948 - loss: 0.0044 - pixel_accuracy: 0.9995 - precision_smooth: 0.9984 - recall_smooth: 0.9964
# Epoch 54: val_iou_score did not improve from 0.99921
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - dice_coefficient: 0.9974 - iou_score: 0.9948 - loss: 0.0044 - pixel_accuracy: 0.9995 - precision_smooth: 0.9984 - recall_smooth: 0.9964 - val_dice_coefficient: 0.9996 - val_iou_score: 0.9991 - val_loss: 8.8146e-04 - val_pixel_accuracy: 0.9998 - val_precision_smooth: 0.9992 - val_recall_smooth: 0.9999 - learning_rate: 2.5000e-05
# Epoch 55/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9990 - iou_score: 0.9981 - loss: 0.0020 - pixel_accuracy: 0.9997 - precision_smooth: 0.9990 - recall_smooth: 0.9991
# Epoch 55: val_iou_score did not improve from 0.99921
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 97s 275ms/step - dice_coefficient: 0.9990 - iou_score: 0.9980 - loss: 0.0021 - pixel_accuracy: 0.9996 - precision_smooth: 0.9990 - recall_smooth: 0.9990 - val_dice_coefficient: 0.9995 - val_iou_score: 0.9990 - val_loss: 0.0010 - val_pixel_accuracy: 0.9998 - val_precision_smooth: 0.9991 - val_recall_smooth: 0.9999 - learning_rate: 1.2500e-05
# Epoch 56/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:09 198ms/step - dice_coefficient: 0.9983 - iou_score: 0.9966 - loss: 0.0026 - pixel_accuracy: 0.9998 - precision_smooth: 0.9980 - recall_smooth: 0.9986
# Epoch 56: val_iou_score did not improve from 0.99921
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - dice_coefficient: 0.9983 - iou_score: 0.9966 - loss: 0.0026 - pixel_accuracy: 0.9998 - precision_smooth: 0.9980 - recall_smooth: 0.9986 - val_dice_coefficient: 0.9995 - val_iou_score: 0.9990 - val_loss: 0.0010 - val_pixel_accuracy: 0.9998 - val_precision_smooth: 0.9990 - val_recall_smooth: 0.9999 - learning_rate: 1.2500e-05
# Epoch 57/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9991 - iou_score: 0.9981 - loss: 0.0020 - pixel_accuracy: 0.9997 - precision_smooth: 0.9990 - recall_smooth: 0.9991
# Epoch 57: val_iou_score did not improve from 0.99921
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 97s 276ms/step - dice_coefficient: 0.9990 - iou_score: 0.9980 - loss: 0.0021 - pixel_accuracy: 0.9996 - precision_smooth: 0.9990 - recall_smooth: 0.9990 - val_dice_coefficient: 0.9996 - val_iou_score: 0.9992 - val_loss: 8.0757e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9993 - val_recall_smooth: 0.9999 - learning_rate: 1.2500e-05
# Epoch 58/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:10 200ms/step - dice_coefficient: 0.9988 - iou_score: 0.9977 - loss: 0.0016 - pixel_accuracy: 0.9999 - precision_smooth: 0.9984 - recall_smooth: 0.9993
# Epoch 58: val_iou_score did not improve from 0.99921
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - dice_coefficient: 0.9988 - iou_score: 0.9977 - loss: 0.0016 - pixel_accuracy: 0.9999 - precision_smooth: 0.9984 - recall_smooth: 0.9993 - val_dice_coefficient: 0.9996 - val_iou_score: 0.9992 - val_loss: 8.1347e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9993 - val_recall_smooth: 0.9999 - learning_rate: 1.2500e-05
# Epoch 59/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9991 - iou_score: 0.9982 - loss: 0.0019 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9991
# Epoch 59: val_iou_score did not improve from 0.99921
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 97s 276ms/step - dice_coefficient: 0.9990 - iou_score: 0.9981 - loss: 0.0020 - pixel_accuracy: 0.9996 - precision_smooth: 0.9990 - recall_smooth: 0.9991 - val_dice_coefficient: 0.9996 - val_iou_score: 0.9992 - val_loss: 8.3647e-04 - val_pixel_accuracy: 0.9998 - val_precision_smooth: 0.9992 - val_recall_smooth: 0.9999 - learning_rate: 1.2500e-05
# Epoch 60/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:11 204ms/step - dice_coefficient: 0.9983 - iou_score: 0.9966 - loss: 0.0025 - pixel_accuracy: 0.9998 - precision_smooth: 0.9984 - recall_smooth: 0.9983
# Prediction after epoch 60
#
#
# Epoch 60: val_iou_score did not improve from 0.99921
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - dice_coefficient: 0.9983 - iou_score: 0.9966 - loss: 0.0025 - pixel_accuracy: 0.9998 - precision_smooth: 0.9984 - recall_smooth: 0.9983 - val_dice_coefficient: 0.9996 - val_iou_score: 0.9992 - val_loss: 8.5313e-04 - val_pixel_accuracy: 0.9998 - val_precision_smooth: 0.9992 - val_recall_smooth: 0.9999 - learning_rate: 6.2500e-06
# Epoch 61/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9991 - iou_score: 0.9983 - loss: 0.0018 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9992
# Epoch 61: val_iou_score improved from 0.99921 to 0.99923, saving model to best_model.keras
#
# Epoch 61: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 278ms/step - dice_coefficient: 0.9991 - iou_score: 0.9982 - loss: 0.0019 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9991 - val_dice_coefficient: 0.9996 - val_iou_score: 0.9992 - val_loss: 7.7997e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9993 - val_recall_smooth: 0.9999 - learning_rate: 6.2500e-06
# Epoch 62/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:11 205ms/step - dice_coefficient: 0.9987 - iou_score: 0.9973 - loss: 0.0019 - pixel_accuracy: 0.9998 - precision_smooth: 0.9985 - recall_smooth: 0.9988
# Epoch 62: val_iou_score improved from 0.99923 to 0.99924, saving model to best_model.keras
#
# Epoch 62: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - dice_coefficient: 0.9987 - iou_score: 0.9973 - loss: 0.0019 - pixel_accuracy: 0.9998 - precision_smooth: 0.9985 - recall_smooth: 0.9988 - val_dice_coefficient: 0.9996 - val_iou_score: 0.9992 - val_loss: 7.7450e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9993 - val_recall_smooth: 0.9999 - learning_rate: 6.2500e-06
# Epoch 63/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - dice_coefficient: 0.9991 - iou_score: 0.9983 - loss: 0.0018 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9992
# Epoch 63: val_iou_score improved from 0.99924 to 0.99925, saving model to best_model.keras
#
# Epoch 63: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 279ms/step - dice_coefficient: 0.9991 - iou_score: 0.9982 - loss: 0.0019 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9991 - val_dice_coefficient: 0.9996 - val_iou_score: 0.9993 - val_loss: 7.6675e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9993 - val_recall_smooth: 0.9999 - learning_rate: 6.2500e-06
# Epoch 64/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:11 205ms/step - dice_coefficient: 0.9985 - iou_score: 0.9969 - loss: 0.0023 - pixel_accuracy: 0.9998 - precision_smooth: 0.9984 - recall_smooth: 0.9985
# Epoch 64: val_iou_score improved from 0.99925 to 0.99925, saving model to best_model.keras
#
# Epoch 64: finished saving model to best_model.keras
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - dice_coefficient: 0.9985 - iou_score: 0.9969 - loss: 0.0023 - pixel_accuracy: 0.9998 - precision_smooth: 0.9984 - recall_smooth: 0.9985 - val_dice_coefficient: 0.9996 - val_iou_score: 0.9993 - val_loss: 7.6456e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9993 - val_recall_smooth: 0.9999 - learning_rate: 6.2500e-06
# Epoch 65/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9991 - iou_score: 0.9983 - loss: 0.0018 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9992
# Epoch 65: val_iou_score improved from 0.99925 to 0.99931, saving model to best_model.keras
#
# Epoch 65: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 97s 278ms/step - dice_coefficient: 0.9991 - iou_score: 0.9982 - loss: 0.0019 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9991 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 7.0162e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 0.9999 - learning_rate: 3.1250e-06
# Epoch 66/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:09 200ms/step - dice_coefficient: 0.9988 - iou_score: 0.9976 - loss: 0.0017 - pixel_accuracy: 0.9999 - precision_smooth: 0.9981 - recall_smooth: 0.9995
# Epoch 66: val_iou_score improved from 0.99931 to 0.99931, saving model to best_model.keras
#
# Epoch 66: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - dice_coefficient: 0.9988 - iou_score: 0.9976 - loss: 0.0017 - pixel_accuracy: 0.9999 - precision_smooth: 0.9981 - recall_smooth: 0.9995 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 7.0081e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 0.9999 - learning_rate: 3.1250e-06
# Epoch 67/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9992 - iou_score: 0.9983 - loss: 0.0018 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9992
# Epoch 67: val_iou_score improved from 0.99931 to 0.99932, saving model to best_model.keras
#
# Epoch 67: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 278ms/step - dice_coefficient: 0.9991 - iou_score: 0.9982 - loss: 0.0019 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9991 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.9299e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 0.9999 - learning_rate: 3.1250e-06
# Epoch 68/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:10 201ms/step - dice_coefficient: 0.9982 - iou_score: 0.9964 - loss: 0.0028 - pixel_accuracy: 0.9997 - precision_smooth: 0.9986 - recall_smooth: 0.9977
# Epoch 68: val_iou_score improved from 0.99932 to 0.99932, saving model to best_model.keras
#
# Epoch 68: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - dice_coefficient: 0.9982 - iou_score: 0.9964 - loss: 0.0028 - pixel_accuracy: 0.9997 - precision_smooth: 0.9986 - recall_smooth: 0.9977 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.9214e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 0.9999 - learning_rate: 3.1250e-06
# Epoch 69/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9992 - iou_score: 0.9983 - loss: 0.0018 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9992
# Epoch 69: val_iou_score did not improve from 0.99932
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 97s 275ms/step - dice_coefficient: 0.9991 - iou_score: 0.9982 - loss: 0.0019 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9991 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 7.0813e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 0.9999 - learning_rate: 3.1250e-06
# Epoch 70/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:11 204ms/step - dice_coefficient: 0.9988 - iou_score: 0.9977 - loss: 0.0016 - pixel_accuracy: 0.9999 - precision_smooth: 0.9981 - recall_smooth: 0.9995
# Prediction after epoch 70
#
#
# Epoch 70: val_iou_score did not improve from 0.99932
#
# ...
# Epoch 77/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9992 - iou_score: 0.9984 - loss: 0.0017 - pixel_accuracy: 0.9997 - precision_smooth: 0.9992 - recall_smooth: 0.9992
# Epoch 77: val_iou_score improved from 0.99932 to 0.99932, saving model to best_model.keras
#
# Epoch 77: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 97s 278ms/step - dice_coefficient: 0.9992 - iou_score: 0.9983 - loss: 0.0018 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9992 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.9010e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 7.8125e-07
# Epoch 78/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:10 201ms/step - dice_coefficient: 0.9986 - iou_score: 0.9972 - loss: 0.0021 - pixel_accuracy: 0.9998 - precision_smooth: 0.9984 - recall_smooth: 0.9988
# Epoch 78: val_iou_score did not improve from 0.99932
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - dice_coefficient: 0.9986 - iou_score: 0.9972 - loss: 0.0021 - pixel_accuracy: 0.9998 - precision_smooth: 0.9984 - recall_smooth: 0.9988 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.9092e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 7.8125e-07
# Epoch 79/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9992 - iou_score: 0.9984 - loss: 0.0017 - pixel_accuracy: 0.9997 - precision_smooth: 0.9992 - recall_smooth: 0.9992
# Epoch 79: val_iou_score did not improve from 0.99932
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 97s 275ms/step - dice_coefficient: 0.9991 - iou_score: 0.9983 - loss: 0.0018 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9991 - val_dice_coefficient: 0.9996 - val_iou_score: 0.9993 - val_loss: 7.2050e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9993 - val_recall_smooth: 1.0000 - learning_rate: 7.8125e-07
# Epoch 80/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:10 202ms/step - dice_coefficient: 0.9983 - iou_score: 0.9967 - loss: 0.0025 - pixel_accuracy: 0.9997 - precision_smooth: 0.9986 - recall_smooth: 0.9981
# Prediction after epoch 80
#
#
# Epoch 80: val_iou_score did not improve from 0.99932
#
# Epoch 80: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - dice_coefficient: 0.9983 - iou_score: 0.9967 - loss: 0.0025 - pixel_accuracy: 0.9997 - precision_smooth: 0.9986 - recall_smooth: 0.9981 - val_dice_coefficient: 0.9996 - val_iou_score: 0.9993 - val_loss: 7.1974e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9993 - val_recall_smooth: 1.0000 - learning_rate: 7.8125e-07
# Epoch 81/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9992 - iou_score: 0.9984 - loss: 0.0017 - pixel_accuracy: 0.9997 - precision_smooth: 0.9992 - recall_smooth: 0.9992
# Epoch 81: val_iou_score did not improve from 0.99932
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 97s 276ms/step - dice_coefficient: 0.9991 - iou_score: 0.9983 - loss: 0.0018 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9992 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 7.1528e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9993 - val_recall_smooth: 1.0000 - learning_rate: 3.9062e-07
# Epoch 82/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:10 202ms/step - dice_coefficient: 0.9980 - iou_score: 0.9959 - loss: 0.0032 - pixel_accuracy: 0.9997 - precision_smooth: 0.9984 - recall_smooth: 0.9975
# Epoch 82: val_iou_score did not improve from 0.99932
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - dice_coefficient: 0.9980 - iou_score: 0.9959 - loss: 0.0032 - pixel_accuracy: 0.9997 - precision_smooth: 0.9984 - recall_smooth: 0.9975 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 7.1372e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9993 - val_recall_smooth: 1.0000 - learning_rate: 3.9062e-07
# Epoch 83/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9992 - iou_score: 0.9984 - loss: 0.0017 - pixel_accuracy: 0.9997 - precision_smooth: 0.9992 - recall_smooth: 0.9993
# Epoch 83: val_iou_score did not improve from 0.99932
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 97s 275ms/step - dice_coefficient: 0.9992 - iou_score: 0.9983 - loss: 0.0018 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9992 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 7.0208e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 3.9062e-07
# Epoch 84/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:11 204ms/step - dice_coefficient: 0.9989 - iou_score: 0.9977 - loss: 0.0016 - pixel_accuracy: 0.9999 - precision_smooth: 0.9984 - recall_smooth: 0.9993
# Epoch 84: val_iou_score did not improve from 0.99932
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - dice_coefficient: 0.9989 - iou_score: 0.9977 - loss: 0.0016 - pixel_accuracy: 0.9999 - precision_smooth: 0.9984 - recall_smooth: 0.9993 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 7.0182e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 3.9062e-07
# Epoch 85/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9992 - iou_score: 0.9984 - loss: 0.0017 - pixel_accuracy: 0.9997 - precision_smooth: 0.9992 - recall_smooth: 0.9992
# Epoch 85: val_iou_score did not improve from 0.99932
#
# Epoch 85: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 97s 275ms/step - dice_coefficient: 0.9991 - iou_score: 0.9983 - loss: 0.0018 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9991 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.9892e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 3.9062e-07
# Epoch 86/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:10 200ms/step - dice_coefficient: 0.9986 - iou_score: 0.9971 - loss: 0.0021 - pixel_accuracy: 0.9998 - precision_smooth: 0.9986 - recall_smooth: 0.9985
# Epoch 86: val_iou_score did not improve from 0.99932
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - dice_coefficient: 0.9986 - iou_score: 0.9971 - loss: 0.0021 - pixel_accuracy: 0.9998 - precision_smooth: 0.9986 - recall_smooth: 0.9985 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.9759e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 1.9531e-07
# Epoch 87/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9992 - iou_score: 0.9984 - loss: 0.0017 - pixel_accuracy: 0.9997 - precision_smooth: 0.9992 - recall_smooth: 0.9992
# Epoch 87: val_iou_score did not improve from 0.99932
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 97s 275ms/step - dice_coefficient: 0.9991 - iou_score: 0.9983 - loss: 0.0018 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9991 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.9897e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 1.9531e-07
# Epoch 88/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:10 202ms/step - dice_coefficient: 0.9988 - iou_score: 0.9976 - loss: 0.0017 - pixel_accuracy: 0.9999 - precision_smooth: 0.9984 - recall_smooth: 0.9992
# Epoch 88: val_iou_score did not improve from 0.99932
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - dice_coefficient: 0.9988 - iou_score: 0.9976 - loss: 0.0017 - pixel_accuracy: 0.9999 - precision_smooth: 0.9984 - recall_smooth: 0.9992 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.9809e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 1.9531e-07
# Epoch 89/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9992 - iou_score: 0.9984 - loss: 0.0017 - pixel_accuracy: 0.9997 - precision_smooth: 0.9992 - recall_smooth: 0.9992
# Epoch 89: val_iou_score did not improve from 0.99932
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 97s 275ms/step - dice_coefficient: 0.9991 - iou_score: 0.9983 - loss: 0.0018 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9992 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.9189e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 1.9531e-07
# Epoch 90/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:11 203ms/step - dice_coefficient: 0.9985 - iou_score: 0.9970 - loss: 0.0023 - pixel_accuracy: 0.9998 - precision_smooth: 0.9984 - recall_smooth: 0.9986
# Prediction after epoch 90
#
#
# Epoch 90: val_iou_score improved from 0.99932 to 0.99932, saving model to best_model.keras
#
# Epoch 90: finished saving model to best_model.keras
#
# Epoch 90: ReduceLROnPlateau reducing learning rate to 1e-07.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - dice_coefficient: 0.9985 - iou_score: 0.9970 - loss: 0.0023 - pixel_accuracy: 0.9998 - precision_smooth: 0.9984 - recall_smooth: 0.9986 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.9068e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 1.9531e-07
# Epoch 91/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9992 - iou_score: 0.9984 - loss: 0.0016 - pixel_accuracy: 0.9997 - precision_smooth: 0.9992 - recall_smooth: 0.9993
# Epoch 91: val_iou_score improved from 0.99932 to 0.99933, saving model to best_model.keras
#
# Epoch 91: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 98s 278ms/step - dice_coefficient: 0.9992 - iou_score: 0.9983 - loss: 0.0018 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9992 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.8029e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 92/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:09 198ms/step - dice_coefficient: 0.9985 - iou_score: 0.9971 - loss: 0.0022 - pixel_accuracy: 0.9998 - precision_smooth: 0.9986 - recall_smooth: 0.9985
# Epoch 92: val_iou_score improved from 0.99933 to 0.99933, saving model to best_model.keras
#
# Epoch 92: finished saving model to best_model.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - dice_coefficient: 0.9985 - iou_score: 0.9971 - loss: 0.0022 - pixel_accuracy: 0.9998 - precision_smooth: 0.9986 - recall_smooth: 0.9985 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.8000e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 93/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9992 - iou_score: 0.9984 - loss: 0.0017 - pixel_accuracy: 0.9997 - precision_smooth: 0.9992 - recall_smooth: 0.9992
# Epoch 93: val_iou_score did not improve from 0.99933
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 97s 275ms/step - dice_coefficient: 0.9991 - iou_score: 0.9983 - loss: 0.0018 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9992 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.8368e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 94/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:09 198ms/step - dice_coefficient: 0.9986 - iou_score: 0.9972 - loss: 0.0021 - pixel_accuracy: 0.9998 - precision_smooth: 0.9983 - recall_smooth: 0.9989
# Epoch 94: val_iou_score did not improve from 0.99933
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - dice_coefficient: 0.9986 - iou_score: 0.9972 - loss: 0.0021 - pixel_accuracy: 0.9998 - precision_smooth: 0.9983 - recall_smooth: 0.9989 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.8285e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 95/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - dice_coefficient: 0.9992 - iou_score: 0.9984 - loss: 0.0017 - pixel_accuracy: 0.9997 - precision_smooth: 0.9992 - recall_smooth: 0.9992
# Epoch 95: val_iou_score did not improve from 0.99933
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 96s 275ms/step - dice_coefficient: 0.9991 - iou_score: 0.9983 - loss: 0.0018 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9991 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.8970e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 96/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:11 204ms/step - dice_coefficient: 0.9988 - iou_score: 0.9976 - loss: 0.0017 - pixel_accuracy: 0.9999 - precision_smooth: 0.9982 - recall_smooth: 0.9994
# Epoch 96: val_iou_score did not improve from 0.99933
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - dice_coefficient: 0.9988 - iou_score: 0.9976 - loss: 0.0017 - pixel_accuracy: 0.9999 - precision_smooth: 0.9982 - recall_smooth: 0.9994 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.8973e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 97/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - dice_coefficient: 0.9992 - iou_score: 0.9984 - loss: 0.0017 - pixel_accuracy: 0.9997 - precision_smooth: 0.9992 - recall_smooth: 0.9992
# Epoch 97: val_iou_score did not improve from 0.99933
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 97s 275ms/step - dice_coefficient: 0.9992 - iou_score: 0.9983 - loss: 0.0018 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9992 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.8876e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 98/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:11 204ms/step - dice_coefficient: 0.9988 - iou_score: 0.9976 - loss: 0.0017 - pixel_accuracy: 0.9999 - precision_smooth: 0.9987 - recall_smooth: 0.9990
# Epoch 98: val_iou_score did not improve from 0.99933
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - dice_coefficient: 0.9988 - iou_score: 0.9976 - loss: 0.0017 - pixel_accuracy: 0.9999 - precision_smooth: 0.9987 - recall_smooth: 0.9990 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.8756e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 99/100
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - dice_coefficient: 0.9992 - iou_score: 0.9984 - loss: 0.0017 - pixel_accuracy: 0.9997 - precision_smooth: 0.9992 - recall_smooth: 0.9992
# Epoch 99: val_iou_score did not improve from 0.99933
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 97s 275ms/step - dice_coefficient: 0.9991 - iou_score: 0.9983 - loss: 0.0018 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9991 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.8622e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Epoch 100/100
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:10 201ms/step - dice_coefficient: 0.9987 - iou_score: 0.9974 - loss: 0.0018 - pixel_accuracy: 0.9998 - precision_smooth: 0.9983 - recall_smooth: 0.9991
# Prediction after epoch 100
#
#
# Epoch 100: val_iou_score did not improve from 0.99933
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - dice_coefficient: 0.9987 - iou_score: 0.9974 - loss: 0.0018 - pixel_accuracy: 0.9998 - precision_smooth: 0.9983 - recall_smooth: 0.9991 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.8642e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-07
# Restoring model weights from the end of the best epoch: 92.
#
# Training time: 91.1 min

# %% [markdown]
# ## 13. Training Graphs

# %%
H = history.history

fig, axes = plt.subplots(3, 2, figsize=(14, 16))
fig.suptitle('VGG16-UNet  |  Alzheimer MRI Segmentation  |  Training History',
             fontsize=15, fontweight='bold', y=0.98)

plot_specs = [
    ('loss',             'val_loss',             'Loss (Dice + BCE)',      'Loss',     'upper right'),
    ('dice_coefficient', 'val_dice_coefficient', 'Dice Coefficient',       'Dice',     'lower right'),
    ('iou_score',        'val_iou_score',        'IoU / Jaccard Index',    'IoU',      'lower right'),
    ('precision_smooth', 'val_precision_smooth', 'Precision',              'Precision','lower right'),
    ('recall_smooth',    'val_recall_smooth',    'Recall',                 'Recall',   'lower right'),
    ('pixel_accuracy',   'val_pixel_accuracy',   'Pixel Accuracy',         'Accuracy', 'lower right'),
]

for ax, (train_key, val_key, title, ylabel, loc) in zip(axes.flatten(), plot_specs):
    epochs_range = range(1, len(H[train_key]) + 1)
    ax.plot(epochs_range, H[train_key], label='Train',      color='steelblue',   linewidth=2)
    ax.plot(epochs_range, H[val_key],   label='Validation', color='darkorange',  linewidth=2, linestyle='--')
    ax.set_title(title, fontsize=12, fontweight='bold')
    ax.set_xlabel('Epoch')
    ax.set_ylabel(ylabel)
    ax.legend(loc=loc, fontsize=10)
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('training_history.png', dpi=150, bbox_inches='tight')
plt.show()
print('Plot saved → training_history.png')
# Out:
# Plot saved → training_history.png

# %% [markdown]
# ## 14. Best & Average Metrics Table

# %%
metric_spec = [
    ('Loss',           'loss',             'min'),
    ('Dice',           'dice_coefficient', 'max'),
    ('IoU (Jaccard)',  'iou_score',        'max'),
    ('Precision',      'precision_smooth', 'max'),
    ('Recall',         'recall_smooth',    'max'),
    ('Pixel Accuracy', 'pixel_accuracy',   'max'),
]

rows = []
for disp, key, mode in metric_spec:
    tr = np.asarray(H[key],          dtype=np.float64)
    va = np.asarray(H['val_' + key], dtype=np.float64)
    pick = np.min if mode == 'min' else np.max
    rows.append({
        'Metric':     disp,
        'Train Best': pick(tr), 'Train Avg': tr.mean(),
        'Val Best':   pick(va), 'Val Avg':   va.mean(),
    })

# F1 derived from precision & recall
def f1_curve(p, r):
    p = np.asarray(p, dtype=np.float64); r = np.asarray(r, dtype=np.float64)
    return 2.0 * p * r / (p + r + 1e-7)

tr_f1 = f1_curve(H['precision_smooth'],     H['recall_smooth'])
va_f1 = f1_curve(H['val_precision_smooth'], H['val_recall_smooth'])
rows.append({'Metric': 'F1-Score',
             'Train Best': tr_f1.max(), 'Train Avg': tr_f1.mean(),
             'Val Best':   va_f1.max(), 'Val Avg':   va_f1.mean()})

report = pd.DataFrame(rows).set_index('Metric').round(4)

print('=' * 68)
print('   BEST & AVERAGE METRICS  —  VGG16-UNet  |  OASIS Alzheimer')
print('=' * 68)
print(report.to_string())
print('=' * 68)

best_epoch_iou  = int(np.argmax(H['val_iou_score']))  + 1
best_epoch_dice = int(np.argmax(H['val_dice_coefficient'])) + 1
print(f'\nBest Val IoU : {max(H["val_iou_score"]):.4f}  (epoch {best_epoch_iou})')
print(f'Best Val Dice: {max(H["val_dice_coefficient"]):.4f}  (epoch {best_epoch_dice})')

report
# Out:
# ====================================================================
#    BEST & AVERAGE METRICS  —  VGG16-UNet  |  OASIS Alzheimer
# ====================================================================
#                 Train Best  Train Avg  Val Best  Val Avg
# Metric
# Loss                0.0016     0.0114    0.0007   0.0037
# Dice                0.9992     0.9922    0.9997   0.9981
# IoU (Jaccard)       0.9983     0.9855    0.9993   0.9962
# Precision           0.9991     0.9882    0.9994   0.9972
# Recall              0.9995     0.9972    1.0000   0.9990
# Pixel Accuracy      0.9999     0.9992    0.9999   0.9994
# F1-Score            0.9992     0.9924    0.9997   0.9981
# ====================================================================
#
# Best Val IoU : 0.9993  (epoch 92)
# Best Val Dice: 0.9997  (epoch 92)
#                 Train Best  Train Avg  Val Best  Val Avg
# Metric
# Loss                0.0016     0.0114    0.0007   0.0037
# Dice                0.9992     0.9922    0.9997   0.9981
# IoU (Jaccard)       0.9983     0.9855    0.9993   0.9962
# Precision           0.9991     0.9882    0.9994   0.9972
# Recall              0.9995     0.9972    1.0000   0.9990
# Pixel Accuracy      0.9999     0.9992    0.9999   0.9994
# F1-Score            0.9992     0.9924    0.9997   0.9981

# %% [markdown]
# ## 15. Load Best Model & Final Evaluation

# %%
best_model = tf.keras.models.load_model(
    'best_model.keras',
    custom_objects={
        'combined_loss':   combined_loss,
        'dice_coefficient': dice_coefficient,
        'iou_score':        iou_score,
        'precision_smooth': precision_smooth,
        'recall_smooth':    recall_smooth,
        'pixel_accuracy':   pixel_accuracy,
    }
)
print('Best model loaded ✓')
best_model.summary()
# Out:
# Best model loaded ✓
# Model: "VGG16_UNet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 224, 224,  │          0 │ -                 │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 224, 224,  │      1,792 │ input[0][0]       │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 224, 224,  │     36,928 │ block1_conv1[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 112, 112,  │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 112, 112,  │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 112, 112,  │    147,584 │ block2_conv1[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 56, 56,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 56, 56,    │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 56, 56,    │    590,080 │ block3_conv1[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 56, 56,    │    590,080 │ block3_conv2[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 28, 28,    │          0 │ block3_conv3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 28, 28,    │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 28, 28,    │  2,359,808 │ block4_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 28, 28,    │  2,359,808 │ block4_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 14, 14,    │          0 │ block4_conv3[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 14, 14,    │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 14, 14,    │  2,359,808 │ block5_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 14, 14,    │  2,359,808 │ block5_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_up             │ (None, 28, 28,    │          0 │ block5_conv3[0][… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_cat            │ (None, 28, 28,    │          0 │ dec4_up[0][0],    │
# │ (Concatenate)       │ 1024)             │            │ block4_conv3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_drop (Dropout) │ (None, 28, 28,    │          0 │ dec4_cat[0][0]    │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_c1 (Conv2D)    │ (None, 28, 28,    │  4,719,104 │ dec4_drop[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_bn1            │ (None, 28, 28,    │      2,048 │ dec4_c1[0][0]     │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_act1           │ (None, 28, 28,    │          0 │ dec4_bn1[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_c2 (Conv2D)    │ (None, 28, 28,    │  2,359,808 │ dec4_act1[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_bn2            │ (None, 28, 28,    │      2,048 │ dec4_c2[0][0]     │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec4_act2           │ (None, 28, 28,    │          0 │ dec4_bn2[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_up             │ (None, 56, 56,    │          0 │ dec4_act2[0][0]   │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_cat            │ (None, 56, 56,    │          0 │ dec3_up[0][0],    │
# │ (Concatenate)       │ 768)              │            │ block3_conv3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_drop (Dropout) │ (None, 56, 56,    │          0 │ dec3_cat[0][0]    │
# │                     │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_c1 (Conv2D)    │ (None, 56, 56,    │  1,769,728 │ dec3_drop[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_bn1            │ (None, 56, 56,    │      1,024 │ dec3_c1[0][0]     │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_act1           │ (None, 56, 56,    │          0 │ dec3_bn1[0][0]    │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_c2 (Conv2D)    │ (None, 56, 56,    │    590,080 │ dec3_act1[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_bn2            │ (None, 56, 56,    │      1,024 │ dec3_c2[0][0]     │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec3_act2           │ (None, 56, 56,    │          0 │ dec3_bn2[0][0]    │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_up             │ (None, 112, 112,  │          0 │ dec3_act2[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_cat            │ (None, 112, 112,  │          0 │ dec2_up[0][0],    │
# │ (Concatenate)       │ 384)              │            │ block2_conv2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_drop (Dropout) │ (None, 112, 112,  │          0 │ dec2_cat[0][0]    │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_c1 (Conv2D)    │ (None, 112, 112,  │    442,496 │ dec2_drop[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_bn1            │ (None, 112, 112,  │        512 │ dec2_c1[0][0]     │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_act1           │ (None, 112, 112,  │          0 │ dec2_bn1[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_c2 (Conv2D)    │ (None, 112, 112,  │    147,584 │ dec2_act1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_bn2            │ (None, 112, 112,  │        512 │ dec2_c2[0][0]     │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec2_act2           │ (None, 112, 112,  │          0 │ dec2_bn2[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_up             │ (None, 224, 224,  │          0 │ dec2_act2[0][0]   │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_cat            │ (None, 224, 224,  │          0 │ dec1_up[0][0],    │
# │ (Concatenate)       │ 192)              │            │ block1_conv2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_drop (Dropout) │ (None, 224, 224,  │          0 │ dec1_cat[0][0]    │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_c1 (Conv2D)    │ (None, 224, 224,  │    110,656 │ dec1_drop[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_bn1            │ (None, 224, 224,  │        256 │ dec1_c1[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_act1           │ (None, 224, 224,  │          0 │ dec1_bn1[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_c2 (Conv2D)    │ (None, 224, 224,  │     36,928 │ dec1_act1[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_bn2            │ (None, 224, 224,  │        256 │ dec1_c2[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_act2           │ (None, 224, 224,  │          0 │ dec1_bn2[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Conv2D)     │ (None, 224, 224,  │         65 │ dec1_act2[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 45,259,397 (172.65 MB)
#  Trainable params: 10,180,289 (38.83 MB)
#  Non-trainable params: 14,718,528 (56.15 MB)
#  Optimizer params: 20,360,580 (77.67 MB)

# %%
print('Evaluating best model on held-out test set...\n')
test_results = best_model.evaluate(test_dataset, verbose=1)
test_dict    = dict(zip(best_model.metrics_names, test_results))

label_map = {
    'loss': 'Loss', 'dice_coefficient': 'Dice', 'iou_score': 'IoU (Jaccard)',
    'precision_smooth': 'Precision', 'recall_smooth': 'Recall', 'pixel_accuracy': 'Pixel Accuracy'
}

P = test_dict.get('precision_smooth', 0)
R = test_dict.get('recall_smooth',    0)
f1 = 2 * P * R / (P + R + 1e-7)

print('\n' + '=' * 60)
print('  FINAL TEST-SET METRICS  (VGG16-UNet | OASIS)')
print('=' * 60)
for k, v in test_dict.items():
    print(f'  {label_map.get(k, k):20s}: {v:.4f}')
print(f'  {"F1-Score":20s}: {f1:.4f}')
print('=' * 60)

final_df = pd.DataFrame([{
    'Model':      'VGG16-UNet (OASIS)',
    'IoU':        round(test_dict.get('iou_score', float('nan')), 4),
    'Dice':       round(test_dict.get('dice_coefficient', float('nan')), 4),
    'Precision':  round(P, 4),
    'Recall':     round(R, 4),
    'Accuracy':   round(test_dict.get('pixel_accuracy', float('nan')), 4),
    'F1':         round(f1, 4),
}]).set_index('Model')
final_df
# Out:
# Evaluating best model on held-out test set...
#
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - dice_coefficient: 0.9997 - iou_score: 0.9993 - loss: 6.5873e-04 - pixel_accuracy: 0.9999 - precision_smooth: 0.9994 - recall_smooth: 1.0000
# 2026-06-16 11:05:51.012294: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-16 11:05:51.257225: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 13s 172ms/step - dice_coefficient: 0.9997 - iou_score: 0.9993 - loss: 6.8001e-04 - pixel_accuracy: 0.9999 - precision_smooth: 0.9994 - recall_smooth: 1.0000
#
# ============================================================
#   FINAL TEST-SET METRICS  (VGG16-UNet | OASIS)
# ============================================================
#   Loss                : 0.0007
#   compile_metrics     : 0.9997
#   F1-Score            : 0.0000
# ============================================================
#                     IoU  Dice  Precision  Recall  Accuracy   F1
# Model
# VGG16-UNet (OASIS)  NaN   NaN          0       0       NaN  0.0

# %% [markdown]
# ## 16. Test Predictions Visualization

# %%
print('Test set predictions:')
show_predictions(test_dataset, num=5, model_to_use=best_model)
# Out:
# Test set predictions:

# %% [markdown]
# ## 17. Detailed Prediction Grid

# %%
def prediction_grid(dataset, best_model, n_rows=4):
    """Grid: Input | Ground Truth | Prediction | Overlay  ×  n_rows"""
    for imgs, masks in dataset.take(1):
        preds = best_model.predict(imgs[:n_rows], verbose=0)

        fig, axes = plt.subplots(n_rows, 4, figsize=(16, 4 * n_rows))
        col_titles = ['Input MRI', 'Ground Truth', 'Prediction', 'Overlay']
        for col, t in enumerate(col_titles):
            axes[0, col].set_title(t, fontsize=12, fontweight='bold')

        for row in range(n_rows):
            img   = imgs[row].numpy()
            gt    = masks[row].numpy()[..., 0]
            pred  = create_mask(preds[row]).numpy()[..., 0]

            # Overlay
            ov = (img * 255).astype(np.uint8)
            ov[pred > 0.5, 0] = 255
            ov[pred > 0.5, 1] = 0
            ov[pred > 0.5, 2] = 0

            # Per-sample IoU
            inter = np.sum(gt * pred)
            union = np.sum(gt) + np.sum(pred) - inter
            sample_iou = (inter + 1) / (union + 1)

            axes[row, 0].imshow(img)
            axes[row, 1].imshow(gt,   cmap='gray')
            axes[row, 2].imshow(pred, cmap='gray')
            axes[row, 2].set_xlabel(f'IoU: {sample_iou:.3f}', fontsize=10, color='green')
            axes[row, 3].imshow(ov)

            for col in range(4):
                axes[row, col].axis('off')

        plt.suptitle('VGG16-UNet — Alzheimer Brain MRI Segmentation Results',
                     fontsize=14, fontweight='bold')
        plt.tight_layout()
        plt.savefig('prediction_grid.png', dpi=150, bbox_inches='tight')
        plt.show()
        print('Grid saved → prediction_grid.png')


prediction_grid(test_dataset, best_model, n_rows=4)
# Out:
# 2026-06-16 11:05:59.923361: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-16 11:06:00.168852: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Grid saved → prediction_grid.png

# %% [markdown]
# ## 18. IoU Distribution Plot

# %%
iou_scores = []

for imgs, masks in test_dataset:
    preds = best_model.predict(imgs, verbose=0)
    for i in range(len(imgs)):
        gt   = masks[i].numpy()[..., 0]
        pred = (preds[i][..., 0] > 0.5).astype(float)
        inter = np.sum(gt * pred)
        union = np.sum(gt) + np.sum(pred) - inter
        iou_scores.append((inter + 1) / (union + 1))

iou_arr = np.array(iou_scores)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Histogram
axes[0].hist(iou_arr, bins=30, color='steelblue', edgecolor='white', alpha=0.85)
axes[0].axvline(iou_arr.mean(), color='red', linestyle='--', linewidth=2,
                label=f'Mean IoU: {iou_arr.mean():.3f}')
axes[0].axvline(np.median(iou_arr), color='orange', linestyle='--', linewidth=2,
                label=f'Median IoU: {np.median(iou_arr):.3f}')
axes[0].set_xlabel('IoU Score', fontsize=12)
axes[0].set_ylabel('Count', fontsize=12)
axes[0].set_title('IoU Distribution (Test Set)', fontsize=13, fontweight='bold')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# CDF
sorted_iou = np.sort(iou_arr)
cdf = np.arange(1, len(sorted_iou) + 1) / len(sorted_iou)
axes[1].plot(sorted_iou, cdf, color='darkorange', linewidth=2)
axes[1].axvline(0.5, color='gray', linestyle=':', label='IoU = 0.5')
pct_above_50 = np.mean(iou_arr > 0.5) * 100
axes[1].set_xlabel('IoU Score', fontsize=12)
axes[1].set_ylabel('Cumulative Fraction', fontsize=12)
axes[1].set_title(f'CDF of IoU  ({pct_above_50:.1f}% slices > 0.5)', fontsize=13, fontweight='bold')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.suptitle('Per-Sample IoU Analysis', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('iou_distribution.png', dpi=150, bbox_inches='tight')
plt.show()

print(f'\nIoU Stats — Mean: {iou_arr.mean():.4f}  |  Std: {iou_arr.std():.4f}')
print(f'             Min : {iou_arr.min():.4f}  |  Max: {iou_arr.max():.4f}')
print(f'% slices IoU > 0.5 : {pct_above_50:.1f}%')
# Out:
# IoU Stats — Mean: 0.9995  |  Std: 0.0008
#              Min : 0.9871  |  Max: 1.0000
# % slices IoU > 0.5 : 100.0%

# %% [markdown]
# ## 19. Fine-tuning (Optional — unfreeze encoder)

# %%
# ─── Unfreeze top VGG16 blocks for fine-tuning ────────────────────────────────
# Run this cell ONLY after initial training has converged.

for layer in best_model.layers:
    if layer.name.startswith('block4') or layer.name.startswith('block5'):
        layer.trainable = True

best_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),   # lower LR
    loss=combined_loss,
    metrics=[dice_coefficient, iou_score, precision_smooth, recall_smooth, pixel_accuracy]
)

print('Fine-tuning enabled — trainable params:',
      sum([K.count_params(w) for w in best_model.trainable_weights]))

ft_callbacks = [
    callbacks.ModelCheckpoint('best_model_finetuned.keras', save_best_only=True,
                               monitor='val_iou_score', mode='max', verbose=1),
    callbacks.EarlyStopping(monitor='val_iou_score', patience=10, mode='max',
                             restore_best_weights=True, verbose=1),
    callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5,
                                 min_lr=1e-8, verbose=1),
]

history_ft = best_model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=20,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps,
    callbacks=ft_callbacks
)
# Out:
# Fine-tuning enabled — trainable params: 23159489
# Epoch 1/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - dice_coefficient: 0.9992 - iou_score: 0.9984 - loss: 0.0017 - pixel_accuracy: 0.9997 - precision_smooth: 0.9992 - recall_smooth: 0.9992
# Epoch 1: val_iou_score improved from None to 0.99929, saving model to best_model_finetuned.keras
#
# Epoch 1: finished saving model to best_model_finetuned.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 126s 312ms/step - dice_coefficient: 0.9992 - iou_score: 0.9983 - loss: 0.0018 - pixel_accuracy: 0.9997 - precision_smooth: 0.9991 - recall_smooth: 0.9992 - val_dice_coefficient: 0.9996 - val_iou_score: 0.9993 - val_loss: 7.2050e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9993 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-05
# Epoch 2/20
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 53:19 9s/step - dice_coefficient: 0.9989 - iou_score: 0.9979 - loss: 0.0015 - pixel_accuracy: 0.9999 - precision_smooth: 0.9981 - recall_smooth: 0.9998
# Epoch 2: val_iou_score did not improve from 0.99929
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - dice_coefficient: 0.9989 - iou_score: 0.9979 - loss: 0.0015 - pixel_accuracy: 0.9999 - precision_smooth: 0.9981 - recall_smooth: 0.9998 - val_dice_coefficient: 0.9996 - val_iou_score: 0.9993 - val_loss: 7.4953e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9993 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-05
# Epoch 3/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - dice_coefficient: 0.9992 - iou_score: 0.9984 - loss: 0.0017 - pixel_accuracy: 0.9997 - precision_smooth: 0.9992 - recall_smooth: 0.9992
# Epoch 3: val_iou_score did not improve from 0.99929
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 106s 303ms/step - dice_coefficient: 0.9992 - iou_score: 0.9983 - loss: 0.0018 - pixel_accuracy: 0.9997 - precision_smooth: 0.9992 - recall_smooth: 0.9992 - val_dice_coefficient: 0.9995 - val_iou_score: 0.9991 - val_loss: 9.5179e-04 - val_pixel_accuracy: 0.9998 - val_precision_smooth: 0.9991 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-05
# Epoch 4/20
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:18 225ms/step - dice_coefficient: 0.9987 - iou_score: 0.9974 - loss: 0.0019 - pixel_accuracy: 0.9998 - precision_smooth: 0.9988 - recall_smooth: 0.9986
# Epoch 4: val_iou_score did not improve from 0.99929
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - dice_coefficient: 0.9987 - iou_score: 0.9974 - loss: 0.0019 - pixel_accuracy: 0.9998 - precision_smooth: 0.9988 - recall_smooth: 0.9986 - val_dice_coefficient: 0.9995 - val_iou_score: 0.9990 - val_loss: 0.0010 - val_pixel_accuracy: 0.9998 - val_precision_smooth: 0.9991 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-05
# Epoch 5/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - dice_coefficient: 0.9992 - iou_score: 0.9984 - loss: 0.0017 - pixel_accuracy: 0.9997 - precision_smooth: 0.9992 - recall_smooth: 0.9992
# Epoch 5: val_iou_score improved from 0.99929 to 0.99938, saving model to best_model_finetuned.keras
#
# Epoch 5: finished saving model to best_model_finetuned.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 107s 306ms/step - dice_coefficient: 0.9992 - iou_score: 0.9984 - loss: 0.0018 - pixel_accuracy: 0.9997 - precision_smooth: 0.9992 - recall_smooth: 0.9992 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9994 - val_loss: 6.2119e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-05
# Epoch 6/20
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:18 226ms/step - dice_coefficient: 0.9984 - iou_score: 0.9968 - loss: 0.0025 - pixel_accuracy: 0.9997 - precision_smooth: 0.9986 - recall_smooth: 0.9982
# Epoch 6: val_iou_score did not improve from 0.99938
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - dice_coefficient: 0.9984 - iou_score: 0.9968 - loss: 0.0025 - pixel_accuracy: 0.9997 - precision_smooth: 0.9986 - recall_smooth: 0.9982 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.6442e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 1.0000e-05
# Epoch 7/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - dice_coefficient: 0.9993 - iou_score: 0.9985 - loss: 0.0016 - pixel_accuracy: 0.9997 - precision_smooth: 0.9992 - recall_smooth: 0.9993
# Epoch 7: val_iou_score did not improve from 0.99938
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 106s 302ms/step - dice_coefficient: 0.9992 - iou_score: 0.9984 - loss: 0.0017 - pixel_accuracy: 0.9997 - precision_smooth: 0.9992 - recall_smooth: 0.9992 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.8112e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-06
# Epoch 8/20
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:19 226ms/step - dice_coefficient: 0.9987 - iou_score: 0.9975 - loss: 0.0019 - pixel_accuracy: 0.9998 - precision_smooth: 0.9985 - recall_smooth: 0.9990
# Epoch 8: val_iou_score did not improve from 0.99938
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - dice_coefficient: 0.9987 - iou_score: 0.9975 - loss: 0.0019 - pixel_accuracy: 0.9998 - precision_smooth: 0.9985 - recall_smooth: 0.9990 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.9851e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9993 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-06
# Epoch 9/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - dice_coefficient: 0.9993 - iou_score: 0.9986 - loss: 0.0015 - pixel_accuracy: 0.9997 - precision_smooth: 0.9993 - recall_smooth: 0.9993
# Epoch 9: val_iou_score did not improve from 0.99938
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 106s 303ms/step - dice_coefficient: 0.9992 - iou_score: 0.9985 - loss: 0.0016 - pixel_accuracy: 0.9997 - precision_smooth: 0.9992 - recall_smooth: 0.9992 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9994 - val_loss: 6.4415e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-06
# Epoch 10/20
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:20 230ms/step - dice_coefficient: 0.9990 - iou_score: 0.9979 - loss: 0.0014 - pixel_accuracy: 0.9999 - precision_smooth: 0.9989 - recall_smooth: 0.9991
# Epoch 10: val_iou_score did not improve from 0.99938
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - dice_coefficient: 0.9990 - iou_score: 0.9979 - loss: 0.0014 - pixel_accuracy: 0.9999 - precision_smooth: 0.9989 - recall_smooth: 0.9991 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9994 - val_loss: 6.3182e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-06
# Epoch 11/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - dice_coefficient: 0.9993 - iou_score: 0.9986 - loss: 0.0015 - pixel_accuracy: 0.9997 - precision_smooth: 0.9993 - recall_smooth: 0.9993
# Epoch 11: val_iou_score improved from 0.99938 to 0.99940, saving model to best_model_finetuned.keras
#
# Epoch 11: finished saving model to best_model_finetuned.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 107s 306ms/step - dice_coefficient: 0.9993 - iou_score: 0.9985 - loss: 0.0016 - pixel_accuracy: 0.9997 - precision_smooth: 0.9993 - recall_smooth: 0.9993 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9994 - val_loss: 6.1422e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-06
# Epoch 12/20
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:18 226ms/step - dice_coefficient: 0.9987 - iou_score: 0.9975 - loss: 0.0018 - pixel_accuracy: 0.9998 - precision_smooth: 0.9988 - recall_smooth: 0.9987
# Epoch 12: val_iou_score did not improve from 0.99940
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - dice_coefficient: 0.9987 - iou_score: 0.9975 - loss: 0.0018 - pixel_accuracy: 0.9998 - precision_smooth: 0.9988 - recall_smooth: 0.9987 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9993 - val_loss: 6.6971e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9994 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-06
# Epoch 13/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - dice_coefficient: 0.9993 - iou_score: 0.9986 - loss: 0.0015 - pixel_accuracy: 0.9997 - precision_smooth: 0.9993 - recall_smooth: 0.9993
# Epoch 13: val_iou_score improved from 0.99940 to 0.99945, saving model to best_model_finetuned.keras
#
# Epoch 13: finished saving model to best_model_finetuned.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 107s 306ms/step - dice_coefficient: 0.9993 - iou_score: 0.9985 - loss: 0.0016 - pixel_accuracy: 0.9997 - precision_smooth: 0.9993 - recall_smooth: 0.9993 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9995 - val_loss: 5.5409e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9995 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-06
# Epoch 14/20
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:18 226ms/step - dice_coefficient: 0.9984 - iou_score: 0.9967 - loss: 0.0026 - pixel_accuracy: 0.9997 - precision_smooth: 0.9988 - recall_smooth: 0.9979
# Epoch 14: val_iou_score did not improve from 0.99945
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - dice_coefficient: 0.9984 - iou_score: 0.9967 - loss: 0.0026 - pixel_accuracy: 0.9997 - precision_smooth: 0.9988 - recall_smooth: 0.9979 - val_dice_coefficient: 0.9997 - val_iou_score: 0.9994 - val_loss: 5.7207e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9995 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-06
# Epoch 15/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - dice_coefficient: 0.9993 - iou_score: 0.9987 - loss: 0.0014 - pixel_accuracy: 0.9997 - precision_smooth: 0.9993 - recall_smooth: 0.9993
# Epoch 15: val_iou_score improved from 0.99945 to 0.99950, saving model to best_model_finetuned.keras
#
# Epoch 15: finished saving model to best_model_finetuned.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 107s 306ms/step - dice_coefficient: 0.9993 - iou_score: 0.9986 - loss: 0.0015 - pixel_accuracy: 0.9997 - precision_smooth: 0.9993 - recall_smooth: 0.9993 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9995 - val_loss: 5.0890e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9995 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-06
# Epoch 16/20
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:18 225ms/step - dice_coefficient: 0.9988 - iou_score: 0.9975 - loss: 0.0019 - pixel_accuracy: 0.9998 - precision_smooth: 0.9989 - recall_smooth: 0.9986
# Epoch 16: val_iou_score improved from 0.99950 to 0.99950, saving model to best_model_finetuned.keras
#
# Epoch 16: finished saving model to best_model_finetuned.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - dice_coefficient: 0.9988 - iou_score: 0.9975 - loss: 0.0019 - pixel_accuracy: 0.9998 - precision_smooth: 0.9989 - recall_smooth: 0.9986 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9995 - val_loss: 5.0868e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9995 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-06
# Epoch 17/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - dice_coefficient: 0.9994 - iou_score: 0.9987 - loss: 0.0014 - pixel_accuracy: 0.9998 - precision_smooth: 0.9994 - recall_smooth: 0.9994
# Epoch 17: val_iou_score improved from 0.99950 to 0.99950, saving model to best_model_finetuned.keras
#
# Epoch 17: finished saving model to best_model_finetuned.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 107s 306ms/step - dice_coefficient: 0.9993 - iou_score: 0.9986 - loss: 0.0015 - pixel_accuracy: 0.9997 - precision_smooth: 0.9993 - recall_smooth: 0.9993 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9995 - val_loss: 4.9999e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9995 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-06
# Epoch 18/20
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:19 226ms/step - dice_coefficient: 0.9990 - iou_score: 0.9979 - loss: 0.0015 - pixel_accuracy: 0.9999 - precision_smooth: 0.9990 - recall_smooth: 0.9989
# Epoch 18: val_iou_score improved from 0.99950 to 0.99951, saving model to best_model_finetuned.keras
#
# Epoch 18: finished saving model to best_model_finetuned.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - dice_coefficient: 0.9990 - iou_score: 0.9979 - loss: 0.0015 - pixel_accuracy: 0.9999 - precision_smooth: 0.9990 - recall_smooth: 0.9989 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9995 - val_loss: 4.8849e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-06
# Epoch 19/20
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - dice_coefficient: 0.9994 - iou_score: 0.9988 - loss: 0.0013 - pixel_accuracy: 0.9998 - precision_smooth: 0.9994 - recall_smooth: 0.9994
# Epoch 19: val_iou_score improved from 0.99951 to 0.99953, saving model to best_model_finetuned.keras
#
# Epoch 19: finished saving model to best_model_finetuned.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 107s 305ms/step - dice_coefficient: 0.9993 - iou_score: 0.9986 - loss: 0.0015 - pixel_accuracy: 0.9997 - precision_smooth: 0.9993 - recall_smooth: 0.9993 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9995 - val_loss: 4.7709e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-06
# Epoch 20/20
#   1/351 ━━━━━━━━━━━━━━━━━━━━ 1:18 226ms/step - dice_coefficient: 0.9991 - iou_score: 0.9981 - loss: 0.0014 - pixel_accuracy: 0.9999 - precision_smooth: 0.9989 - recall_smooth: 0.9992
# Epoch 20: val_iou_score improved from 0.99953 to 0.99954, saving model to best_model_finetuned.keras
#
# Epoch 20: finished saving model to best_model_finetuned.keras
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - dice_coefficient: 0.9991 - iou_score: 0.9981 - loss: 0.0014 - pixel_accuracy: 0.9999 - precision_smooth: 0.9989 - recall_smooth: 0.9992 - val_dice_coefficient: 0.9998 - val_iou_score: 0.9995 - val_loss: 4.6724e-04 - val_pixel_accuracy: 0.9999 - val_precision_smooth: 0.9996 - val_recall_smooth: 1.0000 - learning_rate: 5.0000e-06
# Restoring model weights from the end of the best epoch: 20.

# %% [markdown]
# ## 20. Save Final Model

# %%
best_model.save('alzheimer_vgg16_unet_final.keras')
print('Model saved → alzheimer_vgg16_unet_final.keras')
# Out:
# Model saved → alzheimer_vgg16_unet_final.keras
